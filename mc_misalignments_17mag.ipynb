# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import matplotlib.cm as color
better_magma = color.magma
better_magma.set_bad('black',1.)
import matplotlib.colors as c

from prysm import (
    mathops, 
    conf,
)
from prysm.mathops import (
    _np,
    np,
    fft,
    interpolate,
    ndimage,
)
from prysm.coordinates import (
    make_xy_grid, 
    cart_to_polar,
)
from prysm.propagation import Wavefront as WF
from prysm.propagation import (
    focus_fixed_sampling,
    focus_fixed_sampling_backprop
)                              
from prysm.thinlens import (
    defocus_to_image_displacement,
    image_displacement_to_defocus,
)
from prysm.geometry import (
    offset_circle,
    circle,
    spider,
    gaussian,
)
from prysm.polynomials import (
    lstsq,
    noll_to_nm,
    zernike_nm,
    zernike_nm_seq,
    hopkins,
    sum_of_2d_modes,
    sum_of_2d_modes_backprop
)
mathops.set_backend_to_cupy()
# conf.config.precision = 32

from astropy.io import (
    fits,
    ascii,
)

from skimage.measure import centroid

import copy

from algos import BING_BONG, FFPR2, PDPR, model, mean_squared_error, gain_invariant_error
import utils

from functools import partial

from lina.utils import TikhonovInverse

import config_um
import config_um_wcc
from Batoid4LOFT.LAZULI_STOP_mark11 import Lazuli_stop, readBulkMotion, readDeformation

from psd_utils import PSDUtils

from scipy.optimize import minimize

from scipy.interpolate import RegularGridInterpolator

from tqdm import tqdm

from psd_utils import PSDUtils

from model import telescope
# from algos import pdpr, OPD, ADPR
import utils

from functools import partial

from opt import F77LBFGSB, runN, RAdam
from IPython.display import clear_output

# logging stuff
import logging
psd_log = logging.getLogger('__psd_utils__')
psd_log.disabled = True

# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

import toml

# %%
# !nvidia-smi
# Out:
# Mon Jun  8 12:33:08 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 565.57.01              Driver Version: 565.57.01      CUDA Version: 12.7     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100 80GB PCIe          On  |   00000000:25:00.0 Off |                    0 |
# | N/A   31C    P0             65W /  300W |    6364MiB /  81920MiB |     10%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A   1182782      C   ...rojects/venv-scoob-poppy/bin/python       1620MiB |
# |    0   N/A  N/A   1497464      G   /usr/lib/xorg/Xorg                              4MiB |
# |    0   N/A  N/A   1511048      C   ...rojects/venv-scoob-poppy/bin/python       3266MiB |
# |    0   N/A  N/A   2089189      C   ...onda3/envs/py310-stp-env/bin/python        872MiB |
# |    0   N/A  N/A   3831258      C   python                                        566MiB |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ## SETUP MODEL

# %%
config = toml.load('/home/derbyk/src/ffpr/data/3m_off_axis_default.toml')
optic_opd_data = utils.load_pickle('/home/derbyk/src/ffpr/data/opd_maps.pkl')

sys = telescope(config=config, optic_opd_data=optic_opd_data)

dark = sys.get_dark(stacked_frames=1)
images = [im - dark for im in sys.snap(stacked_frames=1)]

for i, im in enumerate(images):
    print(f'Image {i + 1:02.0f} SNR = {im.max() / dark.std():.1f}')
# Out:
# Image 01 SNR = 631.3
# Image 02 SNR = 1000.4
# Image 03 SNR = 574.3
# Image 04 SNR = 1246.2
# Image 05 SNR = 707.2
# Image 06 SNR = 719.9
# Image 07 SNR = 1215.1

# %% [markdown]
# ## PLOT PSFS

# %%
pupil = sys.pupil
fields = [(sys.cfg['sources'][src]['position_x'], sys.cfg['sources'][src]['position_y']) for src in sys.cfg['sources']]

utils.plot_psfs_7(psfs=images, fields=fields)

# %% [markdown]
# ## PLOT WFES

# %%
opds_fields = copy.deepcopy(sys.opds_field)
opds_optics = copy.deepcopy(sys.opds_optics)
opds_truths = [opd_field + opd_optics for (opd_field, opd_optics) in zip(opds_fields, opds_optics)]

opds_fields_nominal = opds_fields

utils.plot_opds_7(opds=opds_fields, pupil=pupil, fields=fields)
utils.plot_opds_7(opds=opds_optics, pupil=pupil, fields=fields)
utils.plot_opds_7(opds=opds_truths, pupil=pupil, fields=fields)

# %% [markdown]
# ## MONTE CARLO

# %%
misalignments = utils.load_pickle('/home/derbyk/src/ffpr/data/misalignments_cases_100_dec_50um_tilt_5as.pkl')

# %%
# SNR threshold
snr_thresh = 3

# system stuff
fields = [(sys.cfg['sources'][src]['position_x'], sys.cfg['sources'][src]['position_y']) for src in sys.cfg['sources']]
efl = sys.cfg['general']['f_eff']
pupil_dx = sys.cfg['optics']['m1']['diam'] / sys.cfg['general']['npix_pupil']
focal_dx = sys.cfg['detector']['dx_focal']

# stuff to save
data = {}

case = 1

for m in misalignments:

    print(f'CASE {case:03.0f} ----------------------------------')
    print()

    # apply misalignment
    sys.move_optics(M1_motion=m['M1'], M2_motion=m['M4'], M3_motion=m['M4'], M4_motion=m['M4'])

    # get total OPDs per field
    opds_fields = copy.deepcopy(sys.opds_field)
    opds_optics = copy.deepcopy(sys.opds_optics)
    opds_truths = [opd_field + opd_optic for opd_field, opd_optic in zip(opds_fields, opds_optics)]

    # calculate RMS of ground truth OPDs per field
    rms_truth_per_field = []
    for opd in opds_truths:
        opd -= np.mean(opd[pupil])
        rms_truth_per_field.append(float(np.sqrt(np.mean(opd[pupil] ** 2))))

    # calculate RMS of diversity per field
    rms_diversity_per_field = []
    for opd in opds_fields_nominal:
        opd -= np.mean(opd[pupil])
        rms_diversity_per_field.append(float(np.sqrt(np.mean(opd[pupil] ** 2))))

    # take images for FFPR
    dark = sys.get_dark(stacked_frames=1)
    images = [im - dark for im in sys.snap(stacked_frames=1)]

    # get image SNRs and filter
    noise_lvl = dark.std()
    masks = []
    snr_per_field = []
    for im in images:
        snr_per_field.append(float(im.max() / dark.std()))
        mask = im > noise_lvl * snr_thresh
        masks.append(mask)

    print(f'MEDIAN RMS OPD ACROSS FIELD = {np.median(np.array(rms_truth_per_field)):.2f} nm')
    print(f'MEDIAN IMAGE SNR ACROSS FIELD = {np.median(np.array(snr_per_field)):.1f}')
    print()

    # initialize FFPR
    opt = FFPR2(wvls=sys.wvls.tolist(), amp=sys.pupil, max_zernike=11, fields=fields, divs=opds_fields_nominal, efl=efl, 
                psfs=images, pupil_dx=pupil_dx, focal_dx=focal_dx, error=gain_invariant_error, masks=masks, jitter_kernel=sys.jitter_kernel)

    # BING BONG
    BING_BONG(opt=opt, modal_cleanup=True, zonal_cleanup=False,
              max_kicks=10, iter_per_bing_bong=10, iter_per_psf=10,
              max_ls=10, thresh_conv=1e-1, frac_conv=1e-2)

    # calculate estimate residuals
    opds_estimates = [pdpr.models[0].opd + pdpr.models[0].div for pdpr in opt.PDPR_list]
    opds_residuals = [estimate - truth for estimate, truth in zip(opds_estimates, opds_truths)]

    # get RMS of residual per field
    rms_residual_per_field = []
    for opd in opds_residuals:
        opd -= np.mean(opd[pupil])
        rms_residual_per_field.append(float(np.sqrt(np.mean(opd[pupil] ** 2))))

    print(f'MEDIAN RMS RESIDUAL ACROSS FIELD = {np.median(np.array(rms_residual_per_field)):.2f} nm')
    print()
    print()

    # save to data cube
    data.update({f'CASE{case:03.0f}' : {'RMS_TRUTH_PER_FIELD' : rms_truth_per_field,
                                        'RMS_RESIDUAL_PER_FIELD' : rms_residual_per_field,
                                        'RMS_DIVERSITY_PER_FIELD' : rms_diversity_per_field,
                                        'SNR_PER_FIELD' : snr_per_field,
                                        'FIELDS' : fields}})

    case += 1

utils.save_pickle('/home/derbyk/src/ffpr/sim_results/20260608_mc_misalignments_17mag_dec_50um_tilt_5as.pkl', data=data)
# Out:
# CASE 001 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 84.62 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 954.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 9.81e-03
# BONG 01 | f = 9.65e-03
# ---------------
# BING 02 | f = 9.65e-03
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.78 nm
#
#
# CASE 002 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 389.87 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 124.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.60e-01
# BONG 01 | f = 4.57e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 3.92e-01
# BONG 02 | f = 3.90e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 4.47e-01
# BONG 03 | f = 4.43e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 5.59e-01
# BONG 04 | f = 5.57e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 4.72e-01
# BONG 05 | f = 4.63e-01
# ---------------
# BING 06 | f = 4.61e-01
# BONG 06 | f = 4.61e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 4.50e-01
# BONG 07 | f = 4.45e-01
# ---------------
# BING 08 | f = 4.04e-01
# BONG 08 | f = 4.03e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 4.12e-01
# BONG 09 | f = 4.04e-01
# ---------------
# BING 10 | f = 3.99e-01
# BONG 10 | f = 3.99e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 5.54e-01
# BONG 11 | f = 5.30e-01
# ---------------
# BING 12 | f = 4.81e-01
# BONG 12 | f = 4.81e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 4.10e-01
# BONG 13 | f = 3.96e-01
# ---------------
# BING 14 | f = 3.68e-01
# BONG 14 | f = 3.67e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 2.69e-01
# BONG 15 | f = 2.65e-01
# ---------------
# BING 16 | f = 1.05e-01
# BONG 16 | f = 1.01e-01
# ---------------
# BING 17 | f = 7.89e-02
# BONG 17 | f = 7.89e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 27.67 nm
#
#
# CASE 003 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 293.51 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 165.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.59e-01
# BONG 01 | f = 4.39e-01
# ---------------
# BING 02 | f = 2.40e-01
# BONG 02 | f = 2.38e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 3.82e-01
# BONG 03 | f = 3.53e-01
# ---------------
# BING 04 | f = 3.29e-01
# BONG 04 | f = 3.29e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 4.15e-01
# BONG 05 | f = 3.84e-01
# ---------------
# BING 06 | f = 2.65e-01
# BONG 06 | f = 2.53e-01
# ---------------
# BING 07 | f = 2.51e-01
# BONG 07 | f = 2.51e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 3.92e-01
# BONG 08 | f = 3.26e-01
# ---------------
# BING 09 | f = 1.79e-01
# BONG 09 | f = 1.79e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 1.14e-01
# BONG 10 | f = 1.09e-01
# ---------------
# BING 11 | f = 7.49e-02
# BONG 11 | f = 7.42e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 39.90 nm
#
#
# CASE 004 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 157.80 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 364.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.55e-02
# BONG 01 | f = 2.54e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 25.62 nm
#
#
# CASE 005 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 203.81 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 268.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.46e-02
# BONG 01 | f = 4.29e-02
# ---------------
# BING 02 | f = 3.28e-02
# BONG 02 | f = 3.28e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.52 nm
#
#
# CASE 006 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 160.54 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 330.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.66e-02
# BONG 01 | f = 2.66e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 26.46 nm
#
#
# CASE 007 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 154.47 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 249.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.95e-02
# BONG 01 | f = 2.93e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.37 nm
#
#
# CASE 008 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 330.33 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 114.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.70e-01
# BONG 01 | f = 5.65e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 2.97e-01
# BONG 02 | f = 2.80e-01
# ---------------
# BING 03 | f = 1.76e-01
# BONG 03 | f = 1.74e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 4.12e-01
# BONG 04 | f = 3.89e-01
# ---------------
# BING 05 | f = 3.55e-01
# BONG 05 | f = 3.52e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 3.42e-01
# BONG 06 | f = 3.29e-01
# ---------------
# BING 07 | f = 1.59e-01
# BONG 07 | f = 1.47e-01
# ---------------
# BING 08 | f = 1.35e-01
# BONG 08 | f = 1.35e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 5.15e-01
# BONG 09 | f = 4.47e-01
# ---------------
# BING 10 | f = 2.44e-01
# BONG 10 | f = 2.22e-01
# ---------------
# BING 11 | f = 2.02e-01
# BONG 11 | f = 2.02e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 4.51e-01
# BONG 12 | f = 4.43e-01
# ---------------
# BING 13 | f = 4.40e-01
# BONG 13 | f = 4.40e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 4.09e-01
# BONG 14 | f = 4.09e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 5.32e-01
# BONG 15 | f = 5.30e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 3.32e-01
# BONG 16 | f = 3.28e-01
# ---------------
# BING 17 | f = 3.27e-01
# BONG 17 | f = 3.27e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 18 | f = 3.31e-01
# BONG 18 | f = 3.26e-01
# ---------------
# BING 19 | f = 3.25e-01
# BONG 19 | f = 3.24e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 20 | f = 4.21e-01
# BONG 20 | f = 3.98e-01
# ---------------
# BING 21 | f = 3.62e-01
# BONG 21 | f = 3.62e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 680.44 nm
#
#
# CASE 009 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 397.51 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 116.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.57e-01
# BONG 01 | f = 5.55e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 5.88e-01
# BONG 02 | f = 5.73e-01
# ---------------
# BING 03 | f = 4.52e-01
# BONG 03 | f = 4.46e-01
# ---------------
# BING 04 | f = 2.76e-01
# BONG 04 | f = 2.69e-01
# ---------------
# BING 05 | f = 2.67e-01
# BONG 05 | f = 2.66e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 2.96e-01
# BONG 06 | f = 2.61e-01
# ---------------
# BING 07 | f = 1.80e-01
# BONG 07 | f = 1.80e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 3.31e-01
# BONG 08 | f = 3.02e-01
# ---------------
# BING 09 | f = 2.73e-01
# BONG 09 | f = 2.73e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 3.87e-01
# BONG 10 | f = 3.81e-01
# ---------------
# BING 11 | f = 3.00e-01
# BONG 11 | f = 2.90e-01
# ---------------
# BING 12 | f = 2.78e-01
# BONG 12 | f = 2.76e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 4.08e-01
# BONG 13 | f = 3.84e-01
# ---------------
# BING 14 | f = 2.05e-01
# BONG 14 | f = 2.04e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 2.52e-01
# BONG 15 | f = 2.25e-01
# ---------------
# BING 16 | f = 1.54e-01
# BONG 16 | f = 1.40e-01
# ---------------
# BING 17 | f = 1.09e-01
# BONG 17 | f = 1.09e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 18 | f = 3.40e-01
# BONG 18 | f = 2.99e-01
# ---------------
# BING 19 | f = 2.73e-01
# BONG 19 | f = 2.73e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 20 | f = 3.31e-01
# BONG 20 | f = 3.10e-01
# ---------------
# BING 21 | f = 2.78e-01
# BONG 21 | f = 2.78e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 22 | f = 3.33e-01
# BONG 22 | f = 3.03e-01
# ---------------
# BING 23 | f = 2.86e-01
# BONG 23 | f = 2.86e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 24 | f = 3.61e-01
# BONG 24 | f = 3.39e-01
# ---------------
# BING 25 | f = 3.30e-01
# BONG 25 | f = 3.30e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 754.42 nm
#
#
# CASE 010 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 215.99 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 186.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.29e-01
# BONG 01 | f = 2.27e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 2.88e-01
# BONG 02 | f = 2.55e-01
# ---------------
# BING 03 | f = 1.69e-01
# BONG 03 | f = 1.69e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 4.80e-01
# BONG 04 | f = 4.73e-01
# ---------------
# BING 05 | f = 3.09e-01
# BONG 05 | f = 3.02e-01
# ---------------
# BING 06 | f = 2.39e-01
# BONG 06 | f = 2.32e-01
# ---------------
# BING 07 | f = 2.31e-01
# BONG 07 | f = 2.30e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 1.67e-01
# BONG 08 | f = 1.54e-01
# ---------------
# BING 09 | f = 7.69e-02
# BONG 09 | f = 7.28e-02
# ---------------
# BING 10 | f = 7.14e-02
# BONG 10 | f = 7.14e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 26.08 nm
#
#
# CASE 011 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 344.51 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 85.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.22e-01
# BONG 01 | f = 5.22e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 5.91e-01
# BONG 02 | f = 5.89e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 4.96e-01
# BONG 03 | f = 4.89e-01
# ---------------
# BING 04 | f = 4.68e-01
# BONG 04 | f = 4.68e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 5.15e-01
# BONG 05 | f = 5.15e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 3.87e-01
# BONG 06 | f = 3.85e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 3.03e-01
# BONG 07 | f = 2.89e-01
# ---------------
# BING 08 | f = 1.41e-01
# BONG 08 | f = 1.41e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 9.08e-02
# BONG 09 | f = 9.03e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 25.60 nm
#
#
# CASE 012 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 403.73 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 91.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.88e-01
# BONG 01 | f = 5.84e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 5.19e-01
# BONG 02 | f = 5.12e-01
# ---------------
# BING 03 | f = 5.12e-01
# BONG 03 | f = 5.12e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 6.57e-01
# BONG 04 | f = 6.49e-01
# ---------------
# BING 05 | f = 6.49e-01
# BONG 05 | f = 6.49e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 4.69e-01
# BONG 06 | f = 4.62e-01
# ---------------
# BING 07 | f = 3.45e-01
# BONG 07 | f = 3.45e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 3.47e-01
# BONG 08 | f = 3.37e-01
# ---------------
# BING 09 | f = 3.35e-01
# BONG 09 | f = 3.35e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 4.78e-01
# BONG 10 | f = 4.15e-01
# ---------------
# BING 11 | f = 3.74e-01
# BONG 11 | f = 3.74e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 4.46e-01
# BONG 12 | f = 4.20e-01
# ---------------
# BING 13 | f = 3.40e-01
# BONG 13 | f = 3.37e-01
# ---------------
# BING 14 | f = 3.35e-01
# BONG 14 | f = 3.35e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 2.46e-01
# BONG 15 | f = 2.39e-01
# ---------------
# BING 16 | f = 1.26e-01
# BONG 16 | f = 1.24e-01
# ---------------
# BING 17 | f = 1.22e-01
# BONG 17 | f = 1.22e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 18 | f = 1.43e-01
# BONG 18 | f = 1.39e-01
# ---------------
# BING 19 | f = 1.25e-01
# BONG 19 | f = 1.25e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 20 | f = 3.76e-01
# BONG 20 | f = 3.39e-01
# ---------------
# BING 21 | f = 1.48e-01
# BONG 21 | f = 1.47e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 22 | f = 2.03e-01
# BONG 22 | f = 1.98e-01
# ---------------
# BING 23 | f = 1.42e-01
# BONG 23 | f = 1.42e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 116.81 nm
#
#
# CASE 013 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 404.51 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 112.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.94e-01
# BONG 01 | f = 4.89e-01
# ---------------
# BING 02 | f = 2.87e-01
# BONG 02 | f = 2.87e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 1.99e-01
# BONG 03 | f = 1.95e-01
# ---------------
# BING 04 | f = 1.41e-01
# BONG 04 | f = 1.39e-01
# ---------------
# BING 05 | f = 8.62e-02
# BONG 05 | f = 8.62e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 51.29 nm
#
#
# CASE 014 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 221.62 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 160.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.92e-01
# BONG 01 | f = 5.63e-01
# ---------------
# BING 02 | f = 4.75e-01
# BONG 02 | f = 4.74e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 3.86e-01
# BONG 03 | f = 3.84e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 4.73e-01
# BONG 04 | f = 4.58e-01
# ---------------
# BING 05 | f = 4.58e-01
# BONG 05 | f = 4.58e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 3.65e-01
# BONG 06 | f = 3.43e-01
# ---------------
# BING 07 | f = 2.90e-01
# BONG 07 | f = 2.71e-01
# ---------------
# BING 08 | f = 2.64e-01
# BONG 08 | f = 2.64e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 3.10e-01
# BONG 09 | f = 2.77e-01
# ---------------
# BING 10 | f = 2.59e-01
# BONG 10 | f = 2.59e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 1.91e-01
# BONG 11 | f = 1.85e-01
# ---------------
# BING 12 | f = 6.62e-02
# BONG 12 | f = 6.33e-02
# ---------------
# BING 13 | f = 5.55e-02
# BONG 13 | f = 5.50e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.31 nm
#
#
# CASE 015 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 71.97 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 807.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.32e-02
# BONG 01 | f = 1.27e-02
# ---------------
# BING 02 | f = 1.26e-02
# BONG 02 | f = 1.26e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.78 nm
#
#
# CASE 016 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 555.08 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 69.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.65e-01
# BONG 01 | f = 5.40e-01
# ---------------
# BING 02 | f = 5.40e-01
# BONG 02 | f = 5.40e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 4.50e-01
# BONG 03 | f = 4.43e-01
# ---------------
# BING 04 | f = 3.33e-01
# BONG 04 | f = 3.32e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 7.23e-01
# BONG 05 | f = 6.94e-01
# ---------------
# BING 06 | f = 6.94e-01
# BONG 06 | f = 6.94e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 6.28e-01
# BONG 07 | f = 6.23e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 7.11e-01
# BONG 08 | f = 6.93e-01
# ---------------
# BING 09 | f = 6.93e-01
# BONG 09 | f = 6.93e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 5.51e-01
# BONG 10 | f = 5.49e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 5.54e-01
# BONG 11 | f = 5.49e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 6.97e-01
# BONG 12 | f = 6.81e-01
# ---------------
# BING 13 | f = 6.81e-01
# BONG 13 | f = 6.81e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 5.33e-01
# BONG 14 | f = 5.29e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 4.66e-01
# BONG 15 | f = 4.65e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 5.98e-01
# BONG 16 | f = 5.96e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 885.60 nm
#
#
# CASE 017 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 162.75 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 230.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 7.07e-02
# BONG 01 | f = 6.47e-02
# ---------------
# BING 02 | f = 3.85e-02
# BONG 02 | f = 3.76e-02
# ---------------
# BING 03 | f = 3.70e-02
# BONG 03 | f = 3.69e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.49 nm
#
#
# CASE 018 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 74.75 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 787.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.26e-02
# BONG 01 | f = 1.23e-02
# ---------------
# BING 02 | f = 1.23e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.36 nm
#
#
# CASE 019 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 383.71 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 140.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.00e-01
# BONG 01 | f = 3.71e-01
# ---------------
# BING 02 | f = 3.23e-01
# BONG 02 | f = 3.21e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 5.72e-01
# BONG 03 | f = 5.66e-01
# ---------------
# BING 04 | f = 3.33e-01
# BONG 04 | f = 3.03e-01
# ---------------
# BING 05 | f = 2.18e-01
# BONG 05 | f = 2.18e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 5.10e-01
# BONG 06 | f = 4.81e-01
# ---------------
# BING 07 | f = 4.36e-01
# BONG 07 | f = 4.36e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 3.67e-01
# BONG 08 | f = 3.58e-01
# ---------------
# BING 09 | f = 3.42e-01
# BONG 09 | f = 3.41e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 3.03e-01
# BONG 10 | f = 2.90e-01
# ---------------
# BING 11 | f = 2.58e-01
# BONG 11 | f = 2.55e-01
# ---------------
# BING 12 | f = 2.51e-01
# BONG 12 | f = 2.49e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 2.17e-01
# BONG 13 | f = 2.09e-01
# ---------------
# BING 14 | f = 1.15e-01
# BONG 14 | f = 1.15e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 2.89e-01
# BONG 15 | f = 2.62e-01
# ---------------
# BING 16 | f = 2.53e-01
# BONG 16 | f = 2.53e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 17 | f = 4.86e-01
# BONG 17 | f = 4.84e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 18 | f = 2.16e-01
# BONG 18 | f = 2.13e-01
# ---------------
# BING 19 | f = 9.58e-02
# BONG 19 | f = 9.42e-02
# ---------------
# BING 20 | f = 6.56e-02
# BONG 20 | f = 6.55e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 56.91 nm
#
#
# CASE 020 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 309.45 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 127.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.71e-01
# BONG 01 | f = 5.65e-01
# ---------------
# BING 02 | f = 4.80e-01
# BONG 02 | f = 4.77e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 4.54e-01
# BONG 03 | f = 4.53e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 4.25e-01
# BONG 04 | f = 4.15e-01
# ---------------
# BING 05 | f = 2.92e-01
# BONG 05 | f = 2.86e-01
# ---------------
# BING 06 | f = 2.85e-01
# BONG 06 | f = 2.85e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 4.65e-01
# BONG 07 | f = 4.51e-01
# ---------------
# BING 08 | f = 2.42e-01
# BONG 08 | f = 2.39e-01
# ---------------
# BING 09 | f = 2.03e-01
# BONG 09 | f = 2.03e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 1.73e-01
# BONG 10 | f = 1.65e-01
# ---------------
# BING 11 | f = 1.56e-01
# BONG 11 | f = 1.56e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 3.53e-01
# BONG 12 | f = 3.35e-01
# ---------------
# BING 13 | f = 3.14e-01
# BONG 13 | f = 3.13e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 3.86e-01
# BONG 14 | f = 3.62e-01
# ---------------
# BING 15 | f = 3.60e-01
# BONG 15 | f = 3.60e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 2.73e-01
# BONG 16 | f = 2.67e-01
# ---------------
# BING 17 | f = 1.85e-01
# BONG 17 | f = 1.80e-01
# ---------------
# BING 18 | f = 1.78e-01
# BONG 18 | f = 1.78e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 19 | f = 5.17e-01
# BONG 19 | f = 5.16e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 20 | f = 5.27e-01
# BONG 20 | f = 5.22e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 21 | f = 5.62e-01
# BONG 21 | f = 5.62e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 310.89 nm
#
#
# CASE 021 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 169.93 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 298.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.94e-02
# BONG 01 | f = 2.83e-02
# ---------------
# BING 02 | f = 2.62e-02
# BONG 02 | f = 2.61e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.48 nm
#
#
# CASE 022 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 591.90 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 69.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.77e-01
# BONG 01 | f = 6.75e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 6.33e-01
# BONG 02 | f = 6.33e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 6.74e-01
# BONG 03 | f = 6.72e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 6.62e-01
# BONG 04 | f = 6.57e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 4.90e-01
# BONG 05 | f = 4.74e-01
# ---------------
# BING 06 | f = 3.31e-01
# BONG 06 | f = 3.14e-01
# ---------------
# BING 07 | f = 2.80e-01
# BONG 07 | f = 2.80e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 4.31e-01
# BONG 08 | f = 4.16e-01
# ---------------
# BING 09 | f = 4.12e-01
# BONG 09 | f = 4.12e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 4.74e-01
# BONG 10 | f = 4.56e-01
# ---------------
# BING 11 | f = 4.36e-01
# BONG 11 | f = 4.36e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 3.77e-01
# BONG 12 | f = 3.70e-01
# ---------------
# BING 13 | f = 3.70e-01
# BONG 13 | f = 3.70e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 3.44e-01
# BONG 14 | f = 3.35e-01
# ---------------
# BING 15 | f = 3.35e-01
# BONG 15 | f = 3.35e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 3.48e-01
# BONG 16 | f = 3.39e-01
# ---------------
# BING 17 | f = 3.39e-01
# BONG 17 | f = 3.39e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 18 | f = 3.43e-01
# BONG 18 | f = 3.34e-01
# ---------------
# BING 19 | f = 3.34e-01
# BONG 19 | f = 3.34e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 740.72 nm
#
#
# CASE 023 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 289.44 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 129.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.22e-01
# BONG 01 | f = 3.64e-01
# ---------------
# BING 02 | f = 3.13e-01
# BONG 02 | f = 3.09e-01
# ---------------
# BING 03 | f = 3.09e-01
# BONG 03 | f = 3.09e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 4.07e-01
# BONG 04 | f = 3.86e-01
# ---------------
# BING 05 | f = 3.01e-01
# BONG 05 | f = 2.83e-01
# ---------------
# BING 06 | f = 2.79e-01
# BONG 06 | f = 2.78e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 1.49e-01
# BONG 07 | f = 1.48e-01
# ---------------
# BING 08 | f = 7.94e-02
# BONG 08 | f = 7.82e-02
# ---------------
# BING 09 | f = 7.72e-02
# BONG 09 | f = 7.72e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 25.17 nm
#
#
# CASE 024 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 244.40 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 148.1
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.68e-02
# BONG 01 | f = 5.51e-02
# ---------------
# BING 02 | f = 5.44e-02
# BONG 02 | f = 5.44e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.87 nm
#
#
# CASE 025 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 466.26 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 79.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.20e-01
# BONG 01 | f = 6.18e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 5.28e-01
# BONG 02 | f = 5.24e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 6.36e-01
# BONG 03 | f = 6.31e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 8.91e-01
# BONG 04 | f = 5.64e-01
# ---------------
# BING 05 | f = 4.77e-01
# BONG 05 | f = 4.51e-01
# ---------------
# BING 06 | f = 4.51e-01
# BONG 06 | f = 4.51e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 4.08e-01
# BONG 07 | f = 3.82e-01
# ---------------
# BING 08 | f = 3.81e-01
# BONG 08 | f = 3.81e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 3.27e-01
# BONG 09 | f = 3.26e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 4.60e-01
# BONG 10 | f = 4.57e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 3.87e-01
# BONG 11 | f = 3.34e-01
# ---------------
# BING 12 | f = 3.16e-01
# BONG 12 | f = 3.16e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 3.79e-01
# BONG 13 | f = 3.24e-01
# ---------------
# BING 14 | f = 3.07e-01
# BONG 14 | f = 3.04e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 4.28e-01
# BONG 15 | f = 3.94e-01
# ---------------
# BING 16 | f = 3.54e-01
# BONG 16 | f = 3.54e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 17 | f = 3.88e-01
# BONG 17 | f = 3.44e-01
# ---------------
# BING 18 | f = 3.37e-01
# BONG 18 | f = 3.35e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 862.06 nm
#
#
# CASE 026 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 216.55 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 209.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.39e-02
# BONG 01 | f = 4.39e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.32 nm
#
#
# CASE 027 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 263.49 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 121.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.42e-01
# BONG 01 | f = 5.38e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 4.54e-01
# BONG 02 | f = 4.54e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 5.47e-01
# BONG 03 | f = 5.43e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 5.39e-01
# BONG 04 | f = 5.23e-01
# ---------------
# BING 05 | f = 5.05e-01
# BONG 05 | f = 5.03e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 3.54e-01
# BONG 06 | f = 3.54e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 3.84e-01
# BONG 07 | f = 3.78e-01
# ---------------
# BING 08 | f = 2.11e-01
# BONG 08 | f = 2.07e-01
# ---------------
# BING 09 | f = 8.78e-02
# BONG 09 | f = 8.35e-02
# ---------------
# BING 10 | f = 8.18e-02
# BONG 10 | f = 8.18e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 27.81 nm
#
#
# CASE 028 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 249.34 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 214.1
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.45e-01
# BONG 01 | f = 2.43e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 1.55e-01
# BONG 02 | f = 1.48e-01
# ---------------
# BING 03 | f = 4.81e-02
# BONG 03 | f = 4.55e-02
# ---------------
# BING 04 | f = 4.12e-02
# BONG 04 | f = 4.12e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 26.97 nm
#
#
# CASE 029 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 437.93 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 55.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.40e-01
# BONG 01 | f = 6.21e-01
# ---------------
# BING 02 | f = 6.21e-01
# BONG 02 | f = 6.21e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 5.25e-01
# BONG 03 | f = 5.21e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 6.41e-01
# BONG 04 | f = 6.29e-01
# ---------------
# BING 05 | f = 6.29e-01
# BONG 05 | f = 6.29e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 4.90e-01
# BONG 06 | f = 4.90e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 4.36e-01
# BONG 07 | f = 4.31e-01
# ---------------
# BING 08 | f = 4.31e-01
# BONG 08 | f = 4.31e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 6.20e-01
# BONG 09 | f = 6.17e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 5.90e-01
# BONG 10 | f = 5.72e-01
# ---------------
# BING 11 | f = 5.72e-01
# BONG 11 | f = 5.72e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 4.48e-01
# BONG 12 | f = 4.47e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 5.98e-01
# BONG 13 | f = 5.87e-01
# ---------------
# BING 14 | f = 5.87e-01
# BONG 14 | f = 5.87e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 6.73e-01
# BONG 15 | f = 6.40e-01
# ---------------
# BING 16 | f = 6.40e-01
# BONG 16 | f = 6.40e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 17 | f = 5.37e-01
# BONG 17 | f = 5.33e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 716.71 nm
#
#
# CASE 030 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 321.50 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 140.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.66e-01
# BONG 01 | f = 3.43e-01
# ---------------
# BING 02 | f = 3.15e-01
# BONG 02 | f = 3.12e-01
# ---------------
# BING 03 | f = 3.00e-01
# BONG 03 | f = 3.00e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 4.93e-01
# BONG 04 | f = 4.86e-01
# ---------------
# BING 05 | f = 3.95e-01
# BONG 05 | f = 3.74e-01
# ---------------
# BING 06 | f = 3.48e-01
# BONG 06 | f = 3.40e-01
# ---------------
# BING 07 | f = 3.33e-01
# BONG 07 | f = 3.32e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 5.61e-01
# BONG 08 | f = 5.48e-01
# ---------------
# BING 09 | f = 5.36e-01
# BONG 09 | f = 5.30e-01
# ---------------
# BING 10 | f = 5.30e-01
# BONG 10 | f = 5.30e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 4.98e-01
# BONG 11 | f = 4.84e-01
# ---------------
# BING 12 | f = 4.73e-01
# BONG 12 | f = 4.73e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 2.98e-01
# BONG 13 | f = 2.76e-01
# ---------------
# BING 14 | f = 1.23e-01
# BONG 14 | f = 1.18e-01
# ---------------
# BING 15 | f = 7.33e-02
# BONG 15 | f = 7.33e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 25.19 nm
#
#
# CASE 031 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 175.77 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 244.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.44e-02
# BONG 01 | f = 3.36e-02
# ---------------
# BING 02 | f = 3.13e-02
# BONG 02 | f = 3.13e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.41 nm
#
#
# CASE 032 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 201.98 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 232.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.18e-02
# BONG 01 | f = 4.03e-02
# ---------------
# BING 02 | f = 3.24e-02
# BONG 02 | f = 3.24e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.83 nm
#
#
# CASE 033 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 384.34 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 104.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.47e-01
# BONG 01 | f = 6.26e-01
# ---------------
# BING 02 | f = 5.40e-01
# BONG 02 | f = 5.37e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 4.75e-01
# BONG 03 | f = 4.72e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 4.38e-01
# BONG 04 | f = 4.16e-01
# ---------------
# BING 05 | f = 4.10e-01
# BONG 05 | f = 4.06e-01
# ---------------
# BING 06 | f = 4.05e-01
# BONG 06 | f = 4.05e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 4.19e-01
# BONG 07 | f = 4.03e-01
# ---------------
# BING 08 | f = 3.95e-01
# BONG 08 | f = 3.93e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 5.30e-01
# BONG 09 | f = 5.20e-01
# ---------------
# BING 10 | f = 4.89e-01
# BONG 10 | f = 4.89e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 5.21e-01
# BONG 11 | f = 5.21e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 6.16e-01
# BONG 12 | f = 6.15e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 5.37e-01
# BONG 13 | f = 5.27e-01
# ---------------
# BING 14 | f = 4.20e-01
# BONG 14 | f = 4.19e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 5.43e-01
# BONG 15 | f = 5.27e-01
# ---------------
# BING 16 | f = 5.03e-01
# BONG 16 | f = 4.97e-01
# ---------------
# BING 17 | f = 4.97e-01
# BONG 17 | f = 4.97e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 18 | f = 5.64e-01
# BONG 18 | f = 5.43e-01
# ---------------
# BING 19 | f = 4.45e-01
# BONG 19 | f = 4.24e-01
# ---------------
# BING 20 | f = 4.19e-01
# BONG 20 | f = 4.19e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 21 | f = 4.51e-01
# BONG 21 | f = 4.10e-01
# ---------------
# BING 22 | f = 3.78e-01
# BONG 22 | f = 3.71e-01
# ---------------
# BING 23 | f = 3.71e-01
# BONG 23 | f = 3.71e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 481.21 nm
#
#
# CASE 034 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 412.72 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 76.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.65e-01
# BONG 01 | f = 6.53e-01
# ---------------
# BING 02 | f = 6.41e-01
# BONG 02 | f = 6.38e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 5.05e-01
# BONG 03 | f = 5.02e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 4.91e-01
# BONG 04 | f = 4.87e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 5.29e-01
# BONG 05 | f = 5.26e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 5.15e-01
# BONG 06 | f = 5.06e-01
# ---------------
# BING 07 | f = 4.95e-01
# BONG 07 | f = 4.95e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 3.73e-01
# BONG 08 | f = 3.65e-01
# ---------------
# BING 09 | f = 3.65e-01
# BONG 09 | f = 3.65e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 5.41e-01
# BONG 10 | f = 5.40e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 5.78e-01
# BONG 11 | f = 5.65e-01
# ---------------
# BING 12 | f = 5.65e-01
# BONG 12 | f = 5.65e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 5.13e-01
# BONG 13 | f = 5.04e-01
# ---------------
# BING 14 | f = 5.04e-01
# BONG 14 | f = 5.04e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 4.50e-01
# BONG 15 | f = 4.41e-01
# ---------------
# BING 16 | f = 3.49e-01
# BONG 16 | f = 3.31e-01
# ---------------
# BING 17 | f = 1.37e-01
# BONG 17 | f = 1.37e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 18 | f = 1.07e-01
# BONG 18 | f = 1.06e-01
# ---------------
# BING 19 | f = 1.06e-01
# BONG 19 | f = 1.06e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 30.37 nm
#
#
# CASE 035 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 234.44 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 198.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.91e-01
# BONG 01 | f = 1.89e-01
# ---------------
# BING 02 | f = 4.59e-02
# BONG 02 | f = 4.30e-02
# ---------------
# BING 03 | f = 3.75e-02
# BONG 03 | f = 3.75e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.48 nm
#
#
# CASE 036 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 109.12 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 409.1
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.87e-02
# BONG 01 | f = 1.81e-02
# ---------------
# BING 02 | f = 1.80e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.37 nm
#
#
# CASE 037 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 241.18 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 217.1
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.40e-01
# BONG 01 | f = 3.30e-01
# ---------------
# BING 02 | f = 2.59e-01
# BONG 02 | f = 2.59e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 2.46e-01
# BONG 03 | f = 2.30e-01
# ---------------
# BING 04 | f = 1.45e-01
# BONG 04 | f = 1.45e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 4.09e-01
# BONG 05 | f = 4.01e-01
# ---------------
# BING 06 | f = 3.45e-01
# BONG 06 | f = 3.38e-01
# ---------------
# BING 07 | f = 3.17e-01
# BONG 07 | f = 3.17e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 2.71e-01
# BONG 08 | f = 2.69e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 1.41e-01
# BONG 09 | f = 1.37e-01
# ---------------
# BING 10 | f = 4.74e-02
# BONG 10 | f = 4.74e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 32.93 nm
#
#
# CASE 038 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 381.77 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 113.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.28e-01
# BONG 01 | f = 6.10e-01
# ---------------
# BING 02 | f = 6.10e-01
# BONG 02 | f = 6.10e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 3.80e-01
# BONG 03 | f = 3.45e-01
# ---------------
# BING 04 | f = 2.89e-01
# BONG 04 | f = 2.83e-01
# ---------------
# BING 05 | f = 2.83e-01
# BONG 05 | f = 2.83e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 4.16e-01
# BONG 06 | f = 3.90e-01
# ---------------
# BING 07 | f = 3.87e-01
# BONG 07 | f = 3.87e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 2.59e-01
# BONG 08 | f = 2.58e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 2.24e-01
# BONG 09 | f = 2.23e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 4.51e-01
# BONG 10 | f = 4.27e-01
# ---------------
# BING 11 | f = 4.22e-01
# BONG 11 | f = 4.22e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 4.65e-01
# BONG 12 | f = 4.63e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 3.77e-01
# BONG 13 | f = 3.73e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 2.75e-01
# BONG 14 | f = 2.74e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 1.70e-01
# BONG 15 | f = 1.63e-01
# ---------------
# BING 16 | f = 1.43e-01
# BONG 16 | f = 1.41e-01
# ---------------
# BING 17 | f = 1.40e-01
# BONG 17 | f = 1.40e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 18 | f = 1.64e-01
# BONG 18 | f = 1.61e-01
# ---------------
# BING 19 | f = 1.58e-01
# BONG 19 | f = 1.58e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 192.31 nm
#
#
# CASE 039 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 96.04 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 566.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.57e-02
# BONG 01 | f = 1.47e-02
# ---------------
# BING 02 | f = 1.46e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.71 nm
#
#
# CASE 040 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 203.74 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 204.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.01e-02
# BONG 01 | f = 4.91e-02
# ---------------
# BING 02 | f = 4.87e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.95 nm
#
#
# CASE 041 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 358.38 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 150.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.83e-01
# BONG 01 | f = 3.73e-01
# ---------------
# BING 02 | f = 3.71e-01
# BONG 02 | f = 3.70e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 2.42e-01
# BONG 03 | f = 2.36e-01
# ---------------
# BING 04 | f = 8.29e-02
# BONG 04 | f = 8.22e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 61.05 nm
#
#
# CASE 042 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 287.27 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 122.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.64e-01
# BONG 01 | f = 1.57e-01
# ---------------
# BING 02 | f = 7.66e-02
# BONG 02 | f = 7.07e-02
# ---------------
# BING 03 | f = 6.65e-02
# BONG 03 | f = 6.65e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 25.00 nm
#
#
# CASE 043 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 141.45 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 357.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.25e-02
# BONG 01 | f = 2.20e-02
# ---------------
# BING 02 | f = 2.14e-02
# BONG 02 | f = 2.14e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.49 nm
#
#
# CASE 044 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 456.07 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 71.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.12e-01
# BONG 01 | f = 6.06e-01
# ---------------
# BING 02 | f = 5.91e-01
# BONG 02 | f = 5.91e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 5.52e-01
# BONG 03 | f = 5.48e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 6.19e-01
# BONG 04 | f = 6.04e-01
# ---------------
# BING 05 | f = 6.04e-01
# BONG 05 | f = 6.04e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 5.46e-01
# BONG 06 | f = 5.43e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 5.43e-01
# BONG 07 | f = 5.38e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 7.62e-01
# BONG 08 | f = 7.57e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 6.28e-01
# BONG 09 | f = 5.87e-01
# ---------------
# BING 10 | f = 5.41e-01
# BONG 10 | f = 5.39e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 5.18e-01
# BONG 11 | f = 4.92e-01
# ---------------
# BING 12 | f = 4.92e-01
# BONG 12 | f = 4.92e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 4.51e-01
# BONG 13 | f = 4.42e-01
# ---------------
# BING 14 | f = 2.88e-01
# BONG 14 | f = 2.87e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 2.78e-01
# BONG 15 | f = 2.70e-01
# ---------------
# BING 16 | f = 2.70e-01
# BONG 16 | f = 2.70e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 17 | f = 3.72e-01
# BONG 17 | f = 3.68e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 348.74 nm
#
#
# CASE 045 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 115.07 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 428.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.87e-02
# BONG 01 | f = 1.82e-02
# ---------------
# BING 02 | f = 1.80e-02
# BONG 02 | f = 1.80e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# ...
# BING 05 | f = 7.16e-01
# BONG 05 | f = 7.13e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 6.62e-01
# BONG 06 | f = 6.56e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 6.62e-01
# BONG 07 | f = 6.40e-01
# ---------------
# BING 08 | f = 6.40e-01
# BONG 08 | f = 6.40e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 5.51e-01
# BONG 09 | f = 5.32e-01
# ---------------
# BING 10 | f = 5.13e-01
# BONG 10 | f = 4.96e-01
# ---------------
# BING 11 | f = 4.96e-01
# BONG 11 | f = 4.96e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 6.44e-01
# BONG 12 | f = 6.35e-01
# ---------------
# BING 13 | f = 6.35e-01
# BONG 13 | f = 6.35e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 6.32e-01
# BONG 14 | f = 6.27e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 5.00e-01
# BONG 15 | f = 4.63e-01
# ---------------
# BING 16 | f = 4.14e-01
# BONG 16 | f = 4.14e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 923.65 nm
#
#
# CASE 086 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 241.82 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 155.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.41e-01
# BONG 01 | f = 3.40e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 2.25e-01
# BONG 02 | f = 2.20e-01
# ---------------
# BING 03 | f = 1.44e-01
# BONG 03 | f = 1.44e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 3.81e-01
# BONG 04 | f = 3.57e-01
# ---------------
# BING 05 | f = 3.44e-01
# BONG 05 | f = 3.40e-01
# ---------------
# BING 06 | f = 3.40e-01
# BONG 06 | f = 3.40e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 1.38e-01
# BONG 07 | f = 1.33e-01
# ---------------
# BING 08 | f = 7.13e-02
# BONG 08 | f = 6.91e-02
# ---------------
# BING 09 | f = 6.91e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 28.33 nm
#
#
# CASE 087 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 171.01 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 304.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.31e-02
# BONG 01 | f = 3.25e-02
# ---------------
# BING 02 | f = 3.23e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.58 nm
#
#
# CASE 088 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 247.88 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 153.1
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.06e-01
# BONG 01 | f = 3.93e-01
# ---------------
# BING 02 | f = 3.87e-01
# BONG 02 | f = 3.85e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 3.64e-01
# BONG 03 | f = 3.48e-01
# ---------------
# BING 04 | f = 3.07e-01
# BONG 04 | f = 3.04e-01
# ---------------
# BING 05 | f = 2.90e-01
# BONG 05 | f = 2.82e-01
# ---------------
# BING 06 | f = 2.76e-01
# BONG 06 | f = 2.76e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 1.52e-01
# BONG 07 | f = 1.50e-01
# ---------------
# BING 08 | f = 1.46e-01
# BONG 08 | f = 1.46e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 4.76e-01
# BONG 09 | f = 4.62e-01
# ---------------
# BING 10 | f = 4.60e-01
# BONG 10 | f = 4.60e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 4.40e-01
# BONG 11 | f = 4.24e-01
# ---------------
# BING 12 | f = 3.07e-01
# BONG 12 | f = 3.02e-01
# ---------------
# BING 13 | f = 2.61e-01
# BONG 13 | f = 2.61e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 2.19e-01
# BONG 14 | f = 2.12e-01
# ---------------
# BING 15 | f = 1.55e-01
# BONG 15 | f = 1.54e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 1.52e-01
# BONG 16 | f = 1.49e-01
# ---------------
# BING 17 | f = 1.46e-01
# BONG 17 | f = 1.46e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 18 | f = 3.19e-01
# BONG 18 | f = 2.84e-01
# ---------------
# BING 19 | f = 2.68e-01
# BONG 19 | f = 2.68e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 20 | f = 3.12e-01
# BONG 20 | f = 2.57e-01
# ---------------
# BING 21 | f = 2.34e-01
# BONG 21 | f = 2.34e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 22 | f = 2.98e-01
# BONG 22 | f = 2.36e-01
# ---------------
# BING 23 | f = 2.16e-01
# BONG 23 | f = 2.16e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 24 | f = 5.16e-01
# BONG 24 | f = 5.09e-01
# ---------------
# BING 25 | f = 5.03e-01
# BONG 25 | f = 5.03e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 434.31 nm
#
#
# CASE 089 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 303.23 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 112.1
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.39e-01
# BONG 01 | f = 3.31e-01
# ---------------
# BING 02 | f = 3.17e-01
# BONG 02 | f = 3.17e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 2.57e-01
# BONG 03 | f = 2.57e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 4.67e-01
# BONG 04 | f = 4.55e-01
# ---------------
# BING 05 | f = 4.55e-01
# BONG 05 | f = 4.55e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 4.05e-01
# BONG 06 | f = 4.05e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 4.66e-01
# BONG 07 | f = 4.58e-01
# ---------------
# BING 08 | f = 4.54e-01
# BONG 08 | f = 4.54e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 4.28e-01
# BONG 09 | f = 4.19e-01
# ---------------
# BING 10 | f = 4.17e-01
# BONG 10 | f = 4.17e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 3.82e-01
# BONG 11 | f = 3.74e-01
# ---------------
# BING 12 | f = 3.74e-01
# BONG 12 | f = 3.74e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 4.15e-01
# BONG 13 | f = 3.76e-01
# ---------------
# BING 14 | f = 3.27e-01
# BONG 14 | f = 3.23e-01
# ---------------
# BING 15 | f = 3.01e-01
# BONG 15 | f = 3.01e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 4.25e-01
# BONG 16 | f = 4.20e-01
# ---------------
# BING 17 | f = 4.17e-01
# BONG 17 | f = 4.17e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 18 | f = 4.77e-01
# BONG 18 | f = 4.62e-01
# ---------------
# BING 19 | f = 4.62e-01
# BONG 19 | f = 4.62e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 20 | f = 3.22e-01
# BONG 20 | f = 3.19e-01
# ---------------
# BING 21 | f = 3.16e-01
# BONG 21 | f = 3.14e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 215.60 nm
#
#
# CASE 090 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 114.79 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 383.1
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.74e-02
# BONG 01 | f = 1.72e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.94 nm
#
#
# CASE 091 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 104.38 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 513.1
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.53e-02
# BONG 01 | f = 1.50e-02
# ---------------
# BING 02 | f = 1.49e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.78 nm
#
#
# CASE 092 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 458.83 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 114.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.75e-01
# BONG 01 | f = 5.70e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 3.23e-01
# BONG 02 | f = 3.23e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 4.12e-01
# BONG 03 | f = 3.84e-01
# ---------------
# BING 04 | f = 3.84e-01
# BONG 04 | f = 3.84e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 2.99e-01
# BONG 05 | f = 2.97e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 2.53e-01
# BONG 06 | f = 2.50e-01
# ---------------
# BING 07 | f = 1.59e-01
# BONG 07 | f = 1.58e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 4.10e-01
# BONG 08 | f = 3.83e-01
# ---------------
# BING 09 | f = 3.44e-01
# BONG 09 | f = 3.42e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 3.50e-01
# BONG 10 | f = 3.32e-01
# ---------------
# BING 11 | f = 3.31e-01
# BONG 11 | f = 3.31e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 6.25e-01
# BONG 12 | f = 6.25e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 3.92e-01
# BONG 13 | f = 3.72e-01
# ---------------
# BING 14 | f = 2.80e-01
# BONG 14 | f = 2.80e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 3.57e-01
# BONG 15 | f = 3.32e-01
# ---------------
# BING 16 | f = 3.32e-01
# BONG 16 | f = 3.32e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 17 | f = 4.24e-01
# BONG 17 | f = 3.92e-01
# ---------------
# BING 18 | f = 3.73e-01
# BONG 18 | f = 3.73e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 613.17 nm
#
#
# CASE 093 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 242.18 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 199.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.93e-01
# BONG 01 | f = 2.86e-01
# ---------------
# BING 02 | f = 1.86e-01
# BONG 02 | f = 1.76e-01
# ---------------
# BING 03 | f = 5.75e-02
# BONG 03 | f = 5.75e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.37 nm
#
#
# CASE 094 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 147.42 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 332.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.52e-02
# BONG 01 | f = 2.45e-02
# ---------------
# BING 02 | f = 2.40e-02
# BONG 02 | f = 2.39e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.22 nm
#
#
# CASE 095 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 217.69 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 250.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.64e-02
# BONG 01 | f = 6.32e-02
# ---------------
# BING 02 | f = 3.71e-02
# BONG 02 | f = 3.67e-02
# ---------------
# BING 03 | f = 3.66e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.74 nm
#
#
# CASE 096 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 419.04 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 131.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.51e-01
# BONG 01 | f = 4.40e-01
# ---------------
# BING 02 | f = 3.63e-01
# BONG 02 | f = 3.56e-01
# ---------------
# BING 03 | f = 3.47e-01
# BONG 03 | f = 3.44e-01
# ---------------
# BING 04 | f = 3.36e-01
# BONG 04 | f = 3.35e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 3.91e-01
# BONG 05 | f = 3.89e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 2.99e-01
# BONG 06 | f = 2.97e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 3.94e-01
# BONG 07 | f = 3.92e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 3.09e-01
# BONG 08 | f = 3.09e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 4.19e-01
# BONG 09 | f = 4.12e-01
# ---------------
# BING 10 | f = 4.12e-01
# BONG 10 | f = 4.12e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 3.32e-01
# BONG 11 | f = 3.25e-01
# ---------------
# BING 12 | f = 2.97e-01
# BONG 12 | f = 2.97e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 3.93e-01
# BONG 13 | f = 3.90e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 1.85e-01
# BONG 14 | f = 1.81e-01
# ---------------
# BING 15 | f = 9.16e-02
# BONG 15 | f = 9.16e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 76.33 nm
#
#
# CASE 097 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 162.01 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 325.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.21e-02
# BONG 01 | f = 3.11e-02
# ---------------
# BING 02 | f = 2.50e-02
# BONG 02 | f = 2.50e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.55 nm
#
#
# CASE 098 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 452.55 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 62.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.37e-01
# BONG 01 | f = 6.21e-01
# ---------------
# BING 02 | f = 6.21e-01
# BONG 02 | f = 6.21e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 5.33e-01
# BONG 03 | f = 5.31e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 6.28e-01
# BONG 04 | f = 6.25e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 8.09e-01
# BONG 05 | f = 6.12e-01
# ---------------
# BING 06 | f = 4.46e-01
# BONG 06 | f = 4.46e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 7.42e-01
# BONG 07 | f = 6.94e-01
# ---------------
# BING 08 | f = 6.94e-01
# BONG 08 | f = 6.94e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 4.05e-01
# BONG 09 | f = 3.99e-01
# ---------------
# BING 10 | f = 3.99e-01
# BONG 10 | f = 3.99e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 5.22e-01
# BONG 11 | f = 5.10e-01
# ---------------
# BING 12 | f = 4.84e-01
# BONG 12 | f = 4.84e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 5.42e-01
# BONG 13 | f = 5.38e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 5.81e-01
# BONG 14 | f = 5.78e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 5.87e-01
# BONG 15 | f = 5.83e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 6.00e-01
# BONG 16 | f = 5.98e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 820.71 nm
#
#
# CASE 099 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 159.13 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 300.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.67e-02
# BONG 01 | f = 2.58e-02
# ---------------
# BING 02 | f = 2.49e-02
# BONG 02 | f = 2.49e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.72 nm
#
#
# CASE 100 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 117.76 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 372.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.25e-02
# BONG 01 | f = 2.20e-02
# ---------------
# BING 02 | f = 2.20e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.80 nm
#
#
# Saved data to:  /home/derbyk/src/ffpr/sim_results/20260608_mc_misalignments_17mag_dec_50um_tilt_5as.pkl

# %% [markdown]
# ## VISUALIZE

# %%
data = utils.load_pickle('/home/derbyk/src/ffpr/sim_results/20260608_mc_misalignments_17mag_dec_50um_tilt_5as.pkl')

median_rms_truth = np.zeros(len(data))
median_rms_residual = np.zeros(len(data))
max_rms_residual = np.zeros(len(data))
min_rms_residual = np.zeros(len(data))
std_rms_residual = np.zeros(len(data))
median_snr = np.zeros(len(data))

for i, case in enumerate(data):
    median_rms_truth[i] = np.median(np.array(data[case]['RMS_TRUTH_PER_FIELD']))
    median_rms_residual[i] = np.median(np.array(data[case]['RMS_RESIDUAL_PER_FIELD']))
    max_rms_residual[i] = np.max(np.array(data[case]['RMS_RESIDUAL_PER_FIELD']))
    min_rms_residual[i] = np.min(np.array(data[case]['RMS_RESIDUAL_PER_FIELD']))
    std_rms_residual[i] = np.std(np.array(data[case]['RMS_RESIDUAL_PER_FIELD']))
    median_snr[i] = np.median(np.array(data[case]['SNR_PER_FIELD']))

fig, axs = plt.subplot_mosaic([['histx', 'poop'],
                               ['scatter', 'histy']],
                               figsize=(8, 6), 
                               height_ratios=[1, 3],
                               width_ratios=[3, 1],
                               layout='tight',
                               dpi=150)

count = 0
fails_x = []
fails_y = []
xs = []
ys = []
cs = []

for x, y, c in zip(median_rms_truth, median_snr, median_rms_residual):
    if c < 62.5:
        xs.append(float(x))
        ys.append(float(y))
        cs.append(float(c))
    else:
        fails_x.append(float(x))
        fails_y.append(float(y))

xs = _np.array(xs)
ys = _np.array(ys)
cs = _np.array(cs)
fails_x = _np.array(fails_x)
fails_y = _np.array(fails_y)

xmin = _np.array([xs.min(), fails_x.min()]).min()
xmax = _np.array([xs.max(), fails_x.max()]).max()

ymin = _np.array([ys.min(), fails_y.min()]).min()
ymax = _np.array([ys.max(), fails_y.max()]).max()

cmin = 20
cmax = 62.5

sorted_fails_x = sorted(fails_x)
cdf_opd = [1]
cdf_x = [xmin * 0.8]
x = xmin
count = 0
while x < xmax:
    if count == len(fails_x):
        x += 10
        cdf_x.append(xmax * 1.1)
        cdf_opd.append(cdf_opd[-1])
        break
    if x + 10 < sorted_fails_x[count]:
        x += 10
        cdf_x.append(x)
        cdf_opd.append(cdf_opd[-1])
    else:
        x = sorted_fails_x[count]
        cdf_x.append(x)
        cdf_opd.append((1 - ((count + 1) / len(data))))
        count += 1
cdf_opd = _np.array(cdf_opd)
cdf_x = _np.array(cdf_x)

sorted_fails_y = sorted(fails_y)
cdf_snr = [1]
cdf_y = [ymin * 0.8]
y = ymin
count = 0
while y < ymax:
    if count == len(fails_y):
        y += 10
        cdf_y.append(ymax * 1.1)
        cdf_snr.append(cdf_snr[-1])
        break
    if y + 10 < sorted_fails_y[count]:
        y += 10
        cdf_y.append(y)
        cdf_snr.append(cdf_snr[-1])
    else:
        y = sorted_fails_y[count]
        cdf_y.append(y)
        cdf_snr.append((1 - ((count + 1) / len(data))))
        count += 1
cdf_snr = _np.array(cdf_snr)
cdf_y = _np.array(cdf_y)

axs['poop'].set_axis_off()

ax = axs['scatter']
ax.scatter(fails_x, fails_y, c='k', alpha=0.8, marker='x')
s = ax.scatter(xs, ys, c=cs, alpha=0.8, marker='.')
s.set_clim([cmin, cmax])
ax.set_xlabel('Median RMS OPD (nm)')
ax.set_ylabel('Median SNR')
ax.set_xlim([xmin * 0.8, xmax * 1.1])
ax.set_ylim([ymin * 0.8, ymax * 1.1])
ax.grid(which='both', alpha=0.3)

plt.colorbar(s, ax=axs['histy'], pad=0.2, label='Median RMS Residual (nm)')

ax = axs['histx']
ax.plot(cdf_x, cdf_opd)
ax.fill_between(cdf_x, cdf_opd, alpha=0.2)
# ax.hist(np.array(fails_x).get(), bins=40, color='r')
ax.tick_params(axis='x', labelbottom=False)
ax.set_ylabel('Cumulative\nSuccess Rate')
ax.set_xlim([xmin * 0.8, xmax * 1.1])
ax.set_ylim([0, 1.05])
ax.grid(which='both', alpha=0.3)

ax = axs['histy']
ax.plot(cdf_snr, _np.flip(cdf_y),)
ax.fill_betweenx(_np.flip(cdf_y), cdf_snr, alpha=0.2)
# ax.hist(np.array(fails_y).get(), bins=20, color='r', orientation='horizontal')
ax.tick_params(axis='y', labelleft=False)
ax.set_xticks([0, 0.5, 1])
ax.set_xlabel('Cumulative\nSuccess Rate')
ax.set_ylim([ymin * 0.8, ymax * 1.1])
ax.set_xlim([0, 1.05])
ax.grid(which='both', alpha=0.3)


fig.suptitle(f'RMag 17 Guide Stars\n{len(data):02.0f} Misalignment Cases; {len(cs) / len(data) * 100:02.0f}% Convergence Rate\n$\pm25\mu m$ Decenter X, Y; $\pm2.5$" Tilt X, Y')
# Out:
# Text(0.5, 0.98, 'RMag 17 Guide Stars\n100 Misalignment Cases; 67% Convergence Rate\n$\\pm25\\mu m$ Decenter X, Y; $\\pm2.5$" Tilt X, Y')
