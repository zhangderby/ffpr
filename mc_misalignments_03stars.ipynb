# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import matplotlib.cm as color
better_magma = color.magma
better_magma.set_bad('black',1.)
import matplotlib.colors as c

from prysm import (
    mathops, 
    conf,
)
from prysm.mathops import (
    _np,
    np,
    fft,
    interpolate,
    ndimage,
)
from prysm.coordinates import (
    make_xy_grid, 
    cart_to_polar,
)
from prysm.propagation import Wavefront as WF
from prysm.propagation import (
    focus_fixed_sampling,
    focus_fixed_sampling_backprop
)                              
from prysm.thinlens import (
    defocus_to_image_displacement,
    image_displacement_to_defocus,
)
from prysm.geometry import (
    offset_circle,
    circle,
    spider,
    gaussian,
)
from prysm.polynomials import (
    lstsq,
    noll_to_nm,
    zernike_nm,
    zernike_nm_seq,
    hopkins,
    sum_of_2d_modes,
    sum_of_2d_modes_backprop
)
mathops.set_backend_to_cupy()
# conf.config.precision = 32

from astropy.io import (
    fits,
    ascii,
)

from skimage.measure import centroid

import copy

from algos import BING_BONG, FFPR2, PDPR, model, mean_squared_error, gain_invariant_error
import utils

from functools import partial

from lina.utils import TikhonovInverse

import config_um
import config_um_wcc
from Batoid4LOFT.LAZULI_STOP_mark11 import Lazuli_stop, readBulkMotion, readDeformation

from psd_utils import PSDUtils

from scipy.optimize import minimize

from scipy.interpolate import RegularGridInterpolator

from tqdm import tqdm

from psd_utils import PSDUtils

from model import telescope
# from algos import pdpr, OPD, ADPR
import utils

from functools import partial

from opt import F77LBFGSB, runN, RAdam
from IPython.display import clear_output

# logging stuff
import logging
psd_log = logging.getLogger('__psd_utils__')
psd_log.disabled = True

# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

import toml

# %%
# !nvidia-smi
# Out:
# Wed May  6 00:59:54 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 565.57.01              Driver Version: 565.57.01      CUDA Version: 12.7     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100 80GB PCIe          On  |   00000000:25:00.0 Off |                    0 |
# | N/A   31C    P0             63W /  300W |    2816MiB /  81920MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A   1132933      C   ...onda3/envs/py310-stp-env/bin/python        744MiB |
# |    0   N/A  N/A   1133390      C   ...onda3/envs/py310-stp-env/bin/python        418MiB |
# |    0   N/A  N/A   1182782      C   ...rojects/venv-scoob-poppy/bin/python       1620MiB |
# |    0   N/A  N/A   1403299      G   /usr/lib/xorg/Xorg                              4MiB |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ## SETUP MODEL

# %%
config = toml.load('/home/derbyk/src/ffpr/data/3m_off_axis_default.toml')
optic_opd_data = utils.load_pickle('/home/derbyk/src/ffpr/data/opd_maps.pkl')

sys = telescope(config=config, optic_opd_data=optic_opd_data)

dark = sys.get_dark(stacked_frames=1)
images = [im - dark for im in sys.snap(stacked_frames=1)]

for i, im in enumerate(images):
    print(f'Image {i + 1:02.0f} SNR = {im.max() / dark.std():.1f}')
# Out:
# Image 01 SNR = 629.2
# Image 02 SNR = 1027.5
# Image 03 SNR = 585.1
# Image 04 SNR = 1254.4
# Image 05 SNR = 713.3
# Image 06 SNR = 703.9
# Image 07 SNR = 1153.0

# %% [markdown]
# ## PLOT PSFS

# %%
pupil = sys.pupil
fields = [(sys.cfg['sources'][src]['position_x'], sys.cfg['sources'][src]['position_y']) for src in sys.cfg['sources']]

utils.plot_psfs_7(psfs=images, fields=fields)

# %% [markdown]
# ## PLOT WFES

# %%
opds_fields = copy.deepcopy(sys.opds_field)
opds_optics = copy.deepcopy(sys.opds_optics)
opds_truths = [opd_field + opd_optics for (opd_field, opd_optics) in zip(opds_fields, opds_optics)]

opds_fields_nominal = opds_fields

utils.plot_opds_7(opds=opds_fields, pupil=pupil, fields=fields)
utils.plot_opds_7(opds=opds_optics, pupil=pupil, fields=fields)
utils.plot_opds_7(opds=opds_truths, pupil=pupil, fields=fields)

# %% [markdown]
# ## SEMICIRCLE FOV
#
# Telescope designed with semicircle FOV in mind. Recreated here so that random source positions fall within this region. See "Large Etendue 3-Meter Unobscured Three Mirror Anastigmat Telescope for Astrophysics" by Kim et al. 2025 for more details.

# %%
fx = np.linspace(-16.2, 16.2, 325)
fy = np.linspace(-9.0, 4.8, 139)

Fx, Fy = np.meshgrid(fx, fy)

semicirc_fov = np.sqrt(Fx ** 2 + (Fy + 14.5) ** 2) <= 19.2
Fx_valid = Fx[semicirc_fov]
Fy_valid = Fy[semicirc_fov]

plt.imshow(semicirc_fov.get(), extent=[fx.min().get(), fx.max().get(), fy.min().get(), fy.max().get()])
plt.xlabel('arcmin')
plt.ylabel('arcmin')
plt.title('Telescope Semicircle FOV')
# Out:
# Text(0.5, 1.0, 'Telescope Semicircle FOV')

# %% [markdown]
# ## MONTE CARLO

# %%
misalignments = utils.load_pickle('/home/derbyk/src/ffpr/data/misalignments_cases_100_dec_50um_tilt_5as.pkl')

# %%
# SNR threshold
snr_thresh = 5

# number of sources
n_sources = 3

# system stuff
efl = sys.cfg['general']['f_eff']
pupil_dx = sys.cfg['optics']['m1']['diam'] / sys.cfg['general']['npix_pupil']
focal_dx = sys.cfg['detector']['dx_focal']

# set rng for repeatability on source positions
rng = np.random.default_rng(seed=73)

# stuff to save
data = {}

case = 1

for m in misalignments:

    print(f'CASE {case:03.0f} ----------------------------------')
    print()

    # get random source positions
    inds = rng.integers(low=0, high=Fx_valid.size, size=n_sources)
    new_positions = [(float(Fx_valid[i]), float(Fy_valid[i])) for i in inds]
    mags = [15 for _ in range(n_sources)]

    # send positions to model 
    sys.set_source_parameters(magnitudes=mags, positions=new_positions)

    # reset optics to nominal alignment
    sys.reset_optics()

    # get field dependent OPD at nominal alignment
    opds_fields_nominal = copy.deepcopy(sys.opds_field)

    # calculate RMS of diversity per field
    # diversity comes from field dependent OPD at nominal alignment
    rms_diversity_per_field = []
    for opd in opds_fields_nominal:
        opd -= np.mean(opd[pupil])
        rms_diversity_per_field.append(float(np.sqrt(np.mean(opd[pupil] ** 2))))

    # apply misalignment
    sys.move_optics(M1_motion=m['M1'], M2_motion=m['M4'], M3_motion=m['M4'], M4_motion=m['M4'])

    # get total OPDs per field
    opds_fields = copy.deepcopy(sys.opds_field)
    opds_optics = copy.deepcopy(sys.opds_optics)
    opds_truths = [opd_field + opd_optic for opd_field, opd_optic in zip(opds_fields, opds_optics)]

    # calculate RMS of ground truth OPDs per field
    rms_truth_per_field = []
    for opd in opds_truths:
        opd -= np.mean(opd[pupil])
        rms_truth_per_field.append(float(np.sqrt(np.mean(opd[pupil] ** 2))))

    # take images for FFPR
    dark = sys.get_dark(stacked_frames=1)
    images = [im - dark for im in sys.snap(stacked_frames=1)]

    # get image SNRs and filter
    noise_lvl = dark.std()
    masks = []
    snr_per_field = []
    for im in images:
        snr_per_field.append(float(im.max() / dark.std()))
        mask = im > noise_lvl * snr_thresh
        masks.append(mask)

    print(f'MEDIAN RMS OPD ACROSS FIELD = {np.median(np.array(rms_truth_per_field)):.2f} nm')
    print(f'MEDIAN IMAGE SNR ACROSS FIELD = {np.median(np.array(snr_per_field)):.1f}')
    print()

    # initialize FFPR
    opt = FFPR2(wvls=sys.wvls.tolist(), amp=sys.pupil, max_zernike=11, fields=new_positions, divs=opds_fields_nominal, efl=efl, 
                psfs=images, pupil_dx=pupil_dx, focal_dx=focal_dx, error=gain_invariant_error, masks=masks, jitter_kernel=sys.jitter_kernel)

    # BING BONG
    BING_BONG(opt=opt, modal_cleanup=True, zonal_cleanup=False,
              max_kicks=10, iter_per_bing_bong=10, iter_per_psf=10,
              max_ls=10, thresh_conv=1e-1, frac_conv=1e-2)

    # calculate estimate residuals
    opds_estimates = [pdpr.models[0].opd + pdpr.models[0].div for pdpr in opt.PDPR_list]
    opds_residuals = [estimate - truth for estimate, truth in zip(opds_estimates, opds_truths)]

    # get RMS of residual per field
    rms_residual_per_field = []
    for opd in opds_residuals:
        opd -= np.mean(opd[pupil])
        rms_residual_per_field.append(float(np.sqrt(np.mean(opd[pupil] ** 2))))

    print(f'MEDIAN RMS RESIDUAL ACROSS FIELD = {np.median(np.array(rms_residual_per_field)):.2f} nm')
    print()
    print()

    # save to data cube
    data.update({f'CASE{case:03.0f}' : {'RMS_TRUTH_PER_FIELD' : rms_truth_per_field,
                                        'RMS_RESIDUAL_PER_FIELD' : rms_residual_per_field,
                                        'RMS_DIVERSITY_PER_FIELD' : rms_diversity_per_field,
                                        'SNR_PER_FIELD' : snr_per_field,
                                        'FIELDS' : new_positions}})

    case += 1

utils.save_pickle('/home/derbyk/src/ffpr/sim_results/20260506_mc_misalignments_3stars_dec_50um_tilt_5as.pkl', data=data)
# Out:
# CASE 001 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 276.46 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 139.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.72e-01
# BONG 01 | f = 5.05e-01
# ---------------
# BING 02 | f = 2.37e-01
# BONG 02 | f = 2.13e-01
# ---------------
# BING 03 | f = 2.02e-01
# BONG 03 | f = 2.02e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 3.89e-01
# BONG 04 | f = 3.05e-01
# ---------------
# BING 05 | f = 2.78e-01
# BONG 05 | f = 2.70e-01
# ---------------
# BING 06 | f = 2.70e-01
# BONG 06 | f = 2.70e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 3.32e-01
# BONG 07 | f = 2.92e-01
# ---------------
# BING 08 | f = 2.34e-01
# BONG 08 | f = 2.16e-01
# ---------------
# BING 09 | f = 9.72e-02
# BONG 09 | f = 6.43e-02
# ---------------
# BING 10 | f = 5.51e-02
# BONG 10 | f = 5.51e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 39.94 nm
#
#
# CASE 002 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 361.01 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 107.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.76e-01
# BONG 01 | f = 5.46e-01
# ---------------
# BING 02 | f = 2.49e-01
# BONG 02 | f = 2.46e-01
# ---------------
# BING 03 | f = 2.38e-01
# BONG 03 | f = 2.33e-01
# ---------------
# BING 04 | f = 1.91e-01
# BONG 04 | f = 1.58e-01
# ---------------
# BING 05 | f = 1.29e-01
# BONG 05 | f = 1.26e-01
# ---------------
# BING 06 | f = 1.26e-01
# BONG 06 | f = 1.23e-01
# ---------------
# BING 07 | f = 1.23e-01
# BONG 07 | f = 1.23e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 2.61e-01
# BONG 08 | f = 2.28e-01
# ---------------
# BING 09 | f = 2.14e-01
# BONG 09 | f = 2.08e-01
# ---------------
# BING 10 | f = 1.93e-01
# BONG 10 | f = 1.49e-01
# ---------------
# BING 11 | f = 1.47e-01
# BONG 11 | f = 1.40e-01
# ---------------
# BING 12 | f = 1.40e-01
# BONG 12 | f = 1.40e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 6.28e-02
# BONG 13 | f = 6.20e-02
# ---------------
# BING 14 | f = 4.23e-02
# BONG 14 | f = 3.85e-02
# ---------------
# BING 15 | f = 3.85e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.54 nm
#
#
# CASE 003 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 316.05 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 166.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.38e-01
# BONG 01 | f = 3.33e-01
# ---------------
# BING 02 | f = 3.33e-01
# BONG 02 | f = 3.33e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 3.66e-01
# BONG 03 | f = 2.98e-01
# ---------------
# BING 04 | f = 2.24e-01
# BONG 04 | f = 2.16e-01
# ---------------
# BING 05 | f = 1.38e-01
# BONG 05 | f = 1.38e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 4.04e-01
# BONG 06 | f = 3.90e-01
# ---------------
# BING 07 | f = 3.90e-01
# BONG 07 | f = 3.90e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 2.40e-01
# BONG 08 | f = 2.35e-01
# ---------------
# BING 09 | f = 1.77e-01
# BONG 09 | f = 1.77e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 4.06e-01
# BONG 10 | f = 3.57e-01
# ---------------
# BING 11 | f = 2.69e-01
# BONG 11 | f = 2.31e-01
# ---------------
# BING 12 | f = 2.05e-01
# BONG 12 | f = 2.05e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 3.57e-01
# BONG 13 | f = 2.90e-01
# ---------------
# BING 14 | f = 2.32e-01
# BONG 14 | f = 2.32e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 1.29e-01
# BONG 15 | f = 1.26e-01
# ---------------
# BING 16 | f = 4.66e-02
# BONG 16 | f = 4.62e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 61.38 nm
#
#
# CASE 004 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 125.87 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 546.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.49e-01
# BONG 01 | f = 9.19e-02
# ---------------
# BING 02 | f = 7.25e-02
# BONG 02 | f = 6.49e-02
# ---------------
# BING 03 | f = 6.42e-02
# BONG 03 | f = 6.35e-02
# ---------------
# BING 04 | f = 6.34e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 181.35 nm
#
#
# CASE 005 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 256.49 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 208.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.10e-01
# BONG 01 | f = 2.05e-01
# ---------------
# BING 02 | f = 1.88e-01
# BONG 02 | f = 1.74e-01
# ---------------
# BING 03 | f = 1.74e-01
# BONG 03 | f = 1.74e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 2.92e-01
# BONG 04 | f = 2.50e-01
# ---------------
# BING 05 | f = 2.44e-01
# BONG 05 | f = 2.27e-01
# ---------------
# BING 06 | f = 2.27e-01
# BONG 06 | f = 2.27e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 1.16e-01
# BONG 07 | f = 1.16e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 4.70e-01
# BONG 08 | f = 2.18e-01
# ---------------
# BING 09 | f = 1.76e-01
# BONG 09 | f = 1.59e-01
# ---------------
# BING 10 | f = 1.49e-01
# BONG 10 | f = 1.38e-01
# ---------------
# BING 11 | f = 1.38e-01
# BONG 11 | f = 1.38e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 3.03e-01
# BONG 12 | f = 2.19e-01
# ---------------
# BING 13 | f = 2.09e-01
# BONG 13 | f = 1.83e-01
# ---------------
# BING 14 | f = 1.78e-01
# BONG 14 | f = 1.54e-01
# ---------------
# BING 15 | f = 1.44e-01
# BONG 15 | f = 1.37e-01
# ---------------
# BING 16 | f = 1.37e-01
# BONG 16 | f = 1.37e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 17 | f = 8.27e-02
# BONG 17 | f = 6.28e-02
# ---------------
# BING 18 | f = 3.04e-02
# BONG 18 | f = 3.04e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 25.07 nm
#
#
# CASE 006 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 221.44 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 218.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.23e-01
# BONG 01 | f = 2.22e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 3.05e-01
# BONG 02 | f = 2.75e-01
# ---------------
# BING 03 | f = 2.74e-01
# BONG 03 | f = 2.67e-01
# ---------------
# BING 04 | f = 2.30e-01
# BONG 04 | f = 2.17e-01
# ---------------
# BING 05 | f = 2.16e-01
# BONG 05 | f = 1.96e-01
# ---------------
# BING 06 | f = 1.75e-01
# BONG 06 | f = 1.54e-01
# ---------------
# BING 07 | f = 1.40e-01
# BONG 07 | f = 1.36e-01
# ---------------
# BING 08 | f = 1.36e-01
# BONG 08 | f = 1.33e-01
# ---------------
# BING 09 | f = 1.32e-01
# BONG 09 | f = 1.32e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 2.28e-01
# BONG 10 | f = 1.86e-01
# ---------------
# BING 11 | f = 1.47e-01
# BONG 11 | f = 1.09e-01
# ---------------
# BING 12 | f = 1.09e-01
# BONG 12 | f = 1.07e-01
# ---------------
# BING 13 | f = 6.66e-02
# BONG 13 | f = 5.18e-02
# ---------------
# BING 14 | f = 4.41e-02
# BONG 14 | f = 4.25e-02
# ---------------
# BING 15 | f = 3.93e-02
# BONG 15 | f = 3.92e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 399.17 nm
#
#
# CASE 007 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 243.56 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 97.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 7.01e-01
# BONG 01 | f = 6.75e-01
# ---------------
# BING 02 | f = 6.75e-01
# BONG 02 | f = 6.75e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 6.80e-01
# BONG 03 | f = 6.59e-01
# ---------------
# BING 04 | f = 4.80e-01
# BONG 04 | f = 4.80e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 6.74e-01
# BONG 05 | f = 5.83e-01
# ---------------
# BING 06 | f = 4.84e-01
# BONG 06 | f = 4.84e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 5.69e-01
# BONG 07 | f = 5.67e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 4.31e-01
# BONG 08 | f = 3.59e-01
# ---------------
# BING 09 | f = 3.40e-01
# BONG 09 | f = 3.37e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 3.18e-01
# BONG 10 | f = 3.05e-01
# ---------------
# BING 11 | f = 1.80e-01
# BONG 11 | f = 1.42e-01
# ---------------
# BING 12 | f = 1.42e-01
# BONG 12 | f = 1.42e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 1.30e-01
# BONG 13 | f = 1.17e-01
# ---------------
# BING 14 | f = 7.91e-02
# BONG 14 | f = 7.91e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 30.89 nm
#
#
# CASE 008 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 274.14 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 206.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 7.05e-02
# BONG 01 | f = 5.44e-02
# ---------------
# BING 02 | f = 3.32e-02
# BONG 02 | f = 3.26e-02
# ---------------
# BING 03 | f = 3.19e-02
# BONG 03 | f = 3.19e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 34.80 nm
#
#
# CASE 009 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 331.53 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 126.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.31e-01
# BONG 01 | f = 1.26e-01
# ---------------
# BING 02 | f = 8.14e-02
# BONG 02 | f = 6.40e-02
# ---------------
# BING 03 | f = 5.66e-02
# BONG 03 | f = 5.39e-02
# ---------------
# BING 04 | f = 5.39e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 72.18 nm
#
#
# CASE 010 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 295.82 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 137.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.07e-01
# BONG 01 | f = 1.02e-01
# ---------------
# BING 02 | f = 1.02e-01
# BONG 02 | f = 1.02e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 3.49e-01
# BONG 03 | f = 3.09e-01
# ---------------
# BING 04 | f = 3.05e-01
# BONG 04 | f = 3.05e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 1.04e-01
# BONG 05 | f = 1.01e-01
# ---------------
# BING 06 | f = 1.01e-01
# BONG 06 | f = 1.01e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 2.14e-01
# BONG 07 | f = 1.96e-01
# ---------------
# BING 08 | f = 1.95e-01
# BONG 08 | f = 1.95e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 4.37e-01
# BONG 09 | f = 4.03e-01
# ---------------
# BING 10 | f = 3.95e-01
# BONG 10 | f = 3.95e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 3.87e-01
# BONG 11 | f = 3.59e-01
# ---------------
# BING 12 | f = 3.59e-01
# BONG 12 | f = 3.59e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 4.89e-01
# BONG 13 | f = 3.92e-01
# ---------------
# BING 14 | f = 3.59e-01
# BONG 14 | f = 3.59e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 1.41e-01
# BONG 15 | f = 1.16e-01
# ---------------
# BING 16 | f = 1.16e-01
# BONG 16 | f = 1.16e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 17 | f = 3.43e-01
# BONG 17 | f = 3.13e-01
# ---------------
# BING 18 | f = 3.13e-01
# BONG 18 | f = 3.13e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 19 | f = 2.74e-01
# BONG 19 | f = 1.86e-01
# ---------------
# BING 20 | f = 1.86e-01
# BONG 20 | f = 1.86e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 21 | f = 2.82e-01
# BONG 21 | f = 2.48e-01
# ---------------
# BING 22 | f = 2.39e-01
# BONG 22 | f = 2.39e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 344.01 nm
#
#
# CASE 011 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 326.44 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 89.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.22e-01
# BONG 01 | f = 6.05e-01
# ---------------
# BING 02 | f = 6.05e-01
# BONG 02 | f = 6.05e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 4.23e-01
# BONG 03 | f = 3.71e-01
# ---------------
# BING 04 | f = 2.61e-01
# BONG 04 | f = 2.61e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 2.07e-01
# BONG 05 | f = 2.07e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 4.62e-01
# BONG 06 | f = 3.38e-01
# ---------------
# BING 07 | f = 2.19e-01
# BONG 07 | f = 2.17e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 2.31e-01
# BONG 08 | f = 1.46e-01
# ---------------
# BING 09 | f = 1.46e-01
# BONG 09 | f = 1.44e-01
# ---------------
# BING 10 | f = 1.44e-01
# BONG 10 | f = 1.44e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 3.68e-01
# BONG 11 | f = 3.01e-01
# ---------------
# BING 12 | f = 1.78e-01
# BONG 12 | f = 1.17e-01
# ---------------
# BING 13 | f = 7.94e-02
# BONG 13 | f = 7.78e-02
# ---------------
# BING 14 | f = 7.44e-02
# BONG 14 | f = 7.21e-02
# ---------------
# BING 15 | f = 7.21e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 531.94 nm
#
#
# CASE 012 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 325.50 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 135.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.05e-01
# BONG 01 | f = 5.04e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 4.57e-01
# BONG 02 | f = 4.02e-01
# ---------------
# BING 03 | f = 3.59e-01
# BONG 03 | f = 3.29e-01
# ---------------
# BING 04 | f = 3.27e-01
# BONG 04 | f = 3.27e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 8.12e-01
# BONG 05 | f = 3.41e-01
# ---------------
# BING 06 | f = 2.59e-01
# BONG 06 | f = 2.59e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 4.16e-01
# BONG 07 | f = 3.68e-01
# ---------------
# BING 08 | f = 2.14e-01
# BONG 08 | f = 2.03e-01
# ---------------
# BING 09 | f = 1.16e-01
# BONG 09 | f = 1.07e-01
# ---------------
# BING 10 | f = 1.07e-01
# BONG 10 | f = 1.07e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 5.51e-01
# BONG 11 | f = 5.44e-01
# ---------------
# BING 12 | f = 5.44e-01
# BONG 12 | f = 5.44e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 2.02e-01
# BONG 13 | f = 2.02e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 1.70e-01
# BONG 14 | f = 1.66e-01
# ---------------
# BING 15 | f = 1.66e-01
# BONG 15 | f = 1.66e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 3.26e-01
# BONG 16 | f = 2.21e-01
# ---------------
# BING 17 | f = 2.20e-01
# BONG 17 | f = 2.20e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 18 | f = 2.21e-01
# BONG 18 | f = 2.14e-01
# ---------------
# BING 19 | f = 1.24e-01
# BONG 19 | f = 1.17e-01
# ---------------
# BING 20 | f = 4.45e-02
# BONG 20 | f = 4.33e-02
# ---------------
# BING 21 | f = 4.33e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 53.85 nm
#
#
# CASE 013 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 332.07 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 138.1
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.65e-01
# BONG 01 | f = 5.65e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 3.55e-01
# BONG 02 | f = 3.09e-01
# ---------------
# BING 03 | f = 1.80e-01
# BONG 03 | f = 1.66e-01
# ---------------
# BING 04 | f = 1.49e-01
# BONG 04 | f = 1.47e-01
# ---------------
# BING 05 | f = 1.42e-01
# BONG 05 | f = 1.42e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 1.17e-01
# BONG 06 | f = 9.01e-02
# ---------------
# BING 07 | f = 4.57e-02
# BONG 07 | f = 4.52e-02
# ---------------
# BING 08 | f = 4.33e-02
# BONG 08 | f = 4.29e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 34.79 nm
#
#
# CASE 014 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 106.54 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 654.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.76e-03
# BONG 01 | f = 5.96e-03
# ---------------
# BING 02 | f = 4.88e-03
# BONG 02 | f = 4.82e-03
# ---------------
# BING 03 | f = 4.82e-03
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 20.96 nm
#
#
# CASE 015 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 70.11 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 958.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.56e-03
# BONG 01 | f = 3.24e-03
# ---------------
# BING 02 | f = 3.21e-03
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.01 nm
#
#
# CASE 016 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 434.60 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 122.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.18e-01
# BONG 01 | f = 1.88e-01
# ---------------
# BING 02 | f = 1.07e-01
# BONG 02 | f = 9.94e-02
# ---------------
# BING 03 | f = 9.94e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 207.14 nm
#
#
# CASE 017 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 107.11 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 675.1
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.96e-03
# BONG 01 | f = 5.42e-03
# ---------------
# BING 02 | f = 5.42e-03
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 21.45 nm
#
#
# CASE 018 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 290.88 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 179.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 7.61e-02
# BONG 01 | f = 7.61e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 135.87 nm
#
#
# CASE 019 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 427.03 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 153.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.77e-01
# BONG 01 | f = 5.72e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 3.53e-01
# BONG 02 | f = 2.63e-01
# ---------------
# BING 03 | f = 1.76e-01
# BONG 03 | f = 1.76e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 5.82e-01
# BONG 04 | f = 5.82e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 6.14e-01
# BONG 05 | f = 6.03e-01
# ---------------
# BING 06 | f = 5.57e-01
# BONG 06 | f = 5.52e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 5.97e-01
# BONG 07 | f = 5.94e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 4.88e-01
# BONG 08 | f = 3.27e-01
# ---------------
# BING 09 | f = 2.21e-01
# BONG 09 | f = 2.19e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 1.76e-01
# BONG 10 | f = 1.70e-01
# ---------------
# BING 11 | f = 7.50e-02
# BONG 11 | f = 6.47e-02
# ---------------
# BING 12 | f = 6.47e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 144.13 nm
#
#
# CASE 020 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 282.03 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 151.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 7.01e-01
# BONG 01 | f = 3.42e-01
# ---------------
# BING 02 | f = 1.82e-01
# BONG 02 | f = 1.57e-01
# ---------------
# BING 03 | f = 1.57e-01
# BONG 03 | f = 1.46e-01
# ---------------
# BING 04 | f = 1.45e-01
# BONG 04 | f = 1.45e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 3.80e-01
# BONG 05 | f = 3.49e-01
# ---------------
# BING 06 | f = 2.78e-01
# BONG 06 | f = 2.71e-01
# ---------------
# BING 07 | f = 2.71e-01
# BONG 07 | f = 2.71e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 1.16e-01
# BONG 08 | f = 1.16e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 5.97e-01
# BONG 09 | f = 4.29e-01
# ---------------
# BING 10 | f = 1.95e-01
# BONG 10 | f = 1.68e-01
# ---------------
# BING 11 | f = 7.36e-02
# BONG 11 | f = 6.72e-02
# ---------------
# BING 12 | f = 4.72e-02
# BONG 12 | f = 4.38e-02
# ---------------
# BING 13 | f = 4.16e-02
# BONG 13 | f = 4.07e-02
# ---------------
# BING 14 | f = 3.89e-02
# BONG 14 | f = 3.89e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 31.90 nm
#
#
# CASE 021 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 321.71 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 175.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.03e-01
# BONG 01 | f = 1.85e-01
# ---------------
# BING 02 | f = 4.07e-02
# BONG 02 | f = 3.93e-02
# ---------------
# BING 03 | f = 3.33e-02
# BONG 03 | f = 3.29e-02
# ---------------
# BING 04 | f = 3.29e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 28.57 nm
#
#
# CASE 022 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 418.76 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 96.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.94e-01
# BONG 01 | f = 2.21e-01
# ---------------
# BING 02 | f = 1.54e-01
# BONG 02 | f = 1.51e-01
# ---------------
# BING 03 | f = 1.40e-01
# BONG 03 | f = 1.40e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 4.87e-01
# BONG 04 | f = 3.03e-01
# ---------------
# BING 05 | f = 2.25e-01
# BONG 05 | f = 2.23e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 2.13e-01
# BONG 06 | f = 2.13e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 5.89e-01
# BONG 07 | f = 5.64e-01
# ---------------
# BING 08 | f = 5.64e-01
# BONG 08 | f = 5.64e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 6.05e-01
# BONG 09 | f = 5.71e-01
# ---------------
# BING 10 | f = 5.71e-01
# BONG 10 | f = 5.71e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 2.19e-01
# BONG 11 | f = 2.17e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 1.97e-01
# BONG 12 | f = 1.97e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 2.35e-01
# BONG 13 | f = 2.35e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 2.09e-01
# BONG 14 | f = 1.97e-01
# ---------------
# BING 15 | f = 1.97e-01
# BONG 15 | f = 1.97e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 8.31e-01
# BONG 16 | f = 6.61e-01
# ---------------
# BING 17 | f = 6.61e-01
# BONG 17 | f = 6.61e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 18 | f = 2.43e-01
# BONG 18 | f = 2.43e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 381.52 nm
#
#
# CASE 023 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 230.61 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 147.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.54e-01
# BONG 01 | f = 3.73e-01
# ---------------
# BING 02 | f = 2.01e-01
# BONG 02 | f = 1.36e-01
# ---------------
# BING 03 | f = 1.09e-01
# BONG 03 | f = 1.02e-01
# ---------------
# BING 04 | f = 1.02e-01
# BONG 04 | f = 1.02e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 2.95e-01
# BONG 05 | f = 1.36e-01
# ---------------
# BING 06 | f = 1.19e-01
# BONG 06 | f = 1.11e-01
# ---------------
# BING 07 | f = 1.11e-01
# BONG 07 | f = 1.11e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 3.10e-01
# BONG 08 | f = 1.58e-01
# ---------------
# BING 09 | f = 1.54e-01
# BONG 09 | f = 1.54e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 5.04e-01
# BONG 10 | f = 4.57e-01
# ---------------
# BING 11 | f = 4.57e-01
# BONG 11 | f = 4.57e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 2.94e-01
# BONG 12 | f = 1.26e-01
# ---------------
# BING 13 | f = 1.21e-01
# BONG 13 | f = 1.19e-01
# ---------------
# BING 14 | f = 1.19e-01
# BONG 14 | f = 1.19e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 4.66e-01
# BONG 15 | f = 3.63e-01
# ---------------
# BING 16 | f = 3.63e-01
# BONG 16 | f = 3.62e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 17 | f = 5.59e-01
# BONG 17 | f = 4.15e-01
# ---------------
# BING 18 | f = 4.15e-01
# BONG 18 | f = 4.15e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 19 | f = 3.47e-01
# BONG 19 | f = 2.54e-01
# ---------------
# BING 20 | f = 1.51e-01
# BONG 20 | f = 1.21e-01
# ---------------
# BING 21 | f = 1.21e-01
# BONG 21 | f = 1.21e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 22 | f = 4.50e-01
# BONG 22 | f = 3.55e-01
# ---------------
# BING 23 | f = 1.34e-01
# BONG 23 | f = 1.03e-01
# ---------------
# BING 24 | f = 1.03e-01
# BONG 24 | f = 1.03e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 25 | f = 3.03e-01
# BONG 25 | f = 1.36e-01
# ---------------
# BING 26 | f = 1.34e-01
# BONG 26 | f = 1.34e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 27 | f = 3.08e-01
# BONG 27 | f = 1.81e-01
# ---------------
# BING 28 | f = 1.32e-01
# BONG 28 | f = 1.20e-01
# ---------------
# BING 29 | f = 1.20e-01
# BONG 29 | f = 1.20e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 440.86 nm
#
#
# CASE 024 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 201.94 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 151.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.41e-01
# BONG 01 | f = 4.19e-01
# ---------------
# BING 02 | f = 4.19e-01
# BONG 02 | f = 4.19e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 5.08e-01
# BONG 03 | f = 4.85e-01
# ---------------
# BING 04 | f = 4.85e-01
# BONG 04 | f = 4.85e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 2.53e-01
# BONG 05 | f = 2.53e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 2.89e-01
# BONG 06 | f = 2.89e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 1.54e-01
# BONG 07 | f = 8.09e-02
# ---------------
# BING 08 | f = 4.19e-02
# BONG 08 | f = 4.19e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.41 nm
#
#
# CASE 025 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 369.51 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 104.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.61e-01
# BONG 01 | f = 2.38e-01
# ---------------
# BING 02 | f = 2.00e-01
# BONG 02 | f = 1.94e-01
# ---------------
# BING 03 | f = 1.59e-01
# BONG 03 | f = 1.55e-01
# ---------------
# BING 04 | f = 1.55e-01
# BONG 04 | f = 1.55e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 4.61e-01
# BONG 05 | f = 3.47e-01
# ---------------
# BING 06 | f = 2.18e-01
# BONG 06 | f = 2.18e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 2.62e-01
# BONG 07 | f = 2.10e-01
# ---------------
# BING 08 | f = 1.52e-01
# BONG 08 | f = 1.46e-01
# ---------------
# BING 09 | f = 6.83e-02
# BONG 09 | f = 6.81e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 104.84 nm
#
#
# CASE 026 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 175.07 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 312.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.65e-01
# BONG 01 | f = 3.63e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 4.97e-02
# BONG 02 | f = 4.91e-02
# ---------------
# BING 03 | f = 3.14e-02
# BONG 03 | f = 3.11e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 21.72 nm
#
#
# CASE 027 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 384.40 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 166.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.14e-01
# BONG 01 | f = 3.67e-01
# ---------------
# BING 02 | f = 2.34e-01
# BONG 02 | f = 2.28e-01
# ---------------
# BING 03 | f = 1.88e-01
# BONG 03 | f = 1.26e-01
# ---------------
# BING 04 | f = 7.50e-02
# BONG 04 | f = 6.55e-02
# ---------------
# BING 05 | f = 4.71e-02
# BONG 05 | f = 4.39e-02
# ---------------
# BING 06 | f = 3.91e-02
# BONG 06 | f = 3.84e-02
# ---------------
# BING 07 | f = 3.84e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 50.70 nm
#
#
# CASE 028 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 323.20 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 183.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.49e-01
# BONG 01 | f = 1.31e-01
# ---------------
# BING 02 | f = 1.07e-01
# BONG 02 | f = 7.56e-02
# ---------------
# BING 03 | f = 4.31e-02
# BONG 03 | f = 4.27e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 69.64 nm
#
#
# CASE 029 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 227.67 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 138.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.44e-01
# BONG 01 | f = 4.35e-01
# ---------------
# BING 02 | f = 4.35e-01
# BONG 02 | f = 4.35e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 1.18e-01
# BONG 03 | f = 8.01e-02
# ---------------
# BING 04 | f = 7.33e-02
# BONG 04 | f = 7.24e-02
# ---------------
# BING 05 | f = 7.24e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 26.77 nm
#
#
# CASE 030 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 374.05 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 124.1
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.08e-01
# BONG 01 | f = 2.79e-01
# ---------------
# BING 02 | f = 1.11e-01
# BONG 02 | f = 1.06e-01
# ---------------
# BING 03 | f = 5.07e-02
# BONG 03 | f = 4.10e-02
# ---------------
# BING 04 | f = 4.10e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 41.37 nm
#
#
# CASE 031 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 192.78 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 136.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.58e-01
# BONG 01 | f = 2.18e-01
# ---------------
# BING 02 | f = 1.94e-01
# BONG 02 | f = 1.72e-01
# ---------------
# BING 03 | f = 1.52e-01
# BONG 03 | f = 1.40e-01
# ---------------
# BING 04 | f = 1.40e-01
# BONG 04 | f = 1.40e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 1.09e-01
# BONG 05 | f = 1.09e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 2.18e-01
# BONG 06 | f = 2.01e-01
# ---------------
# BING 07 | f = 1.98e-01
# BONG 07 | f = 1.98e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 4.12e-01
# BONG 08 | f = 4.12e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 3.09e-01
# BONG 09 | f = 1.74e-01
# ---------------
# BING 10 | f = 1.51e-01
# BONG 10 | f = 1.39e-01
# ---------------
# BING 11 | f = 1.38e-01
# BONG 11 | f = 1.38e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 1.99e-01
# BONG 12 | f = 1.63e-01
# ---------------
# BING 13 | f = 1.03e-01
# BONG 13 | f = 1.03e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 3.84e-01
# BONG 14 | f = 2.36e-01
# ---------------
# BING 15 | f = 2.36e-01
# BONG 15 | f = 1.24e-01
# ---------------
# BING 16 | f = 5.53e-02
# BONG 16 | f = 4.85e-02
# ---------------
# BING 17 | f = 4.70e-02
# BONG 17 | f = 4.70e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 25.51 nm
#
#
# CASE 032 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 124.65 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 411.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.20e-01
# BONG 01 | f = 1.79e-01
# ---------------
# BING 02 | f = 1.78e-01
# BONG 02 | f = 1.78e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 2.02e-01
# BONG 03 | f = 1.60e-01
# ---------------
# BING 04 | f = 1.36e-01
# BONG 04 | f = 1.21e-01
# ---------------
# BING 05 | f = 1.18e-01
# BONG 05 | f = 1.15e-01
# ---------------
# BING 06 | f = 1.15e-01
# BONG 06 | f = 1.15e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 1.88e-02
# BONG 07 | f = 1.69e-02
# ---------------
# BING 08 | f = 1.23e-02
# BONG 08 | f = 1.20e-02
# ---------------
# BING 09 | f = 1.17e-02
# BONG 09 | f = 1.16e-02
# ---------------
# BING 10 | f = 1.14e-02
# BONG 10 | f = 1.13e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 21.63 nm
#
#
# CASE 033 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 174.10 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 256.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.27e-01
# BONG 01 | f = 1.07e-01
# ---------------
# BING 02 | f = 1.04e-01
# BONG 02 | f = 1.01e-01
# ---------------
# BING 03 | f = 9.97e-02
# BONG 03 | f = 8.05e-02
# ---------------
# BING 04 | f = 6.83e-02
# BONG 04 | f = 6.49e-02
# ---------------
# BING 05 | f = 6.49e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 280.26 nm
#
#
# CASE 034 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 419.50 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 79.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.50e-01
# BONG 01 | f = 3.50e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 6.81e-01
# BONG 02 | f = 6.79e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 6.09e-01
# BONG 03 | f = 6.07e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 3.91e-01
# BONG 04 | f = 3.85e-01
# ---------------
# BING 05 | f = 3.22e-01
# BONG 05 | f = 3.22e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 3.59e-01
# BONG 06 | f = 3.59e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 4.43e-01
# BONG 07 | f = 4.43e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 5.07e-01
# BONG 08 | f = 5.07e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 3.30e-01
# BONG 09 | f = 3.30e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 3.60e-01
# BONG 10 | f = 3.60e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 3.57e-01
# BONG 11 | f = 3.57e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 4.43e-01
# BONG 12 | f = 4.43e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 302.15 nm
#
#
# CASE 035 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 238.35 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 258.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.14e-01
# BONG 01 | f = 7.64e-02
# ---------------
# BING 02 | f = 4.66e-02
# BONG 02 | f = 4.65e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 35.46 nm
#
#
# CASE 036 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 139.87 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 404.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 7.58e-02
# BONG 01 | f = 2.90e-02
# ---------------
# BING 02 | f = 1.52e-02
# BONG 02 | f = 1.47e-02
# ---------------
# BING 03 | f = 1.43e-02
# BONG 03 | f = 1.42e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 28.98 nm
#
#
# CASE 037 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 372.19 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 172.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.42e-01
# BONG 01 | f = 3.65e-01
# ---------------
# BING 02 | f = 2.32e-01
# BONG 02 | f = 2.29e-01
# ---------------
# BING 03 | f = 2.19e-01
# BONG 03 | f = 2.18e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 1.83e-01
# BONG 04 | f = 1.83e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 5.18e-01
# BONG 05 | f = 4.84e-01
# ---------------
# BING 06 | f = 3.61e-01
# BONG 06 | f = 3.43e-01
# ---------------
# BING 07 | f = 3.43e-01
# BONG 07 | f = 3.43e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 6.06e-01
# BONG 08 | f = 5.21e-01
# ---------------
# BING 09 | f = 2.88e-01
# BONG 09 | f = 2.04e-01
# ---------------
# BING 10 | f = 2.02e-01
# BONG 10 | f = 2.02e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 2.54e-01
# BONG 11 | f = 2.14e-01
# ---------------
# BING 12 | f = 1.34e-01
# BONG 12 | f = 1.34e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 3.49e-01
# BONG 13 | f = 2.52e-01
# ---------------
# BING 14 | f = 2.30e-01
# BONG 14 | f = 2.30e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 2.37e-01
# BONG 15 | f = 1.91e-01
# ---------------
# BING 16 | f = 1.78e-01
# BONG 16 | f = 1.56e-01
# ---------------
# BING 17 | f = 1.25e-01
# BONG 17 | f = 1.09e-01
# ---------------
# BING 18 | f = 6.61e-02
# BONG 18 | f = 5.52e-02
# ---------------
# BING 19 | f = 5.25e-02
# BONG 19 | f = 5.05e-02
# ---------------
# BING 20 | f = 4.16e-02
# BONG 20 | f = 4.07e-02
# ---------------
# BING 21 | f = 4.02e-02
# BONG 21 | f = 3.99e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 49.54 nm
#
#
# CASE 038 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 393.75 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 122.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.55e-01
# BONG 01 | f = 2.40e-01
# ---------------
# BING 02 | f = 2.39e-01
# BONG 02 | f = 2.39e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 3.06e-01
# BONG 03 | f = 2.66e-01
# ---------------
# BING 04 | f = 2.06e-01
# BONG 04 | f = 2.06e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 1.01e-01
# BONG 05 | f = 1.01e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 3.79e-01
# BONG 06 | f = 3.49e-01
# ---------------
# BING 07 | f = 3.22e-01
# BONG 07 | f = 3.13e-01
# ---------------
# BING 08 | f = 3.09e-01
# BONG 08 | f = 3.06e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 8.18e-01
# BONG 09 | f = 4.63e-01
# ---------------
# BING 10 | f = 3.90e-01
# BONG 10 | f = 3.90e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 1.90e-01
# BONG 11 | f = 1.90e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 1.73e-01
# BONG 12 | f = 1.73e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 2.71e-01
# BONG 13 | f = 2.45e-01
# ---------------
# BING 14 | f = 2.10e-01
# BONG 14 | f = 2.10e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 2.52e-01
# BONG 15 | f = 2.52e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 2.19e-01
# BONG 16 | f = 2.19e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 17 | f = 1.44e-01
# BONG 17 | f = 1.44e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 302.23 nm
#
#
# CASE 039 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 81.24 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 838.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 8.67e-03
# BONG 01 | f = 7.34e-03
# ---------------
# BING 02 | f = 5.99e-03
# BONG 02 | f = 5.95e-03
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 21.96 nm
#
#
# CASE 040 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 362.28 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 141.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.56e-01
# BONG 01 | f = 1.41e-01
# ---------------
# BING 02 | f = 6.87e-02
# BONG 02 | f = 5.98e-02
# ---------------
# BING 03 | f = 5.37e-02
# BONG 03 | f = 5.32e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 27.47 nm
#
#
# CASE 041 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 420.36 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 152.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.32e-01
# BONG 01 | f = 1.16e-01
# ---------------
# BING 02 | f = 9.67e-02
# BONG 02 | f = 9.67e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 264.62 nm
#
#
# CASE 042 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 255.52 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 174.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.79e-01
# BONG 01 | f = 3.52e-01
# ---------------
# BING 02 | f = 3.52e-01
# BONG 02 | f = 3.52e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 5.41e-01
# BONG 03 | f = 5.32e-01
# ---------------
# BING 04 | f = 4.62e-01
# BONG 04 | f = 4.31e-01
# ---------------
# BING 05 | f = 2.68e-01
# BONG 05 | f = 2.62e-01
# ---------------
# BING 06 | f = 6.66e-02
# BONG 06 | f = 3.31e-02
# ---------------
# BING 07 | f = 2.96e-02
# BONG 07 | f = 2.92e-02
# ---------------
# BING 08 | f = 2.92e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 26.03 nm
#
#
# CASE 043 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 101.53 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 528.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.56e-02
# BONG 01 | f = 1.25e-02
# ---------------
# BING 02 | f = 7.87e-03
# BONG 02 | f = 7.65e-03
# ---------------
# BING 03 | f = 7.57e-03
# BONG 03 | f = 7.56e-03
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.54 nm
#
#
# CASE 044 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 242.09 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 125.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.41e-01
# BONG 01 | f = 2.79e-01
# ---------------
# BING 02 | f = 2.05e-01
# BONG 02 | f = 1.76e-01
# ---------------
# BING 03 | f = 1.50e-01
# BONG 03 | f = 1.42e-01
# ---------------
# BING 04 | f = 1.19e-01
# BONG 04 | f = 1.19e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 1.23e-01
# BONG 05 | f = 8.16e-02
# ---------------
# BING 06 | f = 5.69e-02
# BONG 06 | f = 5.69e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.61 nm
#
#
# CASE 045 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 102.87 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 490.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.79e-02
# BONG 01 | f = 1.39e-02
# ---------------
# BING 02 | f = 6.55e-03
# BONG 02 | f = 6.55e-03
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.92 nm
#
#
# CASE 046 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 310.62 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 172.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.53e-01
# BONG 01 | f = 3.47e-01
# ---------------
# BING 02 | f = 3.01e-01
# BONG 02 | f = 3.00e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 3.56e-01
# BONG 03 | f = 3.45e-01
# ---------------
# BING 04 | f = 3.40e-01
# BONG 04 | f = 3.34e-01
# ---------------
# BING 05 | f = 3.34e-01
# BONG 05 | f = 3.34e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 1.10e-01
# BONG 06 | f = 9.17e-02
# ---------------
# BING 07 | f = 5.22e-02
# BONG 07 | f = 5.03e-02
# ---------------
# BING 08 | f = 5.02e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 41.04 nm
#
#
# CASE 047 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 295.95 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 139.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.06e-01
# BONG 01 | f = 9.29e-02
# ---------------
# BING 02 | f = 4.31e-02
# BONG 02 | f = 3.79e-02
# ---------------
# BING 03 | f = 3.79e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 34.04 nm
#
#
# CASE 048 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 238.22 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 279.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.62e-02
# BONG 01 | f = 3.01e-02
# ---------------
# BING 02 | f = 2.20e-02
# BONG 02 | f = 2.20e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.62 nm
#
#
# CASE 049 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 284.95 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 155.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.47e-01
# BONG 01 | f = 1.70e-01
# ---------------
# BING 02 | f = 4.67e-02
# BONG 02 | f = 4.11e-02
# ---------------
# BING 03 | f = 4.11e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 519.40 nm
#
#
# CASE 050 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 297.76 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 139.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.68e-01
# BONG 01 | f = 5.56e-01
# ---------------
# BING 02 | f = 5.27e-01
# BONG 02 | f = 4.78e-01
# ---------------
# BING 03 | f = 3.14e-01
# BONG 03 | f = 3.10e-01
# ---------------
# BING 04 | f = 3.10e-01
# BONG 04 | f = 3.10e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 5.88e-01
# BONG 05 | f = 5.85e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ...
# ---------------
# BING 14 | f = 4.95e-01
# BONG 14 | f = 3.87e-01
# ---------------
# BING 15 | f = 3.87e-01
# BONG 15 | f = 3.87e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 9.07e-01
# BONG 16 | f = 9.07e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 17 | f = 1.31e-01
# BONG 17 | f = 9.54e-02
# ---------------
# BING 18 | f = 7.46e-02
# BONG 18 | f = 7.28e-02
# ---------------
# BING 19 | f = 7.28e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 31.54 nm
#
#
# CASE 084 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 275.66 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 145.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.38e-01
# BONG 01 | f = 3.38e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 3.62e-01
# BONG 02 | f = 2.97e-01
# ---------------
# BING 03 | f = 2.42e-01
# BONG 03 | f = 2.23e-01
# ---------------
# BING 04 | f = 1.78e-01
# BONG 04 | f = 1.77e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 6.86e-01
# BONG 05 | f = 6.48e-01
# ---------------
# BING 06 | f = 6.48e-01
# BONG 06 | f = 6.48e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 1.32e-01
# BONG 07 | f = 1.24e-01
# ---------------
# BING 08 | f = 5.61e-02
# BONG 08 | f = 5.44e-02
# ---------------
# BING 09 | f = 5.44e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 36.47 nm
#
#
# CASE 085 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 284.82 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 135.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 7.20e-02
# BONG 01 | f = 6.02e-02
# ---------------
# BING 02 | f = 6.02e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 51.17 nm
#
#
# CASE 086 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 272.82 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 194.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.91e-01
# BONG 01 | f = 2.87e-01
# ---------------
# BING 02 | f = 2.39e-01
# BONG 02 | f = 2.26e-01
# ---------------
# BING 03 | f = 2.19e-01
# BONG 03 | f = 2.12e-01
# ---------------
# BING 04 | f = 2.12e-01
# BONG 04 | f = 2.12e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 2.42e-01
# BONG 05 | f = 2.34e-01
# ---------------
# BING 06 | f = 1.88e-01
# BONG 06 | f = 1.84e-01
# ---------------
# BING 07 | f = 1.83e-01
# BONG 07 | f = 1.81e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 7.06e-02
# BONG 08 | f = 7.06e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 37.53 nm
#
#
# CASE 087 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 234.37 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 270.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.32e-02
# BONG 01 | f = 2.14e-02
# ---------------
# BING 02 | f = 1.99e-02
# BONG 02 | f = 1.99e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.37 nm
#
#
# CASE 088 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 170.56 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 143.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.97e-01
# BONG 01 | f = 2.04e-01
# ---------------
# BING 02 | f = 1.46e-01
# BONG 02 | f = 1.30e-01
# ---------------
# BING 03 | f = 1.30e-01
# BONG 03 | f = 1.30e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 1.93e-01
# BONG 04 | f = 1.00e-01
# ---------------
# BING 05 | f = 1.00e-01
# BONG 05 | f = 1.00e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 1.51e-01
# BONG 06 | f = 1.29e-01
# ---------------
# BING 07 | f = 1.29e-01
# BONG 07 | f = 1.29e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 4.83e-01
# BONG 08 | f = 3.87e-01
# ---------------
# BING 09 | f = 1.99e-01
# BONG 09 | f = 1.99e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 1.62e-01
# BONG 10 | f = 1.36e-01
# ---------------
# BING 11 | f = 1.34e-01
# BONG 11 | f = 1.34e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 2.33e-01
# BONG 12 | f = 1.08e-01
# ---------------
# BING 13 | f = 1.08e-01
# BONG 13 | f = 1.08e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 1.94e-01
# BONG 14 | f = 1.04e-01
# ---------------
# BING 15 | f = 1.04e-01
# BONG 15 | f = 1.04e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 3.30e-01
# BONG 16 | f = 2.43e-01
# ---------------
# BING 17 | f = 2.43e-01
# BONG 17 | f = 2.34e-01
# ---------------
# BING 18 | f = 2.08e-01
# BONG 18 | f = 2.03e-01
# ---------------
# BING 19 | f = 2.03e-01
# BONG 19 | f = 2.03e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 20 | f = 1.54e-01
# BONG 20 | f = 1.33e-01
# ---------------
# BING 21 | f = 1.33e-01
# BONG 21 | f = 1.33e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 22 | f = 2.00e-01
# BONG 22 | f = 1.39e-01
# ---------------
# BING 23 | f = 1.29e-01
# BONG 23 | f = 1.25e-01
# ---------------
# BING 24 | f = 1.25e-01
# BONG 24 | f = 1.25e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 25 | f = 1.58e-01
# BONG 25 | f = 1.36e-01
# ---------------
# BING 26 | f = 1.31e-01
# BONG 26 | f = 1.26e-01
# ---------------
# BING 27 | f = 1.26e-01
# BONG 27 | f = 1.26e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 327.98 nm
#
#
# CASE 089 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 314.92 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 107.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.14e-01
# BONG 01 | f = 1.20e-01
# ---------------
# BING 02 | f = 8.79e-02
# BONG 02 | f = 8.79e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 150.63 nm
#
#
# CASE 090 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 128.51 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 326.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.15e-01
# BONG 01 | f = 1.16e-01
# ---------------
# BING 02 | f = 7.25e-02
# BONG 02 | f = 3.07e-02
# ---------------
# BING 03 | f = 2.47e-02
# BONG 03 | f = 2.21e-02
# ---------------
# BING 04 | f = 2.12e-02
# BONG 04 | f = 2.11e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 227.83 nm
#
#
# CASE 091 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 205.62 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 362.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.08e-02
# BONG 01 | f = 2.08e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.67 nm
#
#
# CASE 092 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 429.58 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 141.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.19e-01
# BONG 01 | f = 1.18e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 5.04e-01
# BONG 02 | f = 4.70e-01
# ---------------
# BING 03 | f = 4.61e-01
# BONG 03 | f = 4.61e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 4.27e-01
# BONG 04 | f = 4.20e-01
# ---------------
# BING 05 | f = 4.20e-01
# BONG 05 | f = 4.20e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 3.06e-01
# BONG 06 | f = 2.76e-01
# ---------------
# BING 07 | f = 1.65e-01
# BONG 07 | f = 1.61e-01
# ---------------
# BING 08 | f = 1.38e-01
# BONG 08 | f = 1.38e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 5.18e-01
# BONG 09 | f = 5.10e-01
# ---------------
# BING 10 | f = 5.10e-01
# BONG 10 | f = 5.10e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 4.18e-01
# BONG 11 | f = 3.47e-01
# ---------------
# BING 12 | f = 2.33e-01
# BONG 12 | f = 2.24e-01
# ---------------
# BING 13 | f = 1.63e-01
# BONG 13 | f = 1.44e-01
# ---------------
# BING 14 | f = 1.43e-01
# BONG 14 | f = 1.43e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 2.04e-01
# BONG 15 | f = 1.56e-01
# ---------------
# BING 16 | f = 1.56e-01
# BONG 16 | f = 1.54e-01
# ---------------
# BING 17 | f = 1.53e-01
# BONG 17 | f = 1.53e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 18 | f = 1.19e-01
# BONG 18 | f = 1.19e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 19 | f = 4.15e-01
# BONG 19 | f = 4.10e-01
# ---------------
# BING 20 | f = 4.10e-01
# BONG 20 | f = 4.10e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 21 | f = 8.88e-01
# BONG 21 | f = 7.48e-01
# ---------------
# BING 22 | f = 5.38e-01
# BONG 22 | f = 5.36e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 23 | f = 9.38e-01
# BONG 23 | f = 7.32e-01
# ---------------
# BING 24 | f = 5.99e-01
# BONG 24 | f = 4.16e-01
# ---------------
# BING 25 | f = 3.53e-01
# BONG 25 | f = 2.44e-01
# ---------------
# BING 26 | f = 2.08e-01
# BONG 26 | f = 1.94e-01
# ---------------
# BING 27 | f = 1.94e-01
# BONG 27 | f = 1.94e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 585.45 nm
#
#
# CASE 093 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 225.93 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 313.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.21e-02
# BONG 01 | f = 4.91e-02
# ---------------
# BING 02 | f = 2.03e-02
# BONG 02 | f = 2.03e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.37 nm
#
#
# CASE 094 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 148.37 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 310.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.84e-02
# BONG 01 | f = 4.40e-02
# ---------------
# BING 02 | f = 1.73e-02
# BONG 02 | f = 1.38e-02
# ---------------
# BING 03 | f = 1.37e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.04 nm
#
#
# CASE 095 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 238.37 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 290.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.88e-02
# BONG 01 | f = 6.69e-02
# ---------------
# BING 02 | f = 2.23e-02
# BONG 02 | f = 1.82e-02
# ---------------
# BING 03 | f = 1.64e-02
# BONG 03 | f = 1.64e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 27.34 nm
#
#
# CASE 096 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 333.96 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 133.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.94e-01
# BONG 01 | f = 1.51e-01
# ---------------
# BING 02 | f = 4.35e-02
# BONG 02 | f = 3.99e-02
# ---------------
# BING 03 | f = 3.99e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 41.22 nm
#
#
# CASE 097 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 79.77 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 817.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 9.23e-03
# BONG 01 | f = 5.90e-03
# ---------------
# BING 02 | f = 4.17e-03
# BONG 02 | f = 4.17e-03
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 21.45 nm
#
#
# CASE 098 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 228.77 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 167.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.50e-01
# BONG 01 | f = 1.42e-01
# ---------------
# BING 02 | f = 3.30e-02
# BONG 02 | f = 3.24e-02
# ---------------
# BING 03 | f = 3.24e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 21.48 nm
#
#
# CASE 099 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 176.85 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 231.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.87e-01
# BONG 01 | f = 2.55e-01
# ---------------
# BING 02 | f = 2.16e-01
# BONG 02 | f = 1.92e-01
# ---------------
# BING 03 | f = 1.76e-01
# BONG 03 | f = 1.71e-01
# ---------------
# BING 04 | f = 1.64e-01
# BONG 04 | f = 1.58e-01
# ---------------
# BING 05 | f = 1.52e-01
# BONG 05 | f = 1.47e-01
# ---------------
# BING 06 | f = 1.42e-01
# BONG 06 | f = 1.38e-01
# ---------------
# BING 07 | f = 1.34e-01
# BONG 07 | f = 1.29e-01
# ---------------
# BING 08 | f = 1.23e-01
# BONG 08 | f = 1.22e-01
# ---------------
# BING 09 | f = 1.18e-01
# BONG 09 | f = 1.15e-01
# ---------------
# BING 10 | f = 1.03e-01
# BONG 10 | f = 9.65e-02
# ---------------
# BING 11 | f = 8.37e-02
# BONG 11 | f = 6.36e-02
# ---------------
# BING 12 | f = 5.74e-02
# BONG 12 | f = 5.32e-02
# ---------------
# BING 13 | f = 5.31e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 259.79 nm
#
#
# CASE 100 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 274.21 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 198.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.10e-01
# BONG 01 | f = 1.07e-01
# ---------------
# BING 02 | f = 1.07e-01
# BONG 02 | f = 1.07e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 4.00e-01
# BONG 03 | f = 3.86e-01
# ---------------
# BING 04 | f = 2.85e-01
# BONG 04 | f = 2.73e-01
# ---------------
# BING 05 | f = 2.05e-01
# BONG 05 | f = 1.88e-01
# ---------------
# BING 06 | f = 1.88e-01
# BONG 06 | f = 1.88e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 2.43e-01
# BONG 07 | f = 2.43e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 3.77e-01
# BONG 08 | f = 3.74e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 4.54e-01
# BONG 09 | f = 4.42e-01
# ---------------
# BING 10 | f = 4.42e-01
# BONG 10 | f = 4.42e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 4.39e-01
# BONG 11 | f = 4.33e-01
# ---------------
# BING 12 | f = 4.33e-01
# BONG 12 | f = 4.33e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 2.95e-01
# BONG 13 | f = 2.64e-01
# ---------------
# BING 14 | f = 1.52e-01
# BONG 14 | f = 1.51e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 3.27e-01
# BONG 15 | f = 3.19e-01
# ---------------
# BING 16 | f = 2.92e-01
# BONG 16 | f = 2.90e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 17 | f = 1.55e-01
# BONG 17 | f = 1.32e-01
# ---------------
# BING 18 | f = 1.32e-01
# BONG 18 | f = 1.32e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 19 | f = 4.31e-01
# BONG 19 | f = 3.42e-01
# ---------------
# BING 20 | f = 3.01e-01
# BONG 20 | f = 3.01e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 21 | f = 1.11e-01
# BONG 21 | f = 1.11e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 80.29 nm
#
#
# Saved data to:  /home/derbyk/src/ffpr/sim_results/20260505_mc_misalignments_3stars_dec_50um_tilt_5as.pkl

# %% [markdown]
# ## VISUALIZE

# %%
data = utils.load_pickle('/home/derbyk/src/ffpr/sim_results/20260505_mc_misalignments_3stars_dec_50um_tilt_5as.pkl')

median_rms_truth = np.zeros(len(data))
median_rms_residual = np.zeros(len(data))
max_rms_residual = np.zeros(len(data))
min_rms_residual = np.zeros(len(data))
std_rms_residual = np.zeros(len(data))
weighted_sum_diversity = np.zeros(len(data))

for i, case in enumerate(data):
    median_rms_truth[i] = np.median(np.array(data[case]['RMS_TRUTH_PER_FIELD']))
    median_rms_residual[i] = np.median(np.array(data[case]['RMS_RESIDUAL_PER_FIELD']))
    max_rms_residual[i] = np.max(np.array(data[case]['RMS_RESIDUAL_PER_FIELD']))
    min_rms_residual[i] = np.min(np.array(data[case]['RMS_RESIDUAL_PER_FIELD']))
    std_rms_residual[i] = np.std(np.array(data[case]['RMS_RESIDUAL_PER_FIELD']))
    median_snr = np.median(np.array(data[case]['SNR_PER_FIELD']))
    wsum = 0
    for snr, div in zip(data[case]['SNR_PER_FIELD'], data[case]['RMS_DIVERSITY_PER_FIELD']):
        wsum += snr / median_snr * div
    weighted_sum_diversity[i] = wsum

fig, axs = plt.subplot_mosaic([['histx', 'poop'],
                               ['scatter', 'histy']],
                               figsize=(8, 6), 
                               height_ratios=[1, 3],
                               width_ratios=[3, 1],
                               layout='tight',
                               dpi=150)

count = 0
fails_x = []
fails_y = []
xs = []
ys = []
cs = []

for x, y, c in zip(median_rms_truth, weighted_sum_diversity, median_rms_residual):
    if c < 62.5:
        xs.append(float(x))
        ys.append(float(y))
        cs.append(float(c))
    else:
        fails_x.append(float(x))
        fails_y.append(float(y))

xs = _np.array(xs)
ys = _np.array(ys)
cs = _np.array(cs)
fails_x = _np.array(fails_x)
fails_y = _np.array(fails_y)

xmin = _np.array([xs.min(), fails_x.min()]).min() * 0.9
xmax = _np.array([xs.max(), fails_x.max()]).max() * 1.02

ymin = _np.array([ys.min(), fails_y.min()]).min() * 0.9
ymax = _np.array([ys.max(), fails_y.max()]).max() * 1.05

cmin = 20
cmax = 62.5

sorted_fails_x = sorted(fails_x)
cdf_opd = [0]
cdf_x = [xmin ]
x = xmin
count = 0
while x < xmax:
    if count == len(fails_x):
        x += 10
        break
    if x + 10 < sorted_fails_x[count]:
        x += 10
        cdf_x.append(x)
        cdf_opd.append(cdf_opd[-1])
    else:
        x = sorted_fails_x[count]
        cdf_x.append(x)
        cdf_opd.append((((count + 1) / 100)))
        count += 1
cdf_x.append(xmax )
cdf_opd.append(cdf_opd[-1])
cdf_opd = _np.array(cdf_opd)
cdf_x = _np.array(cdf_x)

sorted_fails_y = _np.flip(sorted(fails_y))
cdf_snr = [0]
cdf_y = [ymax ]
y = ymax
count = 0
while y > ymin:
    if count == len(fails_y):
        y -= 10
        break
    if y - 10 > sorted_fails_y[count]:
        y -= 10
        cdf_y.append(y)
        cdf_snr.append(cdf_snr[-1])
    else:
        y = sorted_fails_y[count]
        cdf_y.append(y)
        cdf_snr.append((((count + 1) / 100)))
        count += 1
cdf_y.append(ymin )
cdf_snr.append(cdf_snr[-1])
cdf_snr = _np.array(cdf_snr)
cdf_y = _np.array(cdf_y)

axs['poop'].set_axis_off()

ax = axs['scatter']
ax.scatter(fails_x, fails_y, c='r', alpha=0.7, marker='x')
s = ax.scatter(xs, ys, c=cs, alpha=0.7, marker='.')
s.set_clim([cmin, cmax])
ax.set_xlabel('Median RMS OPD (nm)')
ax.set_ylabel('SNR Weighted Sum of Diversity (nm)')
ax.set_xlim([xmin , xmax ])
ax.set_ylim([ymin , ymax ])
ax.grid(which='both', alpha=0.3)

plt.colorbar(s, ax=axs['histy'], pad=0.2, label='Median RMS Residual (nm)')

ax = axs['histx']
ax.plot(cdf_x, cdf_opd, color='r')
ax.fill_between(cdf_x, cdf_opd, alpha=0.2, color='r')
# ax.hist(np.array(fails_x).get(), bins=40, color='r')
ax.tick_params(axis='x', labelbottom=False)
ax.set_ylabel('Cumulative\nFailure Rate')
ax.set_xlim([xmin , xmax ])
ax.set_ylim([0, 1.05])
ax.grid(which='both', alpha=0.3)

ax = axs['histy']
ax.plot(cdf_snr, cdf_y, color='r')
ax.fill_betweenx(cdf_y, cdf_snr, alpha=0.2, color='r')
# ax.hist(np.array(fails_y).get(), bins=20, color='r', orientation='horizontal')
ax.tick_params(axis='y', labelleft=False)
ax.set_xticks([0, 0.5, 1])
ax.set_xlabel('Cumulative\nFailure Rate')
ax.set_ylim([ymin , ymax ])
ax.set_xlim([0, 1.05])
ax.grid(which='both', alpha=0.3)


fig.suptitle(f'RMag 17 Guide Stars\n{len(data):02.0f} Misalignment Cases; {len(cs) / len(data) * 100:02.0f}% Convergence Rate\n$\pm25\mu m$ Decenter X, Y; $\pm2.5$" Tilt X, Y')
# Out:
# Text(0.5, 0.98, 'RMag 17 Guide Stars\n100 Misalignment Cases; 66% Convergence Rate\n$\\pm25\\mu m$ Decenter X, Y; $\\pm2.5$" Tilt X, Y')
