# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import matplotlib.cm as color
better_magma = color.magma
better_magma.set_bad('black',1.)
import matplotlib.colors as c

from prysm import (
    mathops, 
    conf,
)
from prysm.mathops import (
    _np,
    np,
    fft,
    interpolate,
    ndimage,
)
from prysm.coordinates import (
    make_xy_grid, 
    cart_to_polar,
)
from prysm.propagation import Wavefront as WF
from prysm.propagation import (
    focus_fixed_sampling,
    focus_fixed_sampling_backprop
)                              
from prysm.thinlens import (
    defocus_to_image_displacement,
    image_displacement_to_defocus,
)
from prysm.geometry import (
    offset_circle,
    circle,
    spider,
    gaussian,
)
from prysm.polynomials import (
    lstsq,
    noll_to_nm,
    zernike_nm,
    zernike_nm_seq,
    hopkins,
    sum_of_2d_modes,
    sum_of_2d_modes_backprop
)
mathops.set_backend_to_cupy()
# conf.config.precision = 32

from astropy.io import (
    fits,
    ascii,
)

from skimage.measure import centroid

import copy

from algos import BING_BONG, FFPR2, PDPR, model, mean_squared_error, gain_invariant_error
import utils

from functools import partial

from lina.utils import TikhonovInverse

import config_um
import config_um_wcc
from Batoid4LOFT.LAZULI_STOP_mark11 import Lazuli_stop, readBulkMotion, readDeformation

from psd_utils import PSDUtils

from scipy.optimize import minimize

from scipy.interpolate import RegularGridInterpolator

from tqdm import tqdm

from psd_utils import PSDUtils

from model import telescope
# from algos import pdpr, OPD, ADPR
import utils

from functools import partial

from opt import F77LBFGSB, runN, RAdam
from IPython.display import clear_output

# logging stuff
import logging
psd_log = logging.getLogger('__psd_utils__')
psd_log.disabled = True

# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

import toml

# %%
# !nvidia-smi
# Out:
# Wed Jun 17 12:19:44 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 565.57.01              Driver Version: 565.57.01      CUDA Version: 12.7     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100 80GB PCIe          On  |   00000000:25:00.0 Off |                    0 |
# | N/A   32C    P0             65W /  300W |    8738MiB /  81920MiB |     10%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A   1182782      C   ...rojects/venv-scoob-poppy/bin/python       1620MiB |
# |    0   N/A  N/A   1497464      G   /usr/lib/xorg/Xorg                              4MiB |
# |    0   N/A  N/A   1511048      C   ...rojects/venv-scoob-poppy/bin/python       3266MiB |
# |    0   N/A  N/A   2353885      C   ...onda3/envs/py310-stp-env/bin/python        996MiB |
# |    0   N/A  N/A   2688165      C   ...onda3/envs/py310-stp-env/bin/python        744MiB |
# |    0   N/A  N/A   2688201      C   ...onda3/envs/py310-stp-env/bin/python        744MiB |
# |    0   N/A  N/A   2688218      C   ...onda3/envs/py310-stp-env/bin/python        744MiB |
# |    0   N/A  N/A   3831258      C   python                                        566MiB |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ## SETUP MODEL

# %%
config = toml.load('/home/derbyk/src/ffpr/data/3m_off_axis_default.toml')
optic_opd_data = utils.load_pickle('/home/derbyk/src/ffpr/data/opd_maps.pkl')

sources = config['sources']
for s in sources:
    sources[s]['magnitude'] = 18

sys = telescope(config=config, optic_opd_data=optic_opd_data)

dark = sys.get_dark(stacked_frames=1)
images = [im - dark for im in sys.snap(stacked_frames=1)]

for i, im in enumerate(images):
    print(f'Image {i + 1:02.0f} SNR = {im.max() / dark.std():.1f}')
# Out:
# Image 01 SNR = 247.2
# Image 02 SNR = 413.9
# Image 03 SNR = 239.7
# Image 04 SNR = 468.3
# Image 05 SNR = 273.2
# Image 06 SNR = 283.4
# Image 07 SNR = 452.9

# %% [markdown]
# ## PLOT PSFS

# %%
pupil = sys.pupil
fields = [(sys.cfg['sources'][src]['position_x'], sys.cfg['sources'][src]['position_y']) for src in sys.cfg['sources']]

utils.plot_psfs_7(psfs=images, fields=fields)

# %% [markdown]
# ## PLOT WFES

# %%
opds_fields = copy.deepcopy(sys.opds_field)
opds_optics = copy.deepcopy(sys.opds_optics)
opds_truths = [opd_field + opd_optics for (opd_field, opd_optics) in zip(opds_fields, opds_optics)]

opds_fields_nominal = opds_fields

utils.plot_opds_7(opds=opds_fields, pupil=pupil, fields=fields)
utils.plot_opds_7(opds=opds_optics, pupil=pupil, fields=fields)
utils.plot_opds_7(opds=opds_truths, pupil=pupil, fields=fields)

# %% [markdown]
# ## SEMICIRCLE FOV
#
# Telescope designed with semicircle FOV in mind. Recreated here so that random source positions fall within this region. See "Large Etendue 3-Meter Unobscured Three Mirror Anastigmat Telescope for Astrophysics" by Kim et al. 2025 for more details.

# %%
fx = np.linspace(-16.2, 16.2, 325)
fy = np.linspace(-9.0, 4.8, 139)

Fx, Fy = np.meshgrid(fx, fy)

semicirc_fov = np.sqrt(Fx ** 2 + (Fy + 14.5) ** 2) <= 19.2
Fx_valid = Fx[semicirc_fov]
Fy_valid = Fy[semicirc_fov]

plt.imshow(semicirc_fov.get(), extent=[fx.min().get(), fx.max().get(), fy.min().get(), fy.max().get()])
plt.xlabel('arcmin')
plt.ylabel('arcmin')
plt.title('Telescope Semicircle FOV')
# Out:
# Text(0.5, 1.0, 'Telescope Semicircle FOV')

# %% [markdown]
# ## MONTE CARLO

# %%
misalignments = utils.load_pickle('/home/derbyk/src/ffpr/data/misalignments_cases_100_dec_50um_tilt_5as.pkl')
snr_thresh = 5
n_sources = 7
source_mag = 18.
random_fields = True

# %%
# system stuff
efl = sys.cfg['general']['f_eff']
pupil_dx = sys.cfg['optics']['m1']['diam'] / sys.cfg['general']['npix_pupil']
focal_dx = sys.cfg['detector']['dx_focal']

# set rng for repeatability on source positions
rng = np.random.default_rng(seed=727)

# stuff to save
data = {}

case = 1

for m in misalignments:

    print(f'CASE {case:03.0f} ----------------------------------')
    print()

    if random_fields:
        # get random source positions
        inds = rng.integers(low=0, high=Fx_valid.size, size=n_sources)
        new_positions = [(float(Fx_valid[i]), float(Fy_valid[i])) for i in inds]
    else:
        new_positions = fields = [(sys.cfg['sources'][src]['position_x'], sys.cfg['sources'][src]['position_y']) for src in sys.cfg['sources']]

    mags = [source_mag for _ in range(n_sources)]

    # send positions to model 
    sys.set_source_parameters(magnitudes=mags, positions=new_positions)

    # reset optics to nominal alignment
    sys.reset_optics()

    # get field dependent OPD at nominal alignment
    opds_fields_nominal = copy.deepcopy(sys.opds_field)

    # calculate RMS of diversity per field
    # diversity comes from field dependent OPD at nominal alignment
    rms_diversity_per_field = []
    for opd in opds_fields_nominal:
        opd -= np.mean(opd[pupil])
        rms_diversity_per_field.append(float(np.sqrt(np.mean(opd[pupil] ** 2))))

    # apply misalignment
    sys.move_optics(M1_motion=m['M1'], M2_motion=m['M4'], M3_motion=m['M4'], M4_motion=m['M4'])

    # get total OPDs per field
    opds_fields = copy.deepcopy(sys.opds_field)
    opds_optics = copy.deepcopy(sys.opds_optics)
    opds_truths = [opd_field + opd_optic for opd_field, opd_optic in zip(opds_fields, opds_optics)]

    # calculate RMS of ground truth OPDs per field
    rms_truth_per_field = []
    for opd in opds_truths:
        opd -= np.mean(opd[pupil])
        rms_truth_per_field.append(float(np.sqrt(np.mean(opd[pupil] ** 2))))

    # take images for FFPR
    dark = sys.get_dark(stacked_frames=1)
    images = [im - dark for im in sys.snap(stacked_frames=1)]

    # get image SNRs and filter
    noise_lvl = dark.std()
    masks = []
    snr_per_field = []
    for im in images:
        snr_per_field.append(float(im.max() / dark.std()))
        mask = im > noise_lvl * snr_thresh
        masks.append(mask)

    print(f'MEDIAN RMS OPD ACROSS FIELD = {np.median(np.array(rms_truth_per_field)):.2f} nm')
    print(f'MEDIAN IMAGE SNR ACROSS FIELD = {np.median(np.array(snr_per_field)):.1f}')
    print()

    # initialize FFPR
    opt = FFPR2(wvls=sys.wvls.tolist(), amp=sys.pupil, max_zernike=11, fields=new_positions, divs=opds_fields_nominal, efl=efl, 
                psfs=images, pupil_dx=pupil_dx, focal_dx=focal_dx, error=gain_invariant_error, masks=masks, jitter_kernel=sys.jitter_kernel)

    # BING BONG
    BING_BONG(opt=opt, modal_cleanup=True, zonal_cleanup=False,
              max_kicks=10, iter_per_bing_bong=10, iter_per_psf=10,
              max_ls=10, thresh_conv=1e-1, frac_conv=1e-2)

    # calculate estimate residuals
    opds_estimates = [pdpr.models[0].opd + pdpr.models[0].div for pdpr in opt.PDPR_list]
    opds_residuals = [estimate - truth for estimate, truth in zip(opds_estimates, opds_truths)]

    # get RMS of residual per field
    rms_residual_per_field = []
    for opd in opds_residuals:
        opd -= np.mean(opd[pupil])
        rms_residual_per_field.append(float(np.sqrt(np.mean(opd[pupil] ** 2))))

    print(f'MEDIAN RMS RESIDUAL ACROSS FIELD = {np.median(np.array(rms_residual_per_field)):.2f} nm')
    print()
    print()

    # save to data cube
    data.update({f'CASE{case:03.0f}' : {'WFE_NOMINAL' : opds_fields_nominal,
                                        'WFE_TRUTH' : opds_truths,
                                        'WFE_ESTIMATE' : opds_estimates,
                                        'SNR_PER_FIELD' : snr_per_field,
                                        'FIELDS' : new_positions}})

    case += 1

utils.save_pickle(f'/npool/nvme/derbyk/20260616_mfpr_mc/mis_med_srcmag_{source_mag:.0f}_nsrc_{n_sources:.0f}_randf_true.pkl', data=data)
# Out:
# CASE 001 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 95.09 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 309.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.11e-02
# BONG 01 | f = 1.06e-02
# ---------------
# BING 02 | f = 1.05e-02
# BONG 02 | f = 1.05e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.12 nm
#
#
# CASE 002 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 371.48 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 63.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.57e-01
# BONG 01 | f = 4.51e-01
# ---------------
# BING 02 | f = 4.47e-01
# BONG 02 | f = 4.47e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 4.57e-01
# BONG 03 | f = 4.57e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 4.61e-01
# BONG 04 | f = 4.58e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 4.34e-01
# BONG 05 | f = 4.27e-01
# ---------------
# BING 06 | f = 4.27e-01
# BONG 06 | f = 4.27e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 4.66e-01
# BONG 07 | f = 4.65e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 4.61e-01
# BONG 08 | f = 4.61e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 4.68e-01
# BONG 09 | f = 4.68e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 7.24e-01
# BONG 10 | f = 7.23e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 4.71e-01
# BONG 11 | f = 4.71e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 4.85e-01
# BONG 12 | f = 4.85e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 2.05e-01
# BONG 13 | f = 2.05e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 174.27 nm
#
#
# CASE 003 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 332.95 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 62.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.36e-01
# BONG 01 | f = 4.31e-01
# ---------------
# BING 02 | f = 4.31e-01
# BONG 02 | f = 4.31e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 4.11e-01
# BONG 03 | f = 4.06e-01
# ---------------
# BING 04 | f = 4.06e-01
# BONG 04 | f = 4.06e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 3.17e-01
# BONG 05 | f = 2.91e-01
# ---------------
# BING 06 | f = 2.91e-01
# BONG 06 | f = 2.91e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 4.48e-01
# BONG 07 | f = 4.13e-01
# ---------------
# BING 08 | f = 4.13e-01
# BONG 08 | f = 4.12e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 4.99e-01
# BONG 09 | f = 4.79e-01
# ---------------
# BING 10 | f = 4.79e-01
# BONG 10 | f = 4.79e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 3.64e-01
# BONG 11 | f = 3.36e-01
# ---------------
# BING 12 | f = 3.27e-01
# BONG 12 | f = 3.24e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 2.46e-01
# BONG 13 | f = 2.19e-01
# ---------------
# BING 14 | f = 2.19e-01
# BONG 14 | f = 2.19e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 4.04e-01
# BONG 15 | f = 3.83e-01
# ---------------
# BING 16 | f = 3.83e-01
# BONG 16 | f = 3.83e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 17 | f = 4.27e-01
# BONG 17 | f = 4.13e-01
# ---------------
# BING 18 | f = 4.13e-01
# BONG 18 | f = 4.13e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 19 | f = 4.43e-01
# BONG 19 | f = 4.26e-01
# ---------------
# BING 20 | f = 4.26e-01
# BONG 20 | f = 4.26e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 21 | f = 3.72e-01
# BONG 21 | f = 3.57e-01
# ---------------
# BING 22 | f = 3.57e-01
# BONG 22 | f = 3.57e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 390.56 nm
#
#
# CASE 004 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 164.94 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 146.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.02e-02
# BONG 01 | f = 3.02e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 25.69 nm
#
#
# CASE 005 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 210.85 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 95.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.92e-02
# BONG 01 | f = 4.48e-02
# ---------------
# BING 02 | f = 4.26e-02
# BONG 02 | f = 4.24e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.78 nm
#
#
# CASE 006 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 212.34 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 143.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.83e-02
# BONG 01 | f = 3.83e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.75 nm
#
#
# CASE 007 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 117.35 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 146.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.98e-02
# BONG 01 | f = 3.75e-02
# ---------------
# BING 02 | f = 3.75e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 28.42 nm
#
#
# CASE 008 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 369.65 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 43.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.16e-01
# BONG 01 | f = 4.94e-01
# ---------------
# BING 02 | f = 4.74e-01
# BONG 02 | f = 4.68e-01
# ---------------
# BING 03 | f = 4.67e-01
# BONG 03 | f = 4.66e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 3.50e-01
# BONG 04 | f = 3.39e-01
# ---------------
# BING 05 | f = 3.36e-01
# BONG 05 | f = 3.36e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 5.73e-01
# BONG 06 | f = 5.40e-01
# ---------------
# BING 07 | f = 4.97e-01
# BONG 07 | f = 4.97e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 5.01e-01
# BONG 08 | f = 4.96e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 5.58e-01
# BONG 09 | f = 5.49e-01
# ---------------
# BING 10 | f = 5.49e-01
# BONG 10 | f = 5.49e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 5.63e-01
# BONG 11 | f = 5.41e-01
# ---------------
# BING 12 | f = 5.05e-01
# BONG 12 | f = 5.00e-01
# ---------------
# BING 13 | f = 3.72e-01
# BONG 13 | f = 3.66e-01
# ---------------
# BING 14 | f = 3.49e-01
# BONG 14 | f = 3.49e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 6.71e-01
# BONG 15 | f = 6.44e-01
# ---------------
# BING 16 | f = 6.44e-01
# BONG 16 | f = 6.44e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 17 | f = 5.34e-01
# BONG 17 | f = 5.34e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 18 | f = 4.88e-01
# BONG 18 | f = 4.73e-01
# ---------------
# BING 19 | f = 4.73e-01
# BONG 19 | f = 4.73e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 20 | f = 4.88e-01
# BONG 20 | f = 4.88e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 21 | f = 4.83e-01
# BONG 21 | f = 4.72e-01
# ---------------
# BING 22 | f = 4.72e-01
# BONG 22 | f = 4.72e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 497.69 nm
#
#
# CASE 009 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 413.33 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 52.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 7.20e-01
# BONG 01 | f = 6.29e-01
# ---------------
# BING 02 | f = 5.91e-01
# BONG 02 | f = 5.85e-01
# ---------------
# BING 03 | f = 5.85e-01
# BONG 03 | f = 5.85e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 6.36e-01
# BONG 04 | f = 5.29e-01
# ---------------
# BING 05 | f = 5.25e-01
# BONG 05 | f = 5.23e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 4.70e-01
# BONG 06 | f = 4.37e-01
# ---------------
# BING 07 | f = 2.87e-01
# BONG 07 | f = 2.84e-01
# ---------------
# BING 08 | f = 2.75e-01
# BONG 08 | f = 2.75e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 6.17e-01
# BONG 09 | f = 5.14e-01
# ---------------
# BING 10 | f = 4.69e-01
# BONG 10 | f = 4.69e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 6.24e-01
# BONG 11 | f = 5.23e-01
# ---------------
# BING 12 | f = 5.10e-01
# BONG 12 | f = 5.10e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 7.45e-01
# BONG 13 | f = 6.67e-01
# ---------------
# BING 14 | f = 5.86e-01
# BONG 14 | f = 5.24e-01
# ---------------
# BING 15 | f = 5.13e-01
# BONG 15 | f = 5.13e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 6.27e-01
# BONG 16 | f = 5.22e-01
# ---------------
# BING 17 | f = 5.21e-01
# BONG 17 | f = 5.21e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 18 | f = 7.56e-01
# BONG 18 | f = 6.29e-01
# ---------------
# BING 19 | f = 5.16e-01
# BONG 19 | f = 5.16e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 20 | f = 6.46e-01
# BONG 20 | f = 5.39e-01
# ---------------
# BING 21 | f = 5.37e-01
# BONG 21 | f = 5.37e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 22 | f = 6.07e-01
# BONG 22 | f = 5.58e-01
# ---------------
# BING 23 | f = 3.49e-01
# BONG 23 | f = 3.24e-01
# ---------------
# BING 24 | f = 2.91e-01
# BONG 24 | f = 2.91e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 25 | f = 3.21e-01
# BONG 25 | f = 3.20e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 340.14 nm
#
#
# CASE 010 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 308.58 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 62.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.14e-01
# BONG 01 | f = 3.93e-01
# ---------------
# BING 02 | f = 3.93e-01
# BONG 02 | f = 3.93e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 6.21e-01
# BONG 03 | f = 6.21e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 4.98e-01
# BONG 04 | f = 4.98e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 2.54e-01
# BONG 05 | f = 2.43e-01
# ---------------
# BING 06 | f = 2.43e-01
# BONG 06 | f = 2.43e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 2.30e-01
# BONG 07 | f = 2.21e-01
# ---------------
# BING 08 | f = 2.21e-01
# BONG 08 | f = 2.21e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 4.54e-01
# BONG 09 | f = 4.34e-01
# ---------------
# BING 10 | f = 4.34e-01
# BONG 10 | f = 4.34e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 6.74e-01
# BONG 11 | f = 5.71e-01
# ---------------
# BING 12 | f = 5.71e-01
# BONG 12 | f = 5.71e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 2.97e-01
# BONG 13 | f = 2.82e-01
# ---------------
# BING 14 | f = 2.82e-01
# BONG 14 | f = 2.82e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 3.02e-01
# BONG 15 | f = 2.96e-01
# ---------------
# BING 16 | f = 2.96e-01
# BONG 16 | f = 2.96e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 17 | f = 2.96e-01
# BONG 17 | f = 2.91e-01
# ---------------
# BING 18 | f = 2.91e-01
# BONG 18 | f = 2.91e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 19 | f = 2.04e-01
# BONG 19 | f = 2.01e-01
# ---------------
# BING 20 | f = 2.01e-01
# BONG 20 | f = 2.01e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 182.92 nm
#
#
# CASE 011 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 347.23 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 39.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 7.77e-01
# BONG 01 | f = 7.56e-01
# ---------------
# BING 02 | f = 7.56e-01
# BONG 02 | f = 7.56e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 7.58e-01
# BONG 03 | f = 7.26e-01
# ---------------
# BING 04 | f = 7.26e-01
# BONG 04 | f = 7.26e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 8.05e-01
# BONG 05 | f = 8.05e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 6.60e-01
# BONG 06 | f = 6.45e-01
# ---------------
# BING 07 | f = 6.45e-01
# BONG 07 | f = 6.45e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 8.72e-01
# BONG 08 | f = 7.43e-01
# ---------------
# BING 09 | f = 5.86e-01
# BONG 09 | f = 5.68e-01
# ---------------
# BING 10 | f = 5.65e-01
# BONG 10 | f = 5.61e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 7.87e-01
# BONG 11 | f = 7.27e-01
# ---------------
# BING 12 | f = 7.23e-01
# BONG 12 | f = 7.23e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 7.58e-01
# BONG 13 | f = 7.56e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 6.43e-01
# BONG 14 | f = 6.27e-01
# ---------------
# BING 15 | f = 6.27e-01
# BONG 15 | f = 6.27e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 7.10e-01
# BONG 16 | f = 7.07e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 17 | f = 4.38e-01
# BONG 17 | f = 3.61e-01
# ---------------
# BING 18 | f = 2.62e-01
# BONG 18 | f = 2.62e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 19 | f = 2.73e-01
# BONG 19 | f = 2.73e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 79.53 nm
#
#
# CASE 012 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 322.20 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 45.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.66e-01
# BONG 01 | f = 4.88e-01
# ---------------
# BING 02 | f = 4.88e-01
# BONG 02 | f = 4.88e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 5.68e-01
# BONG 03 | f = 4.92e-01
# ---------------
# BING 04 | f = 4.92e-01
# BONG 04 | f = 4.92e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 7.34e-01
# BONG 05 | f = 7.00e-01
# ---------------
# BING 06 | f = 7.00e-01
# BONG 06 | f = 7.00e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 5.86e-01
# BONG 07 | f = 5.12e-01
# ---------------
# BING 08 | f = 5.12e-01
# BONG 08 | f = 5.12e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 5.92e-01
# BONG 09 | f = 5.19e-01
# ---------------
# BING 10 | f = 5.13e-01
# BONG 10 | f = 5.13e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 7.34e-01
# BONG 11 | f = 6.13e-01
# ---------------
# BING 12 | f = 5.58e-01
# BONG 12 | f = 5.27e-01
# ---------------
# BING 13 | f = 5.24e-01
# BONG 13 | f = 5.21e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 5.98e-01
# BONG 14 | f = 5.40e-01
# ---------------
# BING 15 | f = 5.23e-01
# BONG 15 | f = 5.23e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 7.55e-01
# BONG 16 | f = 7.49e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 17 | f = 5.97e-01
# BONG 17 | f = 5.42e-01
# ---------------
# BING 18 | f = 5.42e-01
# BONG 18 | f = 5.42e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 19 | f = 6.01e-01
# BONG 19 | f = 5.54e-01
# ---------------
# BING 20 | f = 5.29e-01
# BONG 20 | f = 5.29e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 21 | f = 5.98e-01
# BONG 21 | f = 5.22e-01
# ---------------
# BING 22 | f = 5.19e-01
# BONG 22 | f = 5.19e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 611.83 nm
#
#
# CASE 013 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 373.80 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 51.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.18e-01
# BONG 01 | f = 4.67e-01
# ---------------
# BING 02 | f = 4.65e-01
# BONG 02 | f = 4.65e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 5.13e-01
# BONG 03 | f = 4.64e-01
# ---------------
# BING 04 | f = 4.56e-01
# BONG 04 | f = 4.34e-01
# ---------------
# BING 05 | f = 4.27e-01
# BONG 05 | f = 4.27e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 6.14e-01
# BONG 06 | f = 5.94e-01
# ---------------
# BING 07 | f = 5.94e-01
# BONG 07 | f = 5.94e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 5.32e-01
# BONG 08 | f = 4.77e-01
# ---------------
# BING 09 | f = 4.76e-01
# BONG 09 | f = 4.76e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 5.28e-01
# BONG 10 | f = 4.81e-01
# ---------------
# BING 11 | f = 4.54e-01
# BONG 11 | f = 4.49e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 7.75e-01
# BONG 12 | f = 7.01e-01
# ---------------
# BING 13 | f = 5.72e-01
# BONG 13 | f = 5.72e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 6.12e-01
# BONG 14 | f = 6.12e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 5.30e-01
# BONG 15 | f = 4.87e-01
# ---------------
# BING 16 | f = 4.82e-01
# BONG 16 | f = 4.62e-01
# ---------------
# BING 17 | f = 4.44e-01
# BONG 17 | f = 4.40e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 18 | f = 5.27e-01
# BONG 18 | f = 4.75e-01
# ---------------
# BING 19 | f = 4.74e-01
# BONG 19 | f = 4.74e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 20 | f = 5.25e-01
# BONG 20 | f = 4.87e-01
# ---------------
# BING 21 | f = 4.86e-01
# BONG 21 | f = 4.86e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 22 | f = 5.30e-01
# BONG 22 | f = 4.88e-01
# ---------------
# BING 23 | f = 4.85e-01
# BONG 23 | f = 4.84e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 682.65 nm
#
#
# CASE 014 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 186.86 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 82.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.34e-01
# BONG 01 | f = 2.96e-01
# ---------------
# BING 02 | f = 2.95e-01
# BONG 02 | f = 2.95e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 3.38e-01
# BONG 03 | f = 2.97e-01
# ---------------
# BING 04 | f = 2.95e-01
# BONG 04 | f = 2.95e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 1.86e-01
# BONG 05 | f = 1.55e-01
# ---------------
# BING 06 | f = 1.02e-01
# BONG 06 | f = 8.20e-02
# ---------------
# BING 07 | f = 8.20e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 37.56 nm
#
#
# CASE 015 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 165.31 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 184.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.84e-02
# BONG 01 | f = 2.79e-02
# ---------------
# BING 02 | f = 2.78e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 27.06 nm
#
#
# CASE 016 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 561.75 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 32.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 9.98e-01
# BONG 01 | f = 9.98e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 9.98e-01
# BONG 02 | f = 9.98e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 9.98e-01
# BONG 03 | f = 9.98e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 9.98e-01
# BONG 04 | f = 9.98e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 9.98e-01
# BONG 05 | f = 9.98e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 9.98e-01
# BONG 06 | f = 9.98e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 9.98e-01
# BONG 07 | f = 9.98e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 9.98e-01
# BONG 08 | f = 9.98e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 9.98e-01
# BONG 09 | f = 9.98e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 9.98e-01
# BONG 10 | f = 9.98e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 9.98e-01
# BONG 11 | f = 9.98e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 564.82 nm
#
#
# CASE 017 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 153.97 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 96.1
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.59e-02
# BONG 01 | f = 5.31e-02
# ---------------
# BING 02 | f = 5.31e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 28.64 nm
#
#
# CASE 018 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 106.82 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 242.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.85e-02
# BONG 01 | f = 1.81e-02
# ---------------
# BING 02 | f = 1.81e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.31 nm
#
#
# CASE 019 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 424.27 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 62.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.02e-01
# BONG 01 | f = 3.99e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 3.94e-01
# BONG 02 | f = 3.93e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 5.44e-01
# BONG 03 | f = 5.31e-01
# ---------------
# BING 04 | f = 5.31e-01
# BONG 04 | f = 5.31e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 4.29e-01
# BONG 05 | f = 4.29e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 4.52e-01
# BONG 06 | f = 4.40e-01
# ---------------
# BING 07 | f = 4.40e-01
# BONG 07 | f = 4.40e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 7.16e-01
# BONG 08 | f = 6.71e-01
# ---------------
# BING 09 | f = 6.71e-01
# BONG 09 | f = 6.71e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 5.72e-01
# BONG 10 | f = 5.02e-01
# ---------------
# BING 11 | f = 4.76e-01
# BONG 11 | f = 4.76e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 5.86e-01
# BONG 12 | f = 5.73e-01
# ---------------
# BING 13 | f = 5.73e-01
# BONG 13 | f = 5.73e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 3.24e-01
# BONG 14 | f = 3.17e-01
# ---------------
# BING 15 | f = 2.29e-01
# BONG 15 | f = 2.29e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 8.12e-01
# BONG 16 | f = 5.68e-01
# ---------------
# BING 17 | f = 5.66e-01
# BONG 17 | f = 5.66e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 18 | f = 8.15e-01
# BONG 18 | f = 5.77e-01
# ---------------
# BING 19 | f = 5.11e-01
# BONG 19 | f = 4.99e-01
# ---------------
# BING 20 | f = 4.94e-01
# BONG 20 | f = 4.94e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 573.74 nm
#
#
# CASE 020 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 248.96 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 59.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.94e-01
# BONG 01 | f = 4.72e-01
# ---------------
# BING 02 | f = 4.72e-01
# BONG 02 | f = 4.72e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 4.92e-01
# BONG 03 | f = 4.52e-01
# ---------------
# BING 04 | f = 4.52e-01
# BONG 04 | f = 4.52e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 5.26e-01
# BONG 05 | f = 4.76e-01
# ---------------
# BING 06 | f = 2.31e-01
# BONG 06 | f = 2.10e-01
# ---------------
# BING 07 | f = 1.67e-01
# BONG 07 | f = 1.67e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 4.74e-01
# BONG 08 | f = 4.08e-01
# ---------------
# BING 09 | f = 4.08e-01
# BONG 09 | f = 4.08e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 5.29e-01
# BONG 10 | f = 4.25e-01
# ---------------
# BING 11 | f = 4.25e-01
# BONG 11 | f = 4.25e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 4.72e-01
# BONG 12 | f = 4.38e-01
# ---------------
# BING 13 | f = 4.38e-01
# BONG 13 | f = 4.38e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 4.71e-01
# BONG 14 | f = 4.48e-01
# ---------------
# BING 15 | f = 4.48e-01
# BONG 15 | f = 4.48e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 5.29e-01
# BONG 16 | f = 4.43e-01
# ---------------
# BING 17 | f = 3.48e-01
# BONG 17 | f = 3.05e-01
# ---------------
# BING 18 | f = 2.16e-01
# BONG 18 | f = 2.16e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 19 | f = 2.01e-01
# BONG 19 | f = 1.99e-01
# ---------------
# BING 20 | f = 1.99e-01
# BONG 20 | f = 1.99e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 21 | f = 2.21e-01
# BONG 21 | f = 2.21e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 22 | f = 5.79e-01
# BONG 22 | f = 5.66e-01
# ---------------
# BING 23 | f = 5.66e-01
# BONG 23 | f = 5.66e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 245.54 nm
#
#
# CASE 021 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 186.82 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 138.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.09e-02
# BONG 01 | f = 3.96e-02
# ---------------
# BING 02 | f = 3.81e-02
# BONG 02 | f = 3.81e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.10 nm
#
#
# CASE 022 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 579.26 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 28.1
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.94e-01
# BONG 01 | f = 5.89e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 5.70e-01
# BONG 02 | f = 5.70e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 6.78e-01
# BONG 03 | f = 6.66e-01
# ---------------
# BING 04 | f = 6.66e-01
# BONG 04 | f = 6.66e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 7.00e-01
# BONG 05 | f = 6.84e-01
# ---------------
# BING 06 | f = 6.82e-01
# BONG 06 | f = 6.82e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 7.38e-01
# BONG 07 | f = 7.32e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 8.15e-01
# BONG 08 | f = 7.89e-01
# ---------------
# BING 09 | f = 7.30e-01
# BONG 09 | f = 6.77e-01
# ---------------
# BING 10 | f = 6.77e-01
# BONG 10 | f = 6.77e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 7.57e-01
# BONG 11 | f = 6.95e-01
# ---------------
# BING 12 | f = 6.94e-01
# BONG 12 | f = 6.94e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 7.53e-01
# BONG 13 | f = 7.49e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 6.72e-01
# BONG 14 | f = 6.72e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 6.11e-01
# BONG 15 | f = 6.11e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 9.15e-01
# BONG 16 | f = 6.97e-01
# ---------------
# BING 17 | f = 6.90e-01
# BONG 17 | f = 6.90e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 1037.77 nm
#
#
# CASE 023 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 248.63 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 64.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.51e-01
# BONG 01 | f = 4.29e-01
# ---------------
# BING 02 | f = 4.26e-01
# BONG 02 | f = 4.26e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 5.59e-01
# BONG 03 | f = 4.44e-01
# ---------------
# BING 04 | f = 4.35e-01
# BONG 04 | f = 4.35e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 5.36e-01
# BONG 05 | f = 5.26e-01
# ---------------
# BING 06 | f = 5.26e-01
# BONG 06 | f = 5.26e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 6.06e-01
# BONG 07 | f = 6.02e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 6.62e-01
# BONG 08 | f = 6.52e-01
# ---------------
# BING 09 | f = 6.52e-01
# BONG 09 | f = 6.52e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 6.30e-01
# BONG 10 | f = 4.23e-01
# ---------------
# BING 11 | f = 3.32e-01
# BONG 11 | f = 3.21e-01
# ---------------
# BING 12 | f = 3.21e-01
# BONG 12 | f = 3.21e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 5.64e-01
# BONG 13 | f = 3.52e-01
# ---------------
# BING 14 | f = 3.50e-01
# BONG 14 | f = 3.50e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 6.33e-01
# BONG 15 | f = 6.30e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 5.59e-01
# BONG 16 | f = 4.96e-01
# ---------------
# BING 17 | f = 4.96e-01
# BONG 17 | f = 4.96e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 18 | f = 6.67e-01
# BONG 18 | f = 6.37e-01
# ---------------
# BING 19 | f = 6.37e-01
# BONG 19 | f = 6.37e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 20 | f = 3.12e-01
# BONG 20 | f = 3.06e-01
# ---------------
# BING 21 | f = 3.06e-01
# BONG 21 | f = 3.06e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 224.40 nm
#
#
# CASE 024 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 250.43 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 65.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.46e-01
# BONG 01 | f = 5.42e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 5.24e-01
# BONG 02 | f = 5.23e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 1.98e-01
# BONG 03 | f = 1.01e-01
# ---------------
# BING 04 | f = 9.61e-02
# BONG 04 | f = 9.10e-02
# ---------------
# BING 05 | f = 9.10e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 26.44 nm
#
#
# CASE 025 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 455.15 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 34.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.93e-01
# BONG 01 | f = 6.08e-01
# ---------------
# BING 02 | f = 5.47e-01
# BONG 02 | f = 5.47e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 5.79e-01
# BONG 03 | f = 5.33e-01
# ---------------
# BING 04 | f = 5.33e-01
# BONG 04 | f = 5.33e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 5.31e-01
# BONG 05 | f = 5.21e-01
# ---------------
# BING 06 | f = 5.21e-01
# BONG 06 | f = 5.21e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 7.91e-01
# BONG 07 | f = 7.91e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 6.84e-01
# BONG 08 | f = 6.84e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 6.57e-01
# BONG 09 | f = 5.14e-01
# ---------------
# BING 10 | f = 4.99e-01
# BONG 10 | f = 4.99e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 6.38e-01
# BONG 11 | f = 6.06e-01
# ---------------
# BING 12 | f = 6.05e-01
# BONG 12 | f = 5.96e-01
# ---------------
# BING 13 | f = 5.94e-01
# BONG 13 | f = 5.94e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 5.44e-01
# BONG 14 | f = 5.42e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 7.48e-01
# BONG 15 | f = 7.34e-01
# ---------------
# BING 16 | f = 7.34e-01
# BONG 16 | f = 7.34e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 17 | f = 6.37e-01
# BONG 17 | f = 6.37e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 18 | f = 7.95e-01
# BONG 18 | f = 6.53e-01
# ---------------
# BING 19 | f = 6.00e-01
# BONG 19 | f = 5.90e-01
# ---------------
# BING 20 | f = 5.73e-01
# BONG 20 | f = 5.73e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 832.64 nm
#
#
# CASE 026 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 225.07 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 76.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 7.70e-02
# BONG 01 | f = 7.36e-02
# ---------------
# BING 02 | f = 6.63e-02
# BONG 02 | f = 6.63e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 26.64 nm
#
#
# CASE 027 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 282.68 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 50.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.71e-01
# BONG 01 | f = 1.58e-01
# ---------------
# BING 02 | f = 1.58e-01
# BONG 02 | f = 1.58e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 1.51e-01
# BONG 03 | f = 1.48e-01
# ---------------
# BING 04 | f = 1.48e-01
# BONG 04 | f = 1.48e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 6.66e-01
# BONG 05 | f = 6.64e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 7.61e-01
# BONG 06 | f = 7.05e-01
# ---------------
# BING 07 | f = 3.42e-01
# BONG 07 | f = 2.77e-01
# ---------------
# BING 08 | f = 1.78e-01
# BONG 08 | f = 1.78e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 5.68e-01
# BONG 09 | f = 5.52e-01
# ---------------
# BING 10 | f = 5.52e-01
# BONG 10 | f = 5.52e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 3.72e-01
# BONG 11 | f = 3.12e-01
# ---------------
# BING 12 | f = 1.68e-01
# BONG 12 | f = 1.62e-01
# ---------------
# BING 13 | f = 1.56e-01
# BONG 13 | f = 1.56e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 1.51e-01
# BONG 14 | f = 1.51e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 1.99e-01
# BONG 15 | f = 1.99e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 1.46e-01
# BONG 16 | f = 1.46e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 17 | f = 6.08e-01
# BONG 17 | f = 5.91e-01
# ---------------
# BING 18 | f = 5.91e-01
# BONG 18 | f = 5.91e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 19 | f = 5.95e-01
# BONG 19 | f = 5.90e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 462.84 nm
#
#
# CASE 028 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 310.30 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 82.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.07e-01
# BONG 01 | f = 2.08e-01
# ---------------
# BING 02 | f = 1.14e-01
# BONG 02 | f = 1.11e-01
# ---------------
# BING 03 | f = 1.11e-01
# BONG 03 | f = 1.11e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 1.63e-01
# BONG 04 | f = 1.61e-01
# ---------------
# BING 05 | f = 1.05e-01
# BONG 05 | f = 1.05e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 1.52e-01
# BONG 06 | f = 1.52e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 5.49e-01
# BONG 07 | f = 4.74e-01
# ---------------
# BING 08 | f = 4.74e-01
# BONG 08 | f = 4.74e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 1.81e-01
# BONG 09 | f = 1.78e-01
# ---------------
# BING 10 | f = 1.07e-01
# BONG 10 | f = 1.07e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 1.24e-01
# BONG 11 | f = 1.24e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 1.03e-01
# BONG 12 | f = 1.03e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 4.06e-01
# BONG 13 | f = 3.80e-01
# ---------------
# BING 14 | f = 1.76e-01
# BONG 14 | f = 1.18e-01
# ---------------
# BING 15 | f = 1.07e-01
# BONG 15 | f = 1.07e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 1.09e-01
# BONG 16 | f = 1.09e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 17 | f = 4.45e-01
# BONG 17 | f = 4.29e-01
# ---------------
# BING 18 | f = 4.29e-01
# BONG 18 | f = 4.29e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 19 | f = 4.77e-01
# BONG 19 | f = 4.51e-01
# ---------------
# BING 20 | f = 4.51e-01
# BONG 20 | f = 4.51e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 377.97 nm
#
#
# CASE 029 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 496.55 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 29.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.00e+00
# BONG 01 | f = 9.02e-01
# ---------------
# BING 02 | f = 8.43e-01
# BONG 02 | f = 8.39e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 9.94e-01
# BONG 03 | f = 8.25e-01
# ---------------
# BING 04 | f = 7.51e-01
# BONG 04 | f = 7.51e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 9.92e-01
# BONG 05 | f = 9.75e-01
# ---------------
# BING 06 | f = 9.75e-01
# BONG 06 | f = 9.75e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 9.93e-01
# BONG 07 | f = 9.09e-01
# ---------------
# BING 08 | f = 7.79e-01
# BONG 08 | f = 7.79e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 9.90e-01
# BONG 09 | f = 6.80e-01
# ---------------
# BING 10 | f = 6.64e-01
# BONG 10 | f = 6.64e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 8.24e-01
# BONG 11 | f = 7.31e-01
# ---------------
# BING 12 | f = 7.31e-01
# BONG 12 | f = 7.28e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 9.38e-01
# BONG 13 | f = 9.14e-01
# ---------------
# BING 14 | f = 9.14e-01
# BONG 14 | f = 9.14e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 9.48e-01
# BONG 15 | f = 9.48e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 9.48e-01
# BONG 16 | f = 8.91e-01
# ---------------
# BING 17 | f = 7.93e-01
# BONG 17 | f = 7.84e-01
# ---------------
# BING 18 | f = 7.84e-01
# BONG 18 | f = 7.84e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 19 | f = 8.67e-01
# BONG 19 | f = 8.19e-01
# ---------------
# BING 20 | f = 8.19e-01
# BONG 20 | f = 8.19e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 21 | f = 9.47e-01
# BONG 21 | f = 9.10e-01
# ---------------
# BING 22 | f = 6.91e-01
# BONG 22 | f = 6.91e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 819.37 nm
#
#
# CASE 030 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 344.37 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 58.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.26e-01
# BONG 01 | f = 4.60e-01
# ---------------
# BING 02 | f = 4.04e-01
# BONG 02 | f = 4.03e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 4.49e-01
# BONG 03 | f = 4.05e-01
# ---------------
# BING 04 | f = 3.98e-01
# BONG 04 | f = 3.94e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 6.06e-01
# BONG 05 | f = 6.06e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 3.92e-01
# BONG 06 | f = 3.92e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 3.31e-01
# BONG 07 | f = 3.31e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 1.14e-01
# BONG 08 | f = 1.14e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 2.87e-01
# BONG 09 | f = 2.32e-01
# ---------------
# BING 10 | f = 1.76e-01
# BONG 10 | f = 1.64e-01
# ---------------
# BING 11 | f = 1.45e-01
# BONG 11 | f = 1.45e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 6.39e-01
# BONG 12 | f = 5.74e-01
# ---------------
# BING 13 | f = 4.03e-01
# BONG 13 | f = 3.92e-01
# ---------------
# BING 14 | f = 3.63e-01
# BONG 14 | f = 3.60e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 4.51e-01
# BONG 15 | f = 3.75e-01
# ---------------
# BING 16 | f = 3.69e-01
# BONG 16 | f = 3.69e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 17 | f = 2.66e-01
# BONG 17 | f = 2.47e-01
# ---------------
# BING 18 | f = 1.15e-01
# BONG 18 | f = 1.01e-01
# ---------------
# BING 19 | f = 1.01e-01
# BONG 19 | f = 1.01e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 20 | f = 1.15e-01
# BONG 20 | f = 1.15e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 55.89 nm
#
#
# CASE 031 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 120.82 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 107.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.75e-01
# BONG 01 | f = 1.92e-01
# ---------------
# BING 02 | f = 1.89e-01
# BONG 02 | f = 1.78e-01
# ---------------
# BING 03 | f = 1.78e-01
# BONG 03 | f = 1.78e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 2.65e-01
# BONG 04 | f = 2.03e-01
# ---------------
# BING 05 | f = 1.95e-01
# BONG 05 | f = 1.83e-01
# ---------------
# BING 06 | f = 1.83e-01
# BONG 06 | f = 1.83e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 2.81e-01
# BONG 07 | f = 2.10e-01
# ---------------
# BING 08 | f = 1.96e-01
# BONG 08 | f = 1.85e-01
# ---------------
# BING 09 | f = 1.84e-01
# BONG 09 | f = 1.83e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 2.89e-01
# BONG 10 | f = 1.94e-01
# ---------------
# BING 11 | f = 1.90e-01
# BONG 11 | f = 1.89e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 2.71e-01
# BONG 12 | f = 2.04e-01
# ---------------
# BING 13 | f = 1.94e-01
# BONG 13 | f = 1.83e-01
# ---------------
# BING 14 | f = 1.83e-01
# BONG 14 | f = 1.83e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 2.69e-01
# BONG 15 | f = 2.03e-01
# ---------------
# BING 16 | f = 1.92e-01
# BONG 16 | f = 1.81e-01
# ---------------
# BING 17 | f = 1.81e-01
# BONG 17 | f = 1.81e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 18 | f = 2.81e-01
# BONG 18 | f = 1.93e-01
# ---------------
# BING 19 | f = 1.93e-01
# BONG 19 | f = 1.93e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 20 | f = 2.95e-01
# BONG 20 | f = 2.19e-01
# ---------------
# BING 21 | f = 1.99e-01
# BONG 21 | f = 1.89e-01
# ---------------
# BING 22 | f = 1.88e-01
# BONG 22 | f = 1.83e-01
# ---------------
# BING 23 | f = 1.83e-01
# BONG 23 | f = 1.83e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 24 | f = 2.62e-01
# BONG 24 | f = 1.95e-01
# ---------------
# BING 25 | f = 1.87e-01
# BONG 25 | f = 1.75e-01
# ---------------
# BING 26 | f = 1.75e-01
# BONG 26 | f = 1.75e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 27 | f = 2.84e-01
# BONG 27 | f = 2.06e-01
# ---------------
# BING 28 | f = 1.93e-01
# BONG 28 | f = 1.83e-01
# ---------------
# BING 29 | f = 1.83e-01
# BONG 29 | f = 1.83e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 30 | f = 3.17e-01
# BONG 30 | f = 2.21e-01
# ---------------
# BING 31 | f = 1.88e-01
# BONG 31 | f = 1.80e-01
# ---------------
# BING 32 | f = 1.80e-01
# BONG 32 | f = 1.80e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 199.38 nm
#
#
# CASE 032 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 193.38 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 125.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.93e-02
# BONG 01 | f = 5.33e-02
# ---------------
# BING 02 | f = 5.11e-02
# BONG 02 | f = 5.11e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 25.70 nm
#
#
# CASE 033 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 327.31 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 46.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.66e-01
# BONG 01 | f = 5.42e-01
# ---------------
# BING 02 | f = 5.41e-01
# BONG 02 | f = 5.41e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 6.36e-01
# BONG 03 | f = 5.57e-01
# ---------------
# BING 04 | f = 5.55e-01
# BONG 04 | f = 5.52e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 7.44e-01
# BONG 05 | f = 7.43e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 5.51e-01
# BONG 06 | f = 5.37e-01
# ---------------
# BING 07 | f = 5.37e-01
# BONG 07 | f = 5.37e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 5.57e-01
# BONG 08 | f = 5.51e-01
# ---------------
# BING 09 | f = 5.51e-01
# BONG 09 | f = 5.51e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 8.00e-01
# BONG 10 | f = 7.97e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 6.03e-01
# BONG 11 | f = 5.45e-01
# ---------------
# BING 12 | f = 4.00e-01
# BONG 12 | f = 3.92e-01
# ---------------
# BING 13 | f = 3.89e-01
# BONG 13 | f = 3.89e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 5.44e-01
# BONG 14 | f = 5.44e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 6.21e-01
# BONG 15 | f = 6.21e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 6.23e-01
# BONG 16 | f = 6.05e-01
# ---------------
# BING 17 | f = 6.05e-01
# BONG 17 | f = 6.05e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 18 | f = 5.77e-01
# BONG 18 | f = 5.77e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 608.17 nm
#
#
# CASE 034 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 396.27 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 30.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 7.32e-01
# BONG 01 | f = 6.72e-01
# ---------------
# BING 02 | f = 6.72e-01
# BONG 02 | f = 6.72e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 7.27e-01
# BONG 03 | f = 7.27e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 6.20e-01
# BONG 04 | f = 5.95e-01
# ---------------
# BING 05 | f = 3.31e-01
# BONG 05 | f = 2.81e-01
# ---------------
# BING 06 | f = 2.47e-01
# BONG 06 | f = 2.46e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 7.56e-01
# BONG 07 | f = 6.94e-01
# ---------------
# BING 08 | f = 4.60e-01
# BONG 08 | f = 4.11e-01
# ---------------
# BING 09 | f = 3.38e-01
# BONG 09 | f = 3.20e-01
# ---------------
# BING 10 | f = 2.79e-01
# BONG 10 | f = 2.60e-01
# ---------------
# BING 11 | f = 2.50e-01
# BONG 11 | f = 2.49e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 8.68e-01
# BONG 12 | f = 7.28e-01
# ---------------
# BING 13 | f = 6.47e-01
# BONG 13 | f = 5.98e-01
# ...
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 3.83e-01
# BONG 05 | f = 3.48e-01
# ---------------
# BING 06 | f = 2.90e-01
# BONG 06 | f = 2.90e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 6.88e-01
# BONG 07 | f = 6.57e-01
# ---------------
# BING 08 | f = 6.04e-01
# BONG 08 | f = 3.13e-01
# ---------------
# BING 09 | f = 3.07e-01
# BONG 09 | f = 2.81e-01
# ---------------
# BING 10 | f = 2.78e-01
# BONG 10 | f = 2.73e-01
# ---------------
# BING 11 | f = 2.72e-01
# BONG 11 | f = 2.17e-01
# ---------------
# BING 12 | f = 2.09e-01
# BONG 12 | f = 2.09e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 5.92e-01
# BONG 13 | f = 3.61e-01
# ---------------
# BING 14 | f = 3.28e-01
# BONG 14 | f = 3.28e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 4.60e-01
# BONG 15 | f = 3.19e-01
# ---------------
# BING 16 | f = 2.04e-01
# BONG 16 | f = 1.59e-01
# ---------------
# BING 17 | f = 1.39e-01
# BONG 17 | f = 1.39e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 18 | f = 6.42e-01
# BONG 18 | f = 6.01e-01
# ---------------
# BING 19 | f = 6.01e-01
# BONG 19 | f = 6.01e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 20 | f = 5.60e-01
# BONG 20 | f = 5.47e-01
# ---------------
# BING 21 | f = 5.47e-01
# BONG 21 | f = 5.47e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 22 | f = 6.00e-01
# BONG 22 | f = 4.47e-01
# ---------------
# BING 23 | f = 4.29e-01
# BONG 23 | f = 3.95e-01
# ---------------
# BING 24 | f = 3.80e-01
# BONG 24 | f = 3.80e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 25 | f = 5.84e-01
# BONG 25 | f = 4.21e-01
# ---------------
# BING 26 | f = 4.17e-01
# BONG 26 | f = 4.17e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 27 | f = 6.05e-01
# BONG 27 | f = 3.48e-01
# ---------------
# BING 28 | f = 3.36e-01
# BONG 28 | f = 3.36e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 457.26 nm
#
#
# CASE 089 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 320.12 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 42.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.68e-01
# BONG 01 | f = 3.19e-01
# ---------------
# BING 02 | f = 2.17e-01
# BONG 02 | f = 2.17e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 2.15e-01
# BONG 03 | f = 2.10e-01
# ---------------
# BING 04 | f = 2.10e-01
# BONG 04 | f = 2.10e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 6.55e-01
# BONG 05 | f = 6.33e-01
# ---------------
# BING 06 | f = 6.33e-01
# BONG 06 | f = 6.28e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 7.08e-01
# BONG 07 | f = 6.39e-01
# ---------------
# BING 08 | f = 6.39e-01
# BONG 08 | f = 6.39e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 7.18e-01
# BONG 09 | f = 6.43e-01
# ---------------
# BING 10 | f = 6.43e-01
# BONG 10 | f = 6.43e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 6.20e-01
# BONG 11 | f = 6.20e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 5.91e-01
# BONG 12 | f = 5.67e-01
# ---------------
# BING 13 | f = 5.67e-01
# BONG 13 | f = 5.67e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 7.41e-01
# BONG 14 | f = 7.24e-01
# ---------------
# BING 15 | f = 7.24e-01
# BONG 15 | f = 7.24e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 6.24e-01
# BONG 16 | f = 6.06e-01
# ---------------
# BING 17 | f = 6.06e-01
# BONG 17 | f = 6.06e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 18 | f = 8.01e-01
# BONG 18 | f = 7.70e-01
# ---------------
# BING 19 | f = 7.70e-01
# BONG 19 | f = 7.70e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 20 | f = 2.31e-01
# BONG 20 | f = 2.30e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 56.70 nm
#
#
# CASE 090 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 112.17 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 195.1
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.33e-02
# BONG 01 | f = 2.25e-02
# ---------------
# BING 02 | f = 2.25e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.66 nm
#
#
# CASE 091 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 186.73 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 155.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.41e-02
# BONG 01 | f = 3.41e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.89 nm
#
#
# CASE 092 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 490.80 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 41.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.43e-01
# BONG 01 | f = 4.86e-01
# ---------------
# BING 02 | f = 4.72e-01
# BONG 02 | f = 4.72e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 8.33e-01
# BONG 03 | f = 7.99e-01
# ---------------
# BING 04 | f = 7.99e-01
# BONG 04 | f = 7.99e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 3.93e-01
# BONG 05 | f = 3.93e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 8.99e-01
# BONG 06 | f = 8.99e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 7.17e-01
# BONG 07 | f = 7.04e-01
# ---------------
# BING 08 | f = 7.04e-01
# BONG 08 | f = 7.04e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 8.71e-01
# BONG 09 | f = 8.68e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 8.68e-01
# BONG 10 | f = 7.84e-01
# ---------------
# BING 11 | f = 7.36e-01
# BONG 11 | f = 7.36e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 4.57e-01
# BONG 12 | f = 4.40e-01
# ---------------
# BING 13 | f = 4.40e-01
# BONG 13 | f = 4.40e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 4.61e-01
# BONG 14 | f = 4.61e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 4.20e-01
# BONG 15 | f = 4.20e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 5.71e-01
# BONG 16 | f = 5.71e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 774.50 nm
#
#
# CASE 093 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 259.89 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 72.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.46e-01
# BONG 01 | f = 2.06e-01
# ---------------
# BING 02 | f = 1.28e-01
# BONG 02 | f = 1.22e-01
# ---------------
# BING 03 | f = 1.22e-01
# BONG 03 | f = 1.22e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 4.20e-01
# BONG 04 | f = 3.75e-01
# ---------------
# BING 05 | f = 3.75e-01
# BONG 05 | f = 3.75e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 1.97e-01
# BONG 06 | f = 1.71e-01
# ---------------
# BING 07 | f = 1.14e-01
# BONG 07 | f = 1.08e-01
# ---------------
# BING 08 | f = 1.08e-01
# BONG 08 | f = 1.08e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 4.85e-01
# BONG 09 | f = 3.70e-01
# ---------------
# BING 10 | f = 3.63e-01
# BONG 10 | f = 3.25e-01
# ---------------
# BING 11 | f = 3.24e-01
# BONG 11 | f = 3.24e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 3.75e-01
# BONG 12 | f = 3.43e-01
# ---------------
# BING 13 | f = 2.64e-01
# BONG 13 | f = 2.60e-01
# ---------------
# BING 14 | f = 2.14e-01
# BONG 14 | f = 1.73e-01
# ---------------
# BING 15 | f = 1.24e-01
# BONG 15 | f = 1.22e-01
# ---------------
# BING 16 | f = 1.22e-01
# BONG 16 | f = 1.22e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 17 | f = 3.44e-01
# BONG 17 | f = 2.99e-01
# ---------------
# BING 18 | f = 2.99e-01
# BONG 18 | f = 2.99e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 19 | f = 1.59e-01
# BONG 19 | f = 1.53e-01
# ---------------
# BING 20 | f = 1.53e-01
# BONG 20 | f = 1.53e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 21 | f = 4.90e-01
# BONG 21 | f = 3.74e-01
# ---------------
# BING 22 | f = 3.74e-01
# BONG 22 | f = 3.74e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 23 | f = 4.47e-01
# BONG 23 | f = 3.99e-01
# ---------------
# BING 24 | f = 3.87e-01
# BONG 24 | f = 3.76e-01
# ---------------
# BING 25 | f = 3.76e-01
# BONG 25 | f = 3.76e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 26 | f = 1.70e-01
# BONG 26 | f = 1.59e-01
# ---------------
# BING 27 | f = 1.59e-01
# BONG 27 | f = 1.59e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 28 | f = 1.88e-01
# BONG 28 | f = 1.82e-01
# ---------------
# BING 29 | f = 1.82e-01
# BONG 29 | f = 1.82e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 161.55 nm
#
#
# CASE 094 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 167.37 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 144.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.53e-02
# BONG 01 | f = 3.46e-02
# ---------------
# BING 02 | f = 3.45e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.71 nm
#
#
# CASE 095 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 301.54 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 81.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.35e-01
# BONG 01 | f = 1.31e-01
# ---------------
# BING 02 | f = 1.31e-01
# BONG 02 | f = 1.31e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 1.38e-01
# BONG 03 | f = 1.38e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 1.41e-01
# BONG 04 | f = 1.22e-01
# ---------------
# BING 05 | f = 1.02e-01
# BONG 05 | f = 1.02e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 1.96e-01
# BONG 06 | f = 1.67e-01
# ---------------
# BING 07 | f = 1.09e-01
# BONG 07 | f = 1.09e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 1.24e-01
# BONG 08 | f = 1.24e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 1.58e-01
# BONG 09 | f = 1.58e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 9.34e-02
# BONG 10 | f = 9.03e-02
# ---------------
# BING 11 | f = 9.03e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 66.09 nm
#
#
# CASE 096 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 437.49 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 50.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.64e-01
# BONG 01 | f = 3.47e-01
# ---------------
# BING 02 | f = 3.47e-01
# BONG 02 | f = 3.47e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 4.91e-01
# BONG 03 | f = 4.68e-01
# ---------------
# BING 04 | f = 4.67e-01
# BONG 04 | f = 4.67e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 3.58e-01
# BONG 05 | f = 3.51e-01
# ---------------
# BING 06 | f = 3.09e-01
# BONG 06 | f = 3.09e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 4.89e-01
# BONG 07 | f = 4.68e-01
# ---------------
# BING 08 | f = 4.65e-01
# BONG 08 | f = 4.65e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 4.77e-01
# BONG 09 | f = 4.63e-01
# ---------------
# BING 10 | f = 4.63e-01
# BONG 10 | f = 4.63e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 5.48e-01
# BONG 11 | f = 5.14e-01
# ---------------
# BING 12 | f = 4.81e-01
# BONG 12 | f = 4.69e-01
# ---------------
# BING 13 | f = 4.69e-01
# BONG 13 | f = 4.69e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 4.76e-01
# BONG 14 | f = 4.64e-01
# ---------------
# BING 15 | f = 4.64e-01
# BONG 15 | f = 4.64e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 4.06e-01
# BONG 16 | f = 4.05e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 17 | f = 3.27e-01
# BONG 17 | f = 3.22e-01
# ---------------
# BING 18 | f = 3.22e-01
# BONG 18 | f = 3.22e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 19 | f = 6.26e-01
# BONG 19 | f = 5.75e-01
# ---------------
# BING 20 | f = 5.75e-01
# BONG 20 | f = 5.75e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 21 | f = 3.68e-01
# BONG 21 | f = 3.68e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 599.41 nm
#
#
# CASE 097 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 130.48 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 166.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.51e-01
# BONG 01 | f = 1.38e-01
# ---------------
# BING 02 | f = 9.76e-02
# BONG 02 | f = 6.08e-02
# ---------------
# BING 03 | f = 4.23e-02
# BONG 03 | f = 3.73e-02
# ---------------
# BING 04 | f = 3.73e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 25.50 nm
#
#
# CASE 098 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 423.26 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 31.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 9.96e-01
# BONG 01 | f = 9.91e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 9.96e-01
# BONG 02 | f = 9.91e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 9.96e-01
# BONG 03 | f = 9.90e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 9.96e-01
# BONG 04 | f = 9.90e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 9.96e-01
# BONG 05 | f = 9.90e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 9.96e-01
# BONG 06 | f = 9.89e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 9.96e-01
# BONG 07 | f = 9.90e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 9.96e-01
# BONG 08 | f = 9.90e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 9.97e-01
# BONG 09 | f = 9.90e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 9.96e-01
# BONG 10 | f = 9.86e-01
# ---------------
# BING 11 | f = 9.86e-01
# BONG 11 | f = 9.86e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 9.96e-01
# BONG 12 | f = 9.85e-01
# ---------------
# BING 13 | f = 9.85e-01
# BONG 13 | f = 9.85e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 450.59 nm
#
#
# CASE 099 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 186.22 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 85.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.71e-02
# BONG 01 | f = 6.71e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.97 nm
#
#
# CASE 100 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 139.78 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 175.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.43e-02
# BONG 01 | f = 3.29e-02
# ---------------
# BING 02 | f = 3.29e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.33 nm
#
#
# Saved data to:  /npool/nvme/derbyk/20260616_mfpr_mc/mis_med_srcmag_18_nsrc_7_randf_true.pkl

# %%
misalignments = utils.load_pickle('/home/derbyk/src/ffpr/data/misalignments_cases_100_dec_50um_tilt_5as.pkl')

# %%
# SNR threshold
snr_thresh = 5

# system stuff
fields = [(sys.cfg['sources'][src]['position_x'], sys.cfg['sources'][src]['position_y']) for src in sys.cfg['sources']]
efl = sys.cfg['general']['f_eff']
pupil_dx = sys.cfg['optics']['m1']['diam'] / sys.cfg['general']['npix_pupil']
focal_dx = sys.cfg['detector']['dx_focal']

# stuff to save
data = {}

case = 1

for m in misalignments:

    print(f'CASE {case:03.0f} ----------------------------------')
    print()

    # apply misalignment
    sys.move_optics(M1_motion=m['M1'], M2_motion=m['M4'], M3_motion=m['M4'], M4_motion=m['M4'])

    # get total OPDs per field
    opds_fields = copy.deepcopy(sys.opds_field)
    opds_optics = copy.deepcopy(sys.opds_optics)
    opds_truths = [opd_field + opd_optic for opd_field, opd_optic in zip(opds_fields, opds_optics)]

    # calculate RMS of ground truth OPDs per field
    rms_truth_per_field = []
    for opd in opds_truths:
        opd -= np.mean(opd[pupil])
        rms_truth_per_field.append(float(np.sqrt(np.mean(opd[pupil] ** 2))))

    # calculate RMS of diversity per field
    rms_diversity_per_field = []
    for opd in opds_fields_nominal:
        opd -= np.mean(opd[pupil])
        rms_diversity_per_field.append(float(np.sqrt(np.mean(opd[pupil] ** 2))))

    # take images for FFPR
    dark = sys.get_dark(stacked_frames=1)
    images = [im - dark for im in sys.snap(stacked_frames=1)]

    # get image SNRs and filter
    noise_lvl = dark.std()
    masks = []
    snr_per_field = []
    for im in images:
        snr_per_field.append(float(im.max() / dark.std()))
        mask = im > noise_lvl * snr_thresh
        masks.append(mask)

    print(f'MEDIAN RMS OPD ACROSS FIELD = {np.median(np.array(rms_truth_per_field)):.2f} nm')
    print(f'MEDIAN IMAGE SNR ACROSS FIELD = {np.median(np.array(snr_per_field)):.1f}')
    print()

    # initialize FFPR
    opt = FFPR2(wvls=sys.wvls.tolist(), amp=sys.pupil, max_zernike=11, fields=fields, divs=opds_fields_nominal, efl=efl, 
                psfs=images, pupil_dx=pupil_dx, focal_dx=focal_dx, error=gain_invariant_error, masks=masks, jitter_kernel=sys.jitter_kernel)

    # BING BONG
    BING_BONG(opt=opt, modal_cleanup=True, zonal_cleanup=False,
              max_kicks=10, iter_per_bing_bong=10, iter_per_psf=10,
              max_ls=10, thresh_conv=1e-1, frac_conv=1e-2)

    # calculate estimate residuals
    opds_estimates = [pdpr.models[0].opd + pdpr.models[0].div for pdpr in opt.PDPR_list]
    opds_residuals = [estimate - truth for estimate, truth in zip(opds_estimates, opds_truths)]

    # get RMS of residual per field
    rms_residual_per_field = []
    for opd in opds_residuals:
        opd -= np.mean(opd[pupil])
        rms_residual_per_field.append(float(np.sqrt(np.mean(opd[pupil] ** 2))))

    print(f'MEDIAN RMS RESIDUAL ACROSS FIELD = {np.median(np.array(rms_residual_per_field)):.2f} nm')
    print()
    print()

    # save to data cube
    data.update({f'CASE{case:03.0f}' : {'RMS_TRUTH_PER_FIELD' : rms_truth_per_field,
                                        'RMS_RESIDUAL_PER_FIELD' : rms_residual_per_field,
                                        'RMS_DIVERSITY_PER_FIELD' : rms_diversity_per_field,
                                        'SNR_PER_FIELD' : snr_per_field,
                                        'FIELDS' : fields}})

    case += 1

utils.save_pickle('/home/derbyk/src/ffpr/sim_results/20260504_mc_misalignments_18mag_dec_50um_tilt_5as.pkl', data=data)
# Out:
# CASE 001 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 240.37 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 55.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.34e-01
# BONG 01 | f = 4.16e-01
# ---------------
# BING 02 | f = 4.16e-01
# BONG 02 | f = 4.16e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 2.69e-01
# BONG 03 | f = 2.69e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 7.31e-01
# BONG 04 | f = 7.31e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 4.06e-01
# BONG 05 | f = 3.91e-01
# ---------------
# BING 06 | f = 3.91e-01
# BONG 06 | f = 3.91e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 1.77e-01
# BONG 07 | f = 1.77e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 6.64e-01
# BONG 08 | f = 5.93e-01
# ---------------
# BING 09 | f = 4.83e-01
# BONG 09 | f = 4.51e-01
# ---------------
# BING 10 | f = 4.50e-01
# BONG 10 | f = 4.50e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 4.41e-01
# BONG 11 | f = 4.15e-01
# ---------------
# BING 12 | f = 4.15e-01
# BONG 12 | f = 4.15e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 2.99e-01
# BONG 13 | f = 2.40e-01
# ---------------
# BING 14 | f = 1.51e-01
# BONG 14 | f = 1.51e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 6.79e-01
# BONG 15 | f = 6.63e-01
# ---------------
# BING 16 | f = 4.17e-01
# BONG 16 | f = 3.92e-01
# ---------------
# BING 17 | f = 3.92e-01
# BONG 17 | f = 3.92e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 18 | f = 5.47e-01
# BONG 18 | f = 5.41e-01
# ---------------
# BING 19 | f = 5.41e-01
# BONG 19 | f = 5.41e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 20 | f = 3.89e-01
# BONG 20 | f = 3.81e-01
# ---------------
# BING 21 | f = 3.81e-01
# BONG 21 | f = 3.81e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 435.41 nm
#
#
# CASE 002 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 373.94 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 58.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 7.22e-01
# BONG 01 | f = 7.21e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 8.33e-01
# BONG 02 | f = 7.55e-01
# ---------------
# BING 03 | f = 5.82e-01
# BONG 03 | f = 5.62e-01
# ---------------
# BING 04 | f = 5.29e-01
# BONG 04 | f = 5.27e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 2.61e-01
# BONG 05 | f = 2.50e-01
# ---------------
# BING 06 | f = 1.50e-01
# BONG 06 | f = 1.50e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 3.02e-01
# BONG 07 | f = 2.58e-01
# ---------------
# BING 08 | f = 1.42e-01
# BONG 08 | f = 1.41e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 7.53e-01
# BONG 09 | f = 7.53e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 4.84e-01
# BONG 10 | f = 4.81e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 4.99e-01
# BONG 11 | f = 4.95e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 1.73e-01
# BONG 12 | f = 1.72e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 4.65e-01
# BONG 13 | f = 4.59e-01
# ---------------
# BING 14 | f = 4.56e-01
# BONG 14 | f = 4.56e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 4.81e-01
# BONG 15 | f = 4.74e-01
# ---------------
# BING 16 | f = 4.38e-01
# BONG 16 | f = 4.37e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 17 | f = 8.42e-01
# BONG 17 | f = 6.52e-01
# ---------------
# BING 18 | f = 6.27e-01
# BONG 18 | f = 6.23e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 554.34 nm
#
#
# CASE 003 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 248.35 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 81.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.18e-01
# BONG 01 | f = 3.09e-01
# ---------------
# BING 02 | f = 2.98e-01
# BONG 02 | f = 2.98e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 4.33e-01
# BONG 03 | f = 4.31e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 1.85e-01
# BONG 04 | f = 1.77e-01
# ---------------
# BING 05 | f = 1.77e-01
# BONG 05 | f = 1.77e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 3.27e-01
# BONG 06 | f = 3.17e-01
# ---------------
# BING 07 | f = 2.26e-01
# BONG 07 | f = 2.20e-01
# ---------------
# BING 08 | f = 1.15e-01
# BONG 08 | f = 1.14e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 2.34e-01
# BONG 09 | f = 2.27e-01
# ---------------
# BING 10 | f = 1.05e-01
# BONG 10 | f = 9.75e-02
# ---------------
# BING 11 | f = 9.75e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 51.96 nm
#
#
# CASE 004 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 140.99 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 153.1
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.10e-02
# BONG 01 | f = 4.01e-02
# ---------------
# BING 02 | f = 3.04e-02
# BONG 02 | f = 3.01e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 25.94 nm
#
#
# CASE 005 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 252.90 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 70.1
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.17e-01
# BONG 01 | f = 5.17e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 3.64e-01
# BONG 02 | f = 3.55e-01
# ---------------
# BING 03 | f = 3.55e-01
# BONG 03 | f = 3.55e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 1.78e-01
# BONG 04 | f = 1.58e-01
# ---------------
# BING 05 | f = 8.68e-02
# BONG 05 | f = 8.45e-02
# ---------------
# BING 06 | f = 8.45e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 35.34 nm
#
#
# CASE 006 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 227.80 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 92.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.41e-01
# BONG 01 | f = 3.18e-01
# ---------------
# BING 02 | f = 3.18e-01
# BONG 02 | f = 3.18e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 5.35e-01
# BONG 03 | f = 4.70e-01
# ---------------
# BING 04 | f = 2.93e-01
# BONG 04 | f = 1.94e-01
# ---------------
# BING 05 | f = 1.94e-01
# BONG 05 | f = 1.88e-01
# ---------------
# BING 06 | f = 9.15e-02
# BONG 06 | f = 8.96e-02
# ---------------
# BING 07 | f = 8.26e-02
# BONG 07 | f = 8.26e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 50.51 nm
#
#
# CASE 007 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 330.98 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 39.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.80e-01
# BONG 01 | f = 5.50e-01
# ---------------
# BING 02 | f = 5.50e-01
# BONG 02 | f = 5.50e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 7.70e-01
# BONG 03 | f = 7.46e-01
# ---------------
# BING 04 | f = 7.46e-01
# BONG 04 | f = 7.46e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 5.16e-01
# BONG 05 | f = 4.94e-01
# ---------------
# BING 06 | f = 4.94e-01
# BONG 06 | f = 4.94e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 7.62e-01
# BONG 07 | f = 7.44e-01
# ---------------
# BING 08 | f = 7.44e-01
# BONG 08 | f = 7.44e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 7.01e-01
# BONG 09 | f = 7.01e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 6.95e-01
# BONG 10 | f = 6.95e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 5.38e-01
# BONG 11 | f = 5.38e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 4.56e-01
# BONG 12 | f = 4.56e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 6.71e-01
# BONG 13 | f = 6.71e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 9.55e-01
# BONG 14 | f = 8.11e-01
# ---------------
# BING 15 | f = 8.11e-01
# BONG 15 | f = 8.11e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 8.39e-01
# BONG 16 | f = 8.06e-01
# ---------------
# BING 17 | f = 7.15e-01
# BONG 17 | f = 6.90e-01
# ---------------
# BING 18 | f = 6.90e-01
# BONG 18 | f = 6.90e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 587.73 nm
#
#
# CASE 008 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 201.17 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 101.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 7.23e-02
# BONG 01 | f = 7.11e-02
# ---------------
# BING 02 | f = 7.11e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 33.25 nm
#
#
# CASE 009 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 335.10 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 59.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.72e-01
# BONG 01 | f = 6.54e-01
# ---------------
# BING 02 | f = 3.28e-01
# BONG 02 | f = 2.39e-01
# ---------------
# BING 03 | f = 2.23e-01
# BONG 03 | f = 2.19e-01
# ---------------
# BING 04 | f = 2.19e-01
# BONG 04 | f = 2.19e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 6.41e-01
# BONG 05 | f = 6.21e-01
# ---------------
# BING 06 | f = 4.39e-01
# BONG 06 | f = 3.99e-01
# ---------------
# BING 07 | f = 1.86e-01
# BONG 07 | f = 1.81e-01
# ---------------
# BING 08 | f = 1.29e-01
# BONG 08 | f = 1.25e-01
# ---------------
# BING 09 | f = 1.25e-01
# BONG 09 | f = 1.25e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 4.34e-01
# BONG 10 | f = 4.24e-01
# ---------------
# BING 11 | f = 4.24e-01
# BONG 11 | f = 4.24e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 4.44e-01
# BONG 12 | f = 4.38e-01
# ---------------
# BING 13 | f = 4.16e-01
# BONG 13 | f = 4.14e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 4.28e-01
# BONG 14 | f = 4.23e-01
# ---------------
# BING 15 | f = 4.16e-01
# BONG 15 | f = 4.13e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 1.30e-01
# BONG 16 | f = 1.27e-01
# ---------------
# BING 17 | f = 1.20e-01
# BONG 17 | f = 1.20e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 18 | f = 2.11e-01
# BONG 18 | f = 2.11e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 19 | f = 4.12e-01
# BONG 19 | f = 4.07e-01
# ---------------
# BING 20 | f = 4.07e-01
# BONG 20 | f = 4.07e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 21 | f = 2.21e-01
# BONG 21 | f = 2.15e-01
# ---------------
# BING 22 | f = 1.20e-01
# BONG 22 | f = 1.18e-01
# ---------------
# BING 23 | f = 1.18e-01
# BONG 23 | f = 1.18e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 24 | f = 2.07e-01
# BONG 24 | f = 1.88e-01
# ---------------
# BING 25 | f = 1.88e-01
# BONG 25 | f = 1.88e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 26 | f = 4.49e-01
# BONG 26 | f = 4.42e-01
# ---------------
# BING 27 | f = 4.42e-01
# BONG 27 | f = 4.42e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 570.50 nm
#
#
# CASE 010 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 240.68 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 61.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.61e-01
# BONG 01 | f = 6.05e-01
# ---------------
# BING 02 | f = 4.82e-01
# BONG 02 | f = 3.91e-01
# ---------------
# BING 03 | f = 3.91e-01
# BONG 03 | f = 3.86e-01
# ---------------
# BING 04 | f = 3.86e-01
# BONG 04 | f = 3.86e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 5.60e-01
# BONG 05 | f = 5.59e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 6.03e-01
# BONG 06 | f = 5.62e-01
# ---------------
# BING 07 | f = 5.62e-01
# BONG 07 | f = 5.62e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 6.42e-01
# BONG 08 | f = 6.14e-01
# ---------------
# BING 09 | f = 5.61e-01
# BONG 09 | f = 5.61e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 5.35e-01
# BONG 10 | f = 5.24e-01
# ---------------
# BING 11 | f = 5.24e-01
# BONG 11 | f = 5.24e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 7.54e-01
# BONG 12 | f = 5.85e-01
# ---------------
# BING 13 | f = 5.04e-01
# BONG 13 | f = 4.93e-01
# ---------------
# BING 14 | f = 4.19e-01
# BONG 14 | f = 4.00e-01
# ---------------
# BING 15 | f = 4.00e-01
# BONG 15 | f = 4.00e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 1.86e-01
# BONG 16 | f = 1.86e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 17 | f = 6.05e-01
# BONG 17 | f = 5.92e-01
# ---------------
# BING 18 | f = 4.89e-01
# BONG 18 | f = 4.88e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 19 | f = 3.57e-01
# BONG 19 | f = 3.55e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 20 | f = 4.56e-01
# BONG 20 | f = 4.55e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 21 | f = 4.23e-01
# BONG 21 | f = 4.23e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 287.01 nm
#
#
# CASE 011 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 367.38 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 43.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 7.63e-01
# BONG 01 | f = 6.77e-01
# ---------------
# BING 02 | f = 6.77e-01
# BONG 02 | f = 6.77e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 6.20e-01
# BONG 03 | f = 6.13e-01
# ---------------
# BING 04 | f = 6.13e-01
# BONG 04 | f = 6.13e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 1.77e-01
# BONG 05 | f = 1.77e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 5.78e-01
# BONG 06 | f = 5.72e-01
# ---------------
# BING 07 | f = 5.72e-01
# BONG 07 | f = 5.72e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 2.20e-01
# BONG 08 | f = 2.00e-01
# ---------------
# BING 09 | f = 2.00e-01
# BONG 09 | f = 2.00e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 6.30e-01
# BONG 10 | f = 6.21e-01
# ---------------
# BING 11 | f = 6.21e-01
# BONG 11 | f = 6.21e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 6.09e-01
# BONG 12 | f = 6.07e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 2.24e-01
# BONG 13 | f = 2.22e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 5.92e-01
# BONG 14 | f = 5.91e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 6.03e-01
# BONG 15 | f = 6.02e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 4.03e-01
# BONG 16 | f = 3.75e-01
# ---------------
# BING 17 | f = 2.12e-01
# BONG 17 | f = 2.12e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 53.05 nm
#
#
# CASE 012 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 340.29 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 47.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.39e-01
# BONG 01 | f = 5.15e-01
# ---------------
# BING 02 | f = 5.15e-01
# BONG 02 | f = 5.15e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 3.49e-01
# BONG 03 | f = 3.49e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 8.06e-01
# BONG 04 | f = 8.06e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 5.38e-01
# BONG 05 | f = 5.24e-01
# ---------------
# BING 06 | f = 5.24e-01
# BONG 06 | f = 5.24e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 8.57e-01
# BONG 07 | f = 8.12e-01
# ---------------
# BING 08 | f = 4.39e-01
# BONG 08 | f = 4.01e-01
# ---------------
# BING 09 | f = 3.98e-01
# BONG 09 | f = 3.98e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 5.20e-01
# BONG 10 | f = 4.99e-01
# ---------------
# BING 11 | f = 4.99e-01
# BONG 11 | f = 4.99e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 5.42e-01
# BONG 12 | f = 5.13e-01
# ---------------
# BING 13 | f = 5.13e-01
# BONG 13 | f = 5.13e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 3.84e-01
# BONG 14 | f = 3.84e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 7.38e-01
# BONG 15 | f = 7.15e-01
# ---------------
# BING 16 | f = 7.15e-01
# BONG 16 | f = 7.15e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 17 | f = 6.73e-01
# BONG 17 | f = 6.73e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 18 | f = 4.40e-01
# BONG 18 | f = 4.40e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 382.50 nm
#
#
# CASE 013 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 340.63 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 59.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.73e-01
# BONG 01 | f = 6.72e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 4.59e-01
# BONG 02 | f = 4.59e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 1.90e-01
# BONG 03 | f = 1.80e-01
# ---------------
# BING 04 | f = 1.24e-01
# BONG 04 | f = 1.24e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 3.77e-01
# BONG 05 | f = 3.61e-01
# ---------------
# BING 06 | f = 1.43e-01
# BONG 06 | f = 1.38e-01
# ---------------
# BING 07 | f = 1.25e-01
# BONG 07 | f = 1.25e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 7.77e-01
# BONG 08 | f = 7.77e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 4.38e-01
# BONG 09 | f = 4.31e-01
# ---------------
# BING 10 | f = 4.31e-01
# BONG 10 | f = 4.31e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 4.65e-01
# BONG 11 | f = 4.57e-01
# ---------------
# BING 12 | f = 4.31e-01
# BONG 12 | f = 4.30e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 1.36e-01
# BONG 13 | f = 1.35e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 4.45e-01
# BONG 14 | f = 4.33e-01
# ---------------
# BING 15 | f = 4.32e-01
# BONG 15 | f = 4.32e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 4.67e-01
# BONG 16 | f = 4.55e-01
# ---------------
# BING 17 | f = 4.55e-01
# BONG 17 | f = 4.55e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 18 | f = 8.11e-01
# BONG 18 | f = 6.54e-01
# ---------------
# BING 19 | f = 5.40e-01
# BONG 19 | f = 5.40e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 337.77 nm
#
#
# CASE 014 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 95.52 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 265.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.70e-02
# BONG 01 | f = 1.62e-02
# ---------------
# BING 02 | f = 1.53e-02
# BONG 02 | f = 1.53e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.50 nm
#
#
# CASE 015 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 83.02 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 269.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.74e-02
# BONG 01 | f = 1.66e-02
# ---------------
# BING 02 | f = 1.66e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 26.61 nm
#
#
# CASE 016 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 392.63 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 50.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.46e-01
# BONG 01 | f = 5.03e-01
# ---------------
# BING 02 | f = 5.03e-01
# BONG 02 | f = 5.03e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 5.27e-01
# BONG 03 | f = 4.93e-01
# ---------------
# BING 04 | f = 4.13e-01
# BONG 04 | f = 3.93e-01
# ---------------
# BING 05 | f = 3.84e-01
# BONG 05 | f = 3.84e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 5.37e-01
# BONG 06 | f = 5.19e-01
# ---------------
# BING 07 | f = 4.58e-01
# BONG 07 | f = 4.57e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 7.16e-01
# BONG 08 | f = 7.05e-01
# ---------------
# BING 09 | f = 7.05e-01
# BONG 09 | f = 7.05e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 8.52e-01
# BONG 10 | f = 7.39e-01
# ---------------
# BING 11 | f = 6.12e-01
# BONG 11 | f = 6.02e-01
# ---------------
# BING 12 | f = 5.36e-01
# BONG 12 | f = 5.36e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 6.39e-01
# BONG 13 | f = 5.64e-01
# ---------------
# BING 14 | f = 5.58e-01
# BONG 14 | f = 5.58e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 6.99e-01
# BONG 15 | f = 6.92e-01
# ---------------
# BING 16 | f = 6.92e-01
# BONG 16 | f = 6.92e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 17 | f = 2.73e-01
# BONG 17 | f = 2.72e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 18 | f = 5.30e-01
# BONG 18 | f = 4.93e-01
# ---------------
# BING 19 | f = 4.93e-01
# BONG 19 | f = 4.93e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 20 | f = 7.20e-01
# BONG 20 | f = 6.92e-01
# ---------------
# BING 21 | f = 6.92e-01
# BONG 21 | f = 6.92e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 22 | f = 6.97e-01
# BONG 22 | f = 6.73e-01
# ---------------
# BING 23 | f = 6.73e-01
# BONG 23 | f = 6.73e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 621.47 nm
#
#
# CASE 017 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 82.72 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 310.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.43e-02
# BONG 01 | f = 1.39e-02
# ---------------
# BING 02 | f = 1.39e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.86 nm
#
#
# CASE 018 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 206.83 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 80.1
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.42e-01
# BONG 01 | f = 1.41e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 5.36e-01
# BONG 02 | f = 5.18e-01
# ---------------
# BING 03 | f = 4.98e-01
# BONG 03 | f = 4.97e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 1.09e-01
# BONG 04 | f = 9.53e-02
# ---------------
# BING 05 | f = 9.53e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 29.16 nm
#
#
# CASE 019 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 355.31 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 62.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.19e-01
# BONG 01 | f = 4.63e-01
# ---------------
# BING 02 | f = 4.63e-01
# BONG 02 | f = 4.63e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 4.37e-01
# BONG 03 | f = 4.30e-01
# ---------------
# BING 04 | f = 3.74e-01
# BONG 04 | f = 3.72e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 2.30e-01
# BONG 05 | f = 2.23e-01
# ---------------
# BING 06 | f = 2.23e-01
# BONG 06 | f = 2.23e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 2.43e-01
# BONG 07 | f = 2.04e-01
# ---------------
# BING 08 | f = 2.04e-01
# BONG 08 | f = 2.04e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 2.48e-01
# BONG 09 | f = 2.23e-01
# ---------------
# BING 10 | f = 1.38e-01
# BONG 10 | f = 1.35e-01
# ---------------
# BING 11 | f = 1.27e-01
# BONG 11 | f = 1.27e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 4.38e-01
# BONG 12 | f = 3.94e-01
# ---------------
# BING 13 | f = 3.82e-01
# BONG 13 | f = 3.81e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 4.21e-01
# BONG 14 | f = 4.07e-01
# ---------------
# BING 15 | f = 3.88e-01
# BONG 15 | f = 3.88e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 1.76e-01
# BONG 16 | f = 1.71e-01
# ---------------
# BING 17 | f = 1.45e-01
# BONG 17 | f = 1.45e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 18 | f = 4.12e-01
# BONG 18 | f = 4.05e-01
# ---------------
# BING 19 | f = 4.05e-01
# BONG 19 | f = 4.05e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 20 | f = 4.56e-01
# BONG 20 | f = 4.12e-01
# ---------------
# BING 21 | f = 4.12e-01
# BONG 21 | f = 4.11e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 22 | f = 5.15e-01
# BONG 22 | f = 4.90e-01
# ---------------
# BING 23 | f = 4.90e-01
# BONG 23 | f = 4.90e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 631.71 nm
#
#
# CASE 020 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 314.73 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 48.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.82e-01
# BONG 01 | f = 4.65e-01
# ---------------
# BING 02 | f = 4.65e-01
# BONG 02 | f = 4.65e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 3.56e-01
# BONG 03 | f = 3.56e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 4.29e-01
# BONG 04 | f = 4.11e-01
# ---------------
# BING 05 | f = 4.03e-01
# BONG 05 | f = 4.03e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 9.68e-01
# BONG 06 | f = 9.68e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 5.04e-01
# BONG 07 | f = 4.96e-01
# ---------------
# BING 08 | f = 4.96e-01
# BONG 08 | f = 4.96e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 3.57e-01
# BONG 09 | f = 3.57e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 2.92e-01
# BONG 10 | f = 2.92e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 7.32e-01
# BONG 11 | f = 7.21e-01
# ---------------
# BING 12 | f = 7.21e-01
# BONG 12 | f = 7.21e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 3.68e-01
# BONG 13 | f = 3.68e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 8.73e-01
# BONG 14 | f = 8.71e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 4.65e-01
# BONG 15 | f = 4.62e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 598.76 nm
#
#
# CASE 021 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 268.99 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 81.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.22e-01
# BONG 01 | f = 3.99e-01
# ---------------
# BING 02 | f = 3.64e-01
# BONG 02 | f = 3.64e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 2.63e-01
# BONG 03 | f = 2.39e-01
# ---------------
# BING 04 | f = 1.23e-01
# BONG 04 | f = 1.17e-01
# ---------------
# BING 05 | f = 9.79e-02
# BONG 05 | f = 9.79e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 54.38 nm
#
#
# CASE 022 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 411.80 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 48.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 7.28e-01
# BONG 01 | f = 7.10e-01
# ---------------
# BING 02 | f = 7.10e-01
# BONG 02 | f = 7.10e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 5.04e-01
# BONG 03 | f = 4.98e-01
# ---------------
# BING 04 | f = 4.98e-01
# BONG 04 | f = 4.98e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 3.63e-01
# BONG 05 | f = 3.63e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 8.88e-01
# BONG 06 | f = 6.86e-01
# ---------------
# BING 07 | f = 5.48e-01
# BONG 07 | f = 5.48e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 3.65e-01
# BONG 08 | f = 3.54e-01
# ---------------
# BING 09 | f = 3.19e-01
# BONG 09 | f = 3.19e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 4.63e-01
# BONG 10 | f = 4.56e-01
# ---------------
# BING 11 | f = 4.56e-01
# BONG 11 | f = 4.56e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 7.02e-01
# BONG 12 | f = 7.02e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 3.39e-01
# BONG 13 | f = 3.35e-01
# ---------------
# BING 14 | f = 3.35e-01
# BONG 14 | f = 3.35e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 5.09e-01
# BONG 15 | f = 5.03e-01
# ---------------
# BING 16 | f = 5.03e-01
# BONG 16 | f = 5.03e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 17 | f = 8.39e-01
# BONG 17 | f = 8.39e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 18 | f = 5.25e-01
# BONG 18 | f = 5.00e-01
# ---------------
# BING 19 | f = 4.86e-01
# BONG 19 | f = 4.86e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 772.73 nm
#
#
# CASE 023 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 319.57 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 45.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.22e-01
# BONG 01 | f = 5.72e-01
# ---------------
# BING 02 | f = 4.69e-01
# BONG 02 | f = 4.69e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 4.38e-01
# BONG 03 | f = 4.37e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 5.61e-01
# BONG 04 | f = 5.51e-01
# ---------------
# BING 05 | f = 5.51e-01
# BONG 05 | f = 5.51e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 5.09e-01
# BONG 06 | f = 4.43e-01
# ---------------
# BING 07 | f = 4.10e-01
# BONG 07 | f = 3.94e-01
# ---------------
# BING 08 | f = 3.93e-01
# BONG 08 | f = 3.93e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 7.40e-01
# BONG 09 | f = 7.14e-01
# ---------------
# BING 10 | f = 6.24e-01
# BONG 10 | f = 6.18e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 3.48e-01
# BONG 11 | f = 3.48e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 3.16e-01
# BONG 12 | f = 3.16e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 5.47e-01
# BONG 13 | f = 5.23e-01
# ---------------
# BING 14 | f = 5.23e-01
# BONG 14 | f = 5.23e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 3.80e-01
# BONG 15 | f = 3.79e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 8.93e-01
# BONG 16 | f = 7.63e-01
# ---------------
# BING 17 | f = 6.41e-01
# BONG 17 | f = 6.29e-01
# ---------------
# BING 18 | f = 6.27e-01
# BONG 18 | f = 6.27e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 19 | f = 5.75e-01
# BONG 19 | f = 5.75e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 484.97 nm
#
#
# CASE 024 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 249.27 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 59.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.35e-01
# BONG 01 | f = 6.02e-01
# ---------------
# BING 02 | f = 6.02e-01
# BONG 02 | f = 6.02e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 5.00e-01
# BONG 03 | f = 4.51e-01
# ---------------
# BING 04 | f = 1.10e-01
# BONG 04 | f = 9.88e-02
# ---------------
# BING 05 | f = 9.88e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 25.65 nm
#
#
# CASE 025 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 394.15 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 43.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.88e-01
# BONG 01 | f = 5.64e-01
# ---------------
# BING 02 | f = 5.56e-01
# BONG 02 | f = 5.56e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 4.65e-01
# BONG 03 | f = 4.63e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 8.72e-01
# BONG 04 | f = 8.72e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 5.86e-01
# BONG 05 | f = 5.62e-01
# ---------------
# BING 06 | f = 5.52e-01
# BONG 06 | f = 5.52e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 4.14e-01
# BONG 07 | f = 4.14e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 7.81e-01
# BONG 08 | f = 7.81e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 5.11e-01
# BONG 09 | f = 5.11e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 7.61e-01
# BONG 10 | f = 7.61e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 4.48e-01
# BONG 11 | f = 3.92e-01
# ---------------
# BING 12 | f = 3.83e-01
# BONG 12 | f = 3.83e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 5.18e-01
# BONG 13 | f = 5.18e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 4.18e-01
# BONG 14 | f = 4.16e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 102.37 nm
#
#
# CASE 026 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 195.24 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 97.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.49e-01
# BONG 01 | f = 3.37e-01
# ---------------
# BING 02 | f = 3.37e-01
# BONG 02 | f = 3.37e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 8.86e-02
# BONG 03 | f = 7.42e-02
# ---------------
# BING 04 | f = 6.49e-02
# BONG 04 | f = 6.44e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.06 nm
#
#
# CASE 027 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 365.85 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 55.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.98e-01
# BONG 01 | f = 5.71e-01
# ---------------
# BING 02 | f = 5.71e-01
# BONG 02 | f = 5.71e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 4.55e-01
# BONG 03 | f = 4.18e-01
# ---------------
# BING 04 | f = 1.88e-01
# BONG 04 | f = 1.86e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 4.74e-01
# BONG 05 | f = 4.73e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 4.59e-01
# BONG 06 | f = 4.44e-01
# ---------------
# BING 07 | f = 4.11e-01
# BONG 07 | f = 4.11e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 4.69e-01
# BONG 08 | f = 4.68e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 2.53e-01
# BONG 09 | f = 2.44e-01
# ---------------
# BING 10 | f = 1.72e-01
# BONG 10 | f = 1.71e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 2.60e-01
# BONG 11 | f = 2.57e-01
# ---------------
# BING 12 | f = 2.57e-01
# BONG 12 | f = 2.57e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 4.43e-01
# BONG 13 | f = 4.12e-01
# ---------------
# BING 14 | f = 3.96e-01
# BONG 14 | f = 3.96e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 2.00e-01
# BONG 15 | f = 1.95e-01
# ---------------
# BING 16 | f = 1.77e-01
# BONG 16 | f = 1.77e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 17 | f = 1.86e-01
# BONG 17 | f = 1.86e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 18 | f = 4.39e-01
# BONG 18 | f = 4.30e-01
# ---------------
# BING 19 | f = 4.27e-01
# BONG 19 | f = 4.27e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 610.68 nm
#
#
# CASE 028 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 285.09 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 74.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.24e-01
# BONG 01 | f = 3.89e-01
# ---------------
# BING 02 | f = 3.78e-01
# BONG 02 | f = 3.78e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 4.59e-01
# BONG 03 | f = 4.58e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 3.94e-01
# BONG 04 | f = 3.94e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 5.46e-01
# BONG 05 | f = 5.19e-01
# ---------------
# BING 06 | f = 5.19e-01
# BONG 06 | f = 5.19e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 1.86e-01
# BONG 07 | f = 1.78e-01
# ---------------
# BING 08 | f = 1.00e-01
# BONG 08 | f = 9.79e-02
# ---------------
# BING 09 | f = 8.99e-02
# BONG 09 | f = 8.99e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 57.16 nm
#
#
# CASE 029 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 245.01 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 67.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 8.22e-01
# BONG 01 | f = 7.30e-01
# ---------------
# BING 02 | f = 5.74e-01
# BONG 02 | f = 5.65e-01
# ---------------
# BING 03 | f = 5.59e-01
# BONG 03 | f = 5.50e-01
# ---------------
# BING 04 | f = 5.49e-01
# BONG 04 | f = 5.44e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 2.02e-01
# BONG 05 | f = 2.02e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 6.87e-01
# BONG 06 | f = 6.71e-01
# ---------------
# BING 07 | f = 6.71e-01
# BONG 07 | f = 6.71e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 5.46e-01
# BONG 08 | f = 5.31e-01
# ---------------
# BING 09 | f = 5.31e-01
# BONG 09 | f = 5.31e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 6.44e-01
# BONG 10 | f = 5.68e-01
# ---------------
# BING 11 | f = 5.68e-01
# BONG 11 | f = 5.68e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 2.65e-01
# BONG 12 | f = 2.39e-01
# ---------------
# BING 13 | f = 2.39e-01
# BONG 13 | f = 2.39e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 2.77e-01
# BONG 14 | f = 2.36e-01
# ---------------
# BING 15 | f = 2.36e-01
# BONG 15 | f = 2.36e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 5.40e-01
# BONG 16 | f = 5.36e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 17 | f = 4.07e-01
# BONG 17 | f = 4.02e-01
# ---------------
# BING 18 | f = 4.02e-01
# BONG 18 | f = 4.02e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 19 | f = 4.51e-01
# BONG 19 | f = 4.49e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 20 | f = 3.31e-01
# BONG 20 | f = 3.11e-01
# ---------------
# BING 21 | f = 3.11e-01
# BONG 21 | f = 3.11e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 246.33 nm
#
#
# CASE 030 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 314.33 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 60.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.23e-01
# BONG 01 | f = 5.12e-01
# ---------------
# BING 02 | f = 5.12e-01
# BONG 02 | f = 5.12e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 4.52e-01
# BONG 03 | f = 4.52e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 1.23e-01
# BONG 04 | f = 1.18e-01
# ---------------
# BING 05 | f = 1.05e-01
# BONG 05 | f = 1.05e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 4.01e-01
# BONG 06 | f = 3.45e-01
# ---------------
# BING 07 | f = 1.23e-01
# BONG 07 | f = 1.15e-01
# ---------------
# BING 08 | f = 1.12e-01
# BONG 08 | f = 1.12e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 1.15e-01
# BONG 09 | f = 1.13e-01
# ---------------
# BING 10 | f = 1.05e-01
# BONG 10 | f = 1.04e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 5.22e-01
# BONG 11 | f = 5.16e-01
# ---------------
# BING 12 | f = 5.16e-01
# BONG 12 | f = 5.16e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 4.63e-01
# BONG 13 | f = 4.59e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 1.14e-01
# BONG 14 | f = 1.14e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 6.02e-01
# BONG 15 | f = 5.97e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 7.75e-01
# BONG 16 | f = 5.68e-01
# ---------------
# BING 17 | f = 5.38e-01
# BONG 17 | f = 5.38e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 18 | f = 3.18e-01
# BONG 18 | f = 2.57e-01
# ---------------
# BING 19 | f = 1.10e-01
# BONG 19 | f = 1.09e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 29.88 nm
#
#
# CASE 031 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 258.18 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 58.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.09e-01
# BONG 01 | f = 4.60e-01
# ---------------
# BING 02 | f = 4.60e-01
# BONG 02 | f = 4.60e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 3.13e-01
# BONG 03 | f = 3.13e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 7.57e-01
# BONG 04 | f = 7.57e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 7.66e-01
# BONG 05 | f = 7.66e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 5.31e-01
# BONG 06 | f = 4.67e-01
# ---------------
# BING 07 | f = 4.39e-01
# BONG 07 | f = 4.37e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 2.51e-01
# BONG 08 | f = 2.35e-01
# ---------------
# BING 09 | f = 1.39e-01
# BONG 09 | f = 1.39e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 3.23e-01
# BONG 10 | f = 3.23e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 4.66e-01
# BONG 11 | f = 4.44e-01
# ---------------
# BING 12 | f = 4.44e-01
# BONG 12 | f = 4.44e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 2.91e-01
# BONG 13 | f = 2.91e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 7.63e-01
# BONG 14 | f = 5.98e-01
# ---------------
# BING 15 | f = 5.29e-01
# BONG 15 | f = 5.29e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 5.37e-01
# BONG 16 | f = 4.91e-01
# ---------------
# BING 17 | f = 4.56e-01
# BONG 17 | f = 4.56e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 468.05 nm
#
#
# CASE 032 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 169.99 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 116.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.75e-02
# BONG 01 | f = 5.59e-02
# ---------------
# BING 02 | f = 4.04e-02
# BONG 02 | f = 4.04e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 25.09 nm
#
#
# CASE 033 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 204.73 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 90.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.76e-02
# BONG 01 | f = 5.72e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 28.10 nm
#
#
# CASE 034 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 414.04 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 34.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 7.98e-01
# BONG 01 | f = 7.52e-01
# ---------------
# BING 02 | f = 6.88e-01
# BONG 02 | f = 6.85e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 8.18e-01
# BONG 03 | f = 7.32e-01
# ---------------
# BING 04 | f = 6.84e-01
# BONG 04 | f = 6.84e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 5.44e-01
# BONG 05 | f = 5.42e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 6.70e-01
# BONG 06 | f = 6.70e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 4.48e-01
# BONG 07 | f = 4.43e-01
# ---------------
# BING 08 | f = 4.43e-01
# BONG 08 | f = 4.43e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 6.93e-01
# BONG 09 | f = 6.73e-01
# ---------------
# BING 10 | f = 6.73e-01
# BONG 10 | f = 6.73e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 7.01e-01
# BONG 11 | f = 6.89e-01
# ---------------
# BING 12 | f = 6.89e-01
# BONG 12 | f = 6.89e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 4.38e-01
# BONG 13 | f = 4.24e-01
# ---------------
# BING 14 | f = 4.24e-01
# BONG 14 | f = 4.24e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 6.95e-01
# BONG 15 | f = 6.93e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 6.73e-01
# BONG 16 | f = 6.71e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 17 | f = 5.92e-01
# BONG 17 | f = 5.92e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 218.92 nm
#
#
# CASE 035 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 205.47 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 97.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.58e-01
# BONG 01 | f = 1.58e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 6.92e-02
# BONG 02 | f = 6.30e-02
# ---------------
# BING 03 | f = 5.85e-02
# BONG 03 | f = 5.83e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 25.43 nm
#
#
# CASE 036 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 156.38 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 143.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.32e-02
# BONG 01 | f = 4.02e-02
# ---------------
# BING 02 | f = 3.33e-02
# BONG 02 | f = 3.33e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 28.08 nm
#
#
# CASE 037 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 281.85 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 84.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.20e-01
# BONG 01 | f = 4.03e-01
# ---------------
# BING 02 | f = 3.84e-01
# BONG 02 | f = 3.84e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 3.41e-01
# BONG 03 | f = 3.39e-01
# ...
# BING 12 | f = 5.37e-01
# BONG 12 | f = 5.36e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 2.79e-01
# BONG 13 | f = 2.79e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 1.66e-01
# BONG 14 | f = 1.66e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 1.93e-01
# BONG 15 | f = 1.93e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 128.65 nm
#
#
# CASE 087 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 144.18 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 135.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.98e-02
# BONG 01 | f = 3.94e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 28.99 nm
#
#
# CASE 088 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 269.06 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 51.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.62e-01
# BONG 01 | f = 4.68e-01
# ---------------
# BING 02 | f = 4.00e-01
# BONG 02 | f = 4.00e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 3.79e-01
# BONG 03 | f = 3.08e-01
# ---------------
# BING 04 | f = 3.08e-01
# BONG 04 | f = 3.03e-01
# ---------------
# BING 05 | f = 3.03e-01
# BONG 05 | f = 3.03e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 5.53e-01
# BONG 06 | f = 4.92e-01
# ---------------
# BING 07 | f = 4.55e-01
# BONG 07 | f = 4.33e-01
# ---------------
# BING 08 | f = 4.33e-01
# BONG 08 | f = 4.33e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 3.23e-01
# BONG 09 | f = 3.21e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 5.08e-01
# BONG 10 | f = 4.61e-01
# ---------------
# BING 11 | f = 4.61e-01
# BONG 11 | f = 4.61e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 2.73e-01
# BONG 12 | f = 2.69e-01
# ---------------
# BING 13 | f = 2.69e-01
# BONG 13 | f = 2.69e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 3.08e-01
# BONG 14 | f = 3.08e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 5.93e-01
# BONG 15 | f = 5.79e-01
# ---------------
# BING 16 | f = 5.79e-01
# BONG 16 | f = 5.79e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 17 | f = 3.56e-01
# BONG 17 | f = 3.56e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 18 | f = 7.42e-01
# BONG 18 | f = 7.42e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 19 | f = 7.01e-01
# BONG 19 | f = 6.15e-01
# ---------------
# BING 20 | f = 5.49e-01
# BONG 20 | f = 5.45e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 417.34 nm
#
#
# CASE 089 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 316.64 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 53.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 8.15e-01
# BONG 01 | f = 8.15e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 5.62e-01
# BONG 02 | f = 5.21e-01
# ---------------
# BING 03 | f = 2.94e-01
# BONG 03 | f = 2.68e-01
# ---------------
# BING 04 | f = 1.22e-01
# BONG 04 | f = 1.21e-01
# ---------------
# BING 05 | f = 1.21e-01
# BONG 05 | f = 1.21e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 6.84e-01
# BONG 06 | f = 6.66e-01
# ---------------
# BING 07 | f = 6.07e-01
# BONG 07 | f = 5.82e-01
# ---------------
# BING 08 | f = 5.80e-01
# BONG 08 | f = 5.80e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 7.18e-01
# BONG 09 | f = 6.96e-01
# ---------------
# BING 10 | f = 6.96e-01
# BONG 10 | f = 6.96e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 5.49e-01
# BONG 11 | f = 5.45e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 2.02e-01
# BONG 12 | f = 1.94e-01
# ---------------
# BING 13 | f = 1.20e-01
# BONG 13 | f = 1.19e-01
# ---------------
# BING 14 | f = 1.19e-01
# BONG 14 | f = 1.19e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 3.26e-01
# BONG 15 | f = 2.93e-01
# ---------------
# BING 16 | f = 1.23e-01
# BONG 16 | f = 1.23e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 17 | f = 6.25e-01
# BONG 17 | f = 6.25e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 18 | f = 6.93e-01
# BONG 18 | f = 6.84e-01
# ---------------
# BING 19 | f = 6.84e-01
# BONG 19 | f = 6.84e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 20 | f = 5.98e-01
# BONG 20 | f = 5.78e-01
# ---------------
# BING 21 | f = 5.78e-01
# BONG 21 | f = 5.78e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 22 | f = 6.95e-01
# BONG 22 | f = 6.49e-01
# ---------------
# BING 23 | f = 6.14e-01
# BONG 23 | f = 6.07e-01
# ---------------
# BING 24 | f = 6.06e-01
# BONG 24 | f = 6.06e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 723.53 nm
#
#
# CASE 090 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 193.54 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 103.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.02e-01
# BONG 01 | f = 1.42e-01
# ---------------
# BING 02 | f = 7.12e-02
# BONG 02 | f = 6.59e-02
# ---------------
# BING 03 | f = 6.03e-02
# BONG 03 | f = 6.03e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 31.00 nm
#
#
# CASE 091 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 112.59 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 180.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.48e-02
# BONG 01 | f = 2.37e-02
# ---------------
# BING 02 | f = 2.20e-02
# BONG 02 | f = 2.19e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.66 nm
#
#
# CASE 092 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 372.23 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 55.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.12e-01
# BONG 01 | f = 5.03e-01
# ---------------
# BING 02 | f = 4.44e-01
# BONG 02 | f = 4.44e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 4.31e-01
# BONG 03 | f = 4.25e-01
# ---------------
# BING 04 | f = 4.25e-01
# BONG 04 | f = 4.24e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 2.50e-01
# BONG 05 | f = 2.50e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 5.13e-01
# BONG 06 | f = 5.10e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 5.98e-01
# BONG 07 | f = 5.93e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 2.60e-01
# BONG 08 | f = 2.59e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 2.71e-01
# BONG 09 | f = 2.70e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 4.69e-01
# BONG 10 | f = 4.61e-01
# ---------------
# BING 11 | f = 4.23e-01
# BONG 11 | f = 4.10e-01
# ---------------
# BING 12 | f = 4.01e-01
# BONG 12 | f = 4.01e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 2.64e-01
# BONG 13 | f = 2.58e-01
# ---------------
# BING 14 | f = 2.11e-01
# BONG 14 | f = 2.11e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 8.34e-01
# BONG 15 | f = 6.13e-01
# ---------------
# BING 16 | f = 4.78e-01
# BONG 16 | f = 4.78e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 17 | f = 4.24e-01
# BONG 17 | f = 4.18e-01
# ---------------
# BING 18 | f = 4.18e-01
# BONG 18 | f = 4.18e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 689.61 nm
#
#
# CASE 093 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 178.23 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 125.1
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.06e-02
# BONG 01 | f = 5.42e-02
# ---------------
# BING 02 | f = 4.19e-02
# BONG 02 | f = 4.19e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 25.69 nm
#
#
# CASE 094 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 146.47 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 120.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.92e-02
# BONG 01 | f = 4.50e-02
# ---------------
# BING 02 | f = 3.76e-02
# BONG 02 | f = 3.76e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.06 nm
#
#
# CASE 095 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 197.32 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 117.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.33e-02
# BONG 01 | f = 5.60e-02
# ---------------
# BING 02 | f = 5.60e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 36.07 nm
#
#
# CASE 096 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 301.11 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 59.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.96e-01
# BONG 01 | f = 6.94e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 3.94e-01
# BONG 02 | f = 3.47e-01
# ---------------
# BING 03 | f = 1.95e-01
# BONG 03 | f = 1.61e-01
# ---------------
# BING 04 | f = 1.07e-01
# BONG 04 | f = 1.04e-01
# ---------------
# BING 05 | f = 1.04e-01
# BONG 05 | f = 1.04e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 4.72e-01
# BONG 06 | f = 4.70e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 6.23e-01
# BONG 07 | f = 6.12e-01
# ---------------
# BING 08 | f = 6.12e-01
# BONG 08 | f = 6.12e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 4.85e-01
# BONG 09 | f = 4.85e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 1.15e-01
# BONG 10 | f = 1.12e-01
# ---------------
# BING 11 | f = 1.04e-01
# BONG 11 | f = 1.04e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 3.99e-01
# BONG 12 | f = 3.99e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 4.92e-01
# BONG 13 | f = 4.67e-01
# ---------------
# BING 14 | f = 4.65e-01
# BONG 14 | f = 4.65e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 2.44e-01
# BONG 15 | f = 1.89e-01
# ---------------
# BING 16 | f = 1.04e-01
# BONG 16 | f = 9.58e-02
# ---------------
# BING 17 | f = 9.58e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 43.83 nm
#
#
# CASE 097 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 106.25 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 212.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.53e-02
# BONG 01 | f = 2.29e-02
# ---------------
# BING 02 | f = 2.10e-02
# BONG 02 | f = 2.10e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.88 nm
#
#
# CASE 098 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 225.98 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 75.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.21e-01
# BONG 01 | f = 2.20e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 4.82e-01
# BONG 02 | f = 4.23e-01
# ---------------
# BING 03 | f = 4.07e-01
# BONG 03 | f = 4.07e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 1.95e-01
# BONG 04 | f = 1.95e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 6.25e-01
# BONG 05 | f = 6.25e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 2.02e-01
# BONG 06 | f = 2.02e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 7.24e-01
# BONG 07 | f = 6.77e-01
# ---------------
# BING 08 | f = 3.89e-01
# BONG 08 | f = 3.89e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 5.70e-01
# BONG 09 | f = 4.97e-01
# ---------------
# BING 10 | f = 3.87e-01
# BONG 10 | f = 2.90e-01
# ---------------
# BING 11 | f = 2.90e-01
# BONG 11 | f = 2.90e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 6.95e-01
# BONG 12 | f = 6.92e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 1.83e-01
# BONG 13 | f = 1.66e-01
# ---------------
# BING 14 | f = 1.66e-01
# BONG 14 | f = 1.66e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 2.09e-01
# BONG 15 | f = 2.09e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 6.01e-01
# BONG 16 | f = 6.00e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 393.35 nm
#
#
# CASE 099 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 226.15 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 87.1
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.40e-01
# BONG 01 | f = 9.08e-02
# ---------------
# BING 02 | f = 6.43e-02
# BONG 02 | f = 6.29e-02
# ---------------
# BING 03 | f = 6.23e-02
# BONG 03 | f = 6.23e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 31.27 nm
#
#
# CASE 100 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 215.85 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 78.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.15e-01
# BONG 01 | f = 1.85e-01
# ---------------
# BING 02 | f = 1.60e-01
# BONG 02 | f = 1.60e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 4.92e-01
# BONG 03 | f = 4.62e-01
# ---------------
# BING 04 | f = 4.62e-01
# BONG 04 | f = 4.60e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 3.33e-01
# BONG 05 | f = 2.87e-01
# ---------------
# BING 06 | f = 2.87e-01
# BONG 06 | f = 2.87e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 2.86e-01
# BONG 07 | f = 2.42e-01
# ---------------
# BING 08 | f = 1.08e-01
# BONG 08 | f = 1.07e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 5.03e-01
# BONG 09 | f = 4.89e-01
# ---------------
# BING 10 | f = 4.89e-01
# BONG 10 | f = 4.89e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 5.23e-01
# BONG 11 | f = 4.84e-01
# ---------------
# BING 12 | f = 3.17e-01
# BONG 12 | f = 1.99e-01
# ---------------
# BING 13 | f = 1.99e-01
# BONG 13 | f = 1.99e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 1.84e-01
# BONG 14 | f = 1.82e-01
# ---------------
# BING 15 | f = 1.82e-01
# BONG 15 | f = 1.82e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 5.58e-01
# BONG 16 | f = 5.39e-01
# ---------------
# BING 17 | f = 5.39e-01
# BONG 17 | f = 5.39e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 18 | f = 2.96e-01
# BONG 18 | f = 2.95e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 19 | f = 4.46e-01
# BONG 19 | f = 4.45e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 20 | f = 2.26e-01
# BONG 20 | f = 1.86e-01
# ---------------
# BING 21 | f = 1.86e-01
# BONG 21 | f = 1.86e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 121.51 nm
#
#
# Saved data to:  /home/derbyk/src/ffpr/sim_results/20260504_mc_misalignments_18mag_dec_50um_tilt_5as.pkl

# %% [markdown]
# ## VISUALIZE

# %%
data = utils.load_pickle('/home/derbyk/src/ffpr/sim_results/20260504_mc_misalignments_18mag_dec_50um_tilt_5as.pkl')

median_rms_truth = np.zeros(len(data))
median_rms_residual = np.zeros(len(data))
max_rms_residual = np.zeros(len(data))
min_rms_residual = np.zeros(len(data))
std_rms_residual = np.zeros(len(data))
median_snr = np.zeros(len(data))

for i, case in enumerate(data):
    median_rms_truth[i] = np.median(np.array(data[case]['RMS_TRUTH_PER_FIELD']))
    median_rms_residual[i] = np.median(np.array(data[case]['RMS_RESIDUAL_PER_FIELD']))
    max_rms_residual[i] = np.max(np.array(data[case]['RMS_RESIDUAL_PER_FIELD']))
    min_rms_residual[i] = np.min(np.array(data[case]['RMS_RESIDUAL_PER_FIELD']))
    std_rms_residual[i] = np.std(np.array(data[case]['RMS_RESIDUAL_PER_FIELD']))
    median_snr[i] = np.median(np.array(data[case]['SNR_PER_FIELD']))

fig, axs = plt.subplot_mosaic([['histx', 'poop'],
                               ['scatter', 'histy']],
                               figsize=(8, 6), 
                               height_ratios=[1, 3],
                               width_ratios=[3, 1],
                               layout='tight',
                               dpi=150)

count = 0
fails_x = []
fails_y = []
xs = []
ys = []
cs = []

for x, y, c in zip(median_rms_truth, median_snr, median_rms_residual):
    if c < 62.5:
        xs.append(float(x))
        ys.append(float(y))
        cs.append(float(c))
    else:
        fails_x.append(float(x))
        fails_y.append(float(y))

xs = _np.array(xs)
ys = _np.array(ys)
cs = _np.array(cs)
fails_x = _np.array(fails_x)
fails_y = _np.array(fails_y)

xmin = _np.array([xs.min(), fails_x.min()]).min()
xmax = _np.array([xs.max(), fails_x.max()]).max()

ymin = _np.array([ys.min(), fails_y.min()]).min()
ymax = _np.array([ys.max(), fails_y.max()]).max()

cmin = 20
cmax = 62.5

sorted_fails_x = sorted(fails_x)
cdf_opd = [1]
cdf_x = [xmin * 0.8]
x = xmin
count = 0
while x < xmax:
    if count == len(fails_x):
        x += 10
        break
    if x + 10 < sorted_fails_x[count]:
        x += 10
        cdf_x.append(x)
        cdf_opd.append(cdf_opd[-1])
    else:
        x = sorted_fails_x[count]
        cdf_x.append(x)
        cdf_opd.append((1 - ((count + 1) / len(data))))
        count += 1
cdf_x.append(xmax * 1.1)
cdf_opd.append(cdf_opd[-1])
cdf_opd = _np.array(cdf_opd)
cdf_x = _np.array(cdf_x)

sorted_fails_y = sorted(fails_y)
cdf_snr = [1]
cdf_y = [ymin * 0.8]
y = ymin
count = 0
while y < ymax:
    if count == len(fails_y):
        y += 10
        cdf_y.append(ymax * 1.1)
        cdf_snr.append(cdf_snr[-1])
        break
    if y + 10 < sorted_fails_y[count]:
        y += 10
        cdf_y.append(y)
        cdf_snr.append(cdf_snr[-1])
    else:
        y = sorted_fails_y[count]
        cdf_y.append(y)
        cdf_snr.append((1 - ((count + 1) / len(data))))
        count += 1
cdf_snr = _np.array(cdf_snr)
cdf_y = _np.array(cdf_y)

axs['poop'].set_axis_off()

ax = axs['scatter']
ax.scatter(fails_x, fails_y, c='k', alpha=0.8, marker='x')
s = ax.scatter(xs, ys, c=cs, alpha=0.8, marker='.')
s.set_clim([cmin, cmax])
ax.set_xlabel('Median RMS OPD (nm)')
ax.set_ylabel('Median SNR')
ax.set_xlim([xmin * 0.8, xmax * 1.1])
ax.set_ylim([ymin * 0.8, ymax * 1.1])
ax.grid(which='both', alpha=0.3)

plt.colorbar(s, ax=axs['histy'], pad=0.2, label='Median RMS Residual (nm)')

ax = axs['histx']
ax.plot(cdf_x, cdf_opd)
ax.fill_between(cdf_x, cdf_opd, alpha=0.2)
# ax.hist(np.array(fails_x).get(), bins=40, color='r')
ax.tick_params(axis='x', labelbottom=False)
ax.set_ylabel('Cumulative\nSuccess Rate')
ax.set_xlim([xmin * 0.8, xmax * 1.1])
ax.set_ylim([0, 1.05])
ax.grid(which='both', alpha=0.3)

ax = axs['histy']
ax.plot(cdf_snr, _np.flip(cdf_y),)
ax.fill_betweenx(_np.flip(cdf_y), cdf_snr, alpha=0.2)
# ax.hist(np.array(fails_y).get(), bins=20, color='r', orientation='horizontal')
ax.tick_params(axis='y', labelleft=False)
ax.set_xticks([0, 0.5, 1])
ax.set_xlabel('Cumulative\nSuccess Rate')
ax.set_ylim([ymin * 0.8, ymax * 1.1])
ax.set_xlim([0, 1.05])
ax.grid(which='both', alpha=0.3)


fig.suptitle(f'RMag 15 Guide Stars\n{len(data):02.0f} Misalignment Cases; {len(cs) / len(data) * 100:02.0f}% Convergence Rate\n$\pm25\mu m$ Decenter X, Y; $\pm2.5$" Tilt X, Y')
# Out:
# Text(0.5, 0.98, 'RMag 15 Guide Stars\n100 Misalignment Cases; 52% Convergence Rate\n$\\pm25\\mu m$ Decenter X, Y; $\\pm2.5$" Tilt X, Y')
