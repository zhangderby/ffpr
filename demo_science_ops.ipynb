# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import matplotlib.cm as color
better_magma = color.magma
better_magma.set_bad('black',1.)
import matplotlib.colors as c

from prysm import (
    mathops, 
    conf,
)
from prysm.mathops import (
    _np,
    np,
    fft,
    interpolate,
    ndimage,
)
from prysm.coordinates import (
    make_xy_grid, 
    cart_to_polar,
)
from prysm.propagation import Wavefront as WF
from prysm.propagation import (
    focus_fixed_sampling,
    focus_fixed_sampling_backprop
)                              
from prysm.thinlens import (
    defocus_to_image_displacement,
    image_displacement_to_defocus,
)
from prysm.geometry import (
    offset_circle,
    circle,
    spider,
    gaussian,
)
from prysm.polynomials import (
    lstsq,
    noll_to_nm,
    zernike_nm,
    zernike_nm_seq,
    hopkins,
    sum_of_2d_modes,
    sum_of_2d_modes_backprop
)
mathops.set_backend_to_cupy()
# conf.config.precision = 32

from astropy.io import (
    fits,
    ascii,
)

from skimage.measure import centroid

import copy

from algos import BING_BONG, FFPR2, PDPR, model, mean_squared_error, gain_invariant_error
import utils

from functools import partial

from lina.utils import TikhonovInverse

import config_um
import config_um_wcc
from Batoid4LOFT.LAZULI_STOP_mark11 import Lazuli_stop, readBulkMotion, readDeformation

from psd_utils import PSDUtils

from scipy.optimize import minimize

from scipy.interpolate import RegularGridInterpolator

from tqdm import tqdm

from psd_utils import PSDUtils

from model import telescope
# from algos import pdpr, OPD, ADPR
import utils

from functools import partial

from opt import F77LBFGSB, runN, RAdam
from IPython.display import clear_output

# logging stuff
import logging
psd_log = logging.getLogger('__psd_utils__')
psd_log.disabled = True

# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

import toml

# %%
# !nvidia-smi
# Out:
# Tue Jul  7 02:02:18 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 565.57.01              Driver Version: 565.57.01      CUDA Version: 12.7     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100 80GB PCIe          On  |   00000000:25:00.0 Off |                    0 |
# | N/A   31C    P0             63W /  300W |   19943MiB /  81920MiB |     10%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A    124806      C   ...onda3/envs/py310-stp-env/bin/python       6234MiB |
# |    0   N/A  N/A    128393      C   ...onda3/envs/py310-stp-env/bin/python       6860MiB |
# |    0   N/A  N/A    129191      C   ...onda3/envs/py310-stp-env/bin/python       1344MiB |
# |    0   N/A  N/A   1182782      C   ...rojects/venv-scoob-poppy/bin/python       1620MiB |
# |    0   N/A  N/A   1497464      G   /usr/lib/xorg/Xorg                              4MiB |
# |    0   N/A  N/A   1511048      C   ...rojects/venv-scoob-poppy/bin/python       3266MiB |
# |    0   N/A  N/A   3831258      C   python                                        566MiB |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ## SETUP MODEL

# %%
config = toml.load('/home/derbyk/src/ffpr/data/3m_off_axis_default.toml')
optic_opd_data = utils.load_pickle('/home/derbyk/src/ffpr/data/opd_maps.pkl')

sources = config['sources']
for s in sources:
    sources[s]['magnitude'] = 19

sys = telescope(config=config, optic_opd_data=optic_opd_data)

dark = sys.get_dark(stacked_frames=1)
images = [im - dark for im in sys.snap(stacked_frames=1)]

for i, im in enumerate(images):
    print(f'Image {i + 1:02.0f} SNR = {im.max() / dark.std():.1f}')
# Out:
# Image 01 SNR = 100.9
# Image 02 SNR = 163.7
# Image 03 SNR = 87.9
# Image 04 SNR = 186.5
# Image 05 SNR = 115.5
# Image 06 SNR = 110.8
# Image 07 SNR = 190.5

# %% [markdown]
# ## PLOT PSFS

# %%
pupil = sys.pupil
fields = [(sys.cfg['sources'][src]['position_x'], sys.cfg['sources'][src]['position_y']) for src in sys.cfg['sources']]

utils.plot_psfs_7(psfs=images, fields=fields)

# %% [markdown]
# ## PLOT WFES

# %%
opds_fields = copy.deepcopy(sys.opds_field)
opds_optics = copy.deepcopy(sys.opds_optics)
opds_truths = [opd_field + opd_optics for (opd_field, opd_optics) in zip(opds_fields, opds_optics)]

opds_fields_nominal = opds_fields

utils.plot_opds_7(opds=opds_fields, pupil=pupil, fields=fields)
utils.plot_opds_7(opds=opds_optics, pupil=pupil, fields=fields)
utils.plot_opds_7(opds=opds_truths, pupil=pupil, fields=fields)

# %% [markdown]
# ## SEMICIRCLE FOV
#
# Telescope designed with semicircle FOV in mind. Recreated here so that random source positions fall within this region. See "Large Etendue 3-Meter Unobscured Three Mirror Anastigmat Telescope for Astrophysics" by Kim et al. 2025 for more details.

# %%
fx = np.linspace(-16.2, 16.2, 325)
fy = np.linspace(-9.0, 4.8, 139)

Fx, Fy = np.meshgrid(fx, fy)

semicirc_fov = np.sqrt(Fx ** 2 + (Fy + 14.5) ** 2) <= 19.2
Fx_valid = Fx[semicirc_fov]
Fy_valid = Fy[semicirc_fov]

plt.imshow(semicirc_fov.get(), extent=[fx.min().get(), fx.max().get(), fy.min().get(), fy.max().get()])
plt.xlabel('arcmin')
plt.ylabel('arcmin')
plt.title('Telescope Semicircle FOV')
# Out:
# Text(0.5, 1.0, 'Telescope Semicircle FOV')

# %% [markdown]
# ## MONTE CARLO

# %%
misalignments = utils.load_pickle('/home/derbyk/src/ffpr/data/misalignments_cases_100_dec_10um_tilt_1as.pkl')
snr_thresh = 5
n_sources = 3
source_mag = 19.
random_fields = True
science_field = (-12., -6.5)

sys.cfg['detector']['t_exp'] = 360

# %%
# system stuff
efl = sys.cfg['general']['f_eff']
pupil_dx = sys.cfg['optics']['m1']['diam'] / sys.cfg['general']['npix_pupil']
focal_dx = sys.cfg['detector']['dx_focal']

# set rng for repeatability on source positions
rng = np.random.default_rng(seed=272)

# stuff to save
data = {}

case = 1

for m in misalignments:

    print(f'CASE {case:03.0f} ----------------------------------')
    print()

    if random_fields:
        # get random source positions
        inds = rng.integers(low=0, high=Fx_valid.size, size=n_sources)
        new_positions = [(float(Fx_valid[i]), float(Fy_valid[i])) for i in inds]
        new_positions.append(science_field)
    else:
        new_positions = [(sys.cfg['sources'][src]['position_x'], sys.cfg['sources'][src]['position_y']) for src in sys.cfg['sources']]

    mags = [source_mag for _ in range(n_sources + 1)]

    # send positions to model 
    sys.set_source_parameters(magnitudes=mags, positions=new_positions)

    # reset optics to nominal alignment
    sys.reset_optics()

    # get field dependent OPD at nominal alignment
    opds_fields_nominal = copy.deepcopy(sys.opds_field)[:n_sources]
    opd_sci_nominal = copy.deepcopy(sys.opds_field)[-1]
    # opds_fields_nominal += copy.deepcopy(sys.opds_optics)[:n_sources]

    # calculate RMS of diversity per field
    # diversity comes from field dependent OPD at nominal alignment
    rms_diversity_per_field = []
    for opd in opds_fields_nominal:
        opd -= np.mean(opd[pupil])
        rms_diversity_per_field.append(float(np.sqrt(np.mean(opd[pupil] ** 2))))

    # apply misalignment
    sys.move_optics(M1_motion=m['M1'], M2_motion=m['M4'], M3_motion=m['M4'], M4_motion=m['M4'])

    # get total OPDs per field
    opds_fields = copy.deepcopy(sys.opds_field)[:n_sources]
    opds_optics = copy.deepcopy(sys.opds_optics)[:n_sources]
    opds_truths = [opd_field + opd_optic for opd_field, opd_optic in zip(opds_fields, opds_optics)]
    opd_sci_field = copy.deepcopy(sys.opds_field)[-1] 
    opd_sci_optic = copy.deepcopy(sys.opds_optics)[-1]
    opd_sci_truth = opd_sci_field + opd_sci_optic

    # calculate RMS of ground truth OPDs per field
    rms_truth_per_field = []
    for opd in opds_truths:
        opd -= np.mean(opd[pupil])
        rms_truth_per_field.append(float(np.sqrt(np.mean(opd[pupil] ** 2))))

    # take images for FFPR
    dark = sys.get_dark(stacked_frames=1)
    images = [im - dark for im in sys.snap(stacked_frames=1)]
    image_sci = images[-1]

    # get image SNRs and filter
    noise_lvl = dark.std()
    masks = []
    snr_per_field = []
    for im in images:
        snr_per_field.append(float(im.max() / dark.std()))
        mask = im > noise_lvl * snr_thresh
        masks.append(mask)

    print(f'MEDIAN RMS OPD ACROSS FIELD = {np.median(np.array(rms_truth_per_field)):.2f} nm')
    print(f'MEDIAN IMAGE SNR ACROSS FIELD = {np.median(np.array(snr_per_field)):.1f}')
    print()

    # initialize FFPR
    opt = FFPR2(wvls=sys.wvls.tolist(), amp=sys.pupil, max_zernike=11, fields=new_positions[:n_sources], divs=opds_fields_nominal, efl=efl, 
                psfs=images[:n_sources], pupil_dx=pupil_dx, focal_dx=focal_dx, error=gain_invariant_error, masks=masks, jitter_kernel=sys.jitter_kernel)

    # BING BONG
    BING_BONG(opt=opt, modal_cleanup=False, zonal_cleanup=False,
              max_kicks=10, iter_per_bing_bong=10, iter_per_psf=10,
              max_ls=10, thresh_conv=1e-1, frac_conv=1e-2)

    # calculate estimate residuals
    opds_estimates = [pdpr.models[0].opd + pdpr.models[0].div for pdpr in opt.PDPR_list]
    opds_residuals = [estimate - truth for estimate, truth in zip(opds_estimates, opds_truths)]
    opds_residuals = opds_residuals

    # get estimate at science field
    coeffs = copy.deepcopy(opt.coeffs)
    coeffs[2] += opt.field_terms[0] * science_field[0] + opt.field_terms[1] * science_field[1] 
    coeffs[3] += opt.field_terms[2] * science_field[0] + opt.field_terms[3] * science_field[1]
    coeffs[4] += opt.field_terms[4] * science_field[0] + opt.field_terms[5] * science_field[1]
    opd_sci_estimate = sum_of_2d_modes(opt.PDPR_list[0].modes, coeffs) + opd_sci_nominal # + opd_sci_optic

    # calculate science field residuals
    opd_sci_residual = opd_sci_estimate - opd_sci_truth
    opd_sci_residual -= np.mean(opd_sci_residual[pupil])
    opd_sci_residual_rms = np.sqrt(np.mean(opd_sci_residual[pupil] ** 2))

    # get RMS of residual per field
    rms_residual_per_field = []
    for opd in opds_residuals:
        opd -= np.mean(opd[pupil])
        rms_residual_per_field.append(float(np.sqrt(np.mean(opd[pupil] ** 2))))

    print(f'MEDIAN RMS RESIDUAL ACROSS FIELD = {np.median(np.array(rms_residual_per_field)):.2f} nm')
    print(f'RMS RESIDUAL AT SCIENCE FIELD = {np.median(np.array(opd_sci_residual_rms)):.2f} nm')

    print()
    print()

    # save to data cube
    data.update({f'CASE{case:03.0f}' : {'WFE_NOMINAL' : opds_fields_nominal,
                                        'WFE_TRUTH' : opds_truths,
                                        'WFE_ESTIMATE' : opds_estimates,
                                        'SNR_PER_FIELD' : snr_per_field,
                                        'FIELDS' : new_positions,
                                        'SCI_IMAGE' : image_sci,
                                        'SCI_FIELD' : science_field,
                                        'SCI_TRUTH' : opd_sci_truth,
                                        'SCI_ESTIMATE' : opd_sci_estimate}})

    case += 1

utils.save_pickle(f'/npool/nvme/derbyk/20260616_mfpr_mc/mis_smol_srcmag_{source_mag:.0f}_nsrc_{n_sources:.0f}_randf_true_nframes_1_exp_360_sci.pkl', data=data)
# Out:
# CASE 001 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 39.20 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 1106.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.10e-02
# BONG 01 | f = 1.09e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.61 nm
# RMS RESIDUAL AT SCIENCE FIELD = 23.34 nm
#
#
# CASE 002 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 97.87 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 549.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.00e-02
# BONG 01 | f = 1.92e-02
# ---------------
# BING 02 | f = 1.92e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.14 nm
# RMS RESIDUAL AT SCIENCE FIELD = 23.14 nm
#
#
# CASE 003 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 164.87 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 552.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.65e-02
# BONG 01 | f = 2.51e-02
# ---------------
# BING 02 | f = 2.46e-02
# BONG 02 | f = 2.46e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.55 nm
# RMS RESIDUAL AT SCIENCE FIELD = 22.60 nm
#
#
# CASE 004 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 102.34 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 861.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.49e-02
# BONG 01 | f = 1.39e-02
# ---------------
# BING 02 | f = 1.39e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 20.93 nm
# RMS RESIDUAL AT SCIENCE FIELD = 20.59 nm
#
#
# CASE 005 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 115.44 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 626.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.20e-02
# BONG 01 | f = 2.20e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 25.07 nm
# RMS RESIDUAL AT SCIENCE FIELD = 24.11 nm
#
#
# CASE 006 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 116.86 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 610.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.13e-02
# BONG 01 | f = 2.11e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 21.87 nm
# RMS RESIDUAL AT SCIENCE FIELD = 21.65 nm
#
#
# CASE 007 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 58.14 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 885.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.27e-02
# BONG 01 | f = 1.25e-02
# ---------------
# BING 02 | f = 1.25e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.31 nm
# RMS RESIDUAL AT SCIENCE FIELD = 22.95 nm
#
#
# CASE 008 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 131.89 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 672.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.04e-02
# BONG 01 | f = 2.04e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.37 nm
# RMS RESIDUAL AT SCIENCE FIELD = 21.08 nm
#
#
# CASE 009 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 105.07 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 481.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.01e-02
# BONG 01 | f = 3.01e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.28 nm
# RMS RESIDUAL AT SCIENCE FIELD = 22.11 nm
#
#
# CASE 010 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 67.17 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 773.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.48e-02
# BONG 01 | f = 1.43e-02
# ---------------
# BING 02 | f = 1.43e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.39 nm
# RMS RESIDUAL AT SCIENCE FIELD = 21.44 nm
#
#
# CASE 011 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 123.99 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 522.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.19e-02
# BONG 01 | f = 2.17e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.69 nm
# RMS RESIDUAL AT SCIENCE FIELD = 21.66 nm
#
#
# CASE 012 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 87.68 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 598.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.26e-02
# BONG 01 | f = 2.26e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.29 nm
# RMS RESIDUAL AT SCIENCE FIELD = 22.13 nm
#
#
# CASE 013 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 65.89 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 659.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.75e-02
# BONG 01 | f = 1.70e-02
# ---------------
# BING 02 | f = 1.68e-02
# BONG 02 | f = 1.68e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.50 nm
# RMS RESIDUAL AT SCIENCE FIELD = 34.72 nm
#
#
# CASE 014 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 72.33 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 843.1
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.37e-02
# BONG 01 | f = 1.37e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.94 nm
# RMS RESIDUAL AT SCIENCE FIELD = 23.63 nm
#
#
# CASE 015 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 107.50 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 838.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.63e-02
# BONG 01 | f = 1.62e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.04 nm
# RMS RESIDUAL AT SCIENCE FIELD = 25.38 nm
#
#
# CASE 016 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 93.94 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 523.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.70e-02
# BONG 01 | f = 2.65e-02
# ---------------
# BING 02 | f = 2.65e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.20 nm
# RMS RESIDUAL AT SCIENCE FIELD = 21.39 nm
#
#
# CASE 017 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 101.68 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 792.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.53e-02
# BONG 01 | f = 2.41e-02
# ---------------
# BING 02 | f = 2.40e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 25.75 nm
# RMS RESIDUAL AT SCIENCE FIELD = 33.33 nm
#
#
# CASE 018 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 113.68 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 621.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.98e-02
# BONG 01 | f = 1.92e-02
# ---------------
# BING 02 | f = 1.92e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.66 nm
# RMS RESIDUAL AT SCIENCE FIELD = 24.07 nm
#
#
# CASE 019 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 96.49 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 543.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.05e-02
# BONG 01 | f = 2.03e-02
# ---------------
# BING 02 | f = 2.01e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.49 nm
# RMS RESIDUAL AT SCIENCE FIELD = 22.35 nm
#
#
# CASE 020 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 57.32 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 835.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.22e-02
# BONG 01 | f = 1.17e-02
# ---------------
# BING 02 | f = 1.17e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.48 nm
# RMS RESIDUAL AT SCIENCE FIELD = 22.22 nm
#
#
# CASE 021 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 73.59 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 726.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.69e-02
# BONG 01 | f = 1.63e-02
# ---------------
# BING 02 | f = 1.63e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.16 nm
# RMS RESIDUAL AT SCIENCE FIELD = 26.60 nm
#
#
# CASE 022 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 128.75 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 313.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.63e-02
# BONG 01 | f = 4.63e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.35 nm
# RMS RESIDUAL AT SCIENCE FIELD = 24.28 nm
#
#
# CASE 023 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 96.17 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 599.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.36e-02
# BONG 01 | f = 2.33e-02
# ---------------
# BING 02 | f = 2.32e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.06 nm
# RMS RESIDUAL AT SCIENCE FIELD = 21.12 nm
#
#
# CASE 024 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 80.85 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 765.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.35e-02
# BONG 01 | f = 2.35e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.34 nm
# RMS RESIDUAL AT SCIENCE FIELD = 22.97 nm
#
#
# CASE 025 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 94.43 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 456.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.22e-02
# BONG 01 | f = 2.20e-02
# ---------------
# BING 02 | f = 2.20e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.87 nm
# RMS RESIDUAL AT SCIENCE FIELD = 23.18 nm
#
#
# CASE 026 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 108.34 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 510.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.79e-02
# BONG 01 | f = 2.61e-02
# ---------------
# BING 02 | f = 2.60e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.13 nm
# RMS RESIDUAL AT SCIENCE FIELD = 26.66 nm
#
#
# CASE 027 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 123.72 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 591.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.35e-02
# BONG 01 | f = 2.34e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.47 nm
# RMS RESIDUAL AT SCIENCE FIELD = 25.29 nm
#
#
# CASE 028 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 85.69 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 751.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.52e-02
# BONG 01 | f = 2.42e-02
# ---------------
# BING 02 | f = 2.42e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.91 nm
# RMS RESIDUAL AT SCIENCE FIELD = 26.04 nm
#
#
# CASE 029 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 169.93 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 506.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.28e-02
# BONG 01 | f = 3.28e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.41 nm
# RMS RESIDUAL AT SCIENCE FIELD = 22.03 nm
#
#
# CASE 030 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 165.89 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 531.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.38e-02
# BONG 01 | f = 2.38e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.59 nm
# RMS RESIDUAL AT SCIENCE FIELD = 22.56 nm
#
#
# CASE 031 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 168.15 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 409.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.52e-02
# BONG 01 | f = 3.49e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.49 nm
# RMS RESIDUAL AT SCIENCE FIELD = 26.88 nm
#
#
# CASE 032 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 102.68 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 656.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.08e-02
# BONG 01 | f = 2.03e-02
# ---------------
# BING 02 | f = 2.03e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 25.14 nm
# RMS RESIDUAL AT SCIENCE FIELD = 23.90 nm
#
#
# CASE 033 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 77.49 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 693.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.35e-02
# BONG 01 | f = 1.33e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.55 nm
# RMS RESIDUAL AT SCIENCE FIELD = 26.97 nm
#
#
# CASE 034 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 107.87 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 522.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.18e-02
# BONG 01 | f = 2.09e-02
# ---------------
# BING 02 | f = 2.09e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.65 nm
# RMS RESIDUAL AT SCIENCE FIELD = 21.99 nm
#
#
# CASE 035 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 101.46 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 696.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.72e-02
# BONG 01 | f = 1.71e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 20.60 nm
# RMS RESIDUAL AT SCIENCE FIELD = 22.24 nm
#
#
# CASE 036 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 72.74 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 785.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.43e-02
# BONG 01 | f = 1.39e-02
# ---------------
# BING 02 | f = 1.38e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 21.54 nm
# RMS RESIDUAL AT SCIENCE FIELD = 20.96 nm
#
#
# CASE 037 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 88.18 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 713.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.95e-02
# BONG 01 | f = 1.81e-02
# ---------------
# BING 02 | f = 1.81e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.37 nm
# RMS RESIDUAL AT SCIENCE FIELD = 22.42 nm
#
#
# CASE 038 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 171.75 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 486.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.53e-02
# BONG 01 | f = 4.48e-02
# ---------------
# BING 02 | f = 4.48e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.69 nm
# RMS RESIDUAL AT SCIENCE FIELD = 22.83 nm
#
#
# CASE 039 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 111.54 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 838.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.75e-02
# BONG 01 | f = 1.61e-02
# ---------------
# BING 02 | f = 1.60e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.78 nm
# RMS RESIDUAL AT SCIENCE FIELD = 25.80 nm
#
#
# CASE 040 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 97.88 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 729.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.66e-02
# BONG 01 | f = 2.65e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.56 nm
# RMS RESIDUAL AT SCIENCE FIELD = 23.21 nm
#
#
# CASE 041 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 177.93 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 447.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.27e-02
# BONG 01 | f = 3.15e-02
# ---------------
# BING 02 | f = 3.15e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.38 nm
# RMS RESIDUAL AT SCIENCE FIELD = 24.84 nm
#
#
# CASE 042 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 113.71 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 639.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.00e-02
# BONG 01 | f = 1.97e-02
# ---------------
# BING 02 | f = 1.96e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.09 nm
# RMS RESIDUAL AT SCIENCE FIELD = 25.51 nm
#
#
# CASE 043 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 71.37 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 859.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.02e-02
# BONG 01 | f = 1.00e-02
# ---------------
# BING 02 | f = 1.00e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.20 nm
# RMS RESIDUAL AT SCIENCE FIELD = 23.51 nm
#
#
# CASE 044 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 71.04 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 701.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.49e-02
# BONG 01 | f = 1.46e-02
# ---------------
# BING 02 | f = 1.46e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.08 nm
# RMS RESIDUAL AT SCIENCE FIELD = 22.39 nm
#
#
# CASE 045 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 116.41 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 682.1
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.76e-02
# BONG 01 | f = 1.76e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.59 nm
# RMS RESIDUAL AT SCIENCE FIELD = 23.67 nm
#
#
# CASE 046 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 94.17 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 545.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.65e-02
# BONG 01 | f = 2.51e-02
# ---------------
# BING 02 | f = 2.46e-02
# BONG 02 | f = 2.46e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.85 nm
# RMS RESIDUAL AT SCIENCE FIELD = 24.43 nm
#
#
# CASE 047 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 93.18 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 543.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.28e-02
# BONG 01 | f = 2.24e-02
# ---------------
# BING 02 | f = 2.22e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 21.83 nm
# RMS RESIDUAL AT SCIENCE FIELD = 20.69 nm
#
#
# CASE 048 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 83.49 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 682.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.82e-02
# BONG 01 | f = 2.63e-02
# ---------------
# BING 02 | f = 2.62e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.80 nm
# RMS RESIDUAL AT SCIENCE FIELD = 21.30 nm
#
#
# CASE 049 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 78.89 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 662.1
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.90e-02
# BONG 01 | f = 1.70e-02
# ---------------
# BING 02 | f = 1.66e-02
# BONG 02 | f = 1.65e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.48 nm
# RMS RESIDUAL AT SCIENCE FIELD = 31.19 nm
#
#
# CASE 050 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 101.57 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 735.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.70e-02
# BONG 01 | f = 1.69e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.48 nm
# RMS RESIDUAL AT SCIENCE FIELD = 21.93 nm
#
#
# CASE 051 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 86.22 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 621.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.76e-02
# BONG 01 | f = 1.75e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.70 nm
# RMS RESIDUAL AT SCIENCE FIELD = 21.77 nm
#
#
# CASE 052 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 103.97 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 543.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.48e-02
# BONG 01 | f = 2.48e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 21.95 nm
# RMS RESIDUAL AT SCIENCE FIELD = 21.07 nm
#
#
# CASE 053 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 102.26 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 576.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.14e-02
# BONG 01 | f = 2.14e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 21.84 nm
# RMS RESIDUAL AT SCIENCE FIELD = 21.29 nm
#
#
# CASE 054 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 66.63 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 812.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.34e-02
# BONG 01 | f = 1.33e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.60 nm
# RMS RESIDUAL AT SCIENCE FIELD = 23.49 nm
#
#
# CASE 055 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 58.21 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 843.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.72e-02
# BONG 01 | f = 1.67e-02
# ---------------
# BING 02 | f = 1.67e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.91 nm
# RMS RESIDUAL AT SCIENCE FIELD = 22.53 nm
#
#
# CASE 056 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 69.47 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 825.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.86e-02
# BONG 01 | f = 1.85e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.67 nm
# RMS RESIDUAL AT SCIENCE FIELD = 24.57 nm
#
#
# CASE 057 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 141.86 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 586.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.10e-02
# BONG 01 | f = 2.05e-02
# ---------------
# BING 02 | f = 2.05e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.04 nm
# RMS RESIDUAL AT SCIENCE FIELD = 22.79 nm
#
#
# CASE 058 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 82.03 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 867.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.10e-02
# BONG 01 | f = 1.10e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.38 nm
# RMS RESIDUAL AT SCIENCE FIELD = 24.38 nm
#
#
# CASE 059 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 145.81 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 424.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.13e-02
# BONG 01 | f = 4.08e-02
# ---------------
# BING 02 | f = 4.08e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.99 nm
# RMS RESIDUAL AT SCIENCE FIELD = 22.27 nm
#
#
# CASE 060 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 125.70 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 450.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.56e-02
# BONG 01 | f = 2.52e-02
# ---------------
# BING 02 | f = 2.48e-02
# BONG 02 | f = 2.47e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.80 nm
# RMS RESIDUAL AT SCIENCE FIELD = 25.56 nm
#
#
# CASE 061 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 108.69 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 632.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.21e-02
# BONG 01 | f = 2.20e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 21.84 nm
# RMS RESIDUAL AT SCIENCE FIELD = 21.10 nm
#
#
# CASE 062 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 112.61 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 555.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.15e-02
# BONG 01 | f = 3.01e-02
# ---------------
# BING 02 | f = 3.01e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.66 nm
# RMS RESIDUAL AT SCIENCE FIELD = 28.01 nm
#
#
# CASE 063 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 74.40 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 750.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.36e-02
# BONG 01 | f = 1.32e-02
# ---------------
# BING 02 | f = 1.32e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.06 nm
# RMS RESIDUAL AT SCIENCE FIELD = 20.67 nm
#
#
# CASE 064 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 159.49 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 530.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.77e-02
# BONG 01 | f = 3.72e-02
# ---------------
# BING 02 | f = 3.70e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.75 nm
# RMS RESIDUAL AT SCIENCE FIELD = 24.19 nm
#
#
# CASE 065 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 169.11 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 315.1
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.05e-02
# BONG 01 | f = 3.92e-02
# ---------------
# BING 02 | f = 3.89e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 26.51 nm
# RMS RESIDUAL AT SCIENCE FIELD = 26.83 nm
#
#
# CASE 066 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 109.18 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 581.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.58e-02
# BONG 01 | f = 2.57e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.15 nm
# RMS RESIDUAL AT SCIENCE FIELD = 25.57 nm
#
#
# CASE 067 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 94.96 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 644.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.09e-02
# BONG 01 | f = 2.07e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.61 nm
# RMS RESIDUAL AT SCIENCE FIELD = 21.57 nm
#
#
# CASE 068 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 77.49 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 746.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.56e-02
# BONG 01 | f = 1.51e-02
# ---------------
# BING 02 | f = 1.51e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.09 nm
# RMS RESIDUAL AT SCIENCE FIELD = 22.68 nm
#
#
# CASE 069 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 90.22 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 669.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.83e-02
# BONG 01 | f = 1.81e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.43 nm
# RMS RESIDUAL AT SCIENCE FIELD = 23.17 nm
#
#
# CASE 070 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 126.99 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 549.1
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.58e-02
# BONG 01 | f = 2.54e-02
# ---------------
# BING 02 | f = 2.54e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.53 nm
# RMS RESIDUAL AT SCIENCE FIELD = 20.47 nm
#
#
# CASE 071 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 93.88 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 560.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.73e-02
# BONG 01 | f = 1.72e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.71 nm
# RMS RESIDUAL AT SCIENCE FIELD = 23.11 nm
#
#
# CASE 072 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 89.67 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 741.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.20e-02
# BONG 01 | f = 1.18e-02
# ---------------
# BING 02 | f = 1.18e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.11 nm
# RMS RESIDUAL AT SCIENCE FIELD = 25.87 nm
#
#
# CASE 073 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 159.71 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 442.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.44e-02
# BONG 01 | f = 4.42e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 21.27 nm
# RMS RESIDUAL AT SCIENCE FIELD = 21.23 nm
#
#
# CASE 074 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 92.13 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 737.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.00e-02
# BONG 01 | f = 1.97e-02
# ---------------
# BING 02 | f = 1.97e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.06 nm
# RMS RESIDUAL AT SCIENCE FIELD = 25.03 nm
#
#
# CASE 075 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 82.16 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 748.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.45e-02
# BONG 01 | f = 1.45e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.09 nm
# RMS RESIDUAL AT SCIENCE FIELD = 22.64 nm
#
#
# CASE 076 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 87.22 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 665.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.69e-02
# BONG 01 | f = 2.65e-02
# ---------------
# BING 02 | f = 2.64e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.47 nm
# RMS RESIDUAL AT SCIENCE FIELD = 21.31 nm
#
#
# CASE 077 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 106.67 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 766.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.36e-02
# BONG 01 | f = 1.32e-02
# ---------------
# BING 02 | f = 1.32e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 25.16 nm
# RMS RESIDUAL AT SCIENCE FIELD = 26.61 nm
#
#
# CASE 078 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 136.15 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 679.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.56e-02
# BONG 01 | f = 2.54e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.78 nm
# RMS RESIDUAL AT SCIENCE FIELD = 22.40 nm
#
#
# CASE 079 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 72.34 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 810.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.26e-02
# BONG 01 | f = 1.26e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 20.57 nm
# RMS RESIDUAL AT SCIENCE FIELD = 21.98 nm
#
#
# CASE 080 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 61.13 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 789.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.45e-02
# BONG 01 | f = 1.45e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 20.53 nm
# RMS RESIDUAL AT SCIENCE FIELD = 20.54 nm
#
#
# CASE 081 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 73.26 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 875.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.16e-02
# BONG 01 | f = 1.15e-02
# ---------------
# BING 02 | f = 1.14e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.10 nm
# RMS RESIDUAL AT SCIENCE FIELD = 21.17 nm
#
#
# CASE 082 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 97.58 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 848.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.71e-02
# BONG 01 | f = 1.70e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.30 nm
# RMS RESIDUAL AT SCIENCE FIELD = 22.76 nm
#
#
# CASE 083 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 129.80 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 426.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.77e-02
# BONG 01 | f = 2.74e-02
# ---------------
# BING 02 | f = 2.73e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.90 nm
# RMS RESIDUAL AT SCIENCE FIELD = 25.92 nm
#
#
# CASE 084 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 74.52 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 756.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.40e-02
# BONG 01 | f = 1.37e-02
# ---------------
# BING 02 | f = 1.37e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 21.32 nm
# RMS RESIDUAL AT SCIENCE FIELD = 21.12 nm
#
#
# CASE 085 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 95.31 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 452.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.30e-02
# BONG 01 | f = 2.30e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.35 nm
# RMS RESIDUAL AT SCIENCE FIELD = 24.38 nm
#
#
# CASE 086 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 172.03 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 511.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.72e-02
# BONG 01 | f = 2.60e-02
# ---------------
# BING 02 | f = 2.60e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.48 nm
# RMS RESIDUAL AT SCIENCE FIELD = 28.41 nm
#
#
# CASE 087 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 120.92 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 606.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.10e-02
# BONG 01 | f = 2.04e-02
# ---------------
# BING 02 | f = 2.03e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.01 nm
# RMS RESIDUAL AT SCIENCE FIELD = 22.78 nm
#
#
# CASE 088 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 79.65 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 722.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.67e-02
# BONG 01 | f = 1.44e-02
# ---------------
# BING 02 | f = 1.43e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.19 nm
# RMS RESIDUAL AT SCIENCE FIELD = 61.11 nm
#
#
# CASE 089 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 116.29 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 563.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.42e-02
# BONG 01 | f = 2.39e-02
# ---------------
# BING 02 | f = 2.37e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.05 nm
# RMS RESIDUAL AT SCIENCE FIELD = 22.70 nm
#
#
# CASE 090 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 49.59 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 948.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.14e-02
# BONG 01 | f = 1.14e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.38 nm
# RMS RESIDUAL AT SCIENCE FIELD = 22.11 nm
#
#
# CASE 091 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 135.46 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 553.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.91e-02
# BONG 01 | f = 2.82e-02
# ---------------
# BING 02 | f = 2.79e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.30 nm
# RMS RESIDUAL AT SCIENCE FIELD = 22.44 nm
#
#
# CASE 092 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 140.92 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 434.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.62e-02
# BONG 01 | f = 3.56e-02
# ---------------
# BING 02 | f = 3.47e-02
# BONG 02 | f = 3.47e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 26.94 nm
# RMS RESIDUAL AT SCIENCE FIELD = 21.90 nm
#
#
# CASE 093 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 130.59 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 606.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.18e-02
# BONG 01 | f = 3.10e-02
# ---------------
# BING 02 | f = 3.06e-02
# BONG 02 | f = 3.06e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.84 nm
# RMS RESIDUAL AT SCIENCE FIELD = 24.93 nm
#
#
# CASE 094 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 83.59 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 703.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.77e-02
# BONG 01 | f = 1.70e-02
# ---------------
# BING 02 | f = 1.68e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 21.78 nm
# RMS RESIDUAL AT SCIENCE FIELD = 23.30 nm
#
#
# CASE 095 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 69.38 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 806.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.43e-02
# BONG 01 | f = 1.40e-02
# ---------------
# BING 02 | f = 1.40e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.43 nm
# RMS RESIDUAL AT SCIENCE FIELD = 21.42 nm
#
#
# CASE 096 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 87.63 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 578.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.07e-02
# BONG 01 | f = 3.07e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.28 nm
# RMS RESIDUAL AT SCIENCE FIELD = 21.89 nm
#
#
# CASE 097 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 95.90 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 772.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.74e-02
# BONG 01 | f = 1.73e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 21.92 nm
# RMS RESIDUAL AT SCIENCE FIELD = 21.53 nm
#
#
# CASE 098 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 161.61 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 405.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.88e-02
# BONG 01 | f = 3.75e-02
# ---------------
# BING 02 | f = 3.75e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.62 nm
# RMS RESIDUAL AT SCIENCE FIELD = 26.15 nm
#
#
# CASE 099 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 82.19 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 852.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.45e-02
# BONG 01 | f = 1.36e-02
# ---------------
# BING 02 | f = 1.36e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.44 nm
# RMS RESIDUAL AT SCIENCE FIELD = 39.08 nm
#
#
# CASE 100 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 68.73 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 818.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.59e-02
# BONG 01 | f = 1.57e-02
# ---------------
# BING 02 | f = 1.56e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.08 nm
# RMS RESIDUAL AT SCIENCE FIELD = 22.00 nm
#
#
# Saved data to:  /npool/nvme/derbyk/20260616_mfpr_mc/mis_smol_srcmag_19_nsrc_3_randf_true_nframes_1_exp_360_sci.pkl

# %%
misalignments = utils.load_pickle('/home/derbyk/src/ffpr/data/misalignments_cases_100_dec_50um_tilt_5as.pkl')

# %%
# SNR threshold
snr_thresh = 5

# system stuff
fields = [(sys.cfg['sources'][src]['position_x'], sys.cfg['sources'][src]['position_y']) for src in sys.cfg['sources']]
efl = sys.cfg['general']['f_eff']
pupil_dx = sys.cfg['optics']['m1']['diam'] / sys.cfg['general']['npix_pupil']
focal_dx = sys.cfg['detector']['dx_focal']

# stuff to save
data = {}

case = 1

for m in misalignments:

    print(f'CASE {case:03.0f} ----------------------------------')
    print()

    # apply misalignment
    sys.move_optics(M1_motion=m['M1'], M2_motion=m['M4'], M3_motion=m['M4'], M4_motion=m['M4'])

    # get total OPDs per field
    opds_fields = copy.deepcopy(sys.opds_field)
    opds_optics = copy.deepcopy(sys.opds_optics)
    opds_truths = [opd_field + opd_optic for opd_field, opd_optic in zip(opds_fields, opds_optics)]

    # calculate RMS of ground truth OPDs per field
    rms_truth_per_field = []
    for opd in opds_truths:
        opd -= np.mean(opd[pupil])
        rms_truth_per_field.append(float(np.sqrt(np.mean(opd[pupil] ** 2))))

    # calculate RMS of diversity per field
    rms_diversity_per_field = []
    for opd in opds_fields_nominal:
        opd -= np.mean(opd[pupil])
        rms_diversity_per_field.append(float(np.sqrt(np.mean(opd[pupil] ** 2))))

    # take images for FFPR
    dark = sys.get_dark(stacked_frames=1)
    images = [im - dark for im in sys.snap(stacked_frames=1)]

    # get image SNRs and filter
    noise_lvl = dark.std()
    masks = []
    snr_per_field = []
    for im in images:
        snr_per_field.append(float(im.max() / dark.std()))
        mask = im > noise_lvl * snr_thresh
        masks.append(mask)

    print(f'MEDIAN RMS OPD ACROSS FIELD = {np.median(np.array(rms_truth_per_field)):.2f} nm')
    print(f'MEDIAN IMAGE SNR ACROSS FIELD = {np.median(np.array(snr_per_field)):.1f}')
    print()

    # initialize FFPR
    opt = FFPR2(wvls=sys.wvls.tolist(), amp=sys.pupil, max_zernike=11, fields=fields, divs=opds_fields_nominal, efl=efl, 
                psfs=images, pupil_dx=pupil_dx, focal_dx=focal_dx, error=gain_invariant_error, masks=masks, jitter_kernel=sys.jitter_kernel)

    # BING BONG
    BING_BONG(opt=opt, modal_cleanup=True, zonal_cleanup=False,
              max_kicks=10, iter_per_bing_bong=10, iter_per_psf=10,
              max_ls=10, thresh_conv=1e-1, frac_conv=1e-2)

    # calculate estimate residuals
    opds_estimates = [pdpr.models[0].opd + pdpr.models[0].div for pdpr in opt.PDPR_list]
    opds_residuals = [estimate - truth for estimate, truth in zip(opds_estimates, opds_truths)]

    # get RMS of residual per field
    rms_residual_per_field = []
    for opd in opds_residuals:
        opd -= np.mean(opd[pupil])
        rms_residual_per_field.append(float(np.sqrt(np.mean(opd[pupil] ** 2))))

    print(f'MEDIAN RMS RESIDUAL ACROSS FIELD = {np.median(np.array(rms_residual_per_field)):.2f} nm')
    print()
    print()

    # save to data cube
    data.update({f'CASE{case:03.0f}' : {'RMS_TRUTH_PER_FIELD' : rms_truth_per_field,
                                        'RMS_RESIDUAL_PER_FIELD' : rms_residual_per_field,
                                        'RMS_DIVERSITY_PER_FIELD' : rms_diversity_per_field,
                                        'SNR_PER_FIELD' : snr_per_field,
                                        'FIELDS' : fields}})

    case += 1

utils.save_pickle('/home/derbyk/src/ffpr/sim_results/20260504_mc_misalignments_19mag_dec_50um_tilt_5as.pkl', data=data)
# Out:
# CASE 001 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 240.37 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 26.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 7.91e-01
# BONG 01 | f = 7.90e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 6.29e-01
# BONG 02 | f = 6.29e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 8.22e-01
# BONG 03 | f = 8.22e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 7.99e-01
# BONG 04 | f = 7.95e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 6.65e-01
# BONG 05 | f = 6.65e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 7.93e-01
# BONG 06 | f = 7.89e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 8.00e-01
# BONG 07 | f = 7.97e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 7.06e-01
# BONG 08 | f = 7.06e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 6.80e-01
# BONG 09 | f = 6.67e-01
# ---------------
# BING 10 | f = 6.67e-01
# BONG 10 | f = 6.67e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 8.84e-01
# BONG 11 | f = 8.84e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 8.03e-01
# BONG 12 | f = 8.03e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 358.16 nm
#
#
# CASE 002 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 373.94 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 21.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.92e-01
# BONG 01 | f = 6.86e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 8.20e-01
# BONG 02 | f = 7.69e-01
# ---------------
# BING 03 | f = 7.69e-01
# BONG 03 | f = 7.69e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 4.74e-01
# BONG 04 | f = 4.74e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 5.68e-01
# BONG 05 | f = 5.68e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 5.79e-01
# BONG 06 | f = 5.79e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 6.58e-01
# BONG 07 | f = 6.58e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 7.84e-01
# BONG 08 | f = 7.45e-01
# ---------------
# BING 09 | f = 7.13e-01
# BONG 09 | f = 7.13e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 5.13e-01
# BONG 10 | f = 4.99e-01
# ---------------
# BING 11 | f = 4.77e-01
# BONG 11 | f = 4.77e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 6.75e-01
# BONG 12 | f = 6.70e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 6.70e-01
# BONG 13 | f = 6.65e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 8.97e-01
# BONG 14 | f = 8.97e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 347.97 nm
#
#
# CASE 003 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 248.35 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 34.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.62e-01
# BONG 01 | f = 4.57e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 5.10e-01
# BONG 02 | f = 4.75e-01
# ---------------
# BING 03 | f = 4.75e-01
# BONG 03 | f = 4.71e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 8.03e-01
# BONG 04 | f = 7.55e-01
# ---------------
# BING 05 | f = 5.95e-01
# BONG 05 | f = 5.38e-01
# ---------------
# BING 06 | f = 5.36e-01
# BONG 06 | f = 5.36e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 4.89e-01
# BONG 07 | f = 4.87e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 7.86e-01
# BONG 08 | f = 7.12e-01
# ---------------
# BING 09 | f = 5.63e-01
# BONG 09 | f = 5.36e-01
# ---------------
# BING 10 | f = 5.36e-01
# BONG 10 | f = 5.36e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 5.65e-01
# BONG 11 | f = 5.53e-01
# ---------------
# BING 12 | f = 5.53e-01
# BONG 12 | f = 5.53e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 4.49e-01
# BONG 13 | f = 4.47e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 6.12e-01
# BONG 14 | f = 5.42e-01
# ---------------
# BING 15 | f = 5.42e-01
# BONG 15 | f = 5.42e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 4.31e-01
# BONG 16 | f = 4.21e-01
# ---------------
# BING 17 | f = 3.90e-01
# BONG 17 | f = 3.90e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 18 | f = 6.75e-01
# BONG 18 | f = 6.26e-01
# ---------------
# BING 19 | f = 6.26e-01
# BONG 19 | f = 6.26e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 20 | f = 4.79e-01
# BONG 20 | f = 4.76e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 278.86 nm
#
#
# CASE 004 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 140.99 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 59.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.19e-01
# BONG 01 | f = 1.19e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 1.18e-01
# BONG 02 | f = 1.17e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 4.13e-01
# BONG 03 | f = 3.93e-01
# ---------------
# BING 04 | f = 3.93e-01
# BONG 04 | f = 3.93e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 3.62e-01
# BONG 05 | f = 3.62e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 3.92e-01
# BONG 06 | f = 3.92e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 1.20e-01
# BONG 07 | f = 1.19e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 1.17e-01
# BONG 08 | f = 1.17e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 4.28e-01
# BONG 09 | f = 4.11e-01
# ---------------
# BING 10 | f = 3.84e-01
# BONG 10 | f = 3.79e-01
# ---------------
# BING 11 | f = 3.30e-01
# BONG 11 | f = 3.29e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 1.20e-01
# BONG 12 | f = 1.19e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 1.17e-01
# BONG 13 | f = 1.16e-01
# ---------------
# BING 14 | f = 1.16e-01
# BONG 14 | f = 1.16e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 1.17e-01
# BONG 15 | f = 1.13e-01
# ---------------
# BING 16 | f = 1.12e-01
# BONG 16 | f = 1.12e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 35.17 nm
#
#
# CASE 005 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 252.90 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 33.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.55e-01
# BONG 01 | f = 6.25e-01
# ---------------
# BING 02 | f = 3.54e-01
# BONG 02 | f = 3.52e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 7.75e-01
# BONG 03 | f = 7.74e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 3.70e-01
# BONG 04 | f = 3.67e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 5.55e-01
# BONG 05 | f = 5.55e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 5.23e-01
# BONG 06 | f = 5.22e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 3.21e-01
# BONG 07 | f = 3.20e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 3.93e-01
# BONG 08 | f = 3.86e-01
# ---------------
# BING 09 | f = 3.86e-01
# BONG 09 | f = 3.86e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 5.20e-01
# BONG 10 | f = 5.14e-01
# ---------------
# BING 11 | f = 5.14e-01
# BONG 11 | f = 5.14e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 4.54e-01
# BONG 12 | f = 4.54e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 7.71e-01
# BONG 13 | f = 6.69e-01
# ---------------
# BING 14 | f = 6.69e-01
# BONG 14 | f = 6.69e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 5.57e-01
# BONG 15 | f = 5.26e-01
# ---------------
# BING 16 | f = 5.26e-01
# BONG 16 | f = 5.26e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 419.73 nm
#
#
# CASE 006 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 227.80 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 38.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.59e-01
# BONG 01 | f = 4.47e-01
# ---------------
# BING 02 | f = 4.47e-01
# BONG 02 | f = 4.47e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 4.24e-01
# BONG 03 | f = 4.11e-01
# ---------------
# BING 04 | f = 3.15e-01
# BONG 04 | f = 3.15e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 7.08e-01
# BONG 05 | f = 6.39e-01
# ---------------
# BING 06 | f = 6.39e-01
# BONG 06 | f = 6.39e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 4.73e-01
# BONG 07 | f = 4.72e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 4.73e-01
# BONG 08 | f = 4.71e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 5.17e-01
# BONG 09 | f = 5.17e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 5.09e-01
# BONG 10 | f = 4.90e-01
# ---------------
# BING 11 | f = 4.90e-01
# BONG 11 | f = 4.90e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 5.51e-01
# BONG 12 | f = 5.26e-01
# ---------------
# BING 13 | f = 4.77e-01
# BONG 13 | f = 4.77e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 5.27e-01
# BONG 14 | f = 5.27e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 5.80e-01
# BONG 15 | f = 5.76e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 3.70e-01
# BONG 16 | f = 3.62e-01
# ---------------
# BING 17 | f = 3.62e-01
# BONG 17 | f = 3.62e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 178.96 nm
#
#
# CASE 007 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 330.98 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 15.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 7.74e-01
# BONG 01 | f = 7.70e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 9.42e-01
# BONG 02 | f = 9.00e-01
# ---------------
# BING 03 | f = 9.00e-01
# BONG 03 | f = 9.00e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 9.53e-01
# BONG 04 | f = 8.56e-01
# ---------------
# BING 05 | f = 8.56e-01
# BONG 05 | f = 8.56e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 8.15e-01
# BONG 06 | f = 8.15e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 9.43e-01
# BONG 07 | f = 8.59e-01
# ---------------
# BING 08 | f = 8.59e-01
# BONG 08 | f = 8.59e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 9.28e-01
# BONG 09 | f = 9.28e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 8.30e-01
# BONG 10 | f = 8.26e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 8.31e-01
# BONG 11 | f = 8.25e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 8.56e-01
# BONG 12 | f = 8.53e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 9.67e-01
# BONG 13 | f = 9.49e-01
# ---------------
# BING 14 | f = 9.43e-01
# BONG 14 | f = 9.43e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 9.89e-01
# BONG 15 | f = 9.89e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 322.45 nm
#
#
# CASE 008 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 201.17 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 42.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.51e-01
# BONG 01 | f = 5.51e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 5.37e-01
# BONG 02 | f = 4.97e-01
# ---------------
# BING 03 | f = 4.78e-01
# BONG 03 | f = 4.78e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 4.39e-01
# BONG 04 | f = 4.39e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 3.10e-01
# BONG 05 | f = 2.98e-01
# ---------------
# BING 06 | f = 2.98e-01
# BONG 06 | f = 2.98e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 3.64e-01
# BONG 07 | f = 3.64e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 7.37e-01
# BONG 08 | f = 6.36e-01
# ---------------
# BING 09 | f = 6.36e-01
# BONG 09 | f = 6.36e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 2.83e-01
# BONG 10 | f = 2.75e-01
# ---------------
# BING 11 | f = 2.75e-01
# BONG 11 | f = 2.75e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 5.05e-01
# BONG 12 | f = 4.97e-01
# ---------------
# BING 13 | f = 4.97e-01
# BONG 13 | f = 4.97e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 4.30e-01
# BONG 14 | f = 4.30e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 5.46e-01
# BONG 15 | f = 5.37e-01
# ---------------
# BING 16 | f = 5.37e-01
# BONG 16 | f = 5.37e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 17 | f = 4.48e-01
# BONG 17 | f = 4.48e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 256.07 nm
#
#
# CASE 009 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 335.10 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 25.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 8.05e-01
# BONG 01 | f = 7.56e-01
# ---------------
# BING 02 | f = 6.71e-01
# BONG 02 | f = 6.71e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 8.30e-01
# BONG 03 | f = 7.39e-01
# ---------------
# BING 04 | f = 7.39e-01
# BONG 04 | f = 7.39e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 4.02e-01
# BONG 05 | f = 4.02e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 8.09e-01
# BONG 06 | f = 7.41e-01
# ---------------
# BING 07 | f = 5.46e-01
# BONG 07 | f = 5.35e-01
# ---------------
# BING 08 | f = 4.99e-01
# BONG 08 | f = 4.99e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 8.30e-01
# BONG 09 | f = 8.30e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 6.12e-01
# BONG 10 | f = 6.07e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 7.65e-01
# BONG 11 | f = 7.65e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 4.50e-01
# BONG 12 | f = 4.50e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 6.32e-01
# BONG 13 | f = 6.20e-01
# ---------------
# BING 14 | f = 6.20e-01
# BONG 14 | f = 6.20e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 6.14e-01
# BONG 15 | f = 6.04e-01
# ---------------
# BING 16 | f = 6.04e-01
# BONG 16 | f = 6.04e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 17 | f = 8.60e-01
# BONG 17 | f = 8.60e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 337.10 nm
#
#
# CASE 010 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 240.68 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 26.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.79e-01
# BONG 01 | f = 6.57e-01
# ---------------
# BING 02 | f = 6.57e-01
# BONG 02 | f = 6.57e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 7.02e-01
# BONG 03 | f = 6.36e-01
# ---------------
# BING 04 | f = 6.36e-01
# BONG 04 | f = 6.36e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 6.78e-01
# BONG 05 | f = 6.67e-01
# ---------------
# BING 06 | f = 6.67e-01
# BONG 06 | f = 6.67e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 6.17e-01
# BONG 07 | f = 6.14e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 6.82e-01
# BONG 08 | f = 6.13e-01
# ---------------
# BING 09 | f = 5.65e-01
# BONG 09 | f = 5.65e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 6.15e-01
# BONG 10 | f = 6.15e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 6.44e-01
# BONG 11 | f = 6.41e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 6.30e-01
# BONG 12 | f = 6.30e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 6.51e-01
# BONG 13 | f = 6.51e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 7.00e-01
# BONG 14 | f = 7.00e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 8.20e-01
# BONG 15 | f = 8.08e-01
# ---------------
# BING 16 | f = 8.08e-01
# BONG 16 | f = 8.08e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 337.97 nm
#
#
# CASE 011 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 367.38 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 18.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 9.12e-01
# BONG 01 | f = 9.06e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 9.13e-01
# BONG 02 | f = 9.13e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 8.77e-01
# BONG 03 | f = 8.77e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 6.90e-01
# BONG 04 | f = 6.90e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 7.25e-01
# BONG 05 | f = 7.25e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 8.45e-01
# BONG 06 | f = 8.42e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 9.23e-01
# BONG 07 | f = 9.23e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 6.98e-01
# BONG 08 | f = 6.98e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 8.69e-01
# BONG 09 | f = 8.64e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 8.22e-01
# BONG 10 | f = 8.20e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 9.55e-01
# BONG 11 | f = 9.55e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 333.40 nm
#
#
# CASE 012 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 340.29 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 22.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 8.73e-01
# BONG 01 | f = 8.72e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 7.16e-01
# BONG 02 | f = 7.16e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 9.26e-01
# BONG 03 | f = 7.69e-01
# ---------------
# BING 04 | f = 7.69e-01
# BONG 04 | f = 7.69e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 9.29e-01
# BONG 05 | f = 9.29e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 7.67e-01
# BONG 06 | f = 7.46e-01
# ---------------
# BING 07 | f = 7.46e-01
# BONG 07 | f = 7.46e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 6.30e-01
# BONG 08 | f = 6.30e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 7.48e-01
# BONG 09 | f = 7.48e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 8.81e-01
# BONG 10 | f = 8.74e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 6.30e-01
# BONG 11 | f = 6.30e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 9.81e-01
# BONG 12 | f = 9.81e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 7.52e-01
# BONG 13 | f = 7.52e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 611.28 nm
#
#
# CASE 013 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 340.63 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 25.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.47e-01
# BONG 01 | f = 6.36e-01
# ---------------
# BING 02 | f = 6.36e-01
# BONG 02 | f = 6.36e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 8.23e-01
# BONG 03 | f = 8.23e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 4.77e-01
# BONG 04 | f = 4.76e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 8.44e-01
# BONG 05 | f = 8.14e-01
# ---------------
# BING 06 | f = 5.75e-01
# BONG 06 | f = 5.75e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 5.14e-01
# BONG 07 | f = 4.99e-01
# ---------------
# BING 08 | f = 4.43e-01
# BONG 08 | f = 4.43e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 6.16e-01
# BONG 09 | f = 6.08e-01
# ---------------
# BING 10 | f = 6.08e-01
# BONG 10 | f = 6.08e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 7.48e-01
# BONG 11 | f = 7.48e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 4.95e-01
# BONG 12 | f = 4.85e-01
# ---------------
# BING 13 | f = 4.36e-01
# BONG 13 | f = 4.35e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 6.62e-01
# BONG 14 | f = 6.49e-01
# ---------------
# BING 15 | f = 6.49e-01
# BONG 15 | f = 6.49e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 7.99e-01
# BONG 16 | f = 7.44e-01
# ---------------
# BING 17 | f = 6.57e-01
# BONG 17 | f = 6.57e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 18 | f = 8.71e-01
# BONG 18 | f = 8.19e-01
# ---------------
# BING 19 | f = 6.79e-01
# BONG 19 | f = 6.79e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 536.82 nm
#
#
# CASE 014 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 95.52 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 101.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.84e-02
# BONG 01 | f = 5.75e-02
# ---------------
# BING 02 | f = 5.75e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 27.59 nm
#
#
# CASE 015 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 83.02 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 112.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.93e-02
# BONG 01 | f = 6.82e-02
# ---------------
# BING 02 | f = 6.82e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 33.74 nm
#
#
# CASE 016 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 392.63 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 22.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 7.07e-01
# BONG 01 | f = 6.86e-01
# ---------------
# BING 02 | f = 6.86e-01
# BONG 02 | f = 6.86e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 7.61e-01
# BONG 03 | f = 7.42e-01
# ---------------
# BING 04 | f = 7.42e-01
# BONG 04 | f = 7.42e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 6.69e-01
# BONG 05 | f = 6.53e-01
# ---------------
# BING 06 | f = 6.53e-01
# BONG 06 | f = 6.53e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 8.26e-01
# BONG 07 | f = 7.48e-01
# ---------------
# BING 08 | f = 6.15e-01
# BONG 08 | f = 6.15e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 8.39e-01
# BONG 09 | f = 8.15e-01
# ---------------
# BING 10 | f = 8.15e-01
# BONG 10 | f = 8.15e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 5.91e-01
# BONG 11 | f = 5.91e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 5.53e-01
# BONG 12 | f = 5.53e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 8.06e-01
# BONG 13 | f = 8.00e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 6.99e-01
# BONG 14 | f = 6.99e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 6.59e-01
# BONG 15 | f = 6.20e-01
# ---------------
# BING 16 | f = 6.19e-01
# BONG 16 | f = 6.19e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 17 | f = 8.39e-01
# BONG 17 | f = 8.11e-01
# ---------------
# BING 18 | f = 8.11e-01
# BONG 18 | f = 8.11e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 628.13 nm
#
#
# CASE 017 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 82.72 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 121.1
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.18e-02
# BONG 01 | f = 4.18e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.44 nm
#
#
# CASE 018 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 206.83 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 32.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.26e-01
# BONG 01 | f = 5.26e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 5.91e-01
# BONG 02 | f = 5.91e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 8.45e-01
# BONG 03 | f = 7.85e-01
# ---------------
# BING 04 | f = 5.81e-01
# BONG 04 | f = 5.68e-01
# ---------------
# BING 05 | f = 5.51e-01
# BONG 05 | f = 5.43e-01
# ---------------
# BING 06 | f = 5.43e-01
# BONG 06 | f = 5.43e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 4.97e-01
# BONG 07 | f = 4.97e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 4.80e-01
# BONG 08 | f = 4.70e-01
# ---------------
# BING 09 | f = 4.24e-01
# BONG 09 | f = 4.24e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 8.55e-01
# BONG 10 | f = 8.55e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 5.52e-01
# BONG 11 | f = 5.52e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 6.16e-01
# BONG 12 | f = 5.89e-01
# ---------------
# BING 13 | f = 5.89e-01
# BONG 13 | f = 5.89e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 6.72e-01
# BONG 14 | f = 6.61e-01
# ---------------
# BING 15 | f = 6.61e-01
# BONG 15 | f = 6.61e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 8.15e-01
# BONG 16 | f = 7.90e-01
# ---------------
# BING 17 | f = 7.90e-01
# BONG 17 | f = 7.90e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 18 | f = 8.82e-01
# BONG 18 | f = 8.17e-01
# ---------------
# BING 19 | f = 8.17e-01
# BONG 19 | f = 8.17e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 333.10 nm
#
#
# CASE 019 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 355.31 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 27.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 7.35e-01
# BONG 01 | f = 7.20e-01
# ---------------
# BING 02 | f = 7.20e-01
# BONG 02 | f = 7.20e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 7.79e-01
# BONG 03 | f = 7.79e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 5.80e-01
# BONG 04 | f = 5.80e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 8.71e-01
# BONG 05 | f = 7.34e-01
# ---------------
# BING 06 | f = 6.26e-01
# BONG 06 | f = 6.15e-01
# ---------------
# BING 07 | f = 6.15e-01
# BONG 07 | f = 6.15e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 7.05e-01
# BONG 08 | f = 6.92e-01
# ---------------
# BING 09 | f = 6.91e-01
# BONG 09 | f = 6.91e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 4.76e-01
# BONG 10 | f = 4.71e-01
# ---------------
# BING 11 | f = 4.71e-01
# BONG 11 | f = 4.71e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 5.06e-01
# BONG 12 | f = 5.06e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 7.37e-01
# BONG 13 | f = 7.14e-01
# ---------------
# BING 14 | f = 7.14e-01
# BONG 14 | f = 7.14e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 5.64e-01
# BONG 15 | f = 5.64e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 4.86e-01
# BONG 16 | f = 4.83e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 17 | f = 5.39e-01
# BONG 17 | f = 5.39e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 597.73 nm
#
#
# CASE 020 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 314.73 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 22.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 7.00e-01
# BONG 01 | f = 6.96e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 6.46e-01
# BONG 02 | f = 6.44e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 9.11e-01
# BONG 03 | f = 9.11e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 7.02e-01
# BONG 04 | f = 6.96e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 5.90e-01
# BONG 05 | f = 5.90e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 6.95e-01
# BONG 06 | f = 6.95e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 7.97e-01
# BONG 07 | f = 7.97e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 7.07e-01
# BONG 08 | f = 7.07e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 7.70e-01
# BONG 09 | f = 7.70e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 9.56e-01
# BONG 10 | f = 8.43e-01
# ---------------
# BING 11 | f = 7.63e-01
# BONG 11 | f = 7.63e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 7.12e-01
# BONG 12 | f = 7.01e-01
# ---------------
# BING 13 | f = 6.44e-01
# BONG 13 | f = 6.44e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 429.62 nm
#
#
# CASE 021 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 268.99 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 32.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.56e-01
# BONG 01 | f = 5.53e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 4.21e-01
# BONG 02 | f = 4.17e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 5.45e-01
# BONG 03 | f = 5.38e-01
# ---------------
# BING 04 | f = 5.38e-01
# BONG 04 | f = 5.38e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 5.84e-01
# BONG 05 | f = 5.51e-01
# ---------------
# BING 06 | f = 4.58e-01
# BONG 06 | f = 4.42e-01
# ---------------
# BING 07 | f = 3.59e-01
# BONG 07 | f = 3.59e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 4.95e-01
# BONG 08 | f = 4.93e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 4.86e-01
# BONG 09 | f = 4.80e-01
# ---------------
# BING 10 | f = 3.45e-01
# BONG 10 | f = 3.45e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 3.84e-01
# BONG 11 | f = 3.84e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 7.31e-01
# BONG 12 | f = 7.23e-01
# ---------------
# BING 13 | f = 7.23e-01
# BONG 13 | f = 7.23e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 5.10e-01
# BONG 14 | f = 5.10e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 4.52e-01
# BONG 15 | f = 4.41e-01
# ---------------
# BING 16 | f = 4.41e-01
# BONG 16 | f = 4.41e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 17 | f = 6.03e-01
# BONG 17 | f = 5.91e-01
# ---------------
# BING 18 | f = 5.74e-01
# BONG 18 | f = 5.74e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 1029.65 nm
#
#
# CASE 022 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 411.80 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 22.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 8.29e-01
# BONG 01 | f = 8.29e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 8.56e-01
# BONG 02 | f = 7.80e-01
# ---------------
# BING 03 | f = 7.48e-01
# BONG 03 | f = 7.48e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 5.50e-01
# BONG 04 | f = 5.40e-01
# ---------------
# BING 05 | f = 5.40e-01
# BONG 05 | f = 5.40e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 7.69e-01
# BONG 06 | f = 7.69e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 7.55e-01
# BONG 07 | f = 7.55e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 7.29e-01
# BONG 08 | f = 7.28e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 6.25e-01
# BONG 09 | f = 6.14e-01
# ---------------
# BING 10 | f = 6.14e-01
# BONG 10 | f = 6.13e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 7.64e-01
# BONG 11 | f = 7.42e-01
# ---------------
# BING 12 | f = 7.42e-01
# BONG 12 | f = 7.42e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 6.14e-01
# BONG 13 | f = 6.13e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 8.19e-01
# BONG 14 | f = 8.19e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 6.76e-01
# BONG 15 | f = 6.72e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 786.77 nm
#
#
# CASE 023 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 319.57 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 21.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 9.14e-01
# BONG 01 | f = 9.14e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 9.66e-01
# BONG 02 | f = 7.70e-01
# ---------------
# BING 03 | f = 7.27e-01
# BONG 03 | f = 6.89e-01
# ---------------
# BING 04 | f = 6.89e-01
# BONG 04 | f = 6.89e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 7.83e-01
# BONG 05 | f = 7.72e-01
# ---------------
# BING 06 | f = 7.37e-01
# BONG 06 | f = 7.37e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 7.15e-01
# BONG 07 | f = 7.15e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 8.76e-01
# BONG 08 | f = 8.76e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 6.47e-01
# BONG 09 | f = 6.47e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 9.01e-01
# BONG 10 | f = 8.76e-01
# ---------------
# BING 11 | f = 8.76e-01
# BONG 11 | f = 8.76e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 9.48e-01
# BONG 12 | f = 9.48e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 9.29e-01
# BONG 13 | f = 8.72e-01
# ---------------
# BING 14 | f = 8.72e-01
# BONG 14 | f = 8.72e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 6.81e-01
# BONG 15 | f = 6.80e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 9.97e-01
# BONG 16 | f = 9.97e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 954.87 nm
#
#
# CASE 024 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 249.27 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 26.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.11e-01
# BONG 01 | f = 4.80e-01
# ---------------
# BING 02 | f = 3.95e-01
# BONG 02 | f = 3.95e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 6.50e-01
# BONG 03 | f = 6.31e-01
# ---------------
# BING 04 | f = 4.43e-01
# BONG 04 | f = 4.40e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 7.56e-01
# BONG 05 | f = 7.56e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 7.14e-01
# BONG 06 | f = 7.13e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 7.42e-01
# BONG 07 | f = 7.34e-01
# ---------------
# BING 08 | f = 7.34e-01
# BONG 08 | f = 7.34e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 6.71e-01
# BONG 09 | f = 6.71e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 3.90e-01
# BONG 10 | f = 3.89e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 6.77e-01
# BONG 11 | f = 6.77e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 4.00e-01
# BONG 12 | f = 3.99e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 3.88e-01
# BONG 13 | f = 3.87e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 7.30e-01
# BONG 14 | f = 7.12e-01
# ---------------
# BING 15 | f = 6.24e-01
# BONG 15 | f = 6.20e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 94.22 nm
#
#
# CASE 025 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 394.15 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 19.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.96e-01
# BONG 01 | f = 6.96e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 7.95e-01
# BONG 02 | f = 7.91e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 9.49e-01
# BONG 03 | f = 8.93e-01
# ---------------
# BING 04 | f = 7.92e-01
# BONG 04 | f = 7.92e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 9.36e-01
# BONG 05 | f = 9.36e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 9.54e-01
# BONG 06 | f = 9.49e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 9.53e-01
# BONG 07 | f = 9.53e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 9.49e-01
# BONG 08 | f = 8.98e-01
# ---------------
# BING 09 | f = 8.06e-01
# BONG 09 | f = 8.06e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 8.38e-01
# BONG 10 | f = 7.87e-01
# ---------------
# BING 11 | f = 7.70e-01
# BONG 11 | f = 7.70e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 8.29e-01
# BONG 12 | f = 8.12e-01
# ---------------
# BING 13 | f = 8.12e-01
# BONG 13 | f = 8.12e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 9.72e-01
# BONG 14 | f = 9.72e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 9.76e-01
# BONG 15 | f = 9.76e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 460.86 nm
#
#
# CASE 026 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 195.24 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 36.1
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.89e-01
# BONG 01 | f = 6.89e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 2.94e-01
# BONG 02 | f = 2.83e-01
# ---------------
# BING 03 | f = 2.54e-01
# BONG 03 | f = 2.54e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 5.92e-01
# BONG 04 | f = 5.85e-01
# ---------------
# BING 05 | f = 5.85e-01
# BONG 05 | f = 5.85e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 6.70e-01
# BONG 06 | f = 6.58e-01
# ---------------
# BING 07 | f = 6.58e-01
# BONG 07 | f = 6.58e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 6.09e-01
# BONG 08 | f = 6.09e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 2.81e-01
# BONG 09 | f = 2.78e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 2.58e-01
# BONG 10 | f = 2.57e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 5.99e-01
# BONG 11 | f = 5.86e-01
# ---------------
# BING 12 | f = 5.86e-01
# BONG 12 | f = 5.86e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 2.90e-01
# BONG 13 | f = 2.80e-01
# ---------------
# BING 14 | f = 2.61e-01
# BONG 14 | f = 2.60e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 2.50e-01
# BONG 15 | f = 2.49e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 5.99e-01
# BONG 16 | f = 5.99e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 236.45 nm
#
#
# CASE 027 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 365.85 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 28.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 7.67e-01
# BONG 01 | f = 7.48e-01
# ---------------
# BING 02 | f = 7.48e-01
# BONG 02 | f = 7.48e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 7.01e-01
# BONG 03 | f = 6.83e-01
# ---------------
# BING 04 | f = 6.83e-01
# BONG 04 | f = 6.83e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 7.21e-01
# BONG 05 | f = 7.10e-01
# ---------------
# BING 06 | f = 7.10e-01
# BONG 06 | f = 7.10e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 7.10e-01
# BONG 07 | f = 6.96e-01
# ---------------
# BING 08 | f = 6.94e-01
# BONG 08 | f = 6.94e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 6.67e-01
# BONG 09 | f = 6.59e-01
# ---------------
# BING 10 | f = 6.58e-01
# BONG 10 | f = 6.58e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 5.17e-01
# BONG 11 | f = 5.17e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 7.06e-01
# BONG 12 | f = 7.06e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 7.74e-01
# BONG 13 | f = 7.23e-01
# ---------------
# BING 14 | f = 7.05e-01
# BONG 14 | f = 6.93e-01
# ---------------
# BING 15 | f = 6.46e-01
# BONG 15 | f = 6.38e-01
# ---------------
# BING 16 | f = 6.38e-01
# BONG 16 | f = 6.38e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 17 | f = 8.16e-01
# BONG 17 | f = 7.47e-01
# ---------------
# BING 18 | f = 7.47e-01
# BONG 18 | f = 7.47e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 19 | f = 9.00e-01
# BONG 19 | f = 7.98e-01
# ---------------
# BING 20 | f = 6.07e-01
# BONG 20 | f = 6.07e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 21 | f = 6.40e-01
# BONG 21 | f = 6.13e-01
# ---------------
# BING 22 | f = 4.62e-01
# BONG 22 | f = 4.62e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 335.74 nm
#
#
# CASE 028 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 285.09 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 35.1
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.48e-01
# BONG 01 | f = 6.48e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 6.33e-01
# BONG 02 | f = 6.22e-01
# ---------------
# BING 03 | f = 6.22e-01
# BONG 03 | f = 6.22e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 6.76e-01
# BONG 04 | f = 6.76e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 7.07e-01
# BONG 05 | f = 7.07e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 5.74e-01
# BONG 06 | f = 5.58e-01
# ---------------
# BING 07 | f = 5.58e-01
# BONG 07 | f = 5.58e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 3.71e-01
# BONG 08 | f = 3.54e-01
# ---------------
# BING 09 | f = 3.01e-01
# BONG 09 | f = 3.01e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 3.90e-01
# BONG 10 | f = 3.90e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 6.90e-01
# BONG 11 | f = 6.89e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 5.63e-01
# BONG 12 | f = 5.63e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 3.50e-01
# BONG 13 | f = 3.49e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 6.31e-01
# BONG 14 | f = 6.31e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 455.20 nm
#
#
# CASE 029 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 245.01 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 24.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.01e-01
# BONG 01 | f = 6.01e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 6.23e-01
# BONG 02 | f = 6.23e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 7.59e-01
# BONG 03 | f = 7.59e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 8.12e-01
# BONG 04 | f = 8.10e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 7.22e-01
# BONG 05 | f = 7.19e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 6.08e-01
# BONG 06 | f = 6.08e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 6.63e-01
# BONG 07 | f = 6.63e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 6.54e-01
# BONG 08 | f = 6.54e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 6.68e-01
# BONG 09 | f = 6.68e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 7.14e-01
# BONG 10 | f = 7.02e-01
# ---------------
# BING 11 | f = 7.02e-01
# BONG 11 | f = 7.02e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 7.08e-01
# BONG 12 | f = 7.08e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 441.74 nm
#
#
# CASE 030 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 314.33 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 24.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 7.13e-01
# BONG 01 | f = 7.03e-01
# ---------------
# BING 02 | f = 6.93e-01
# BONG 02 | f = 6.87e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 7.55e-01
# BONG 03 | f = 7.35e-01
# ---------------
# BING 04 | f = 6.96e-01
# BONG 04 | f = 6.96e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 6.76e-01
# BONG 05 | f = 6.76e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 7.44e-01
# BONG 06 | f = 7.44e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 4.49e-01
# BONG 07 | f = 4.49e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 6.74e-01
# BONG 08 | f = 6.67e-01
# ---------------
# BING 09 | f = 6.67e-01
# BONG 09 | f = 6.67e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 7.00e-01
# BONG 10 | f = 6.83e-01
# ---------------
# BING 11 | f = 6.82e-01
# BONG 11 | f = 6.82e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 6.19e-01
# BONG 12 | f = 6.19e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 8.10e-01
# BONG 13 | f = 7.77e-01
# ---------------
# BING 14 | f = 7.77e-01
# BONG 14 | f = 7.77e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 7.18e-01
# BONG 15 | f = 7.18e-01
# ...
# ---------------
# BING 03 | f = 5.86e-01
# BONG 03 | f = 4.89e-01
# ---------------
# BING 04 | f = 4.89e-01
# BONG 04 | f = 4.89e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 2.27e-01
# BONG 05 | f = 2.27e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 6.92e-01
# BONG 06 | f = 6.92e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 2.39e-01
# BONG 07 | f = 2.39e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 6.05e-01
# BONG 08 | f = 6.05e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 6.69e-01
# BONG 09 | f = 6.69e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 2.31e-01
# BONG 10 | f = 2.29e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 5.52e-01
# BONG 11 | f = 5.32e-01
# ---------------
# BING 12 | f = 5.32e-01
# BONG 12 | f = 5.32e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 6.65e-01
# BONG 13 | f = 6.65e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 2.63e-01
# BONG 14 | f = 2.63e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 48.08 nm
#
#
# CASE 091 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 112.59 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 82.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 9.02e-02
# BONG 01 | f = 8.98e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 27.58 nm
#
#
# CASE 092 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 372.23 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 27.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 7.08e-01
# BONG 01 | f = 7.08e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 6.94e-01
# BONG 02 | f = 6.90e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 5.35e-01
# BONG 03 | f = 5.18e-01
# ---------------
# BING 04 | f = 5.18e-01
# BONG 04 | f = 5.18e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 5.06e-01
# BONG 05 | f = 5.00e-01
# ---------------
# BING 06 | f = 5.00e-01
# BONG 06 | f = 5.00e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 5.67e-01
# BONG 07 | f = 5.67e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 7.84e-01
# BONG 08 | f = 7.84e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 7.88e-01
# BONG 09 | f = 7.88e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 8.67e-01
# BONG 10 | f = 8.67e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 7.64e-01
# BONG 11 | f = 7.32e-01
# ---------------
# BING 12 | f = 7.20e-01
# BONG 12 | f = 7.20e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 7.96e-01
# BONG 13 | f = 7.51e-01
# ---------------
# BING 14 | f = 7.51e-01
# BONG 14 | f = 7.51e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 5.45e-01
# BONG 15 | f = 5.45e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 452.17 nm
#
#
# CASE 093 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 178.23 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 52.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.77e-01
# BONG 01 | f = 1.65e-01
# ---------------
# BING 02 | f = 1.59e-01
# BONG 02 | f = 1.59e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 3.42e-01
# BONG 03 | f = 3.41e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 1.78e-01
# BONG 04 | f = 1.66e-01
# ---------------
# BING 05 | f = 1.62e-01
# BONG 05 | f = 1.62e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 1.65e-01
# BONG 06 | f = 1.59e-01
# ---------------
# BING 07 | f = 1.59e-01
# BONG 07 | f = 1.59e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 1.64e-01
# BONG 08 | f = 1.63e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 4.62e-01
# BONG 09 | f = 4.15e-01
# ---------------
# BING 10 | f = 4.14e-01
# BONG 10 | f = 4.14e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 1.61e-01
# BONG 11 | f = 1.60e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 4.00e-01
# BONG 12 | f = 3.96e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 1.69e-01
# BONG 13 | f = 1.69e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 1.70e-01
# BONG 14 | f = 1.70e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 1.59e-01
# BONG 15 | f = 1.58e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 49.11 nm
#
#
# CASE 094 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 146.47 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 55.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.58e-01
# BONG 01 | f = 1.58e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 1.39e-01
# BONG 02 | f = 1.39e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 4.66e-01
# BONG 03 | f = 4.57e-01
# ---------------
# BING 04 | f = 4.57e-01
# BONG 04 | f = 4.57e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 1.83e-01
# BONG 05 | f = 1.83e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 1.53e-01
# BONG 06 | f = 1.52e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 4.42e-01
# BONG 07 | f = 4.30e-01
# ---------------
# BING 08 | f = 2.86e-01
# BONG 08 | f = 1.98e-01
# ---------------
# BING 09 | f = 1.44e-01
# BONG 09 | f = 1.43e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 1.63e-01
# BONG 10 | f = 1.63e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 4.90e-01
# BONG 11 | f = 4.68e-01
# ---------------
# BING 12 | f = 4.65e-01
# BONG 12 | f = 4.58e-01
# ---------------
# BING 13 | f = 4.49e-01
# BONG 13 | f = 4.49e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 1.45e-01
# BONG 14 | f = 1.45e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 1.53e-01
# BONG 15 | f = 1.53e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 1.64e-01
# BONG 16 | f = 1.64e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 34.53 nm
#
#
# CASE 095 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 197.32 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 43.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.64e-01
# BONG 01 | f = 1.64e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 3.00e-01
# BONG 02 | f = 2.62e-01
# ---------------
# BING 03 | f = 1.61e-01
# BONG 03 | f = 1.59e-01
# ---------------
# BING 04 | f = 1.59e-01
# BONG 04 | f = 1.59e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 4.12e-01
# BONG 05 | f = 4.07e-01
# ---------------
# BING 06 | f = 4.07e-01
# BONG 06 | f = 4.07e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 3.74e-01
# BONG 07 | f = 3.74e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 1.85e-01
# BONG 08 | f = 1.67e-01
# ---------------
# BING 09 | f = 1.61e-01
# BONG 09 | f = 1.61e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 4.01e-01
# BONG 10 | f = 4.01e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 4.72e-01
# BONG 11 | f = 4.72e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 1.78e-01
# BONG 12 | f = 1.78e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 4.89e-01
# BONG 13 | f = 4.89e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 4.58e-01
# BONG 14 | f = 4.58e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 1.59e-01
# BONG 15 | f = 1.59e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 44.07 nm
#
#
# CASE 096 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 301.11 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 27.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 7.83e-01
# BONG 01 | f = 7.83e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 5.31e-01
# BONG 02 | f = 5.00e-01
# ---------------
# BING 03 | f = 3.63e-01
# BONG 03 | f = 3.62e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 6.45e-01
# BONG 04 | f = 6.42e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 6.76e-01
# BONG 05 | f = 6.75e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 6.82e-01
# BONG 06 | f = 6.80e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 6.08e-01
# BONG 07 | f = 6.08e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 4.60e-01
# BONG 08 | f = 4.39e-01
# ---------------
# BING 09 | f = 3.65e-01
# BONG 09 | f = 3.65e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 6.37e-01
# BONG 10 | f = 6.37e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 6.55e-01
# BONG 11 | f = 6.55e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 6.30e-01
# BONG 12 | f = 6.30e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 6.80e-01
# BONG 13 | f = 6.78e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 487.98 nm
#
#
# CASE 097 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 106.25 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 87.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 7.06e-02
# BONG 01 | f = 7.01e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 26.45 nm
#
#
# CASE 098 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 225.98 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 29.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.66e-01
# BONG 01 | f = 5.35e-01
# ---------------
# BING 02 | f = 5.35e-01
# BONG 02 | f = 5.35e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 6.15e-01
# BONG 03 | f = 6.15e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 8.40e-01
# BONG 04 | f = 8.13e-01
# ---------------
# BING 05 | f = 8.13e-01
# BONG 05 | f = 8.13e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 6.00e-01
# BONG 06 | f = 6.00e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 5.33e-01
# BONG 07 | f = 5.33e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 6.22e-01
# BONG 08 | f = 6.17e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 6.82e-01
# BONG 09 | f = 6.80e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 4.94e-01
# BONG 10 | f = 4.94e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 5.42e-01
# BONG 11 | f = 5.42e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 8.17e-01
# BONG 12 | f = 7.55e-01
# ---------------
# BING 13 | f = 7.17e-01
# BONG 13 | f = 6.40e-01
# ---------------
# BING 14 | f = 6.40e-01
# BONG 14 | f = 6.40e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 5.01e-01
# BONG 15 | f = 5.01e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 222.36 nm
#
#
# CASE 099 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 226.15 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 39.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.31e-01
# BONG 01 | f = 2.78e-01
# ---------------
# BING 02 | f = 2.27e-01
# BONG 02 | f = 2.25e-01
# ---------------
# BING 03 | f = 2.25e-01
# BONG 03 | f = 2.25e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 6.62e-01
# BONG 04 | f = 6.59e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 5.88e-01
# BONG 05 | f = 5.40e-01
# ---------------
# BING 06 | f = 5.39e-01
# BONG 06 | f = 5.39e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 4.87e-01
# BONG 07 | f = 4.74e-01
# ---------------
# BING 08 | f = 4.74e-01
# BONG 08 | f = 4.74e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 4.75e-01
# BONG 09 | f = 4.68e-01
# ---------------
# BING 10 | f = 4.68e-01
# BONG 10 | f = 4.68e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 2.22e-01
# BONG 11 | f = 2.21e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 2.25e-01
# BONG 12 | f = 2.24e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 4.97e-01
# BONG 13 | f = 4.93e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 2.22e-01
# BONG 14 | f = 2.22e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 2.26e-01
# BONG 15 | f = 2.25e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 7.29e-01
# BONG 16 | f = 4.70e-01
# ---------------
# BING 17 | f = 4.53e-01
# BONG 17 | f = 4.47e-01
# ---------------
# BING 18 | f = 4.47e-01
# BONG 18 | f = 4.47e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 686.51 nm
#
#
# CASE 100 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 215.85 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 33.1
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.58e-01
# BONG 01 | f = 5.58e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 6.18e-01
# BONG 02 | f = 5.82e-01
# ---------------
# BING 03 | f = 5.82e-01
# BONG 03 | f = 5.82e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 8.59e-01
# BONG 04 | f = 7.80e-01
# ---------------
# BING 05 | f = 5.70e-01
# BONG 05 | f = 5.52e-01
# ---------------
# BING 06 | f = 5.52e-01
# BONG 06 | f = 5.52e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 5.31e-01
# BONG 07 | f = 5.31e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 6.06e-01
# BONG 08 | f = 6.06e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 5.78e-01
# BONG 09 | f = 5.78e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 6.06e-01
# BONG 10 | f = 5.90e-01
# ---------------
# BING 11 | f = 5.90e-01
# BONG 11 | f = 5.90e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 6.39e-01
# BONG 12 | f = 5.84e-01
# ---------------
# BING 13 | f = 5.57e-01
# BONG 13 | f = 5.57e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 4.60e-01
# BONG 14 | f = 4.54e-01
# ---------------
# BING 15 | f = 4.54e-01
# BONG 15 | f = 4.54e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 4.53e-01
# BONG 16 | f = 4.48e-01
# ---------------
# BING 17 | f = 4.48e-01
# BONG 17 | f = 4.48e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 18 | f = 5.01e-01
# BONG 18 | f = 5.01e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 245.28 nm
#
#
# Saved data to:  /home/derbyk/src/ffpr/sim_results/20260504_mc_misalignments_19mag_dec_50um_tilt_5as.pkl

# %% [markdown]
# ## VISUALIZE

# %%
data = utils.load_pickle('/home/derbyk/src/ffpr/sim_results/20260504_mc_misalignments_19mag_dec_50um_tilt_5as.pkl')

median_rms_truth = np.zeros(len(data))
median_rms_residual = np.zeros(len(data))
max_rms_residual = np.zeros(len(data))
min_rms_residual = np.zeros(len(data))
std_rms_residual = np.zeros(len(data))
median_snr = np.zeros(len(data))

for i, case in enumerate(data):
    median_rms_truth[i] = np.median(np.array(data[case]['RMS_TRUTH_PER_FIELD']))
    median_rms_residual[i] = np.median(np.array(data[case]['RMS_RESIDUAL_PER_FIELD']))
    max_rms_residual[i] = np.max(np.array(data[case]['RMS_RESIDUAL_PER_FIELD']))
    min_rms_residual[i] = np.min(np.array(data[case]['RMS_RESIDUAL_PER_FIELD']))
    std_rms_residual[i] = np.std(np.array(data[case]['RMS_RESIDUAL_PER_FIELD']))
    median_snr[i] = np.median(np.array(data[case]['SNR_PER_FIELD']))

fig, axs = plt.subplot_mosaic([['histx', 'poop'],
                               ['scatter', 'histy']],
                               figsize=(8, 6), 
                               height_ratios=[1, 3],
                               width_ratios=[3, 1],
                               layout='tight',
                               dpi=150)

count = 0
fails_x = []
fails_y = []
xs = []
ys = []
cs = []

for x, y, c in zip(median_rms_truth, median_snr, median_rms_residual):
    if c < 62.5:
        xs.append(float(x))
        ys.append(float(y))
        cs.append(float(c))
    else:
        fails_x.append(float(x))
        fails_y.append(float(y))

xs = _np.array(xs)
ys = _np.array(ys)
cs = _np.array(cs)
fails_x = _np.array(fails_x)
fails_y = _np.array(fails_y)

xmin = _np.array([xs.min(), fails_x.min()]).min()
xmax = _np.array([xs.max(), fails_x.max()]).max()

ymin = _np.array([ys.min(), fails_y.min()]).min()
ymax = _np.array([ys.max(), fails_y.max()]).max()

cmin = 20
cmax = 62.5

sorted_fails_x = sorted(fails_x)
cdf_opd = [1]
cdf_x = [xmin * 0.8]
x = xmin
count = 0
while x < xmax:
    if count == len(fails_x):
        x += 10
        break
    if x + 10 < sorted_fails_x[count]:
        x += 10
        cdf_x.append(x)
        cdf_opd.append(cdf_opd[-1])
    else:
        x = sorted_fails_x[count]
        cdf_x.append(x)
        cdf_opd.append((1 - ((count + 1) / len(data))))
        count += 1
cdf_x.append(xmax * 1.1)
cdf_opd.append(cdf_opd[-1])
cdf_opd = _np.array(cdf_opd)
cdf_x = _np.array(cdf_x)

sorted_fails_y = sorted(fails_y)
cdf_snr = [1]
cdf_y = [ymin * 0.8]
y = ymin
count = 0
while y < ymax:
    if count == len(fails_y):
        y += 10
        cdf_y.append(ymax * 1.1)
        cdf_snr.append(cdf_snr[-1])
        break
    if y + 10 < sorted_fails_y[count]:
        y += 10
        cdf_y.append(y)
        cdf_snr.append(cdf_snr[-1])
    else:
        y = sorted_fails_y[count]
        cdf_y.append(y)
        cdf_snr.append((1 - ((count + 1) / len(data))))
        count += 1
cdf_snr = _np.array(cdf_snr)
cdf_y = _np.array(cdf_y)

axs['poop'].set_axis_off()

ax = axs['scatter']
ax.scatter(fails_x, fails_y, c='k', alpha=0.8, marker='x')
s = ax.scatter(xs, ys, c=cs, alpha=0.8, marker='.')
s.set_clim([cmin, cmax])
ax.set_xlabel('Median RMS OPD (nm)')
ax.set_ylabel('Median SNR')
ax.set_xlim([xmin * 0.8, xmax * 1.1])
ax.set_ylim([ymin * 0.8, ymax * 1.1])
ax.grid(which='both', alpha=0.3)

plt.colorbar(s, ax=axs['histy'], pad=0.2, label='Median RMS Residual (nm)')

ax = axs['histx']
ax.plot(cdf_x, cdf_opd)
ax.fill_between(cdf_x, cdf_opd, alpha=0.2)
# ax.hist(np.array(fails_x).get(), bins=40, color='r')
ax.tick_params(axis='x', labelbottom=False)
ax.set_ylabel('Cumulative\nSuccess Rate')
ax.set_xlim([xmin * 0.8, xmax * 1.1])
ax.set_ylim([0, 1.05])
ax.grid(which='both', alpha=0.3)

ax = axs['histy']
ax.plot(cdf_snr, _np.flip(cdf_y),)
ax.fill_betweenx(_np.flip(cdf_y), cdf_snr, alpha=0.2)
# ax.hist(np.array(fails_y).get(), bins=20, color='r', orientation='horizontal')
ax.tick_params(axis='y', labelleft=False)
ax.set_xticks([0, 0.5, 1])
ax.set_xlabel('Cumulative\nSuccess Rate')
ax.set_ylim([ymin * 0.8, ymax * 1.1])
ax.set_xlim([0, 1.05])
ax.grid(which='both', alpha=0.3)


fig.suptitle(f'RMag 15 Guide Stars\n{len(data):02.0f} Misalignment Cases; {len(cs) / len(data) * 100:02.0f}% Convergence Rate\n$\pm25\mu m$ Decenter X, Y; $\pm2.5$" Tilt X, Y')
# Out:
# Text(0.5, 0.98, 'RMag 15 Guide Stars\n100 Misalignment Cases; 27% Convergence Rate\n$\\pm25\\mu m$ Decenter X, Y; $\\pm2.5$" Tilt X, Y')
