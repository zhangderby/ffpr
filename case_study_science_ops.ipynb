# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import matplotlib.cm as color
better_magma = color.magma
better_magma.set_bad('black',1.)
import matplotlib.colors as c

from prysm import (
    mathops, 
    conf,
)
from prysm.mathops import (
    _np,
    np,
    fft,
    interpolate,
    ndimage,
)
from prysm.coordinates import (
    make_xy_grid, 
    cart_to_polar,
)
from prysm.propagation import Wavefront as WF
from prysm.propagation import (
    focus_fixed_sampling,
    focus_fixed_sampling_backprop
)                              
from prysm.thinlens import (
    defocus_to_image_displacement,
    image_displacement_to_defocus,
)
from prysm.geometry import (
    offset_circle,
    circle,
    spider,
    gaussian,
)
from prysm.polynomials import (
    lstsq,
    noll_to_nm,
    zernike_nm,
    zernike_nm_seq,
    hopkins,
    sum_of_2d_modes,
    sum_of_2d_modes_backprop
)
mathops.set_backend_to_cupy()
# conf.config.precision = 32

from astropy.io import (
    fits,
    ascii,
)

from skimage.measure import centroid

import copy

from algos import BING_BONG, FFPR2, PDPR, model, mean_squared_error, gain_invariant_error
import utils

from functools import partial

from lina.utils import TikhonovInverse

import config_um
import config_um_wcc
from Batoid4LOFT.LAZULI_STOP_mark11 import Lazuli_stop, readBulkMotion, readDeformation

from psd_utils import PSDUtils

from scipy.optimize import minimize

from scipy.interpolate import RegularGridInterpolator

from tqdm import tqdm

from psd_utils import PSDUtils

from model import telescope
# from algos import pdpr, OPD, ADPR
import utils

from functools import partial

from opt import F77LBFGSB, runN, RAdam
from IPython.display import clear_output

# logging stuff
import logging
psd_log = logging.getLogger('__psd_utils__')
psd_log.disabled = True

# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

import toml

# %%
# !nvidia-smi
# Out:
# Mon May 18 11:16:24 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 565.57.01              Driver Version: 565.57.01      CUDA Version: 12.7     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100 80GB PCIe          On  |   00000000:25:00.0 Off |                    0 |
# | N/A   31C    P0             65W /  300W |    5792MiB /  81920MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A    110575      C   ...onda3/envs/py310-stp-env/bin/python        872MiB |
# |    0   N/A  N/A   1182782      C   ...rojects/venv-scoob-poppy/bin/python       1620MiB |
# |    0   N/A  N/A   1403299      G   /usr/lib/xorg/Xorg                              4MiB |
# |    0   N/A  N/A   1511048      C   ...rojects/venv-scoob-poppy/bin/python       3266MiB |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ## SETUP MODEL

# %%
config = toml.load('/home/derbyk/src/ffpr/data/3m_off_axis_default.toml')
optic_opd_data = utils.load_pickle('/home/derbyk/src/ffpr/data/opd_maps.pkl')

sys = telescope(config=config, optic_opd_data=optic_opd_data)

dark = sys.get_dark(stacked_frames=1)
images = [im - dark for im in sys.snap(stacked_frames=1)]

for i, im in enumerate(images):
    print(f'Image {i + 1:02.0f} SNR = {im.max() / dark.std():.1f}')
# Out:
# Image 01 SNR = 614.1
# Image 02 SNR = 1024.7
# Image 03 SNR = 557.3
# Image 04 SNR = 1282.2
# Image 05 SNR = 747.9
# Image 06 SNR = 702.2
# Image 07 SNR = 1074.4

# %% [markdown]
# ## PLOT PSFS

# %%
pupil = sys.pupil
fields = [(sys.cfg['sources'][src]['position_x'], sys.cfg['sources'][src]['position_y']) for src in sys.cfg['sources']]

utils.plot_psfs_7(psfs=images, fields=fields)

# %% [markdown]
# ## PLOT WFES

# %%
opds_fields = copy.deepcopy(sys.opds_field)
opds_optics = copy.deepcopy(sys.opds_optics)
opds_truths = [opd_field + opd_optics for (opd_field, opd_optics) in zip(opds_fields, opds_optics)]

opds_fields_nominal = opds_fields

utils.plot_opds_7(opds=opds_fields, pupil=pupil, fields=fields)
utils.plot_opds_7(opds=opds_optics, pupil=pupil, fields=fields)
utils.plot_opds_7(opds=opds_truths, pupil=pupil, fields=fields)

# %% [markdown]
# ## SEMICIRCLE FOV
#
# Telescope designed with semicircle FOV in mind. Recreated here so that random source positions fall within this region. See "Large Etendue 3-Meter Unobscured Three Mirror Anastigmat Telescope for Astrophysics" by Kim et al. 2025 for more details.

# %%
fx = np.linspace(-16.2, 16.2, 325)
fy = np.linspace(-9.0, 4.8, 139)

Fx, Fy = np.meshgrid(fx, fy)

semicirc_fov = np.sqrt(Fx ** 2 + (Fy + 14.5) ** 2) <= 19.2
Fx_valid = Fx[semicirc_fov]
Fy_valid = Fy[semicirc_fov]

plt.imshow(semicirc_fov.get(), extent=[fx.min().get(), fx.max().get(), fy.min().get(), fy.max().get()])
plt.xlabel('arcmin')
plt.ylabel('arcmin')
plt.title('Telescope Semicircle FOV')
# Out:
# Text(0.5, 1.0, 'Telescope Semicircle FOV')

# %% [markdown]
# ## MONTE CARLO

# %%
misalignments = utils.load_pickle('/home/derbyk/src/ffpr/data/misalignments_cases_100_dec_20um_tilt_2as.pkl')

# %%
# SNR threshold
snr_thresh = 5

# number of sources
n_sources = 3

# system stuff
efl = sys.cfg['general']['f_eff']
pupil_dx = sys.cfg['optics']['m1']['diam'] / sys.cfg['general']['npix_pupil']
focal_dx = sys.cfg['detector']['dx_focal']

# set rng for repeatability on source positions
rng = np.random.default_rng(seed=73)

# stuff to save
data = {}

case = 1

for m in misalignments:

    print(f'CASE {case:03.0f} ----------------------------------')
    print()

    # get random source positions
    inds = rng.integers(low=0, high=Fx_valid.size, size=n_sources)
    new_positions = [(float(Fx_valid[i]), float(Fy_valid[i])) for i in inds]
    mags = [18 for _ in range(n_sources)]

    # send positions to model 
    sys.set_source_parameters(magnitudes=mags, positions=new_positions)

    # reset optics to nominal alignment
    sys.reset_optics()

    # get field dependent OPD at nominal alignment
    opds_fields_nominal = copy.deepcopy(sys.opds_field)

    # calculate RMS of diversity per field
    # diversity comes from field dependent OPD at nominal alignment
    rms_diversity_per_field = []
    for opd in opds_fields_nominal:
        opd -= np.mean(opd[pupil])
        rms_diversity_per_field.append(float(np.sqrt(np.mean(opd[pupil] ** 2))))

    # apply misalignment
    sys.move_optics(M1_motion=m['M1'], M2_motion=m['M4'], M3_motion=m['M4'], M4_motion=m['M4'])

    # get total OPDs per field
    opds_fields = copy.deepcopy(sys.opds_field)
    opds_optics = copy.deepcopy(sys.opds_optics)
    opds_truths = [opd_field + opd_optic for opd_field, opd_optic in zip(opds_fields, opds_optics)]

    # calculate RMS of ground truth OPDs per field
    rms_truth_per_field = []
    for opd in opds_truths:
        opd -= np.mean(opd[pupil])
        rms_truth_per_field.append(float(np.sqrt(np.mean(opd[pupil] ** 2))))

    # take images for FFPR
    dark = sys.get_dark(stacked_frames=1)
    images = [im - dark for im in sys.snap(stacked_frames=1)]

    # get image SNRs and filter
    noise_lvl = dark.std()
    masks = []
    snr_per_field = []
    for im in images:
        snr_per_field.append(float(im.max() / dark.std()))
        mask = im > noise_lvl * snr_thresh
        masks.append(mask)

    print(f'MEDIAN RMS OPD ACROSS FIELD = {np.median(np.array(rms_truth_per_field)):.2f} nm')
    print(f'MEDIAN IMAGE SNR ACROSS FIELD = {np.median(np.array(snr_per_field)):.1f}')
    print()

    # initialize FFPR
    opt = FFPR2(wvls=sys.wvls.tolist(), amp=sys.pupil, max_zernike=11, fields=new_positions, divs=opds_fields_nominal, efl=efl, 
                psfs=images, pupil_dx=pupil_dx, focal_dx=focal_dx, error=gain_invariant_error, masks=masks, jitter_kernel=sys.jitter_kernel)

    # BING BONG
    BING_BONG(opt=opt, modal_cleanup=True, zonal_cleanup=False,
              max_kicks=10, iter_per_bing_bong=10, iter_per_psf=10,
              max_ls=10, thresh_conv=1e-1, frac_conv=1e-2)

    # calculate estimate residuals
    opds_estimates = [pdpr.models[0].opd + pdpr.models[0].div for pdpr in opt.PDPR_list]
    opds_residuals = [estimate - truth for estimate, truth in zip(opds_estimates, opds_truths)]

    # get RMS of residual per field
    rms_residual_per_field = []
    for opd in opds_residuals:
        opd -= np.mean(opd[pupil])
        rms_residual_per_field.append(float(np.sqrt(np.mean(opd[pupil] ** 2))))

    print(f'MEDIAN RMS RESIDUAL ACROSS FIELD = {np.median(np.array(rms_residual_per_field)):.2f} nm')
    print()
    print()

    # save to data cube
    data.update({f'CASE{case:03.0f}' : {'RMS_TRUTH_PER_FIELD' : rms_truth_per_field,
                                        'RMS_RESIDUAL_PER_FIELD' : rms_residual_per_field,
                                        'RMS_DIVERSITY_PER_FIELD' : rms_diversity_per_field,
                                        'SNR_PER_FIELD' : snr_per_field,
                                        'FIELDS' : new_positions}})

    case += 1

utils.save_pickle('/home/derbyk/src/ffpr/sim_results/20260518_case_study_science_ops.pkl', data=data)
# Out:
# CASE 001 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 147.96 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 124.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.31e-02
# BONG 01 | f = 3.06e-02
# ---------------
# BING 02 | f = 3.06e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 30.13 nm
#
#
# CASE 002 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 163.39 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 150.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.06e-02
# BONG 01 | f = 3.45e-02
# ---------------
# BING 02 | f = 3.11e-02
# BONG 02 | f = 3.11e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.22 nm
#
#
# CASE 003 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 167.20 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 151.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.84e-02
# BONG 01 | f = 3.60e-02
# ---------------
# BING 02 | f = 3.60e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 32.58 nm
#
#
# CASE 004 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 59.51 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 430.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.22e-02
# BONG 01 | f = 1.22e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 25.64 nm
#
#
# CASE 005 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 117.96 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 190.1
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.11e-02
# BONG 01 | f = 2.05e-02
# ---------------
# BING 02 | f = 2.04e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 28.08 nm
#
#
# CASE 006 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 90.26 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 258.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.88e-02
# BONG 01 | f = 1.77e-02
# ---------------
# BING 02 | f = 1.77e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 26.87 nm
#
#
# CASE 007 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 75.99 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 294.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.07e-02
# BONG 01 | f = 3.07e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 26.40 nm
#
#
# CASE 008 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 157.42 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 185.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.13e-02
# BONG 01 | f = 3.11e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.69 nm
#
#
# CASE 009 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 143.04 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 139.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.82e-02
# BONG 01 | f = 3.17e-02
# ---------------
# BING 02 | f = 2.73e-02
# BONG 02 | f = 2.73e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 27.54 nm
#
#
# CASE 010 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 153.68 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 207.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.71e-02
# BONG 01 | f = 2.36e-02
# ---------------
# BING 02 | f = 2.36e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.51 nm
#
#
# CASE 011 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 124.10 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 184.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.06e-01
# BONG 01 | f = 5.15e-02
# ---------------
# BING 02 | f = 2.53e-02
# BONG 02 | f = 2.52e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 21.70 nm
#
#
# CASE 012 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 133.10 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 167.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.46e-02
# BONG 01 | f = 3.45e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 25.42 nm
#
#
# CASE 013 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 149.16 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 138.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.11e-02
# BONG 01 | f = 3.85e-02
# ---------------
# BING 02 | f = 3.34e-02
# BONG 02 | f = 3.31e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.49 nm
#
#
# CASE 014 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 78.17 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 336.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.14e-02
# BONG 01 | f = 1.11e-02
# ---------------
# BING 02 | f = 1.11e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.14 nm
#
#
# CASE 015 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 81.00 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 349.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 9.76e-03
# BONG 01 | f = 9.51e-03
# ---------------
# BING 02 | f = 9.00e-03
# BONG 02 | f = 9.00e-03
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.98 nm
#
#
# CASE 016 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 200.14 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 114.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.72e-02
# BONG 01 | f = 4.51e-02
# ---------------
# BING 02 | f = 4.51e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 34.82 nm
#
#
# CASE 017 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 97.76 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 301.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.19e-02
# BONG 01 | f = 1.19e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.24 nm
#
#
# CASE 018 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 167.72 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 188.1
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.71e-02
# BONG 01 | f = 3.71e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 39.62 nm
#
#
# CASE 019 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 222.92 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 133.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.83e-02
# BONG 01 | f = 3.79e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.37 nm
#
#
# CASE 020 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 117.56 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 185.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.78e-02
# BONG 01 | f = 2.72e-02
# ---------------
# BING 02 | f = 2.72e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 33.09 nm
#
#
# CASE 021 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 166.54 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 159.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.54e-02
# BONG 01 | f = 3.37e-02
# ---------------
# BING 02 | f = 3.37e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.56 nm
#
#
# CASE 022 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 187.73 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 88.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.15e-01
# BONG 01 | f = 7.41e-02
# ---------------
# BING 02 | f = 5.36e-02
# BONG 02 | f = 5.36e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 42.82 nm
#
#
# CASE 023 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 69.76 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 373.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.57e-02
# BONG 01 | f = 1.57e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 25.83 nm
#
#
# CASE 024 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 80.79 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 341.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.70e-02
# BONG 01 | f = 1.68e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.84 nm
#
#
# CASE 025 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 147.05 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 145.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.68e-02
# BONG 01 | f = 5.50e-02
# ---------------
# BING 02 | f = 5.49e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 38.25 nm
#
#
# CASE 026 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 77.18 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 298.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.16e-02
# BONG 01 | f = 3.16e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.38 nm
#
#
# CASE 027 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 166.69 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 166.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.37e-01
# BONG 01 | f = 2.18e-01
# ---------------
# BING 02 | f = 2.17e-01
# BONG 02 | f = 1.94e-01
# ---------------
# BING 03 | f = 1.94e-01
# BONG 03 | f = 1.94e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 2.29e-01
# BONG 04 | f = 2.04e-01
# ---------------
# BING 05 | f = 1.62e-01
# BONG 05 | f = 1.56e-01
# ---------------
# BING 06 | f = 1.56e-01
# BONG 06 | f = 1.56e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 2.23e-01
# BONG 07 | f = 2.02e-01
# ---------------
# BING 08 | f = 1.86e-01
# BONG 08 | f = 1.82e-01
# ---------------
# BING 09 | f = 1.79e-01
# BONG 09 | f = 1.74e-01
# ---------------
# BING 10 | f = 1.74e-01
# BONG 10 | f = 1.74e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 11 | f = 2.06e-01
# BONG 11 | f = 1.95e-01
# ---------------
# BING 12 | f = 1.91e-01
# BONG 12 | f = 1.89e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 2.22e-01
# BONG 13 | f = 2.03e-01
# ---------------
# BING 14 | f = 1.84e-01
# BONG 14 | f = 1.78e-01
# ---------------
# BING 15 | f = 1.75e-01
# BONG 15 | f = 1.73e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 2.46e-02
# BONG 16 | f = 2.41e-02
# ---------------
# BING 17 | f = 2.41e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 31.00 nm
#
#
# CASE 028 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 158.53 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 163.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.27e-02
# BONG 01 | f = 4.54e-02
# ---------------
# BING 02 | f = 3.43e-02
# BONG 02 | f = 3.43e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 30.88 nm
#
#
# CASE 029 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 89.95 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 257.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.45e-02
# BONG 01 | f = 2.42e-02
# ---------------
# BING 02 | f = 2.42e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 25.51 nm
#
#
# CASE 030 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 189.71 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 158.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.50e-02
# BONG 01 | f = 4.39e-02
# ---------------
# BING 02 | f = 3.95e-02
# BONG 02 | f = 3.95e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 27.49 nm
#
#
# CASE 031 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 67.06 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 350.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.17e-02
# BONG 01 | f = 2.10e-02
# ---------------
# BING 02 | f = 1.62e-02
# BONG 02 | f = 1.62e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 28.60 nm
#
#
# CASE 032 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 64.48 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 403.1
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.35e-02
# BONG 01 | f = 1.09e-02
# ---------------
# BING 02 | f = 1.04e-02
# BONG 02 | f = 1.04e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.71 nm
#
#
# CASE 033 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 83.12 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 281.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.59e-02
# BONG 01 | f = 2.41e-02
# ---------------
# BING 02 | f = 2.38e-02
# BONG 02 | f = 2.38e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 42.76 nm
#
#
# CASE 034 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 195.20 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 110.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.85e-01
# BONG 01 | f = 2.85e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 3.33e-01
# BONG 02 | f = 3.33e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 2.77e-01
# BONG 03 | f = 2.77e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 3.30e-01
# BONG 04 | f = 3.30e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 2.97e-01
# BONG 05 | f = 2.97e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 1.03e-01
# BONG 06 | f = 7.27e-02
# ---------------
# BING 07 | f = 4.74e-02
# BONG 07 | f = 4.40e-02
# ---------------
# BING 08 | f = 4.40e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 25.24 nm
#
#
# CASE 035 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 113.08 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 210.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.15e-02
# BONG 01 | f = 2.07e-02
# ---------------
# BING 02 | f = 1.82e-02
# BONG 02 | f = 1.82e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.94 nm
#
#
# CASE 036 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 102.37 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 254.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.67e-02
# BONG 01 | f = 1.67e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.91 nm
#
#
# CASE 037 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 199.20 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 157.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.45e-02
# BONG 01 | f = 3.33e-02
# ---------------
# BING 02 | f = 3.33e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 30.22 nm
#
#
# CASE 038 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 204.62 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 145.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 8.22e-02
# BONG 01 | f = 8.22e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 73.01 nm
#
#
# CASE 039 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 77.57 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 364.1
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.13e-02
# BONG 01 | f = 1.13e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.17 nm
#
#
# CASE 040 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 214.75 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 145.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.27e-02
# BONG 01 | f = 3.27e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.57 nm
#
#
# CASE 041 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 231.85 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 132.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 7.18e-02
# BONG 01 | f = 7.18e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 104.88 nm
#
#
# CASE 042 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 116.51 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 192.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.73e-02
# BONG 01 | f = 2.73e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 29.27 nm
#
#
# CASE 043 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 67.09 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 379.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.12e-02
# BONG 01 | f = 1.07e-02
# ---------------
# BING 02 | f = 1.07e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.62 nm
#
#
# CASE 044 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 84.73 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 296.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.78e-02
# BONG 01 | f = 1.76e-02
# ---------------
# BING 02 | f = 1.51e-02
# BONG 02 | f = 1.48e-02
# ---------------
# BING 03 | f = 1.48e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.93 nm
#
#
# CASE 045 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 104.97 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 277.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.48e-02
# BONG 01 | f = 1.41e-02
# ---------------
# BING 02 | f = 1.41e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.19 nm
#
#
# CASE 046 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 157.07 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 159.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.33e-02
# BONG 01 | f = 3.23e-02
# ---------------
# BING 02 | f = 3.23e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 26.33 nm
#
#
# CASE 047 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 149.71 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 160.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.53e-02
# BONG 01 | f = 3.53e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 26.63 nm
#
#
# CASE 048 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 134.19 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 225.1
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.98e-02
# BONG 01 | f = 1.95e-02
# ---------------
# BING 02 | f = 1.95e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.06 nm
#
#
# CASE 049 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 122.18 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 177.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.26e-02
# BONG 01 | f = 2.59e-02
# ---------------
# BING 02 | f = 2.11e-02
# BONG 02 | f = 2.11e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 26.00 nm
#
#
# CASE 050 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 118.06 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 151.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.21e-02
# BONG 01 | f = 4.21e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 32.35 nm
#
#
# CASE 051 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 102.84 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 227.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.10e-02
# BONG 01 | f = 2.04e-02
# ---------------
# BING 02 | f = 2.04e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 26.57 nm
#
#
# CASE 052 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 161.22 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 110.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.56e-02
# BONG 01 | f = 6.56e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 28.52 nm
#
#
# CASE 053 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 76.36 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 339.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.05e-02
# BONG 01 | f = 1.95e-02
# ---------------
# BING 02 | f = 1.56e-02
# BONG 02 | f = 1.55e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.03 nm
#
#
# CASE 054 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 78.04 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 326.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.43e-02
# BONG 01 | f = 1.37e-02
# ---------------
# BING 02 | f = 1.21e-02
# BONG 02 | f = 1.21e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.13 nm
#
#
# CASE 055 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 121.29 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 201.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.88e-02
# BONG 01 | f = 2.45e-02
# ---------------
# BING 02 | f = 2.07e-02
# BONG 02 | f = 2.00e-02
# ---------------
# BING 03 | f = 2.00e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 25.08 nm
#
#
# CASE 056 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 70.69 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 339.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.78e-02
# BONG 01 | f = 1.70e-02
# ---------------
# BING 02 | f = 1.70e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.55 nm
#
#
# CASE 057 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 165.38 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 180.1
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.58e-02
# BONG 01 | f = 3.29e-02
# ---------------
# BING 02 | f = 3.29e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 28.79 nm
#
#
# CASE 058 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 129.99 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 215.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.95e-02
# BONG 01 | f = 1.93e-02
# ---------------
# BING 02 | f = 1.93e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.06 nm
#
#
# CASE 059 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 170.89 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 166.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.09e-02
# BONG 01 | f = 3.84e-02
# ---------------
# BING 02 | f = 3.84e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 26.96 nm
#
#
# CASE 060 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 183.43 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 124.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.86e-02
# BONG 01 | f = 4.74e-02
# ---------------
# BING 02 | f = 4.68e-02
# BONG 02 | f = 4.64e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 27.03 nm
#
#
# CASE 061 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 180.78 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 183.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.54e-02
# BONG 01 | f = 2.48e-02
# ---------------
# BING 02 | f = 2.45e-02
# BONG 02 | f = 2.45e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 26.81 nm
#
#
# CASE 062 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 79.41 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 376.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.42e-02
# BONG 01 | f = 1.42e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.07 nm
#
#
# CASE 063 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 114.24 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 157.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.19e-02
# BONG 01 | f = 2.14e-02
# ---------------
# BING 02 | f = 2.14e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 26.26 nm
#
#
# CASE 064 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 143.90 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 170.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.90e-02
# BONG 01 | f = 3.85e-02
# ---------------
# BING 02 | f = 2.89e-02
# BONG 02 | f = 2.89e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.09 nm
#
#
# CASE 065 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 108.51 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 161.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.40e-01
# BONG 01 | f = 1.35e-01
# ---------------
# BING 02 | f = 1.29e-01
# BONG 02 | f = 1.28e-01
# ---------------
# BING 03 | f = 1.28e-01
# BONG 03 | f = 1.28e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 3.31e-01
# BONG 04 | f = 1.35e-01
# ---------------
# BING 05 | f = 1.27e-01
# BONG 05 | f = 1.24e-01
# ---------------
# BING 06 | f = 1.24e-01
# BONG 06 | f = 1.24e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 4.58e-02
# BONG 07 | f = 4.24e-02
# ---------------
# BING 08 | f = 3.42e-02
# BONG 08 | f = 3.42e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.45 nm
#
#
# CASE 066 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 117.90 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 225.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.35e-02
# BONG 01 | f = 2.34e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.42 nm
#
#
# CASE 067 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 90.45 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 306.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.11e-02
# BONG 01 | f = 1.11e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.67 nm
#
#
# CASE 068 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 89.41 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 286.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.81e-02
# BONG 01 | f = 1.51e-02
# ---------------
# BING 02 | f = 1.51e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.45 nm
#
#
# CASE 069 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 121.23 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 221.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.08e-02
# BONG 01 | f = 2.08e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 25.56 nm
#
#
# CASE 070 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 177.69 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 136.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.16e-02
# BONG 01 | f = 4.08e-02
# ---------------
# BING 02 | f = 4.08e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.61 nm
#
#
# CASE 071 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 186.66 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 117.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.27e-02
# BONG 01 | f = 5.98e-02
# ---------------
# BING 02 | f = 5.16e-02
# BONG 02 | f = 5.16e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.35 nm
#
#
# CASE 072 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 85.83 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 268.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.16e-02
# BONG 01 | f = 2.51e-02
# ---------------
# BING 02 | f = 2.02e-02
# BONG 02 | f = 1.97e-02
# ---------------
# BING 03 | f = 1.85e-02
# BONG 03 | f = 1.85e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 26.05 nm
#
#
# CASE 073 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 154.39 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 120.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.19e-02
# BONG 01 | f = 3.18e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.75 nm
#
#
# CASE 074 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 144.60 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 131.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.65e-02
# BONG 01 | f = 2.54e-02
# ---------------
# BING 02 | f = 2.51e-02
# BONG 02 | f = 2.51e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 30.87 nm
#
#
# CASE 075 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 86.11 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 254.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.67e-02
# BONG 01 | f = 1.65e-02
# ---------------
# BING 02 | f = 1.65e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 25.41 nm
#
#
# CASE 076 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 140.74 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 171.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.35e-02
# BONG 01 | f = 2.35e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.05 nm
#
#
# CASE 077 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 192.66 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 174.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.19e-02
# BONG 01 | f = 2.94e-02
# ---------------
# BING 02 | f = 2.94e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 28.43 nm
#
#
# CASE 078 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 109.02 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 272.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.25e-02
# BONG 01 | f = 1.22e-02
# ---------------
# BING 02 | f = 1.17e-02
# BONG 02 | f = 1.16e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.81 nm
#
#
# CASE 079 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 103.12 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 231.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.14e-02
# BONG 01 | f = 2.10e-02
# ---------------
# BING 02 | f = 2.10e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.53 nm
#
#
# CASE 080 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 134.66 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 172.1
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.33e-02
# BONG 01 | f = 2.29e-02
# ---------------
# BING 02 | f = 2.01e-02
# BONG 02 | f = 2.01e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.54 nm
#
#
# CASE 081 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 116.85 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 250.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.75e-02
# BONG 01 | f = 1.55e-02
# ---------------
# BING 02 | f = 1.55e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.18 nm
#
#
# CASE 082 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 71.35 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 368.4
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 9.45e-03
# BONG 01 | f = 9.45e-03
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.76 nm
#
#
# CASE 083 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 153.42 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 132.1
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.87e-02
# BONG 01 | f = 3.87e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 36.41 nm
#
#
# CASE 084 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 147.92 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 136.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.40e-02
# BONG 01 | f = 3.09e-02
# ---------------
# BING 02 | f = 2.98e-02
# BONG 02 | f = 2.98e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 29.16 nm
#
#
# CASE 085 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 158.58 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 116.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.83e-02
# BONG 01 | f = 3.81e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 29.26 nm
#
#
# CASE 086 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 147.01 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 207.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.42e-02
# BONG 01 | f = 2.29e-02
# ---------------
# BING 02 | f = 2.26e-02
# BONG 02 | f = 2.26e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 28.10 nm
#
#
# CASE 087 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 153.44 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 206.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.14e-02
# BONG 01 | f = 2.07e-02
# ---------------
# BING 02 | f = 2.07e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 27.21 nm
#
#
# CASE 088 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 66.78 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 405.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.13e-02
# BONG 01 | f = 1.13e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.15 nm
#
#
# CASE 089 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 128.44 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 158.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.21e-02
# BONG 01 | f = 3.68e-02
# ---------------
# BING 02 | f = 2.38e-02
# BONG 02 | f = 2.36e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 21.29 nm
#
#
# CASE 090 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 80.66 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 409.9
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.02e-02
# BONG 01 | f = 8.63e-03
# ---------------
# BING 02 | f = 8.63e-03
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 28.94 nm
#
#
# CASE 091 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 145.91 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 216.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.49e-02
# BONG 01 | f = 2.42e-02
# ---------------
# BING 02 | f = 2.42e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 28.10 nm
#
#
# CASE 092 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 206.58 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 141.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 8.19e-02
# BONG 01 | f = 7.18e-02
# ---------------
# BING 02 | f = 5.26e-02
# BONG 02 | f = 5.17e-02
# ---------------
# BING 03 | f = 5.17e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 55.08 nm
#
#
# CASE 093 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 132.48 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 236.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.20e-02
# BONG 01 | f = 2.14e-02
# ---------------
# BING 02 | f = 2.14e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.63 nm
#
#
# CASE 094 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 80.75 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 294.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.51e-02
# BONG 01 | f = 1.40e-02
# ---------------
# BING 02 | f = 1.40e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 25.25 nm
#
#
# CASE 095 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 127.14 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 218.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.82e-02
# BONG 01 | f = 1.81e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 25.28 nm
#
#
# CASE 096 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 167.68 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 156.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.01e-02
# BONG 01 | f = 4.97e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 27.19 nm
#
#
# CASE 097 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 70.49 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 388.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 9.52e-03
# BONG 01 | f = 9.35e-03
# ---------------
# BING 02 | f = 9.35e-03
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.37 nm
#
#
# CASE 098 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 110.23 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 200.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.41e-02
# BONG 01 | f = 3.41e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.92 nm
#
#
# CASE 099 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 58.41 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 401.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.08e-02
# BONG 01 | f = 1.89e-02
# ---------------
# BING 02 | f = 1.89e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 30.31 nm
#
#
# CASE 100 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 147.12 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 190.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.51e-02
# BONG 01 | f = 2.51e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 27.20 nm
#
#
# Saved data to:  /home/derbyk/src/ffpr/sim_results/20260518_case_study_science_ops.pkl

# %% [markdown]
# ## VISUALIZE

# %%
data = utils.load_pickle('/home/derbyk/src/ffpr/sim_results/20260518_case_study_science_ops.pkl')

median_rms_truth = np.zeros(len(data))
median_rms_residual = np.zeros(len(data))
max_rms_residual = np.zeros(len(data))
min_rms_residual = np.zeros(len(data))
std_rms_residual = np.zeros(len(data))
weighted_sum_diversity = np.zeros(len(data))

for i, case in enumerate(data):
    median_rms_truth[i] = np.median(np.array(data[case]['RMS_TRUTH_PER_FIELD']))
    median_rms_residual[i] = np.median(np.array(data[case]['RMS_RESIDUAL_PER_FIELD']))
    max_rms_residual[i] = np.max(np.array(data[case]['RMS_RESIDUAL_PER_FIELD']))
    min_rms_residual[i] = np.min(np.array(data[case]['RMS_RESIDUAL_PER_FIELD']))
    std_rms_residual[i] = np.std(np.array(data[case]['RMS_RESIDUAL_PER_FIELD']))
    median_snr = np.median(np.array(data[case]['SNR_PER_FIELD']))
    wsum = 0
    for snr, div in zip(data[case]['SNR_PER_FIELD'], data[case]['RMS_DIVERSITY_PER_FIELD']):
        wsum += snr / median_snr * div
    weighted_sum_diversity[i] = wsum

fig, axs = plt.subplot_mosaic([['histx', 'poop'],
                               ['scatter', 'histy']],
                               figsize=(8, 6), 
                               height_ratios=[1, 3],
                               width_ratios=[3, 1],
                               layout='tight',
                               dpi=150)

count = 0
fails_x = []
fails_y = []
xs = []
ys = []
cs = []

for x, y, c in zip(median_rms_truth, weighted_sum_diversity, median_rms_residual):
    if c < 62.5:
        xs.append(float(x))
        ys.append(float(y))
        cs.append(float(c))
    else:
        fails_x.append(float(x))
        fails_y.append(float(y))

xs = _np.array(xs)
ys = _np.array(ys)
cs = _np.array(cs)
fails_x = _np.array(fails_x)
fails_y = _np.array(fails_y)

xmin = _np.array([xs.min(), fails_x.min()]).min() * 0.9
xmax = _np.array([xs.max(), fails_x.max()]).max() * 1.02

ymin = _np.array([ys.min(), fails_y.min()]).min() * 0.9
ymax = _np.array([ys.max(), fails_y.max()]).max() * 1.05

cmin = 20
cmax = 62.5

sorted_fails_x = sorted(fails_x)
cdf_opd = [0]
cdf_x = [xmin ]
x = xmin
count = 0
while x < xmax:
    if count == len(fails_x):
        x += 10
        break
    if x + 10 < sorted_fails_x[count]:
        x += 10
        cdf_x.append(x)
        cdf_opd.append(cdf_opd[-1])
    else:
        x = sorted_fails_x[count]
        cdf_x.append(x)
        cdf_opd.append((((count + 1) / 100)))
        count += 1
cdf_x.append(xmax )
cdf_opd.append(cdf_opd[-1])
cdf_opd = _np.array(cdf_opd)
cdf_x = _np.array(cdf_x)

sorted_fails_y = _np.flip(sorted(fails_y))
cdf_snr = [0]
cdf_y = [ymax ]
y = ymax
count = 0
while y > ymin:
    if count == len(fails_y):
        y -= 10
        break
    if y - 10 > sorted_fails_y[count]:
        y -= 10
        cdf_y.append(y)
        cdf_snr.append(cdf_snr[-1])
    else:
        y = sorted_fails_y[count]
        cdf_y.append(y)
        cdf_snr.append((((count + 1) / 100)))
        count += 1
cdf_y.append(ymin )
cdf_snr.append(cdf_snr[-1])
cdf_snr = _np.array(cdf_snr)
cdf_y = _np.array(cdf_y)

axs['poop'].set_axis_off()

ax = axs['scatter']
ax.scatter(fails_x, fails_y, c='r', alpha=0.7, marker='x')
s = ax.scatter(xs, ys, c=cs, alpha=0.7, marker='.')
s.set_clim([cmin, cmax])
ax.set_xlabel('Median RMS OPD (nm)')
ax.set_ylabel('SNR Weighted Sum of Diversity (nm)')
ax.set_xlim([xmin , xmax ])
ax.set_ylim([ymin , ymax ])
ax.grid(which='both', alpha=0.3)

plt.colorbar(s, ax=axs['histy'], pad=0.2, label='Median RMS Residual (nm)')

ax = axs['histx']
ax.plot(cdf_x, cdf_opd, color='r')
ax.fill_between(cdf_x, cdf_opd, alpha=0.2, color='r')
# ax.hist(np.array(fails_x).get(), bins=40, color='r')
ax.tick_params(axis='x', labelbottom=False)
ax.set_ylabel('Cumulative\nFailure Rate')
ax.set_xlim([xmin , xmax ])
ax.set_ylim([0, 1.05])
ax.grid(which='both', alpha=0.3)

ax = axs['histy']
ax.plot(cdf_snr, cdf_y, color='r')
ax.fill_betweenx(cdf_y, cdf_snr, alpha=0.2, color='r')
# ax.hist(np.array(fails_y).get(), bins=20, color='r', orientation='horizontal')
ax.tick_params(axis='y', labelleft=False)
ax.set_xticks([0, 0.5, 1])
ax.set_xlabel('Cumulative\nFailure Rate')
ax.set_ylim([ymin , ymax ])
ax.set_xlim([0, 1.05])
ax.grid(which='both', alpha=0.3)


fig.suptitle(f'RMag 17 Guide Stars\n{len(data):02.0f} Misalignment Cases; {len(cs) / len(data) * 100:02.0f}% Convergence Rate\n$\pm25\mu m$ Decenter X, Y; $\pm2.5$" Tilt X, Y')
# Out:
# Text(0.5, 0.98, 'RMag 17 Guide Stars\n100 Misalignment Cases; 98% Convergence Rate\n$\\pm25\\mu m$ Decenter X, Y; $\\pm2.5$" Tilt X, Y')

# %%
count = 0
fails_x = []
fails_y = []
xs = []
ys = []
tops = []
bots = []

for x, y, top, bot in zip(median_rms_truth, median_rms_residual, max_rms_residual, min_rms_residual):
    if y < 62.5:
        xs.append(float(x))
        ys.append(float(y))
        tops.append(float(top - y))
        bots.append(float(y - bot))
    else:
        fails_x.append(float(x))
        fails_y.append(float(y))

xs = _np.array(xs)
ys = _np.array(ys)
tops = _np.array(tops)
bots = _np.array(bots)
fails_x = _np.array(fails_x)
fails_y = _np.array(fails_y)

xmin = 55
xmax = 235

sorted_fails_x = sorted(fails_x)
cdf_opd = [0]
cdf_x = [xmin ]
x = xmin
count = 0
while x < xmax:
    if count == len(fails_x):
        x += 10
        break
    if x + 10 < sorted_fails_x[count]:
        x += 10
        cdf_x.append(x)
        cdf_opd.append(cdf_opd[-1])
    else:
        x = sorted_fails_x[count]
        cdf_x.append(x)
        cdf_opd.append((((count + 1) / 100)))
        count += 1
cdf_x.append(xmax )
cdf_opd.append(cdf_opd[-1])
cdf_opd = _np.array(cdf_opd)
cdf_x = _np.array(cdf_x)

fig, axs = plt.subplot_mosaic([['histx',],
                               ['scatter',]],
                               figsize=(8, 5), 
                               height_ratios=[1, 3],
                               layout='tight',
                               dpi=150)

ax = axs['histx']
ax.plot(cdf_x, cdf_opd, color='r')
ax.fill_between(cdf_x, cdf_opd, alpha=0.2, color='r')
# ax.hist(np.array(fails_x).get(), bins=40, color='r')
ax.tick_params(axis='x', labelbottom=False)
ax.set_ylabel('Cumulative\nFailure Rate')
ax.set_xlim([xmin , xmax ])
ax.set_ylim([0, 1.05])
ax.grid(which='both', alpha=0.3)

ax = axs['scatter']
ax.errorbar(x=xs, y=ys, yerr=[bots.tolist(), tops.tolist()], marker='.', ls='none', alpha=0.8, capsize=2, elinewidth=1)
ax.scatter(fails_x, _np.ones(len(fails_x)) * 61.3, c='r', alpha=0.7, marker='x', label='Failed Case')
ax.set_xlim([xmin, xmax])
ax.set_ylim([0, 62.5])
ax.grid(which='both', alpha=0.3)
ax.set_xlabel('Median RMS OPD (nm)')
ax.set_ylabel('RMS Residual (nm)')
ax.legend(loc='lower right')

fig.suptitle(f'3 Randomly Distributed Rmag 18 Guide Stars\n{len(data):02.0f} Misalignment Cases; {len(cs) / 100 * 100:02.0f}% Convergence Rate\n$\pm10\mu m$ Decenter X, Y; $\pm1$" Tilt X, Y')
# Out:
# Text(0.5, 0.98, '3 Randomly Distributed Rmag 18 Guide Stars\n100 Misalignment Cases; 98% Convergence Rate\n$\\pm10\\mu m$ Decenter X, Y; $\\pm1$" Tilt X, Y')
