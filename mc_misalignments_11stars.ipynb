# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import matplotlib.cm as color
better_magma = color.magma
better_magma.set_bad('black',1.)
import matplotlib.colors as c

from prysm import (
    mathops, 
    conf,
)
from prysm.mathops import (
    _np,
    np,
    fft,
    interpolate,
    ndimage,
)
from prysm.coordinates import (
    make_xy_grid, 
    cart_to_polar,
)
from prysm.propagation import Wavefront as WF
from prysm.propagation import (
    focus_fixed_sampling,
    focus_fixed_sampling_backprop
)                              
from prysm.thinlens import (
    defocus_to_image_displacement,
    image_displacement_to_defocus,
)
from prysm.geometry import (
    offset_circle,
    circle,
    spider,
    gaussian,
)
from prysm.polynomials import (
    lstsq,
    noll_to_nm,
    zernike_nm,
    zernike_nm_seq,
    hopkins,
    sum_of_2d_modes,
    sum_of_2d_modes_backprop
)
mathops.set_backend_to_cupy()
# conf.config.precision = 32

from astropy.io import (
    fits,
    ascii,
)

from skimage.measure import centroid

import copy

from algos import BING_BONG, FFPR2, PDPR, model, mean_squared_error, gain_invariant_error
import utils

from functools import partial

from lina.utils import TikhonovInverse

import config_um
import config_um_wcc
from Batoid4LOFT.LAZULI_STOP_mark11 import Lazuli_stop, readBulkMotion, readDeformation

from psd_utils import PSDUtils

from scipy.optimize import minimize

from scipy.interpolate import RegularGridInterpolator

from tqdm import tqdm

from psd_utils import PSDUtils

from model import telescope
# from algos import pdpr, OPD, ADPR
import utils

from functools import partial

from opt import F77LBFGSB, runN, RAdam
from IPython.display import clear_output

# logging stuff
import logging
psd_log = logging.getLogger('__psd_utils__')
psd_log.disabled = True

# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

import toml

# %%
# !nvidia-smi
# Out:
# Wed May  6 00:20:47 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 565.57.01              Driver Version: 565.57.01      CUDA Version: 12.7     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100 80GB PCIe          On  |   00000000:25:00.0 Off |                    0 |
# | N/A   30C    P0             63W /  300W |    1643MiB /  81920MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A   1182782      C   ...rojects/venv-scoob-poppy/bin/python       1620MiB |
# |    0   N/A  N/A   1403299      G   /usr/lib/xorg/Xorg                              4MiB |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ## SETUP MODEL

# %%
config = toml.load('/home/derbyk/src/ffpr/data/3m_off_axis_default.toml')
optic_opd_data = utils.load_pickle('/home/derbyk/src/ffpr/data/opd_maps.pkl')

sys = telescope(config=config, optic_opd_data=optic_opd_data)

dark = sys.get_dark(stacked_frames=1)
images = [im - dark for im in sys.snap(stacked_frames=1)]

for i, im in enumerate(images):
    print(f'Image {i + 1:02.0f} SNR = {im.max() / dark.std():.1f}')
# Out:
# Image 01 SNR = 610.2
# Image 02 SNR = 985.5
# Image 03 SNR = 534.6
# Image 04 SNR = 1232.5
# Image 05 SNR = 707.7
# Image 06 SNR = 688.0
# Image 07 SNR = 1144.1

# %% [markdown]
# ## PLOT PSFS

# %%
pupil = sys.pupil
fields = [(sys.cfg['sources'][src]['position_x'], sys.cfg['sources'][src]['position_y']) for src in sys.cfg['sources']]

utils.plot_psfs_7(psfs=images, fields=fields)

# %% [markdown]
# ## PLOT WFES

# %%
opds_fields = copy.deepcopy(sys.opds_field)
opds_optics = copy.deepcopy(sys.opds_optics)
opds_truths = [opd_field + opd_optics for (opd_field, opd_optics) in zip(opds_fields, opds_optics)]

opds_fields_nominal = opds_fields

utils.plot_opds_7(opds=opds_fields, pupil=pupil, fields=fields)
utils.plot_opds_7(opds=opds_optics, pupil=pupil, fields=fields)
utils.plot_opds_7(opds=opds_truths, pupil=pupil, fields=fields)

# %% [markdown]
# ## SEMICIRCLE FOV
#
# Telescope designed with semicircle FOV in mind. Recreated here so that random source positions fall within this region. See "Large Etendue 3-Meter Unobscured Three Mirror Anastigmat Telescope for Astrophysics" by Kim et al. 2025 for more details.

# %%
fx = np.linspace(-16.2, 16.2, 325)
fy = np.linspace(-9.0, 4.8, 139)

Fx, Fy = np.meshgrid(fx, fy)

semicirc_fov = np.sqrt(Fx ** 2 + (Fy + 14.5) ** 2) <= 19.2
Fx_valid = Fx[semicirc_fov]
Fy_valid = Fy[semicirc_fov]

plt.imshow(semicirc_fov.get(), extent=[fx.min().get(), fx.max().get(), fy.min().get(), fy.max().get()])
plt.xlabel('arcmin')
plt.ylabel('arcmin')
plt.title('Telescope Semicircle FOV')
# Out:
# Text(0.5, 1.0, 'Telescope Semicircle FOV')

# %% [markdown]
# ## MONTE CARLO

# %%
misalignments = utils.load_pickle('/home/derbyk/src/ffpr/data/misalignments_cases_100_dec_50um_tilt_5as.pkl')

# %%
# SNR threshold
snr_thresh = 5

# number of sources
n_sources = 11

# system stuff
efl = sys.cfg['general']['f_eff']
pupil_dx = sys.cfg['optics']['m1']['diam'] / sys.cfg['general']['npix_pupil']
focal_dx = sys.cfg['detector']['dx_focal']

# set rng for repeatability on source positions
rng = np.random.default_rng(seed=73)

# stuff to save
data = {}

case = 1

for m in misalignments:

    print(f'CASE {case:03.0f} ----------------------------------')
    print()

    # get random source positions
    inds = rng.integers(low=0, high=Fx_valid.size, size=n_sources)
    new_positions = [(float(Fx_valid[i]), float(Fy_valid[i])) for i in inds]
    mags = [17 for _ in range(n_sources)]

    # send positions to model 
    sys.set_source_parameters(magnitudes=mags, positions=new_positions)

    # reset optics to nominal alignment
    sys.reset_optics()

    # get field dependent OPD at nominal alignment
    opds_fields_nominal = copy.deepcopy(sys.opds_field)

    # calculate RMS of diversity per field
    # diversity comes from field dependent OPD at nominal alignment
    rms_diversity_per_field = []
    for opd in opds_fields_nominal:
        opd -= np.mean(opd[pupil])
        rms_diversity_per_field.append(float(np.sqrt(np.mean(opd[pupil] ** 2))))

    # apply misalignment
    sys.move_optics(M1_motion=m['M1'], M2_motion=m['M4'], M3_motion=m['M4'], M4_motion=m['M4'])

    # get total OPDs per field
    opds_fields = copy.deepcopy(sys.opds_field)
    opds_optics = copy.deepcopy(sys.opds_optics)
    opds_truths = [opd_field + opd_optic for opd_field, opd_optic in zip(opds_fields, opds_optics)]

    # calculate RMS of ground truth OPDs per field
    rms_truth_per_field = []
    for opd in opds_truths:
        opd -= np.mean(opd[pupil])
        rms_truth_per_field.append(float(np.sqrt(np.mean(opd[pupil] ** 2))))

    # take images for FFPR
    dark = sys.get_dark(stacked_frames=1)
    images = [im - dark for im in sys.snap(stacked_frames=1)]

    # get image SNRs and filter
    noise_lvl = dark.std()
    masks = []
    snr_per_field = []
    for im in images:
        snr_per_field.append(float(im.max() / dark.std()))
        mask = im > noise_lvl * snr_thresh
        masks.append(mask)

    print(f'MEDIAN RMS OPD ACROSS FIELD = {np.median(np.array(rms_truth_per_field)):.2f} nm')
    print(f'MEDIAN IMAGE SNR ACROSS FIELD = {np.median(np.array(snr_per_field)):.1f}')
    print()

    # initialize FFPR
    opt = FFPR2(wvls=sys.wvls.tolist(), amp=sys.pupil, max_zernike=11, fields=new_positions, divs=opds_fields_nominal, efl=efl, 
                psfs=images, pupil_dx=pupil_dx, focal_dx=focal_dx, error=gain_invariant_error, masks=masks, jitter_kernel=sys.jitter_kernel)

    # BING BONG
    BING_BONG(opt=opt, modal_cleanup=True, zonal_cleanup=False,
              max_kicks=10, iter_per_bing_bong=10, iter_per_psf=10,
              max_ls=10, thresh_conv=1e-1, frac_conv=1e-2)

    # calculate estimate residuals
    opds_estimates = [pdpr.models[0].opd + pdpr.models[0].div for pdpr in opt.PDPR_list]
    opds_residuals = [estimate - truth for estimate, truth in zip(opds_estimates, opds_truths)]

    # get RMS of residual per field
    rms_residual_per_field = []
    for opd in opds_residuals:
        opd -= np.mean(opd[pupil])
        rms_residual_per_field.append(float(np.sqrt(np.mean(opd[pupil] ** 2))))

    print(f'MEDIAN RMS RESIDUAL ACROSS FIELD = {np.median(np.array(rms_residual_per_field)):.2f} nm')
    print()
    print()

    # save to data cube
    data.update({f'CASE{case:03.0f}' : {'RMS_TRUTH_PER_FIELD' : rms_truth_per_field,
                                        'RMS_RESIDUAL_PER_FIELD' : rms_residual_per_field,
                                        'RMS_DIVERSITY_PER_FIELD' : rms_diversity_per_field,
                                        'SNR_PER_FIELD' : snr_per_field,
                                        'FIELDS' : new_positions}})

    case += 1

utils.save_pickle('/home/derbyk/src/ffpr/sim_results/20260505_mc_misalignments_11stars_dec_50um_tilt_5as.pkl', data=data)
# Out:
# CASE 001 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 213.51 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 151.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.48e-01
# BONG 01 | f = 4.40e-01
# ---------------
# BING 02 | f = 3.91e-01
# BONG 02 | f = 3.91e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 1.34e-01
# BONG 03 | f = 1.23e-01
# ---------------
# BING 04 | f = 4.09e-02
# BONG 04 | f = 4.09e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 24.72 nm
#
#
# CASE 002 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 361.01 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 122.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.36e-01
# BONG 01 | f = 3.35e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 1.42e-01
# BONG 02 | f = 9.99e-02
# ---------------
# BING 03 | f = 4.64e-02
# BONG 03 | f = 4.50e-02
# ---------------
# BING 04 | f = 4.50e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.80 nm
#
#
# CASE 003 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 309.05 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 186.1
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.24e-01
# BONG 01 | f = 2.18e-01
# ---------------
# BING 02 | f = 1.71e-01
# BONG 02 | f = 1.51e-01
# ---------------
# BING 03 | f = 5.33e-02
# BONG 03 | f = 4.13e-02
# ---------------
# BING 04 | f = 4.13e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 34.01 nm
#
#
# CASE 004 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 156.23 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 362.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.09e-02
# BONG 01 | f = 3.05e-02
# ---------------
# BING 02 | f = 1.37e-02
# BONG 02 | f = 1.37e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.71 nm
#
#
# CASE 005 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 207.11 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 199.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.03e-01
# BONG 01 | f = 3.73e-01
# ---------------
# BING 02 | f = 3.73e-01
# BONG 02 | f = 3.73e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 3.18e-01
# BONG 03 | f = 3.18e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 2.89e-01
# BONG 04 | f = 2.69e-01
# ---------------
# BING 05 | f = 6.18e-02
# BONG 05 | f = 5.52e-02
# ---------------
# BING 06 | f = 3.33e-02
# BONG 06 | f = 3.24e-02
# ---------------
# BING 07 | f = 3.24e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 26.84 nm
#
#
# CASE 006 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 255.64 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 216.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 9.28e-02
# BONG 01 | f = 7.61e-02
# ---------------
# BING 02 | f = 7.61e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 103.21 nm
#
#
# CASE 007 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 259.06 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 100.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.63e-01
# BONG 01 | f = 6.45e-01
# ---------------
# BING 02 | f = 6.45e-01
# BONG 02 | f = 6.45e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 7.63e-01
# BONG 03 | f = 7.31e-01
# ---------------
# BING 04 | f = 7.31e-01
# BONG 04 | f = 7.31e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 5.39e-01
# BONG 05 | f = 5.29e-01
# ---------------
# BING 06 | f = 1.15e-01
# BONG 06 | f = 1.12e-01
# ---------------
# BING 07 | f = 8.96e-02
# BONG 07 | f = 8.96e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 27.90 nm
#
#
# CASE 008 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 235.57 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 225.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.11e-02
# BONG 01 | f = 4.11e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 29.14 nm
#
#
# CASE 009 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 325.80 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 143.2
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.74e-01
# BONG 01 | f = 3.48e-01
# ---------------
# BING 02 | f = 2.78e-01
# BONG 02 | f = 2.78e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 3.38e-01
# BONG 03 | f = 3.22e-01
# ---------------
# BING 04 | f = 2.80e-01
# BONG 04 | f = 2.67e-01
# ---------------
# BING 05 | f = 2.65e-01
# BONG 05 | f = 2.65e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 8.20e-02
# BONG 06 | f = 8.20e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 51.13 nm
#
#
# CASE 010 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 295.82 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 147.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.29e-01
# BONG 01 | f = 2.31e-01
# ---------------
# BING 02 | f = 2.31e-01
# BONG 02 | f = 2.31e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 4.15e-01
# BONG 03 | f = 4.09e-01
# ---------------
# BING 04 | f = 4.09e-01
# BONG 04 | f = 4.09e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 5.24e-01
# BONG 05 | f = 4.98e-01
# ---------------
# BING 06 | f = 4.77e-01
# BONG 06 | f = 4.60e-01
# ---------------
# BING 07 | f = 4.59e-01
# BONG 07 | f = 4.57e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 4.47e-01
# BONG 08 | f = 4.41e-01
# ---------------
# BING 09 | f = 4.41e-01
# BONG 09 | f = 4.41e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 1.67e-01
# BONG 10 | f = 1.64e-01
# ---------------
# BING 11 | f = 1.64e-01
# BONG 11 | f = 1.64e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 3.92e-01
# BONG 12 | f = 3.58e-01
# ---------------
# BING 13 | f = 3.57e-01
# BONG 13 | f = 3.57e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 3.45e-01
# BONG 14 | f = 3.32e-01
# ---------------
# BING 15 | f = 2.80e-01
# BONG 15 | f = 2.80e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 16 | f = 3.35e-01
# BONG 16 | f = 3.20e-01
# ---------------
# BING 17 | f = 2.62e-01
# BONG 17 | f = 2.62e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 18 | f = 2.08e-01
# BONG 18 | f = 1.80e-01
# ---------------
# BING 19 | f = 5.52e-02
# BONG 19 | f = 5.09e-02
# ---------------
# BING 20 | f = 5.06e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 26.39 nm
#
#
# CASE 011 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 384.30 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 93.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 5.65e-01
# BONG 01 | f = 5.20e-01
# ---------------
# BING 02 | f = 1.32e-01
# BONG 02 | f = 9.70e-02
# ---------------
# BING 03 | f = 9.70e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 45.14 nm
#
#
# CASE 012 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 353.32 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 119.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.62e-01
# BONG 01 | f = 3.35e-01
# ---------------
# BING 02 | f = 2.01e-01
# BONG 02 | f = 1.89e-01
# ---------------
# BING 03 | f = 8.15e-02
# BONG 03 | f = 6.24e-02
# ---------------
# BING 04 | f = 6.24e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 53.20 nm
#
#
# CASE 013 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 332.07 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 138.1
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.09e-01
# BONG 01 | f = 4.88e-01
# ---------------
# BING 02 | f = 2.59e-01
# BONG 02 | f = 2.13e-01
# ---------------
# BING 03 | f = 1.61e-01
# BONG 03 | f = 1.57e-01
# ---------------
# BING 04 | f = 1.57e-01
# BONG 04 | f = 1.57e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 3.60e-01
# BONG 05 | f = 2.05e-01
# ---------------
# BING 06 | f = 1.60e-01
# BONG 06 | f = 1.58e-01
# ---------------
# BING 07 | f = 1.55e-01
# BONG 07 | f = 1.55e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 1.06e-01
# BONG 08 | f = 9.46e-02
# ---------------
# BING 09 | f = 4.96e-02
# BONG 09 | f = 4.65e-02
# ---------------
# BING 10 | f = 3.90e-02
# BONG 10 | f = 3.72e-02
# ---------------
# BING 11 | f = 3.35e-02
# BONG 11 | f = 3.28e-02
# ---------------
# BING 12 | f = 3.24e-02
# BONG 12 | f = 3.22e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 27.59 nm
#
#
# CASE 014 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 106.54 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 671.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.11e-02
# BONG 01 | f = 1.02e-02
# ---------------
# BING 02 | f = 8.70e-03
# BONG 02 | f = 8.70e-03
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.11 nm
#
#
# CASE 015 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 70.11 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 895.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 7.38e-03
# BONG 01 | f = 7.34e-03
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.36 nm
#
#
# CASE 016 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 434.60 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 127.7
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.42e-01
# BONG 01 | f = 4.28e-01
# ---------------
# BING 02 | f = 4.28e-01
# BONG 02 | f = 4.28e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 2.97e-01
# BONG 03 | f = 2.96e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 4.49e-01
# BONG 04 | f = 4.33e-01
# ---------------
# BING 05 | f = 4.33e-01
# BONG 05 | f = 4.19e-01
# ---------------
# BING 06 | f = 4.11e-01
# BONG 06 | f = 4.07e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 5.38e-01
# BONG 07 | f = 5.33e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 6.42e-01
# BONG 08 | f = 6.38e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 3.44e-01
# BONG 09 | f = 3.15e-01
# ---------------
# BING 10 | f = 1.57e-01
# BONG 10 | f = 1.23e-01
# ---------------
# BING 11 | f = 7.39e-02
# BONG 11 | f = 7.32e-02
# ---------------
# BING 12 | f = 7.32e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 137.19 nm
#
#
# CASE 017 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 114.67 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 712.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.46e-03
# BONG 01 | f = 6.21e-03
# ---------------
# BING 02 | f = 6.21e-03
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 21.87 nm
#
#
# CASE 018 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 283.87 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 177.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 9.15e-02
# BONG 01 | f = 9.00e-02
# ---------------
# BING 02 | f = 3.89e-02
# BONG 02 | f = 3.89e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.90 nm
#
#
# CASE 019 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 393.78 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 149.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.84e-01
# BONG 01 | f = 3.30e-01
# ---------------
# BING 02 | f = 1.87e-01
# BONG 02 | f = 1.73e-01
# ---------------
# BING 03 | f = 1.05e-01
# BONG 03 | f = 7.00e-02
# ---------------
# BING 04 | f = 4.35e-02
# BONG 04 | f = 4.28e-02
# ---------------
# BING 05 | f = 4.28e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 48.25 nm
#
#
# CASE 020 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 285.46 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 139.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.13e-01
# BONG 01 | f = 4.11e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 2.29e-01
# BONG 02 | f = 2.29e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 4.33e-01
# BONG 03 | f = 4.29e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 04 | f = 5.56e-01
# BONG 04 | f = 5.47e-01
# ---------------
# BING 05 | f = 5.47e-01
# BONG 05 | f = 5.47e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 6.66e-01
# BONG 06 | f = 6.56e-01
# ---------------
# BING 07 | f = 6.56e-01
# BONG 07 | f = 6.56e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 2.34e-01
# BONG 08 | f = 2.34e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 1.27e-01
# BONG 09 | f = 1.24e-01
# ---------------
# BING 10 | f = 5.06e-02
# BONG 10 | f = 4.92e-02
# ---------------
# BING 11 | f = 4.92e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 41.48 nm
#
#
# CASE 021 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 286.52 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 176.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.33e-01
# BONG 01 | f = 1.87e-01
# ---------------
# BING 02 | f = 5.24e-02
# BONG 02 | f = 4.05e-02
# ---------------
# BING 03 | f = 3.13e-02
# BONG 03 | f = 3.13e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.15 nm
#
#
# CASE 022 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 359.81 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 117.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.55e-01
# BONG 01 | f = 4.06e-01
# ---------------
# BING 02 | f = 4.06e-01
# BONG 02 | f = 4.06e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 3.86e-01
# BONG 03 | f = 3.64e-01
# ---------------
# BING 04 | f = 3.40e-01
# BONG 04 | f = 3.30e-01
# ---------------
# BING 05 | f = 3.18e-01
# BONG 05 | f = 3.18e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 06 | f = 2.00e-01
# BONG 06 | f = 1.94e-01
# ---------------
# BING 07 | f = 8.72e-02
# BONG 07 | f = 7.70e-02
# ---------------
# BING 08 | f = 7.70e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 136.21 nm
#
#
# CASE 023 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 270.24 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 124.6
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 6.90e-01
# BONG 01 | f = 6.75e-01
# ---------------
# BING 02 | f = 6.75e-01
# BONG 02 | f = 6.75e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 6.85e-01
# BONG 03 | f = 5.31e-01
# ---------------
# BING 04 | f = 5.31e-01
# BONG 04 | f = 5.31e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 5.14e-01
# BONG 05 | f = 4.16e-01
# ---------------
# BING 06 | f = 4.09e-01
# BONG 06 | f = 4.09e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 5.30e-01
# BONG 07 | f = 4.83e-01
# ---------------
# BING 08 | f = 2.86e-01
# BONG 08 | f = 2.86e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 5.15e-01
# BONG 09 | f = 5.15e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 3.09e-01
# BONG 10 | f = 2.54e-01
# ---------------
# BING 11 | f = 1.90e-01
# BONG 11 | f = 1.89e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 12 | f = 2.88e-01
# BONG 12 | f = 2.67e-01
# ---------------
# BING 13 | f = 1.79e-01
# BONG 13 | f = 1.79e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 14 | f = 4.69e-01
# BONG 14 | f = 4.69e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 2.82e-01
# BONG 15 | f = 2.75e-01
# ---------------
# BING 16 | f = 2.75e-01
# BONG 16 | f = 2.75e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 17 | f = 4.33e-01
# BONG 17 | f = 3.02e-01
# ---------------
# BING 18 | f = 3.02e-01
# BONG 18 | f = 3.02e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 19 | f = 5.06e-01
# BONG 19 | f = 5.03e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 486.51 nm
#
#
# CASE 024 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 243.65 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 155.5
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 3.59e-01
# BONG 01 | f = 2.99e-01
# ---------------
# BING 02 | f = 2.93e-01
# BONG 02 | f = 2.93e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 2.79e-01
# BONG 03 | f = 2.44e-01
# ---------------
# BING 04 | f = 2.44e-01
# BONG 04 | f = 2.44e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 05 | f = 3.39e-01
# BONG 05 | f = 3.32e-01
# ---------------
# BING 06 | f = 3.32e-01
# BONG 06 | f = 3.32e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 3.34e-01
# BONG 07 | f = 3.33e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 08 | f = 3.17e-01
# BONG 08 | f = 3.12e-01
# ---------------
# BING 09 | f = 3.12e-01
# BONG 09 | f = 3.12e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 1.49e-01
# BONG 10 | f = 8.66e-02
# ---------------
# BING 11 | f = 3.95e-02
# BONG 11 | f = 3.41e-02
# ---------------
# BING 12 | f = 3.41e-02
# CONVERGED: BING WITHIN  1% OF BONG, f BELOW 1.00e-01
# TERMINATING BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 23.60 nm
#
#
# CASE 025 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 374.92 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 116.8
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 4.55e-01
# BONG 01 | f = 4.15e-01
# ---------------
# BING 02 | f = 4.15e-01
# BONG 02 | f = 4.15e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 03 | f = 3.01e-01
# BONG 03 | f = 2.86e-01
# ---------------
# BING 04 | f = 1.83e-01
# BONG 04 | f = 1.67e-01
# ---------------
# BING 05 | f = 1.15e-01
# BONG 05 | f = 1.09e-01
# ---------------
# BING 06 | f = 1.09e-01
# BONG 06 | f = 1.09e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 07 | f = 4.68e-01
# BONG 07 | f = 4.39e-01
# ---------------
# BING 08 | f = 4.39e-01
# BONG 08 | f = 4.39e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 09 | f = 3.28e-01
# BONG 09 | f = 3.28e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 10 | f = 4.80e-01
# BONG 10 | f = 4.33e-01
# ---------------
# BING 11 | f = 4.25e-01
# BONG 11 | f = 3.93e-01
# ---------------
# BING 12 | f = 3.62e-01
# BONG 12 | f = 3.62e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 13 | f = 2.64e-01
# BONG 13 | f = 2.54e-01
# ---------------
# BING 14 | f = 2.42e-01
# BONG 14 | f = 2.42e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 15 | f = 1.93e-01
# BONG 15 | f = 1.80e-01
# ---------------
# BING 16 | f = 1.80e-01
# BONG 16 | f = 1.80e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 17 | f = 4.34e-01
# BONG 17 | f = 4.05e-01
# ---------------
# BING 18 | f = 3.54e-01
# BONG 18 | f = 3.28e-01
# ---------------
# BING 19 | f = 2.91e-01
# BONG 19 | f = 2.89e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 20 | f = 2.80e-01
# BONG 20 | f = 2.69e-01
# ---------------
# BING 21 | f = 1.96e-01
# BONG 21 | f = 1.89e-01
# ---------------
# BING 22 | f = 1.89e-01
# BONG 22 | f = 1.89e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 23 | f = 7.93e-01
# BONG 23 | f = 7.24e-01
# ---------------
# BING 24 | f = 7.24e-01
# BONG 24 | f = 7.24e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 25 | f = 4.82e-01
# BONG 25 | f = 4.18e-01
# ---------------
# BING 26 | f = 3.77e-01
# BONG 26 | f = 3.77e-01
# NO MORE KICKING, WE MIGHT BE COOKED CHAT
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 751.07 nm
#
#
# CASE 026 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 218.11 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 220.3
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.94e-01
# BONG 01 | f = 2.94e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 2.56e-01
# BONG 02 | f = 2.10e-01
# ---------------
# BING 03 | f = 7.36e-02
# BONG 03 | f = 3.54e-02
# ---------------
# BING 04 | f = 2.84e-02
# BONG 04 | f = 2.82e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 22.40 nm
#
#
# CASE 027 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 399.45 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 137.0
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 2.04e-01
# BONG 01 | f = 2.04e-01
# STUCK ABOVE CONVERGENCE THRESHOLD, KICKING
# ---------------
# BING 02 | f = 3.04e-01
# BONG 02 | f = 2.50e-01
# ---------------
# BING 03 | f = 5.80e-02
# BONG 03 | f = 4.43e-02
# ---------------
# BING 04 | f = 4.38e-02
# BONG 04 | f = 4.38e-02
# CONVERGED: BONG WITHIN  1% OF BING, f BELOW 1.00e-01
# TERMINATE BING BONG
# ---------------
# INDIVIDUAL PSF OPTIMIZATION: MODAL
# ---------------
# DONE
#
# MEDIAN RMS RESIDUAL ACROSS FIELD = 34.30 nm
#
#
# CASE 028 ----------------------------------
#
# MEDIAN RMS OPD ACROSS FIELD = 326.72 nm
# MEDIAN IMAGE SNR ACROSS FIELD = 180.1
#
# INITIALIZE BING BONG
# ---------------
# BING 01 | f = 1.06e-01

# %% [markdown]
# ## VISUALIZE

# %%
data = utils.load_pickle('/home/derbyk/src/ffpr/sim_results/20260505_mc_misalignments_11stars_dec_50um_tilt_5as.pkl')

median_rms_truth = np.zeros(len(data))
median_rms_residual = np.zeros(len(data))
max_rms_residual = np.zeros(len(data))
min_rms_residual = np.zeros(len(data))
std_rms_residual = np.zeros(len(data))
weighted_sum_diversity = np.zeros(len(data))

for i, case in enumerate(data):
    median_rms_truth[i] = np.median(np.array(data[case]['RMS_TRUTH_PER_FIELD']))
    median_rms_residual[i] = np.median(np.array(data[case]['RMS_RESIDUAL_PER_FIELD']))
    max_rms_residual[i] = np.max(np.array(data[case]['RMS_RESIDUAL_PER_FIELD']))
    min_rms_residual[i] = np.min(np.array(data[case]['RMS_RESIDUAL_PER_FIELD']))
    std_rms_residual[i] = np.std(np.array(data[case]['RMS_RESIDUAL_PER_FIELD']))
    median_snr = np.median(np.array(data[case]['SNR_PER_FIELD']))
    wsum = 0
    for snr, div in zip(data[case]['SNR_PER_FIELD'], data[case]['RMS_DIVERSITY_PER_FIELD']):
        wsum += snr / median_snr * div
    weighted_sum_diversity[i] = wsum

fig, axs = plt.subplot_mosaic([['histx', 'poop'],
                               ['scatter', 'histy']],
                               figsize=(8, 6), 
                               height_ratios=[1, 3],
                               width_ratios=[3, 1],
                               layout='tight',
                               dpi=150)

count = 0
fails_x = []
fails_y = []
xs = []
ys = []
cs = []

for x, y, c in zip(median_rms_truth, weighted_sum_diversity, median_rms_residual):
    if c < 62.5:
        xs.append(float(x))
        ys.append(float(y))
        cs.append(float(c))
    else:
        fails_x.append(float(x))
        fails_y.append(float(y))

xs = _np.array(xs)
ys = _np.array(ys)
cs = _np.array(cs)
fails_x = _np.array(fails_x)
fails_y = _np.array(fails_y)

xmin = _np.array([xs.min(), fails_x.min()]).min() * 0.9
xmax = _np.array([xs.max(), fails_x.max()]).max() * 1.02

ymin = _np.array([ys.min(), fails_y.min()]).min() * 0.9
ymax = _np.array([ys.max(), fails_y.max()]).max() * 1.05

cmin = 20
cmax = 62.5

sorted_fails_x = sorted(fails_x)
cdf_opd = [0]
cdf_x = [xmin ]
x = xmin
count = 0
while x < xmax:
    if count == len(fails_x):
        x += 10
        break
    if x + 10 < sorted_fails_x[count]:
        x += 10
        cdf_x.append(x)
        cdf_opd.append(cdf_opd[-1])
    else:
        x = sorted_fails_x[count]
        cdf_x.append(x)
        cdf_opd.append((((count + 1) / 100)))
        count += 1
cdf_x.append(xmax )
cdf_opd.append(cdf_opd[-1])
cdf_opd = _np.array(cdf_opd)
cdf_x = _np.array(cdf_x)

sorted_fails_y = _np.flip(sorted(fails_y))
cdf_snr = [0]
cdf_y = [ymax ]
y = ymax
count = 0
while y > ymin:
    if count == len(fails_y):
        y -= 10
        break
    if y - 10 > sorted_fails_y[count]:
        y -= 10
        cdf_y.append(y)
        cdf_snr.append(cdf_snr[-1])
    else:
        y = sorted_fails_y[count]
        cdf_y.append(y)
        cdf_snr.append((((count + 1) / 100)))
        count += 1
cdf_y.append(ymin )
cdf_snr.append(cdf_snr[-1])
cdf_snr = _np.array(cdf_snr)
cdf_y = _np.array(cdf_y)

axs['poop'].set_axis_off()

ax = axs['scatter']
ax.scatter(fails_x, fails_y, c='r', alpha=0.7, marker='x')
s = ax.scatter(xs, ys, c=cs, alpha=0.7, marker='.')
s.set_clim([cmin, cmax])
ax.set_xlabel('Median RMS OPD (nm)')
ax.set_ylabel('SNR Weighted Sum of Diversity (nm)')
ax.set_xlim([xmin , xmax ])
ax.set_ylim([ymin , ymax ])
ax.grid(which='both', alpha=0.3)

plt.colorbar(s, ax=axs['histy'], pad=0.2, label='Median RMS Residual (nm)')

ax = axs['histx']
ax.plot(cdf_x, cdf_opd, color='r')
ax.fill_between(cdf_x, cdf_opd, alpha=0.2, color='r')
# ax.hist(np.array(fails_x).get(), bins=40, color='r')
ax.tick_params(axis='x', labelbottom=False)
ax.set_ylabel('Cumulative\nFailure Rate')
ax.set_xlim([xmin , xmax ])
ax.set_ylim([0, 1.05])
ax.grid(which='both', alpha=0.3)

ax = axs['histy']
ax.plot(cdf_snr, cdf_y, color='r')
ax.fill_betweenx(cdf_y, cdf_snr, alpha=0.2, color='r')
# ax.hist(np.array(fails_y).get(), bins=20, color='r', orientation='horizontal')
ax.tick_params(axis='y', labelleft=False)
ax.set_xticks([0, 0.5, 1])
ax.set_xlabel('Cumulative\nFailure Rate')
ax.set_ylim([ymin , ymax ])
ax.set_xlim([0, 1.05])
ax.grid(which='both', alpha=0.3)


fig.suptitle(f'RMag 17 Guide Stars\n{len(data):02.0f} Misalignment Cases; {len(cs) / len(data) * 100:02.0f}% Convergence Rate\n$\pm25\mu m$ Decenter X, Y; $\pm2.5$" Tilt X, Y')
# Out:
# Text(0.5, 0.98, 'RMag 17 Guide Stars\n100 Misalignment Cases; 82% Convergence Rate\n$\\pm25\\mu m$ Decenter X, Y; $\\pm2.5$" Tilt X, Y')
